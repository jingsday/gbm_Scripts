# %%
import os
import pandas as pd
import numpy as np

import pylab as plt
import statistics
import scipy.stats

# %%
data_year = "2020"
cell_name = "HUVEC"
task = "Martin_1"

data_dir = os.path.join("00_outputs_" + data_year + "_" + cell_name)

out_dir = "00_plots_" + data_year + "_" + cell_name + "_" + task
os.makedirs(out_dir, exist_ok = True)

# %% [markdown]
# ## Data_norm

# %%
data_file = os.path.join(data_dir, "Data_norm_" + data_year + "_" + cell_name+ ".xlsx")
Data_norm = pd.read_excel(data_file, index_col = 0)
display(Data_norm)

genes_list = Data_norm.columns.to_list()
print("Landmark genes in LINCS data:", len(genes_list), genes_list)

exp_id_list = Data_norm.index.to_list()
print("Experiments in LINCS data for " + cell_name + " cells:", len(exp_id_list), exp_id_list)
# Out:
#                               AARS     ABCB6     ABCC5     ABCF1     ABCF3  \
# LJP007_HUVEC_24H:A05     -0.118534 -0.106533 -0.552448 -0.136094 -0.013804
# LJP007_HUVEC_24H:A06      0.058216  0.151700 -0.571765 -0.150978 -0.063320
# LJP007_HUVEC_24H:B05     -0.136634 -0.264667  0.548352  0.070223 -0.056904
# LJP007_HUVEC_24H:B06     -0.210517 -0.313434 -0.727799 -0.149377 -0.421704
# LJP007_HUVEC_24H:F07      0.075182  0.023066 -0.586449 -0.100211  0.075096
# ...                            ...       ...       ...       ...       ...
# REP.B024_HUVEC.A_24H:P20 -1.905539 -0.007300 -0.731396  0.430556 -0.123994
# REP.B024_HUVEC.A_24H:P21 -0.899890 -1.306725 -0.443996  0.422006 -0.196544
# REP.B024_HUVEC.A_24H:P22 -0.610090 -1.250375 -0.759471 -1.218294 -0.385945
# REP.B024_HUVEC.A_24H:P23 -0.493390 -0.273625 -0.501471  0.178356 -0.416220
# REP.B024_HUVEC.A_24H:P24 -1.129740 -0.957475  3.233678 -1.136093  0.335155
#
#                              ABHD4     ABHD6      ABL1     ACAA1     ACAT2  \
# LJP007_HUVEC_24H:A05     -0.072984  0.909445  0.065044 -0.020653 -0.661483
# LJP007_HUVEC_24H:A06     -0.239401 -0.104672  0.051012  0.038314  0.186550
# LJP007_HUVEC_24H:B05      1.450533 -0.035372  0.021478 -0.248052 -0.851566
# LJP007_HUVEC_24H:B06     -0.485584 -0.247222 -0.006922 -0.131553  0.201866
# LJP007_HUVEC_24H:F07     -0.294834  1.041045  0.119778 -0.076086 -1.342532
# ...                            ...       ...       ...       ...       ...
# REP.B024_HUVEC.A_24H:P20 -0.124384 -2.507582  0.673428 -0.800314  1.072226
# REP.B024_HUVEC.A_24H:P21  1.689516  1.616344  0.300803  1.115086  1.310501
# REP.B024_HUVEC.A_24H:P22 -0.283684 -1.916481  0.326352  0.106261  1.672676
# REP.B024_HUVEC.A_24H:P23 -0.474659 -2.683532  0.249828 -0.068814  1.412802
# REP.B024_HUVEC.A_24H:P24  0.074517 -2.139706  0.323878  0.399536 -1.143549
#
#                           ...     ZMIZ1     ZMYM2    ZNF131    ZNF274  \
# LJP007_HUVEC_24H:A05      ... -0.164372  0.146537  0.036117  0.115300
# LJP007_HUVEC_24H:A06      ... -0.271071 -0.144547 -0.084201  0.244817
# LJP007_HUVEC_24H:B05      ... -0.345803  0.420653  0.212466  0.330435
# LJP007_HUVEC_24H:B06      ...  0.408163  0.158620  0.307850 -0.403699
# LJP007_HUVEC_24H:F07      ...  0.191746  0.154321  0.009766  0.058135
# ...                       ...       ...       ...       ...       ...
# REP.B024_HUVEC.A_24H:P20  ...  0.379562 -0.212133  0.529867 -0.525423
# REP.B024_HUVEC.A_24H:P21  ... -0.362287 -0.747232 -0.086258 -0.460922
# REP.B024_HUVEC.A_24H:P22  ... -0.877188 -1.068082  0.050643 -0.186422
# REP.B024_HUVEC.A_24H:P23  ... -0.672188 -0.282732  0.166068 -0.499798
# REP.B024_HUVEC.A_24H:P24  ...  0.408962 -0.103582 -0.037232 -0.525172
#
#                             ZNF318    ZNF395    ZNF451    ZNF586    ZNF589  \
# LJP007_HUVEC_24H:A05     -0.143709 -0.317039  0.106789  1.323801 -0.082965
# LJP007_HUVEC_24H:A06      0.230891 -0.301105 -0.148794  1.395884 -0.190699
# LJP007_HUVEC_24H:B05      0.351074  0.340061  0.095622 -0.623049  0.092885
# LJP007_HUVEC_24H:B06      0.094174  0.008345  0.040805 -0.465449 -0.309849
# LJP007_HUVEC_24H:F07      0.019191 -0.593889  0.193672 -0.728383 -0.001732
# ...                            ...       ...       ...       ...       ...
# REP.B024_HUVEC.A_24H:P20 -0.088439  0.871560 -0.600894 -3.597260 -1.679630
# REP.B024_HUVEC.A_24H:P21 -0.229714  0.809110 -0.215394  2.225764 -1.067355
# REP.B024_HUVEC.A_24H:P22 -0.074739  1.141760 -0.771319 -3.588660 -1.175005
# REP.B024_HUVEC.A_24H:P23  0.659486  0.910010 -0.145194 -3.728935 -1.278155
# REP.B024_HUVEC.A_24H:P24 -0.185089 -1.040640 -0.104244  2.381265 -0.423705
#
#                               ZW10
# LJP007_HUVEC_24H:A05     -0.391660
# LJP007_HUVEC_24H:A06      0.509806
# LJP007_HUVEC_24H:B05     -0.511843
# LJP007_HUVEC_24H:B06     -0.187745
# LJP007_HUVEC_24H:F07      0.953056
# ...                            ...
# REP.B024_HUVEC.A_24H:P20 -0.288190
# REP.B024_HUVEC.A_24H:P21 -0.608665
# REP.B024_HUVEC.A_24H:P22 -0.057915
# REP.B024_HUVEC.A_24H:P23 -0.641515
# REP.B024_HUVEC.A_24H:P24 -0.353015
#
# [8154 rows x 978 columns]
# Landmark genes in LINCS data: 978 ['AARS', 'ABCB6', 'ABCC5', 'ABCF1', 'ABCF3', 'ABHD4', 'ABHD6', 'ABL1', 'ACAA1', 'ACAT2', 'ACBD3', 'ACD', 'ACLY', 'ACOT9', 'ADAM10', 'ADAT1', 'ADGRE5', 'ADGRG1', 'ADH5', 'ADI1', 'ADO', 'ADRB2', 'AGL', 'AKAP8', 'AKAP8L', 'AKR7A2', 'AKT1', 'ALAS1', 'ALDH7A1', 'ALDOA', 'ALDOC', 'AMDHD2', 'ANKRD10', 'ANO10', 'ANXA7', 'APBB2', 'APOE', 'APP', 'APPBP2', 'ARFIP2', 'ARHGAP1', 'ARHGEF12', 
# %% [markdown]
# ## Sig_info

# %%
data_file = os.path.join(data_dir, "sig_info_" + data_year + "_" + cell_name+ ".xlsx")
sig_info_cell_df = pd.read_excel(data_file, index_col = 0).fillna("")
display(sig_info_cell_df)
# Out:
#                            cell     plate  time  \
# level_5_sig_id
# LJP007_HUVEC_24H:A05      HUVEC    LJP007  24 h
# LJP007_HUVEC_24H:A06      HUVEC    LJP007  24 h
# LJP007_HUVEC_24H:B05      HUVEC    LJP007  24 h
# LJP007_HUVEC_24H:B06      HUVEC    LJP007  24 h
# LJP007_HUVEC_24H:F07      HUVEC    LJP007  24 h
# ...                         ...       ...   ...
# REP.B024_HUVEC.A_24H:P20  HUVEC  REP.B024  24 h
# REP.B024_HUVEC.A_24H:P21  HUVEC  REP.B024  24 h
# REP.B024_HUVEC.A_24H:P22  HUVEC  REP.B024  24 h
# REP.B024_HUVEC.A_24H:P23  HUVEC  REP.B024  24 h
# REP.B024_HUVEC.A_24H:P24  HUVEC  REP.B024  24 h
#
#                                                             level_3_samples  \
# level_5_sig_id
# LJP007_HUVEC_24H:A05      LJP007_HUVEC_24H_X1_B21:A05|LJP007_HUVEC_24H_X...
# LJP007_HUVEC_24H:A06      LJP007_HUVEC_24H_X1_B21:A06|LJP007_HUVEC_24H_X...
# LJP007_HUVEC_24H:B05      LJP007_HUVEC_24H_X1_B21:B05|LJP007_HUVEC_24H_X...
# LJP007_HUVEC_24H:B06      LJP007_HUVEC_24H_X1_B21:B06|LJP007_HUVEC_24H_X...
# LJP007_HUVEC_24H:F07      LJP007_HUVEC_24H_X1_B21:F07|LJP007_HUVEC_24H_X...
# ...                                                                     ...
# REP.B024_HUVEC.A_24H:P20                    REP.B024_HUVEC.A_24H_X2_B25:P20
# REP.B024_HUVEC.A_24H:P21                    REP.B024_HUVEC.A_24H_X2_B25:P21
# REP.B024_HUVEC.A_24H:P22                    REP.B024_HUVEC.A_24H_X2_B25:P22
# REP.B024_HUVEC.A_24H:P23                    REP.B024_HUVEC.A_24H_X2_B25:P23
# REP.B024_HUVEC.A_24H:P24                    REP.B024_HUVEC.A_24H_X2_B25:P24
#
#                           samples_number    pert_type  pert_drug  \
# level_5_sig_id
# LJP007_HUVEC_24H:A05                   3  ctl_vehicle       DMSO
# LJP007_HUVEC_24H:A06                   3  ctl_vehicle       DMSO
# LJP007_HUVEC_24H:B05                   3  ctl_vehicle       DMSO
# LJP007_HUVEC_24H:B06                   3  ctl_vehicle       DMSO
# LJP007_HUVEC_24H:F07                   3  ctl_vehicle       DMSO
# ...                                  ...          ...        ...
# REP.B024_HUVEC.A_24H:P20               1       trt_cp  sirolimus
# REP.B024_HUVEC.A_24H:P21               1       trt_cp  sirolimus
# REP.B024_HUVEC.A_24H:P22               1       trt_cp  sirolimus
# REP.B024_HUVEC.A_24H:P23               1       trt_cp  sirolimus
# REP.B024_HUVEC.A_24H:P24               1       trt_cp  sirolimus
#
#                                  targets  targets_number     dose  dose_float
# level_5_sig_id
# LJP007_HUVEC_24H:A05      DMSO_No_target               0     0 uM        0.00
# LJP007_HUVEC_24H:A06      DMSO_No_target               0     0 uM        0.00
# LJP007_HUVEC_24H:B05      DMSO_No_target               0     0 uM        0.00
# LJP007_HUVEC_24H:B06      DMSO_No_target               0     0 uM        0.00
# LJP007_HUVEC_24H:F07      DMSO_No_target               0     0 uM        0.00
# ...                                  ...             ...      ...         ...
# REP.B024_HUVEC.A_24H:P20    FKBP1A, MTOR               2  0.74 uM        0.74
# REP.B024_HUVEC.A_24H:P21    FKBP1A, MTOR               2  0.25 uM        0.25
# REP.B024_HUVEC.A_24H:P22    FKBP1A, MTOR               2  0.08 uM        0.08
# REP.B024_HUVEC.A_24H:P23    FKBP1A, MTOR               2  0.03 uM        0.03
# REP.B024_HUVEC.A_24H:P24    FKBP1A, MTOR               2  0.01 uM        0.01
#
# [8154 rows x 11 columns]

# %% [markdown]
# ## Input_info - ALL_DATA (modules, STV)

# %%
data_file = "ALL_DATA_" + data_year + "_" + task + ".xlsx"
modules = pd.read_excel(data_file, sheet_name = "modules", index_col = 0)
display(modules)
# Out:
# Empty DataFrame
# Columns: []
# Index: [CDK1/2, PAK, PI3K, ERK, BET, Aurora, TGFbR, VEGFR, PKC]

# %% [markdown]
# ## STV (State Transition Vectors)

# %%
data_file = "ALL_DATA_" + data_year + "_" + task + ".xlsx" 
STVs = pd.read_excel(data_file, sheet_name = "STVs", index_col = 0)
display(STVs)

states = STVs.columns.to_list()
print("States:", states)
# Out:
#               FSS     remod       OSS
# Gene
# KIT      0.159163 -0.085553  0.287581
# E2F2     0.080218  0.057462  0.146547
# TGFBR2  -0.021403 -0.032023  0.093434
# ETV1    -0.034161 -0.012043  0.088598
# KIF20A   0.039590  0.034655  0.083541
# ...           ...       ...       ...
# TSC22D3  0.172875 -0.107161 -0.136908
# CD58     0.014362 -0.034994 -0.152116
# SFN      0.228158 -0.061094 -0.168513
# RAP1GAP  0.215836 -0.022847 -0.187600
# HSPA1A   0.164477  0.084636 -0.247558
#
# [946 rows x 3 columns]
# States: ['FSS', 'remod', 'OSS']

# %%
STV_df = pd.DataFrame(
    np.zeros((len(genes_list), len(states))), 
    index = genes_list, 
    columns = states)

STV_df.loc[STVs.index] = STVs

display(STV_df)
# Out:
#              FSS     remod       OSS
# AARS    0.000000  0.000000  0.000000
# ABCB6  -0.003990 -0.072129 -0.007938
# ABCC5  -0.011552 -0.023766 -0.010069
# ABCF1  -0.020014 -0.021833  0.029174
# ABCF3   0.007379  0.016256  0.008109
# ...          ...       ...       ...
# ZNF395 -0.081815  0.001035  0.051654
# ZNF451  0.000206 -0.016318 -0.020391
# ZNF586 -0.009845 -0.021145 -0.012347
# ZNF589  0.007465 -0.000317 -0.020764
# ZW10    0.018353  0.017701 -0.003142
#
# [978 rows x 3 columns]

# %% [markdown]
# ## DPD calculating

# %%
DPD_df = pd.DataFrame(
    np.zeros((len(exp_id_list), len(states))),
    index = exp_id_list,
    columns = states,
)

for exp_id in DPD_df.index:
    for state in states:
        DPD_df.loc[exp_id, state] = np.dot(Data_norm.loc[exp_id], STV_df.loc[:, state])

display(DPD_df)
# Out:
#                                FSS     remod       OSS
# LJP007_HUVEC_24H:A05     -0.236129  0.222209 -0.104822
# LJP007_HUVEC_24H:A06     -0.216964 -0.184451 -0.025299
# LJP007_HUVEC_24H:B05      0.607028  0.606231  0.744496
# LJP007_HUVEC_24H:B06      0.344296  0.944157  0.000616
# LJP007_HUVEC_24H:F07     -0.181821  0.002615  0.425782
# ...                            ...       ...       ...
# REP.B024_HUVEC.A_24H:P20 -1.132676  0.780040  0.109360
# REP.B024_HUVEC.A_24H:P21 -2.067265 -0.972851 -0.950441
# REP.B024_HUVEC.A_24H:P22 -0.749697 -0.157520 -2.961404
# REP.B024_HUVEC.A_24H:P23  1.477423  0.568278  0.033538
# REP.B024_HUVEC.A_24H:P24 -1.603275  1.519843  0.349649
#
# [8154 rows x 3 columns]

# %%
DPD_inf_df = pd.concat([
                            DPD_df,
                            sig_info_cell_df.loc[DPD_df.index, ["pert_drug", "targets", "dose"]]
                            ], axis = 1)

display(DPD_inf_df)
# Out:
#                                FSS     remod       OSS  pert_drug  \
# LJP007_HUVEC_24H:A05     -0.236129  0.222209 -0.104822       DMSO
# LJP007_HUVEC_24H:A06     -0.216964 -0.184451 -0.025299       DMSO
# LJP007_HUVEC_24H:B05      0.607028  0.606231  0.744496       DMSO
# LJP007_HUVEC_24H:B06      0.344296  0.944157  0.000616       DMSO
# LJP007_HUVEC_24H:F07     -0.181821  0.002615  0.425782       DMSO
# ...                            ...       ...       ...        ...
# REP.B024_HUVEC.A_24H:P20 -1.132676  0.780040  0.109360  sirolimus
# REP.B024_HUVEC.A_24H:P21 -2.067265 -0.972851 -0.950441  sirolimus
# REP.B024_HUVEC.A_24H:P22 -0.749697 -0.157520 -2.961404  sirolimus
# REP.B024_HUVEC.A_24H:P23  1.477423  0.568278  0.033538  sirolimus
# REP.B024_HUVEC.A_24H:P24 -1.603275  1.519843  0.349649  sirolimus
#
#                                  targets     dose
# LJP007_HUVEC_24H:A05      DMSO_No_target     0 uM
# LJP007_HUVEC_24H:A06      DMSO_No_target     0 uM
# LJP007_HUVEC_24H:B05      DMSO_No_target     0 uM
# LJP007_HUVEC_24H:B06      DMSO_No_target     0 uM
# LJP007_HUVEC_24H:F07      DMSO_No_target     0 uM
# ...                                  ...      ...
# REP.B024_HUVEC.A_24H:P20    FKBP1A, MTOR  0.74 uM
# REP.B024_HUVEC.A_24H:P21    FKBP1A, MTOR  0.25 uM
# REP.B024_HUVEC.A_24H:P22    FKBP1A, MTOR  0.08 uM
# REP.B024_HUVEC.A_24H:P23    FKBP1A, MTOR  0.03 uM
# REP.B024_HUVEC.A_24H:P24    FKBP1A, MTOR  0.01 uM
#
# [8154 rows x 6 columns]

# %%
DPD_inf_df.to_excel(os.path.join(out_dir, "DPD_" + data_year + "_" + cell_name + "_" + task + ".xlsx"))
DPD_inf_df.to_csv(os.path.join(out_dir, "DPD_" + data_year + "_" + cell_name + "_" + task + ".csv"))

# %% [markdown]
# ## Analisys of DPD values to find targets

# %%
i = 0
top = 10

DPD_analysis = pd.concat([
                            DPD_inf_df.sort_values(by = states[i])[:top],
                            DPD_inf_df.sort_values(by = states[i])[len(DPD_df.index) - top:]
                            ], axis = 0)

display(DPD_analysis)

print("Targets:", len(set(DPD_analysis.targets)), sorted(set(DPD_analysis.targets)))
# Out:
#                                FSS     remod        OSS  \
# REP.A013_HUVEC.A_24H:L17 -5.369048  1.799238   0.417512
# REP.A011_HUVEC.A_24H:F08 -4.895315 -1.330542   0.955564
# REP.A028_HUVEC.A_24H:B05 -4.632813 -1.201542  -2.235100
# REP.A013_HUVEC.A_24H:J08 -4.523765  1.015899   2.261578
# REP.A014_HUVEC.A_24H:M13 -4.483543 -1.352761   0.378701
# REP.A028_HUVEC.A_24H:N23 -4.360644 -0.608631  -4.509782
# REP.A028_HUVEC.A_24H:N05 -4.214676 -3.028154  -2.466868
# REP.A028_HUVEC.A_24H:F22 -4.104659  0.277810   3.156289
# REP.A014_HUVEC.A_24H:A05 -4.064939 -2.821751  -0.354523
# REP.A014_HUVEC.A_24H:N19 -4.007172 -0.751085  -2.782878
# REP.A013_HUVEC.A_24H:O03  4.333668  0.594979  -4.366348
# REP.A028_HUVEC.A_24H:O02  4.413511 -0.181098  -3.948267
# REP.A014_HUVEC.A_24H:K06  4.543619  1.089587   0.958473
# LJP009_HUVEC.A_24H:B03    4.594973 -7.603411 -10.680193
# REP.A011_HUVEC.A_24H:M11  4.850788 -1.631397  -0.342403
# REP.A014_HUVEC.A_24H:I16  5.107092  1.688976  -4.924839
# REP.A028_HUVEC.A_24H:C20  5.200680  1.581846  -5.079735
# REP.A014_HUVEC.A_24H:C24  5.236936 -0.540216  -3.179802
# REP.A014_HUVEC.A_24H:G15  5.351211  0.796832  -1.607498
# REP.A014_HUVEC.A_24H:L06  5.823866  1.059463  -5.675669
#
#                                          pert_drug              targets  \
# REP.A013_HUVEC.A_24H:L17  butorphanol-(+)-tartrate  OPRD1, OPRK1, OPRM1
# REP.A011_HUVEC.A_24H:F08                      DMSO       DMSO_No_target
# REP.A028_HUVEC.A_24H:B05                      DMSO       DMSO_No_target
# REP.A013_HUVEC.A_24H:J08               balsalazide         PTGS1, PTGS2
# REP.A014_HUVEC.A_24H:M13               rabeprazole                ATP4A
# REP.A028_HUVEC.A_24H:N23                pranlukast     CYSLTR1, CYSLTR2
# REP.A028_HUVEC.A_24H:N05               relcovaptan               AVPR1A
# REP.A028_HUVEC.A_24H:F22                 tamoxifen           ESR1, ESR2
# REP.A014_HUVEC.A_24H:A05                      DMSO       DMSO_No_target
# REP.A014_HUVEC.A_24H:N19                teroxirone
# REP.A013_HUVEC.A_24H:O03                    MG-132                PSMB1
# REP.A028_HUVEC.A_24H:O02                    MG-132                PSMB1
# REP.A014_HUVEC.A_24H:K06              sulforaphane               NFE2L2
# LJP009_HUVEC.A_24H:B03                   sirolimus         FKBP1A, MTOR
# REP.A011_HUVEC.A_24H:M11               moclobemide                 MAOA
# REP.A014_HUVEC.A_24H:I16                  AGI-5198                 IDH1
# REP.A028_HUVEC.A_24H:C20                bortezomib  PSMB1, PSMB2, PSMB5
# REP.A014_HUVEC.A_24H:C24                bortezomib  PSMB1, PSMB2, PSMB5
# REP.A014_HUVEC.A_24H:G15                bortezomib  PSMB1, PSMB2, PSMB5
# REP.A014_HUVEC.A_24H:L06                delanzomib
#
#                               dose
# REP.A013_HUVEC.A_24H:L17  0.125 uM
# REP.A011_HUVEC.A_24H:F08      0 uM
# REP.A028_HUVEC.A_24H:B05      0 uM
# REP.A013_HUVEC.A_24H:J08   3.33 uM
# REP.A014_HUVEC.A_24H:M13     10 uM
# REP.A028_HUVEC.A_24H:N23  0.125 uM
# REP.A028_HUVEC.A_24H:N05  0.125 uM
# REP.A028_HUVEC.A_24H:F22   0.37 uM
# REP.A014_HUVEC.A_24H:A05      0 uM
# REP.A014_HUVEC.A_24H:N19     10 uM
# REP.A013_HUVEC.A_24H:O03     20 uM
# REP.A028_HUVEC.A_24H:O02     20 uM
# REP.A014_HUVEC.A_24H:K06   0.04 uM
# LJP009_HUVEC.A_24H:B03       10 uM
# REP.A011_HUVEC.A_24H:M11  0.125 uM
# REP.A014_HUVEC.A_24H:I16   0.37 uM
# REP.A028_HUVEC.A_24H:C20     20 uM
# REP.A014_HUVEC.A_24H:C24     20 uM
# REP.A014_HUVEC.A_24H:G15     20 uM
# REP.A014_HUVEC.A_24H:L06   0.04 uM
# Targets: 14 ['', 'ATP4A', 'AVPR1A', 'CYSLTR1, CYSLTR2', 'DMSO_No_target', 'ESR1, ESR2', 'FKBP1A, MTOR', 'IDH1', 'MAOA', 'NFE2L2', 'OPRD1, OPRK1, OPRM1', 'PSMB1', 'PSMB1, PSMB2, PSMB5', 'PTGS1, PTGS2']

# %%
i = 1
top = 10

DPD_analysis = pd.concat([
                            DPD_inf_df.sort_values(by = states[i])[:top],
                            DPD_inf_df.sort_values(by = states[i])[len(DPD_df.index) - top:]
                            ], axis = 0)

display(DPD_analysis)

print("Targets:", len(set(DPD_analysis.targets)), sorted(set(DPD_analysis.targets)))
# Out:
#                                FSS     remod        OSS       pert_drug  \
# LJP009_HUVEC.A_24H:B03    4.594973 -7.603411 -10.680193       sirolimus
# LJP009_HUVEC.A_24H:A03    3.336128 -7.036444 -10.191977      vorinostat
# REP.A013_HUVEC.A_24H:A20 -3.846099 -7.005489  -5.237995     zardaverine
# REP.A028_HUVEC.A_24H:P22  1.319280 -6.977041  -0.274315  cyanocobalamin
# REP.A028_HUVEC.A_24H:P24  0.046052 -6.463404   0.066684  cyanocobalamin
# REP.A028_HUVEC.A_24H:I16 -3.257819 -5.947975  -4.401973       asenapine
# REP.A028_HUVEC.A_24H:I18  3.314273 -5.429017   1.277157       asenapine
# REP.A011_HUVEC.A_24H:J10  0.770857 -4.834995   0.640911    voriconazole
# REP.A028_HUVEC.A_24H:K22 -2.255813 -4.596373  -2.603153       brequinar
# REP.A028_HUVEC.A_24H:A23 -1.702654 -4.573322  -5.703485         danazol
# REP.A028_HUVEC.A_24H:I23  0.517669  3.875735   2.664835      nisoxetine
# REP.B013_HUVEC.A_24H:G18  1.605228  3.892132  -9.190345      bortezomib
# REP.A013_HUVEC.A_24H:K21 -0.096329  3.896160  -2.216164       tasisulam
# REP.A014_HUVEC.A_24H:P08  2.224535  3.976190  -0.609771         CT-7758
# REP.A014_HUVEC.A_24H:A17 -1.032193  3.989386  -1.464993       orantinib
# REP.A011_HUVEC.A_24H:I22 -0.743208  4.088065   1.837705     isbufylline
# REP.A014_HUVEC.A_24H:J10 -3.216450  4.274346   0.426617         MK-8033
# REP.A011_HUVEC.A_24H:I14  0.915329  4.689338  -0.995732      nafamostat
# REP.A013_HUVEC.A_24H:N14 -0.662441  4.964757  -1.027244        MLN-2480
# REP.A014_HUVEC.A_24H:D23 -0.102422  5.163510   0.992922       piroxicam
#
#                                                                   targets  \
# LJP009_HUVEC.A_24H:B03                                       FKBP1A, MTOR
# LJP009_HUVEC.A_24H:A03                  HDAC1, HDAC2, HDAC3, HDAC6, HDAC8
# REP.A013_HUVEC.A_24H:A20                                            PDE4D
# REP.A028_HUVEC.A_24H:P22                                             MMUT
# REP.A028_HUVEC.A_24H:P24                                             MMUT
# REP.A028_HUVEC.A_24H:I16     ADRB2, DRD1, DRD2, HRH1, HTR1A, HTR1B, HTR2A
# REP.A028_HUVEC.A_24H:I18     ADRB2, DRD1, DRD2, HRH1, HTR1A, HTR1B, HTR2A
# REP.A011_HUVEC.A_24H:J10           CYP2C19, CYP2C9, CYP3A4, CYP3A5, PTGS1
# REP.A028_HUVEC.A_24H:K22                                            DHODH
# REP.A028_HUVEC.A_24H:A23                                      ESR1, GNRHR
# REP.A028_HUVEC.A_24H:I23                                           SLC6A2
# REP.B013_HUVEC.A_24H:G18                              PSMB1, PSMB2, PSMB5
# REP.A013_HUVEC.A_24H:K21
# REP.A014_HUVEC.A_24H:P08
# REP.A014_HUVEC.A_24H:A17  AURKA, AURKB, FGFR1, FGFR2, KDR, PDGFRA, PDGFRB
# REP.A011_HUVEC.A_24H:I22
# REP.A014_HUVEC.A_24H:J10                                              MET
# REP.A011_HUVEC.A_24H:I14
# REP.A013_HUVEC.A_24H:N14
# REP.A014_HUVEC.A_24H:D23                                     PTGS1, PTGS2
#
#                               dose
# LJP009_HUVEC.A_24H:B03       10 uM
# LJP009_HUVEC.A_24H:A03       10 uM
# REP.A013_HUVEC.A_24H:A20   3.33 uM
# REP.A028_HUVEC.A_24H:P22   0.37 uM
# REP.A028_HUVEC.A_24H:P24   0.04 uM
# REP.A028_HUVEC.A_24H:I16   0.37 uM
# REP.A028_HUVEC.A_24H:I18   0.04 uM
# REP.A011_HUVEC.A_24H:J10   0.37 uM
# REP.A028_HUVEC.A_24H:K22   0.37 uM
# REP.A028_HUVEC.A_24H:A23  0.125 uM
# REP.A028_HUVEC.A_24H:I23  0.125 uM
# REP.B013_HUVEC.A_24H:G18     20 uM
# REP.A013_HUVEC.A_24H:K21   1.11 uM
# REP.A014_HUVEC.A_24H:P08   3.33 uM
# REP.A014_HUVEC.A_24H:A17  0.125 uM
# REP.A011_HUVEC.A_24H:I22   0.37 uM
# REP.A014_HUVEC.A_24H:J10   0.37 uM
# REP.A011_HUVEC.A_24H:I14   3.33 uM
# REP.A013_HUVEC.A_24H:N14   3.33 uM
# REP.A014_HUVEC.A_24H:D23  0.125 uM
# Targets: 14 ['', 'ADRB2, DRD1, DRD2, HRH1, HTR1A, HTR1B, HTR2A', 'AURKA, AURKB, FGFR1, FGFR2, KDR, PDGFRA, PDGFRB', 'CYP2C19, CYP2C9, CYP3A4, CYP3A5, PTGS1', 'DHODH', 'ESR1, GNRHR', 'FKBP1A, MTOR', 'HDAC1, HDAC2, HDAC3, HDAC6, HDAC8', 'MET', 'MMUT', 'PDE4D', 'PSMB1, PSMB2, PSMB5', 'PTGS1, PTGS2', 'SLC6A2']

# %%
i = 2
top = 10

DPD_analysis = pd.concat([
                            DPD_inf_df.sort_values(by = states[i])[:top],
                            DPD_inf_df.sort_values(by = states[i])[len(DPD_df.index) - top:]
                            ], axis = 0)

display(DPD_analysis)

print("Targets:", len(set(DPD_analysis.targets)), sorted(set(DPD_analysis.targets)))
# Out:
#                                FSS     remod        OSS             pert_drug  \
# REP.B023_HUVEC.A_24H:K10 -0.760776  0.128112 -13.034288                MG-132
# REP.B024_HUVEC.A_24H:G18  1.847560  0.543309 -12.765121            bortezomib
# REP.B024_HUVEC.A_24H:K09  2.981545  1.129899 -12.572315                MG-132
# REP.B013_HUVEC.A_24H:C22  0.323153  1.415620 -12.381799            bortezomib
# REP.A009_HUVEC.A_24H:G13 -0.228651 -0.639393 -12.283002            bortezomib
# REP.B022_HUVEC.A_24H:O01  0.913392  0.105277 -12.099377                MG-132
# REP.A009_HUVEC.A_24H:G15  0.698173 -0.750965 -12.031933            bortezomib
# REP.A009_HUVEC.A_24H:K09  1.647125  0.206530 -11.972967                MG-132
# REP.B022_HUVEC.A_24H:K08 -0.276707  0.928626 -11.862400                MG-132
# REP.B021_HUVEC.A_24H:K11  1.224224  1.154211 -11.812207                MG-132
# REP.A028_HUVEC.A_24H:C07 -0.529477 -2.750183   3.789921  diminazene-aceturate
# REP.A028_HUVEC.A_24H:P08  0.959080  1.532086   3.802034         rosiglitazone
# REP.A014_HUVEC.A_24H:M18 -1.553840  0.789227   3.826599           rabeprazole
# REP.A011_HUVEC.A_24H:O09 -0.349147  1.848991   3.827068           roscovitine
# REP.A011_HUVEC.A_24H:D08 -1.188949  0.338044   3.873061             clemizole
# REP.A028_HUVEC.A_24H:E22 -0.468250  2.055651   4.090750             tadalafil
# REP.A014_HUVEC.A_24H:E17  0.245090  0.482986   4.273723               TAK-875
# REP.A028_HUVEC.A_24H:O22 -2.517172  3.243051   4.518302          piperidolate
# REP.A028_HUVEC.A_24H:H23 -0.543013  0.091857   4.690661           PF-04136309
# REP.A028_HUVEC.A_24H:C15 -0.100604  2.379744   4.695972             melperone
#
#                                       targets      dose
# REP.B023_HUVEC.A_24H:K10                PSMB1     20 uM
# REP.B024_HUVEC.A_24H:G18  PSMB1, PSMB2, PSMB5     20 uM
# REP.B024_HUVEC.A_24H:K09                PSMB1     20 uM
# REP.B013_HUVEC.A_24H:C22  PSMB1, PSMB2, PSMB5     20 uM
# REP.A009_HUVEC.A_24H:G13  PSMB1, PSMB2, PSMB5     20 uM
# REP.B022_HUVEC.A_24H:O01                PSMB1     20 uM
# REP.A009_HUVEC.A_24H:G15  PSMB1, PSMB2, PSMB5     20 uM
# REP.A009_HUVEC.A_24H:K09                PSMB1     20 uM
# REP.B022_HUVEC.A_24H:K08                PSMB1     20 uM
# REP.B021_HUVEC.A_24H:K11                PSMB1     20 uM
# REP.A028_HUVEC.A_24H:C07                 AOC1     10 uM
# REP.A028_HUVEC.A_24H:P08                PPARG   3.33 uM
# REP.A014_HUVEC.A_24H:M18                ATP4A   0.04 uM
# REP.A011_HUVEC.A_24H:O09     CDK2, CDK7, CDK9   1.11 uM
# REP.A011_HUVEC.A_24H:D08                        3.33 uM
# REP.A028_HUVEC.A_24H:E22        PDE11A, PDE5A   0.37 uM
# REP.A014_HUVEC.A_24H:E17                FFAR1  0.125 uM
# REP.A028_HUVEC.A_24H:O22                CHRM1   0.37 uM
# REP.A028_HUVEC.A_24H:H23                       0.125 uM
# REP.A028_HUVEC.A_24H:C15          DRD2, HTR2A   1.11 uM
# Targets: 11 ['', 'AOC1', 'ATP4A', 'CDK2, CDK7, CDK9', 'CHRM1', 'DRD2, HTR2A', 'FFAR1', 'PDE11A, PDE5A', 'PPARG', 'PSMB1', 'PSMB1, PSMB2, PSMB5']

# %%
### copy manually
targets_list = ["ATP4A", "AVPR1A", "CYSLTR1", "CYSLTR2", "ESR1", "ESR2", "FKBP1A", "MTOR", "IDH1", "MAOA", "NFE2L2", "OPRD1", "OPRK1", "OPRM1", "PSMB1", "PSMB1", "PSMB2", "PSMB5", "PTGS1", "PTGS2", "ADRB2", "DRD1", "DRD2", "HRH1", "HTR1A", "HTR1B", "HTR2A", "AURKA", "AURKB", "FGFR1", "FGFR2", "KDR", "PDGFRA", "PDGFRB", "CYP2C19", "CYP2C9", "CYP3A4", "CYP3A5", "PTGS1", "DHODH", "ESR1", "GNRHR", "FKBP1A", "MTOR", "HDAC1", "HDAC2", "HDAC3", "HDAC6", "HDAC8", "MET", "MMUT", "PDE4D", "PSMB1", "PSMB2", "PSMB5", "PTGS1", "PTGS2", "SLC6A2", "AOC1", "ATP4A", "CDK2", "CDK7", "CDK9", "CHRM1", "DRD2", "HTR2A", "FFAR1", "PDE11A", "PDE5A", "PPARG", "PSMB1", "PSMB1", "PSMB2", "PSMB5"]
targets_list = sorted(list(set(targets_list )))
print("Targets:", len(targets_list ), targets_list)
# Out:
# Targets: 57 ['ADRB2', 'AOC1', 'ATP4A', 'AURKA', 'AURKB', 'AVPR1A', 'CDK2', 'CDK7', 'CDK9', 'CHRM1', 'CYP2C19', 'CYP2C9', 'CYP3A4', 'CYP3A5', 'CYSLTR1', 'CYSLTR2', 'DHODH', 'DRD1', 'DRD2', 'ESR1', 'ESR2', 'FFAR1', 'FGFR1', 'FGFR2', 'FKBP1A', 'GNRHR', 'HDAC1', 'HDAC2', 'HDAC3', 'HDAC6', 'HDAC8', 'HRH1', 'HTR1A', 'HTR1B', 'HTR2A', 'IDH1', 'KDR', 'MAOA', 'MET', 'MMUT', 'MTOR', 'NFE2L2', 'OPRD1', 'OPRK1', 'OPRM1', 'PDE11A', 'PDE4D', 'PDE5A', 'PDGFRA', 'PDGFRB', 'PPARG', 'PSMB1', 'PSMB2', 'PSMB5', 'PTGS1', 'PTGS2', 'SLC6A2']

# %% [markdown]
# ## Plots for targets

# %%
print_drugs = []

# %% [markdown]
# ### CDK1/2

# %%
target_name = "CDK1_CDK2"

target = "CDK1"
drugs = list(set(sig_info_cell_df.loc[sig_info_cell_df.targets.str.contains(target)].pert_drug))

target = "CDK2"
drugs += list(set(sig_info_cell_df.loc[sig_info_cell_df.targets.str.contains(target)].pert_drug))

drugs = sorted(list(set(drugs)))

print("drugs for target " + target_name + ":" , len(drugs), drugs)
# Out:
# drugs for target CDK1_CDK2: 5 ['CGP-60474', 'PHA-848125', 'alvocidib', 'dinaciclib', 'roscovitine']

# %%
drugs_list = drugs + ["OTS-167", "PHA-767491"]

targets = []
doses = []

for drug in drugs_list:
    targets.append(", ".join(sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].targets)))))
    doses.append(", ".join(sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].dose)))))
    
target_drugs_df = pd.DataFrame(list(zip(targets, doses)), index = drugs_list, columns = ["targets","doses"])

display(target_drugs_df)
# Out:
#                                                        targets  \
# CGP-60474                                                 CDK1
# PHA-848125                             CDK1, CDK2, CDK4, NTRK1
# alvocidib    CDK1, CDK2, CDK4, CDK5, CDK6, CDK7, CDK8, CDK9...
# dinaciclib                              CDK1, CDK2, CDK5, CDK9
# roscovitine                                   CDK2, CDK7, CDK9
# OTS-167
# PHA-767491
#
#                                                          doses
# CGP-60474    0.04 uM, 0.12 uM, 0.37 uM, 1.11 uM, 10 uM, 3.3...
# PHA-848125   0.04 uM, 0.125 uM, 0.37 uM, 1.11 uM, 10 uM, 3....
# alvocidib    0.04 uM, 0.125 uM, 0.37 uM, 1.11 uM, 10 uM, 3....
# dinaciclib                           0.04 uM, 0.37 uM, 1.11 uM
# roscovitine  0.01 uM, 0.03 uM, 0.04 uM, 0.08 uM, 0.125 uM, ...
# OTS-167      0.04 uM, 0.12 uM, 0.37 uM, 1.11 uM, 10 uM, 3.3...
# PHA-767491   0.04 uM, 0.12 uM, 0.37 uM, 1.11 uM, 10 uM, 3.3...

# %%
target_name = "CDK1_CDK2"
target_drugs = ["CGP-60474", "dinaciclib", "roscovitine", "OTS-167", "PHA-767491"]
# deleted PHA-848125, alvocidib because other targets = CDK4, CDK6 (other phase of cell cycle)

for DPD_val in states:
    plt.figure(figsize = (9,8))
    for drug in target_drugs:
        doses = sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].dose_float)))
        DPDs = []
        DPD_errs = []
        for dose in doses:
            labels = sig_info_cell_df.loc[(sig_info_cell_df.pert_drug == drug) & (sig_info_cell_df.dose_float == dose)].index
            DPDs.append(statistics.mean(DPD_df.loc[labels, DPD_val]))
            if (len(labels) > 1):
                DPD_errs.append(scipy.stats.sem(DPD_df.loc[labels, DPD_val]))
            else:
                DPD_errs.append(0)
        plt.errorbar(doses, DPDs, yerr = DPD_errs, fmt = "o-", label = drug, capsize = 5)
    plt.legend()
    plt.plot([0,10], [0,0], "--", color = "black")
    plt.xlabel("Dose, uM")
    plt.ylabel("DPD_" + DPD_val)
    plt.title("Target: " + target_name)
    plt.savefig(os.path.join(out_dir, target_name + "_DPD_" + DPD_val + ".png"), dpi = 300)
    plt.show()

# %%
# delete OTS-167
print_drugs += ["CGP-60474", "dinaciclib", "PHA-767491", "roscovitine"]

# %%
# delete for roscovitine dose 3,33 uM
labels = sig_info_cell_df.loc[(sig_info_cell_df.pert_drug == "roscovitine") & (sig_info_cell_df.dose_float == 3.33)].index.to_list()
print(labels)
# Out:
# ['REP.A011_HUVEC.A_24H:O08']

# %% [markdown]
# ### PAK

# %%
target = "PAK"
drugs = sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.targets.str.contains(target)].pert_drug)))

print("drugs for target " + target + ":" , len(drugs), drugs)
# Out:
# drugs for target PAK: 1 ['PF-03758309']

# %%
drugs_list = drugs

targets = []
doses = []

for drug in drugs_list:
    targets.append(", ".join(sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].targets)))))
    doses.append(", ".join(sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].dose)))))
    
target_drugs_df = pd.DataFrame(list(zip(targets, doses)), index = drugs_list, columns = ["targets","doses"])

display(target_drugs_df)
# Out:
#             targets                                              doses
# PF-03758309    PAK4  0.04 uM, 0.12 uM, 0.125 uM, 0.37 uM, 1.11 uM, ...

# %%
target_name = "PAK"
target_drugs = drugs_list

for DPD_val in states:
    plt.figure(figsize = (9,8))
    for drug in target_drugs:
        doses = sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].dose_float)))
        DPDs = []
        DPD_errs = []
        for dose in doses:
            labels = sig_info_cell_df.loc[(sig_info_cell_df.pert_drug == drug) & (sig_info_cell_df.dose_float == dose)].index
            DPDs.append(statistics.mean(DPD_df.loc[labels, DPD_val]))
            if (len(labels) > 1):
                DPD_errs.append(scipy.stats.sem(DPD_df.loc[labels, DPD_val]))
            else:
                DPD_errs.append(0)
        plt.errorbar(doses, DPDs, yerr = DPD_errs, fmt = "o-", label = drug, capsize = 5)
    plt.legend()
    plt.plot([0,10], [0,0], "--", color = "black")
    plt.xlabel("Dose, uM")
    plt.ylabel("DPD_" + DPD_val)
    plt.title("Target: " + target_name)
    plt.savefig(os.path.join(out_dir, target_name + "_DPD_" + DPD_val + ".png"), dpi = 300)
    plt.show()

# %%
print_drugs += target_drugs

# %%
# delete for PF-03758309 dose 10 uM

labels = sig_info_cell_df.loc[(sig_info_cell_df.pert_drug == "PF-03758309") & (sig_info_cell_df.dose_float == 10)].index.to_list()
print(labels)
# Out:
# ['LJP009_HUVEC.A_24H:D01', 'LJP009_HUVEC_24H:D01']

# %% [markdown]
# ### PI3K

# %%
target = "PIK3"
drugs = sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.targets.str.contains(target)].pert_drug)))

print("drugs for target " + target + ":" , len(drugs), drugs)
# Out:
# drugs for target PIK3: 4 ['PF-04691502', 'XL-147', 'idelalisib', 'quercetin']

# %%
drugs_list = drugs + ["GSK-2334470", "A-66", "BGT-226", "BX-795"]

targets = []
doses = []

for drug in drugs_list:
    targets.append(", ".join(sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].targets)))))
    doses.append(", ".join(sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].dose)))))
    
target_drugs_df = pd.DataFrame(list(zip(targets, doses)), index = drugs_list, columns = ["targets","doses"])

display(target_drugs_df)
# Out:
#                             targets  \
# PF-04691502            MTOR, PIK3CA
# XL-147       PIK3CA, PIK3CD, PIK3CG
# idelalisib           PIK3CD, PIK3CG
# quercetin                    PIK3CG
# GSK-2334470             PDK1, PDPK1
# A-66
# BGT-226
# BX-795                  PDK1, PDPK1
#
#                                                          doses
# PF-04691502  0.01 uM, 0.03 uM, 0.04 uM, 0.08 uM, 0.125 uM, ...
# XL-147       0.04 uM, 0.125 uM, 0.37 uM, 1.11 uM, 10 uM, 3....
# idelalisib   0.04 uM, 0.12 uM, 0.125 uM, 0.37 uM, 1.11 uM, ...
# quercetin            0.04 uM, 0.37 uM, 1.11 uM, 10 uM, 3.33 uM
# GSK-2334470  0.04 uM, 0.12 uM, 0.37 uM, 1.11 uM, 10 uM, 3.3...
# A-66         0.04 uM, 0.12 uM, 0.37 uM, 1.11 uM, 10 uM, 3.3...
# BGT-226            0.04 uM, 0.12 uM, 0.37 uM, 1.11 uM, 3.33 uM
# BX-795       0.04 uM, 0.12 uM, 0.37 uM, 1.11 uM, 10 uM, 3.3...

# %%
target_name = "PI3K"
target_drugs = ["PF-04691502", "XL-147", "GSK-2334470", "A-66", "BGT-226", "BX-795"]
# deleted idelalisib, quercetin because other targets = PIK3CD, PIK3CG (delta, gamma, we use only alpha)


for DPD_val in states:
    plt.figure(figsize = (9,8))
    for drug in target_drugs:
        doses = sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].dose_float)))
        DPDs = []
        DPD_errs = []
        for dose in doses:
            labels = sig_info_cell_df.loc[(sig_info_cell_df.pert_drug == drug) & (sig_info_cell_df.dose_float == dose)].index
            DPDs.append(statistics.mean(DPD_df.loc[labels, DPD_val]))
            if (len(labels) > 1):
                DPD_errs.append(scipy.stats.sem(DPD_df.loc[labels, DPD_val]))
            else:
                DPD_errs.append(0)
        plt.errorbar(doses, DPDs, yerr = DPD_errs, fmt = "o-", label = drug, capsize = 5)
    plt.legend()
    plt.plot([0,10], [0,0], "--", color = "black")
    plt.xlabel("Dose, uM")
    plt.ylabel("DPD_" + DPD_val)
    plt.title("Target: " + target_name)
    plt.savefig(os.path.join(out_dir, target_name + "_DPD_" + DPD_val + ".png"), dpi = 300)
    plt.show()

# %%
print_drugs += target_drugs

# %% [markdown]
# ### ERK

# %%
target_name = "ERK"

target = "MAP2K"
drugs = list(set(sig_info_cell_df.loc[sig_info_cell_df.targets.str.contains(target)].pert_drug))

target = "MAPK"
drugs += list(set(sig_info_cell_df.loc[sig_info_cell_df.targets.str.contains(target)].pert_drug))

target = "RAF"
drugs += list(set(sig_info_cell_df.loc[sig_info_cell_df.targets.str.contains(target)].pert_drug))

drugs = sorted(list(set(drugs)))

print("drugs for target " + target_name + ":" , len(drugs), drugs)
# Out:
# drugs for target ERK: 20 ['AZ-628', 'BIX-02189', 'CG-930', 'FR-180204', 'GDC-0879', 'GW-5074', 'PD-0325901', 'PD-184352', 'SB-203580', 'SB-239063', 'TAK-715', 'TAK-733', 'VX-745', 'XMD-885', 'XMD-892', 'dabrafenib', 'doramapimod', 'pyrazolanthrone', 'refametinib', 'regorafenib']

# %%
drugs_list = drugs + ["RAF-265"]

targets = []
doses = []

for drug in drugs_list:
    targets.append(", ".join(sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].targets)))))
    doses.append(", ".join(sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].dose)))))
    
target_drugs_df = pd.DataFrame(list(zip(targets, doses)), index = drugs_list, columns = ["targets","doses"])

display(target_drugs_df)
# Out:
#                                                            targets  \
# AZ-628                                                  BRAF, RAF1
# BIX-02189                                            MAP2K5, MAPK7
# CG-930                                                       MAPK8
# FR-180204                                             MAPK1, MAPK3
# GDC-0879                                                      BRAF
# GW-5074                                                       RAF1
# PD-0325901                                                  MAP2K1
# PD-184352                                                   MAP2K1
# SB-203580                                    MAPK1, MAPK11, MAPK14
# SB-239063                                           MAPK11, MAPK14
# TAK-715                                                     MAPK14
# TAK-733                                                     MAP2K1
# VX-745                                                      MAPK14
# XMD-885                                               LRRK2, MAPK7
# XMD-892                                                      MAPK7
# dabrafenib                                                    BRAF
# doramapimod                                 MAPK11, MAPK12, MAPK14
# pyrazolanthrone                          MAPK10, MAPK8, MAPK9, TTK
# refametinib                                         MAP2K1, MAP2K2
# regorafenib      ABL1, BRAF, DDR2, FGFR1, FGFR2, FLT1, FLT4, FR...
# RAF-265
#
#                                                              doses
# AZ-628           0.01 uM, 0.03 uM, 0.04 uM, 0.08 uM, 0.12 uM, 0...
# BIX-02189        0.04 uM, 0.12 uM, 0.37 uM, 1.11 uM, 10 uM, 3.3...
# CG-930           0.04 uM, 0.12 uM, 0.37 uM, 1.11 uM, 10 uM, 3.3...
# FR-180204        0.04 uM, 0.12 uM, 0.37 uM, 1.11 uM, 10 uM, 3.3...
# GDC-0879         0.04 uM, 0.12 uM, 0.37 uM, 1.11 uM, 10 uM, 3.3...
# GW-5074          0.04 uM, 0.12 uM, 0.37 uM, 1.11 uM, 10 uM, 3.3...
# PD-0325901       0.04 uM, 0.12 uM, 0.37 uM, 1.11 uM, 10 uM, 3.3...
# PD-184352        0.01 uM, 0.03 uM, 0.04 uM, 0.08 uM, 0.125 uM, ...
# SB-203580        0.04 uM, 0.12 uM, 0.37 uM, 1.11 uM, 10 uM, 3.3...
# SB-239063        0.04 uM, 0.12 uM, 0.37 uM, 1.11 uM, 10 uM, 3.3...
# TAK-715          0.04 uM, 0.12 uM, 0.37 uM, 1.11 uM, 10 uM, 3.3...
# TAK-733          0.04 uM, 0.125 uM, 0.37 uM, 1.11 uM, 10 uM, 3....
# VX-745           0.04 uM, 0.12 uM, 0.37 uM, 1.11 uM, 10 uM, 3.3...
# XMD-885          0.04 uM, 0.12 uM, 0.37 uM, 1.11 uM, 10 uM, 3.3...
# XMD-892          0.04 uM, 0.12 uM, 0.37 uM, 1.11 uM, 10 uM, 3.3...
# dabrafenib       0.04 uM, 0.12 uM, 0.37 uM, 1.11 uM, 10 uM, 3.3...
# doramapimod      0.01 uM, 0.03 uM, 0.04 uM, 0.08 uM, 0.12 uM, 0...
# pyrazolanthrone  0.04 uM, 0.12 uM, 0.37 uM, 1.11 uM, 10 uM, 3.3...
# refametinib      0.01 uM, 0.03 uM, 0.04 uM, 0.08 uM, 0.125 uM, ...
# regorafenib      0.04 uM, 0.12 uM, 0.37 uM, 1.11 uM, 10 uM, 3.3...
# RAF-265          0.04 uM, 0.12 uM, 0.37 uM, 1.11 uM, 10 uM, 3.3...

# %%
target_name = "ERK"
target_drugs = ["AZ-628", "FR-180204", "GDC-0879", "GW-5074", "PD-0325901", "PD-184352", "TAK-733", "dabrafenib", "refametinib", "RAF-265"]
# deleted SB-203580 (MAPK1)
# select only gene name RAF1, BRAF, MAP2K1, MAP2K2, MAPK1, MAPK3   (Kinase pathway RAF->MEK->ERK) = module "ERK2

for DPD_val in states:
    plt.figure(figsize = (9,8))
    for drug in target_drugs:
        doses = sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].dose_float)))
        DPDs = []
        DPD_errs = []
        for dose in doses:
            labels = sig_info_cell_df.loc[(sig_info_cell_df.pert_drug == drug) & (sig_info_cell_df.dose_float == dose)].index
            DPDs.append(statistics.mean(DPD_df.loc[labels, DPD_val]))
            if (len(labels) > 1):
                DPD_errs.append(scipy.stats.sem(DPD_df.loc[labels, DPD_val]))
            else:
                DPD_errs.append(0)
        plt.errorbar(doses, DPDs, yerr = DPD_errs, fmt = "o-", label = drug, capsize = 5)
    plt.legend()
    plt.plot([0,10], [0,0], "--", color = "black")
    plt.xlabel("Dose, uM")
    plt.ylabel("DPD_" + DPD_val)
    plt.title("Target: " + target_name)
    plt.savefig(os.path.join(out_dir, target_name + "_DPD_" + DPD_val + ".png"), dpi = 300)
    plt.show()

# %%
print_drugs += target_drugs

# %% [markdown]
# ### BET

# %%
target = "BRD4"
drugs = sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.targets.str.contains(target)].pert_drug)))

print("drugs for target " + target + ":" , len(drugs), drugs)
# Out:
# drugs for target BRD4: 1 ['I-BET-762']

# %%
drugs_list = drugs + ["I-BET-151", "JQ-1-R", "PFI-1"]

targets = []
doses = []

for drug in drugs_list:
    targets.append(", ".join(sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].targets)))))
    doses.append(", ".join(sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].dose)))))
    
target_drugs_df = pd.DataFrame(list(zip(targets, doses)), index = drugs_list, columns = ["targets","doses"])

display(target_drugs_df)
# Out:
#                     targets                                              doses
# I-BET-762  BRD2, BRD3, BRD4  0.04 uM, 0.12 uM, 0.37 uM, 1.11 uM, 10 uM, 3.3...
# I-BET-151                    0.04 uM, 0.12 uM, 0.37 uM, 1.11 uM, 10 uM, 3.3...
# JQ-1-R                       0.04 uM, 0.12 uM, 0.37 uM, 1.11 uM, 10 uM, 3.3...
# PFI-1                        0.04 uM, 0.12 uM, 0.37 uM, 1.11 uM, 10 uM, 3.3...

# %%
target_name = "BET"
target_drugs = drugs_list

for DPD_val in states:
    plt.figure(figsize = (9,8))
    for drug in target_drugs:
        doses = sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].dose_float)))
        DPDs = []
        DPD_errs = []
        for dose in doses:
            labels = sig_info_cell_df.loc[(sig_info_cell_df.pert_drug == drug) & (sig_info_cell_df.dose_float == dose)].index
            DPDs.append(statistics.mean(DPD_df.loc[labels, DPD_val]))
            if (len(labels) > 1):
                DPD_errs.append(scipy.stats.sem(DPD_df.loc[labels, DPD_val]))
            else:
                DPD_errs.append(0)
        plt.errorbar(doses, DPDs, yerr = DPD_errs, fmt = "o-", label = drug, capsize = 5)
    plt.legend()
    plt.plot([0,10], [0,0], "--", color = "black")
    plt.xlabel("Dose, uM")
    plt.ylabel("DPD_" + DPD_val)
    plt.title("Target: " + target_name)
    plt.savefig(os.path.join(out_dir, target_name + "_DPD_" + DPD_val + ".png"), dpi = 300)
    plt.show()

# %%
print_drugs += target_drugs

# %% [markdown]
# ### Aurora

# %%
target = "AURK"
drugs = sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.targets.str.contains(target)].pert_drug)))

print("drugs for target " + target + ":" , len(drugs), drugs)
# Out:
# drugs for target AURK: 8 ['ENMD-2076', 'GSK-1070916', 'JWE-035', 'KW-2449', 'MLN-8054', 'ZM-447439', 'alisertib', 'orantinib']

# %%
drugs_list = drugs + ["aurora-a-inhibitor-i"]

targets = []
doses = []

for drug in drugs_list:
    targets.append(", ".join(sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].targets)))))
    doses.append(", ".join(sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].dose)))))
    
target_drugs_df = pd.DataFrame(list(zip(targets, doses)), index = drugs_list, columns = ["targets","doses"])

display(target_drugs_df)
# Out:
#                                                               targets  \
# ENMD-2076                               AURKA, FLT3, KDR, PDGFRA, SRC
# GSK-1070916                                              AURKB, AURKC
# JWE-035                                                         AURKA
# KW-2449                                      ABL1, AURKA, FGFR1, FLT3
# MLN-8054                                                        AURKA
# ZM-447439                                                AURKA, AURKB
# alisertib                                                       AURKA
# orantinib             AURKA, AURKB, FGFR1, FGFR2, KDR, PDGFRA, PDGFRB
# aurora-a-inhibitor-i
#
#                                                                   doses
# ENMD-2076             0.01 uM, 0.03 uM, 0.04 uM, 0.08 uM, 0.125 uM, ...
# GSK-1070916           0.04 uM, 0.12 uM, 0.37 uM, 1.11 uM, 10 uM, 3.3...
# JWE-035               0.04 uM, 0.12 uM, 0.37 uM, 1.11 uM, 10 uM, 3.3...
# KW-2449               0.04 uM, 0.12 uM, 0.37 uM, 1.11 uM, 10 uM, 3.3...
# MLN-8054              0.01 uM, 0.03 uM, 0.04 uM, 0.08 uM, 0.12 uM, 0...
# ZM-447439             0.04 uM, 0.12 uM, 0.37 uM, 1.11 uM, 10 uM, 3.3...
# alisertib             0.01 uM, 0.03 uM, 0.08 uM, 0.25 uM, 0.74 uM, 2...
# orantinib             0.04 uM, 0.125 uM, 0.37 uM, 1.11 uM, 10 uM, 3....
# aurora-a-inhibitor-i

# %%
target_name = "Aurora"
target_drugs = ["GSK-1070916", "MLN-8054", "ZM-447439", "alisertib", "JWE-035"]
# deleted ENMD-2076, KW-2449, orantinib because other targets 
# deleted aurora-a-inhibitor-i (2017) - not in data 2020

for DPD_val in states:
    plt.figure(figsize = (9,8))
    for drug in target_drugs:
        doses = sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].dose_float)))
        DPDs = []
        DPD_errs = []
        for dose in doses:
            labels = sig_info_cell_df.loc[(sig_info_cell_df.pert_drug == drug) & (sig_info_cell_df.dose_float == dose)].index
            DPDs.append(statistics.mean(DPD_df.loc[labels, DPD_val]))
            if (len(labels) > 1):
                DPD_errs.append(scipy.stats.sem(DPD_df.loc[labels, DPD_val]))
            else:
                DPD_errs.append(0)
        plt.errorbar(doses, DPDs, yerr = DPD_errs, fmt = "o-", label = drug, capsize = 5)
    plt.legend()
    plt.plot([0,10], [0,0], "--", color = "black")
    plt.xlabel("Dose, uM")
    plt.ylabel("DPD_" + DPD_val)
    plt.title("Target: " + target_name)
    plt.savefig(os.path.join(out_dir, target_name + "_DPD_" + DPD_val + ".png"), dpi = 300)
    plt.show()

# %%
# delete JWE-035 bacause no enought info
print_drugs += ["GSK-1070916", "MLN-8054", "ZM-447439", "alisertib"]

# %% [markdown]
# ### TGFbR

# %%
target = "TGFBR"
drugs = sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.targets.str.contains(target)].pert_drug)))

print("drugs for target " + target + ":" , len(drugs), drugs)
# Out:
# drugs for target TGFBR: 1 ['SB-525334']

# %%
drugs_list = drugs

targets = []
doses = []

for drug in drugs_list:
    targets.append(", ".join(sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].targets)))))
    doses.append(", ".join(sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].dose)))))
    
target_drugs_df = pd.DataFrame(list(zip(targets, doses)), index = drugs_list, columns = ["targets","doses"])

display(target_drugs_df)
# Out:
#           targets                                              doses
# SB-525334  TGFBR1  0.04 uM, 0.12 uM, 0.37 uM, 1.11 uM, 10 uM, 3.3...

# %%
target_name = "TGFbR"
target_drugs = drugs_list

for DPD_val in states:
    plt.figure(figsize = (9,8))
    for drug in target_drugs:
        doses = sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].dose_float)))
        DPDs = []
        DPD_errs = []
        for dose in doses:
            labels = sig_info_cell_df.loc[(sig_info_cell_df.pert_drug == drug) & (sig_info_cell_df.dose_float == dose)].index
            DPDs.append(statistics.mean(DPD_df.loc[labels, DPD_val]))
            if (len(labels) > 1):
                DPD_errs.append(scipy.stats.sem(DPD_df.loc[labels, DPD_val]))
            else:
                DPD_errs.append(0)
        plt.errorbar(doses, DPDs, yerr = DPD_errs, fmt = "o-", label = drug, capsize = 5)
    plt.legend()
    plt.plot([0,10], [0,0], "--", color = "black")
    plt.xlabel("Dose, uM")
    plt.ylabel("DPD_" + DPD_val)
    plt.title("Target: " + target_name)
    plt.savefig(os.path.join(out_dir, target_name + "_DPD_" + DPD_val + ".png"), dpi = 300)
    plt.show()

# %%
print_drugs += target_drugs

# %% [markdown]
# ### VEGFR

# %%
drugs_list = ["rebastinib", "lenvatinib", "orantinib", "foretinib", "cediranib", "sunitinib", "tivozanib"]

targets = []
doses = []

for drug in drugs_list:
    targets.append(", ".join(sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].targets)))))
    doses.append(", ".join(sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].dose)))))
    
target_drugs_df = pd.DataFrame(list(zip(targets, doses)), index = drugs_list, columns = ["targets","doses"])

display(target_drugs_df)
# Out:
#                                                     targets  \
# rebastinib                        ABL1, BCR, FLT3, KDR, TEK
# lenvatinib                      FGFR1, FLT1, FLT4, KDR, KIT
# orantinib   AURKA, AURKB, FGFR1, FGFR2, KDR, PDGFRA, PDGFRB
# foretinib                                          KDR, MET
# cediranib                      FLT1, FLT4, KDR, KIT, PDGFRB
# sunitinib   FLT1, FLT3, FLT4, KDR, KIT, PDGFRA, PDGFRB, RET
# tivozanib              FLT1, FLT4, KDR, KIT, PDGFRA, PDGFRB
#
#                                                         doses
# rebastinib  0.04 uM, 0.12 uM, 0.37 uM, 1.11 uM, 10 uM, 3.3...
# lenvatinib  0.01 uM, 0.03 uM, 0.04 uM, 0.08 uM, 0.125 uM, ...
# orantinib   0.04 uM, 0.125 uM, 0.37 uM, 1.11 uM, 10 uM, 3....
# foretinib   0.01 uM, 0.03 uM, 0.08 uM, 0.25 uM, 0.74 uM, 2...
# cediranib   0.01 uM, 0.03 uM, 0.04 uM, 0.08 uM, 0.125 uM, ...
# sunitinib   0.04 uM, 0.12 uM, 0.37 uM, 1.11 uM, 10 uM, 3.3...
# tivozanib   0.04 uM, 0.12 uM, 0.37 uM, 1.11 uM, 10 uM, 3.3...

# %%
target_name = "VEGFR"
target_drugs = drugs_list

for DPD_val in states:
    plt.figure(figsize = (9,8))
    for drug in target_drugs:
        doses = sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].dose_float)))
        DPDs = []
        DPD_errs = []
        for dose in doses:
            labels = sig_info_cell_df.loc[(sig_info_cell_df.pert_drug == drug) & (sig_info_cell_df.dose_float == dose)].index
            DPDs.append(statistics.mean(DPD_df.loc[labels, DPD_val]))
            if (len(labels) > 1):
                DPD_errs.append(scipy.stats.sem(DPD_df.loc[labels, DPD_val]))
            else:
                DPD_errs.append(0)
        plt.errorbar(doses, DPDs, yerr = DPD_errs, fmt = "o-", label = drug, capsize = 5)
    plt.legend()
    plt.plot([0,10], [0,0], "--", color = "black")
    plt.xlabel("Dose, uM")
    plt.ylabel("DPD_" + DPD_val)
    plt.title("Target: " + target_name)
    plt.savefig(os.path.join(out_dir, target_name + "_DPD_" + DPD_val + ".png"), dpi = 300)
    plt.show()

# %%
print_drugs += target_drugs

# %% [markdown]
# ### PKC

# %%
target = "PRKC"
drugs = sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.targets.str.contains(target)].pert_drug)))

print("drugs for target " + target + ":" , len(drugs), drugs)
# Out:
# drugs for target PRKC: 1 ['enzastaurin']

# %%
drugs_list = drugs

targets = []
doses = []

for drug in drugs_list:
    targets.append(", ".join(sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].targets)))))
    doses.append(", ".join(sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].dose)))))
    
target_drugs_df = pd.DataFrame(list(zip(targets, doses)), index = drugs_list, columns = ["targets","doses"])

display(target_drugs_df)
# Out:
#             targets                                        doses
# enzastaurin   PRKCB  0.01 uM, 0.03 uM, 0.08 uM, 0.74 uM, 2.22 uM

# %%
target_name = "PKC"
target_drugs = drugs_list

for DPD_val in states:
    plt.figure(figsize = (9,8))
    for drug in target_drugs:
        doses = sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].dose_float)))
        DPDs = []
        DPD_errs = []
        for dose in doses:
            labels = sig_info_cell_df.loc[(sig_info_cell_df.pert_drug == drug) & (sig_info_cell_df.dose_float == dose)].index
            DPDs.append(statistics.mean(DPD_df.loc[labels, DPD_val]))
            if (len(labels) > 1):
                DPD_errs.append(scipy.stats.sem(DPD_df.loc[labels, DPD_val]))
            else:
                DPD_errs.append(0)
        plt.errorbar(doses, DPDs, yerr = DPD_errs, fmt = "o-", label = drug, capsize = 5)
    plt.legend()
    plt.plot([0,10], [0,0], "--", color = "black")
    plt.xlabel("Dose, uM")
    plt.ylabel("DPD_" + DPD_val)
    plt.title("Target: " + target_name)
    plt.savefig(os.path.join(out_dir, target_name + "_DPD_" + DPD_val + ".png"), dpi = 300)

# %%
print_drugs += target_drugs

# %% [markdown]
# ### PTGS

# %%
target = "PTGS"
drugs = sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.targets.str.contains(target)].pert_drug)))

print("drugs for target " + target + ":" , len(drugs), drugs)
# Out:
# drugs for target PTGS: 19 ['aminosalicylic-acid', 'amtolmetin-guacil', 'balsalazide', 'celecoxib', 'epirizole', 'etofenamate', 'indometacin', 'indoprofen', 'ketorolac', 'meloxicam', 'metamizole', 'naproxen', 'nepafenac', 'nimesulide', 'paracetamol', 'piroxicam', 'resveratrol', 'sasapyrine', 'voriconazole']

# %%
drugs_list = drugs

targets = []
doses = []

for drug in drugs_list:
    targets.append(", ".join(sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].targets)))))
    doses.append(", ".join(sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].dose)))))
    
target_drugs_df = pd.DataFrame(list(zip(targets, doses)), index = drugs_list, columns = ["targets","doses"])

display(target_drugs_df)
# Out:
#                                                     targets  \
# aminosalicylic-acid                            PTGS1, PTGS2
# amtolmetin-guacil                              PTGS1, PTGS2
# balsalazide                                    PTGS1, PTGS2
# celecoxib                                             PTGS2
# epirizole                                      PTGS1, PTGS2
# etofenamate                                    PTGS1, PTGS2
# indometacin                     PPARG, PTGDR2, PTGS1, PTGS2
# indoprofen                                     PTGS1, PTGS2
# ketorolac                                      PTGS1, PTGS2
# meloxicam                                      PTGS1, PTGS2
# metamizole                                            PTGS1
# naproxen                                       PTGS1, PTGS2
# nepafenac                                      PTGS1, PTGS2
# nimesulide                                       LTF, PTGS2
# paracetamol                                    PTGS1, PTGS2
# piroxicam                                      PTGS1, PTGS2
# resveratrol                             PTGS1, PTGS2, SIRT1
# sasapyrine                                            PTGS1
# voriconazole         CYP2C19, CYP2C9, CYP3A4, CYP3A5, PTGS1
#
#                                                                  doses
# aminosalicylic-acid  0.01 uM, 0.03 uM, 0.04 uM, 0.08 uM, 0.125 uM, ...
# amtolmetin-guacil    0.01 uM, 0.03 uM, 0.08 uM, 0.25 uM, 0.74 uM, 2...
# balsalazide          0.01 uM, 0.03 uM, 0.04 uM, 0.08 uM, 0.125 uM, ...
# celecoxib            0.01 uM, 0.03 uM, 0.08 uM, 0.25 uM, 0.74 uM, 2...
# epirizole            0.01 uM, 0.03 uM, 0.04 uM, 0.08 uM, 0.125 uM, ...
# etofenamate          0.01 uM, 0.03 uM, 0.08 uM, 0.25 uM, 0.74 uM, 2...
# indometacin                  0.04 uM, 0.37 uM, 1.11 uM, 10 uM, 3.33 uM
# indoprofen           0.01 uM, 0.03 uM, 0.04 uM, 0.08 uM, 0.125 uM, ...
# ketorolac            0.01 uM, 0.03 uM, 0.08 uM, 0.125 uM, 0.25 uM, ...
# meloxicam            0.01 uM, 0.03 uM, 0.04 uM, 0.08 uM, 0.125 uM, ...
# metamizole           0.01 uM, 0.03 uM, 0.08 uM, 0.25 uM, 0.74 uM, 2...
# naproxen             0.04 uM, 0.125 uM, 0.37 uM, 1.11 uM, 10 uM, 3....
# nepafenac            0.01 uM, 0.03 uM, 0.04 uM, 0.08 uM, 0.125 uM, ...
# nimesulide           0.01 uM, 0.03 uM, 0.08 uM, 0.25 uM, 0.74 uM, 2...
# paracetamol          0.01 uM, 0.03 uM, 0.08 uM, 0.25 uM, 0.37 uM, 0...
# piroxicam            0.04 uM, 0.125 uM, 0.37 uM, 1.11 uM, 10 uM, 3....
# resveratrol          0.04 uM, 0.12 uM, 0.37 uM, 1.11 uM, 10 uM, 3.3...
# sasapyrine           0.01 uM, 0.03 uM, 0.04 uM, 0.08 uM, 0.125 uM, ...
# voriconazole         0.01 uM, 0.03 uM, 0.04 uM, 0.08 uM, 0.125 uM, ...

# %%
target_name = "PTGS"
target_drugs = drugs_list

for DPD_val in states:
    plt.figure(figsize = (9,8))
    for drug in target_drugs:
        doses = sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].dose_float)))
        DPDs = []
        DPD_errs = []
        for dose in doses:
            labels = sig_info_cell_df.loc[(sig_info_cell_df.pert_drug == drug) & (sig_info_cell_df.dose_float == dose)].index
            DPDs.append(statistics.mean(DPD_df.loc[labels, DPD_val]))
            if (len(labels) > 1):
                DPD_errs.append(scipy.stats.sem(DPD_df.loc[labels, DPD_val]))
            else:
                DPD_errs.append(0)
        plt.errorbar(doses, DPDs, yerr = DPD_errs, fmt = "o-", label = drug, capsize = 5)
    plt.legend()
    plt.plot([0,10], [0,0], "--", color = "black")
    plt.xlabel("Dose, uM")
    plt.ylabel("DPD_" + DPD_val)
    plt.title("Target: " + target_name)
    plt.savefig(os.path.join(out_dir, target_name + "_DPD_" + DPD_val + ".png"), dpi = 300)

# %%
# delete module "PTGS"

# %% [markdown]
# ### PSMB

# %%
target = "PSMB"
drugs = sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.targets.str.contains(target)].pert_drug)))

print("drugs for target " + target + ":" , len(drugs), drugs)
# Out:
# drugs for target PSMB: 3 ['MG-132', 'bortezomib', 'ixazomib']

# %%
drugs_list = drugs

targets = []
doses = []

for drug in drugs_list:
    targets.append(", ".join(sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].targets)))))
    doses.append(", ".join(sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].dose)))))
    
target_drugs_df = pd.DataFrame(list(zip(targets, doses)), index = drugs_list, columns = ["targets","doses"])

display(target_drugs_df)
# Out:
#                         targets  \
# MG-132                    PSMB1
# bortezomib  PSMB1, PSMB2, PSMB5
# ixazomib                  PSMB1
#
#                                                         doses
# MG-132                                                  20 uM
# bortezomib  0.04 uM, 0.125 uM, 0.37 uM, 1.11 uM, 10 uM, 20...
# ixazomib                   0.01 uM, 0.03 uM, 0.08 uM, 0.25 uM

# %%
target_name = "PSMB"
target_drugs = drugs_list

for DPD_val in states:
    plt.figure(figsize = (9,8))
    for drug in target_drugs:
        doses = sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].dose_float)))
        DPDs = []
        DPD_errs = []
        for dose in doses:
            labels = sig_info_cell_df.loc[(sig_info_cell_df.pert_drug == drug) & (sig_info_cell_df.dose_float == dose)].index
            DPDs.append(statistics.mean(DPD_df.loc[labels, DPD_val]))
            if (len(labels) > 1):
                DPD_errs.append(scipy.stats.sem(DPD_df.loc[labels, DPD_val]))
            else:
                DPD_errs.append(0)
        plt.errorbar(doses, DPDs, yerr = DPD_errs, fmt = "o-", label = drug, capsize = 5)
    plt.legend()
    plt.plot([0,20], [0,0], "--", color = "black")
    plt.xlabel("Dose, uM")
    plt.ylabel("DPD_" + DPD_val)
    plt.title("Target: " + target_name)
    plt.savefig(os.path.join(out_dir, target_name + "_DPD_" + DPD_val + ".png"), dpi = 300)

# %%
print_drugs += target_drugs

# %% [markdown]
# ### GPBAR

# %%
target = "GPBAR"
drugs = sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.targets.str.contains(target)].pert_drug)))

print("drugs for target " + target + ":" , len(drugs), drugs)
# Out:
# drugs for target GPBAR: 1 ['betulinic-acid']

# %%
drugs_list = drugs

targets = []
doses = []

for drug in drugs_list:
    targets.append(", ".join(sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].targets)))))
    doses.append(", ".join(sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].dose)))))
    
target_drugs_df = pd.DataFrame(list(zip(targets, doses)), index = drugs_list, columns = ["targets","doses"])

display(target_drugs_df)
# Out:
#                targets                                              doses
# betulinic-acid  GPBAR1  0.01 uM, 0.03 uM, 0.04 uM, 0.08 uM, 0.125 uM, ...

# %%
target_name = "GPBAR"
target_drugs = drugs_list

for DPD_val in states:
    plt.figure(figsize = (9,8))
    for drug in target_drugs:
        doses = sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].dose_float)))
        DPDs = []
        DPD_errs = []
        for dose in doses:
            labels = sig_info_cell_df.loc[(sig_info_cell_df.pert_drug == drug) & (sig_info_cell_df.dose_float == dose)].index
            DPDs.append(statistics.mean(DPD_df.loc[labels, DPD_val]))
            if (len(labels) > 1):
                DPD_errs.append(scipy.stats.sem(DPD_df.loc[labels, DPD_val]))
            else:
                DPD_errs.append(0)
        plt.errorbar(doses, DPDs, yerr = DPD_errs, fmt = "o-", label = drug, capsize = 5)
    plt.legend()
    plt.plot([0,10], [0,0], "--", color = "black")
    plt.xlabel("Dose, uM")
    plt.ylabel("DPD_" + DPD_val)
    plt.title("Target: " + target_name)
    plt.savefig(os.path.join(out_dir, target_name + "_DPD_" + DPD_val + ".png"), dpi = 300)

# %%
# delete module "GPBAR"

# %% [markdown]
# ### PPARG

# %%
target = "PPARG"
drugs = sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.targets.str.contains(target)].pert_drug)))

print("drugs for target " + target + ":" , len(drugs), drugs)
# Out:
# drugs for target PPARG: 6 ['balaglitazone', 'bezafibrate', 'ciglitazone', 'indometacin', 'mifobate', 'rosiglitazone']

# %%
drugs_list = drugs

targets = []
doses = []

for drug in drugs_list:
    targets.append(", ".join(sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].targets)))))
    doses.append(", ".join(sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].dose)))))
    
target_drugs_df = pd.DataFrame(list(zip(targets, doses)), index = drugs_list, columns = ["targets","doses"])

display(target_drugs_df)
# Out:
#                                    targets  \
# balaglitazone                        PPARG
# bezafibrate            PPARA, PPARD, PPARG
# ciglitazone                          PPARG
# indometacin    PPARG, PTGDR2, PTGS1, PTGS2
# mifobate                             PPARG
# rosiglitazone                        PPARG
#
#                                                            doses
# balaglitazone  0.01 uM, 0.03 uM, 0.08 uM, 0.25 uM, 0.74 uM, 2...
# bezafibrate    0.01 uM, 0.03 uM, 0.04 uM, 0.08 uM, 0.125 uM, ...
# ciglitazone    0.04 uM, 0.125 uM, 0.37 uM, 1.11 uM, 10 uM, 3....
# indometacin            0.04 uM, 0.37 uM, 1.11 uM, 10 uM, 3.33 uM
# mifobate       0.01 uM, 0.03 uM, 0.08 uM, 0.25 uM, 0.74 uM, 2...
# rosiglitazone  0.04 uM, 0.125 uM, 0.37 uM, 1.11 uM, 10 uM, 3....

# %%
target_name = "PPARG"
target_drugs = drugs_list

for DPD_val in states:
    plt.figure(figsize = (9,8))
    for drug in target_drugs:
        doses = sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].dose_float)))
        DPDs = []
        DPD_errs = []
        for dose in doses:
            labels = sig_info_cell_df.loc[(sig_info_cell_df.pert_drug == drug) & (sig_info_cell_df.dose_float == dose)].index
            DPDs.append(statistics.mean(DPD_df.loc[labels, DPD_val]))
            if (len(labels) > 1):
                DPD_errs.append(scipy.stats.sem(DPD_df.loc[labels, DPD_val]))
            else:
                DPD_errs.append(0)
        plt.errorbar(doses, DPDs, yerr = DPD_errs, fmt = "o-", label = drug, capsize = 5)
    plt.legend()
    plt.plot([0,10], [0,0], "--", color = "black")
    plt.xlabel("Dose, uM")
    plt.ylabel("DPD_" + DPD_val)
    plt.title("Target: " + target_name)
    plt.savefig(os.path.join(out_dir, target_name + "_DPD_" + DPD_val + ".png"), dpi = 300)

# %%
# delete module "PPARG"

# %%
print(print_drugs)

print_drugs_df = pd.DataFrame(print_drugs)
display(print_drugs_df)

print_drugs_df.to_excel("drugs.xlsx")
# Out:
# ['CGP-60474', 'dinaciclib', 'PHA-767491', 'roscovitine', 'PF-03758309', 'PF-04691502', 'XL-147', 'GSK-2334470', 'A-66', 'BGT-226', 'BX-795', 'AZ-628', 'FR-180204', 'GDC-0879', 'GW-5074', 'PD-0325901', 'PD-184352', 'TAK-733', 'dabrafenib', 'refametinib', 'RAF-265', 'I-BET-762', 'I-BET-151', 'JQ-1-R', 'PFI-1', 'GSK-1070916', 'MLN-8054', 'ZM-447439', 'alisertib', 'SB-525334', 'rebastinib', 'lenvatinib', 'orantinib', 'foretinib', 'cediranib', 'sunitinib', 'tivozanib', 'enzastaurin', 'MG-132', 'bortezomib', 'ixazomib']
#               0
# 0     CGP-60474
# 1    dinaciclib
# 2    PHA-767491
# 3   roscovitine
# 4   PF-03758309
# 5   PF-04691502
# 6        XL-147
# 7   GSK-2334470
# 8          A-66
# 9       BGT-226
# 10       BX-795
# 11       AZ-628
# 12    FR-180204
# 13     GDC-0879
# 14      GW-5074
# 15   PD-0325901
# 16    PD-184352
# 17      TAK-733
# 18   dabrafenib
# 19  refametinib
# 20      RAF-265
# 21    I-BET-762
# 22    I-BET-151
# 23       JQ-1-R
# 24        PFI-1
# 25  GSK-1070916
# 26     MLN-8054
# 27    ZM-447439
# 28    alisertib
# 29    SB-525334
# 30   rebastinib
# 31   lenvatinib
# 32    orantinib
# 33    foretinib
# 34    cediranib
# 35    sunitinib
# 36    tivozanib
# 37  enzastaurin
# 38       MG-132
# 39   bortezomib
# 40     ixazomib
