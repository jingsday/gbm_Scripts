# %%
import os
import pandas as pd
import numpy as np

import pylab as plt
import statistics
import scipy.stats

# %%
task='Jing'
data_year = "2020"
cell_name='GI1'

data_dir = "/home/jing/Phd_project/project_GBM/gbm_OUTPUT/gbm_OUTPUT_LINCS/"

out_dir = "00_plots_" + data_year + "_" + cell_name + "_" 
#os.makedirs(out_dir, exist_ok = True)

# %% [markdown]
# ## Data_norm

# %%
data_file = os.path.join(data_dir, "Data_norm_" + data_year + "_" + cell_name+ ".xlsx")
Data_norm=pd.read_excel(data_file,index_col=0)
display(Data_norm)

genes_list = Data_norm.columns.to_list()
print("Landmark genes in LINCS data:", len(genes_list), genes_list)

exp_id_list = Data_norm.index.to_list()
print("Experiments in LINCS data for " + cell_name + " cells:", len(exp_id_list), exp_id_list)
# Out:
#                          AARS     ABCB6     ABCC5     ABCF1     ABCF3  \
# ASG002_GI1_24H:A03   0.014285  0.302692  0.124004  0.005246  0.340042
# ASG002_GI1_24H:A04   0.084985  0.276642  0.324054 -0.016954  0.079942
# ASG002_GI1_24H:A05  -0.019615  0.183842  0.282254 -0.577354  0.316943
# ASG002_GI1_24H:A06   0.324884  0.146642  0.192004  0.043446  0.141842
# ASG002_GI1_24H:J13   0.182484  0.060892 -0.044696 -0.346554 -0.158858
# ...                       ...       ...       ...       ...       ...
# MOAR012_GI1_24H:P20  0.844125  0.359950  0.014575  0.002151  0.108225
# MOAR012_GI1_24H:P21  0.346174  0.102800 -0.449275 -0.206150  0.500625
# MOAR012_GI1_24H:P22  0.195774  0.285975 -0.675725 -0.243999  0.197526
# MOAR012_GI1_24H:P23  0.093424  0.179075 -0.400900 -0.337299  0.084625
# MOAR012_GI1_24H:P24 -0.471975 -0.503550 -0.028525 -0.379799  0.419825
#
#                         ABHD4     ABHD6      ABL1     ACAA1     ACAT2  ...  \
# ASG002_GI1_24H:A03   0.276465  0.127250  0.328650  0.627212 -0.220684  ...
# ASG002_GI1_24H:A04   0.155465 -0.100200  0.345250  0.183511 -0.080484  ...
# ASG002_GI1_24H:A05   0.109765  0.117800  0.301150 -0.187188  0.275415  ...
# ASG002_GI1_24H:A06  -0.053335 -0.028000 -0.580550  0.622812 -0.080985  ...
# ASG002_GI1_24H:J13  -0.031434  0.068500  0.372950 -0.366439 -0.176334  ...
# ...                       ...       ...       ...       ...       ...  ...
# MOAR012_GI1_24H:P20 -0.232287  0.331775  0.190337 -0.644337 -0.320262  ...
# MOAR012_GI1_24H:P21 -0.383837  0.456875  0.125388 -0.490437 -0.240913  ...
# MOAR012_GI1_24H:P22  0.238638 -0.013250 -0.236763 -0.761688 -0.048863  ...
# MOAR012_GI1_24H:P23 -0.015337 -0.073375 -0.276812  0.107612  0.054488  ...
# MOAR012_GI1_24H:P24 -0.197888  0.481525 -0.420913 -0.394637  0.108887  ...
#
#                         ZMIZ1     ZMYM2    ZNF131    ZNF274    ZNF318  \
# ASG002_GI1_24H:A03  -0.102669  0.893785  0.505962 -0.357469  0.517504
# ASG002_GI1_24H:A04  -0.057569 -0.443416  0.094212 -0.303270  0.271754
# ASG002_GI1_24H:A05   0.082731 -0.124365  0.141711 -0.221269  0.206753
# ASG002_GI1_24H:A06   0.246530  0.644485  0.082212 -0.069869  0.142254
# ASG002_GI1_24H:J13  -0.204769 -0.254016  0.310211 -0.177470 -0.026896
# ...                       ...       ...       ...       ...       ...
# MOAR012_GI1_24H:P20 -0.223550  0.344850 -0.421962 -0.379925  0.154400
# MOAR012_GI1_24H:P21 -0.271100 -0.497100 -0.194638 -0.082924 -0.450300
# MOAR012_GI1_24H:P22 -0.190250 -0.331850 -0.556237 -0.161175 -0.274225
# MOAR012_GI1_24H:P23  0.203775 -0.216850 -1.163637 -0.258825 -0.483600
# MOAR012_GI1_24H:P24  0.054900 -0.138650 -0.099087 -0.057925  0.068699
#
#                        ZNF395    ZNF451    ZNF586    ZNF589      ZW10
# ASG002_GI1_24H:A03   0.255096  0.008023 -0.144581 -0.187158 -0.225612
# ASG002_GI1_24H:A04  -0.176304 -0.028377  0.017819 -0.187858 -0.157212
# ASG002_GI1_24H:A05   0.215946  0.000723  0.130619 -0.080258  0.012289
# ASG002_GI1_24H:A06   0.576146  0.092923 -0.041681 -0.253158 -0.221112
# ASG002_GI1_24H:J13   0.068946  0.070023 -0.011181 -0.366158  0.121888
# ...                       ...       ...       ...       ...       ...
# MOAR012_GI1_24H:P20  0.031300 -0.095100 -0.317588  0.103650  1.095600
# MOAR012_GI1_24H:P21 -0.088776  0.427825 -0.431062 -0.064025  1.196051
# MOAR012_GI1_24H:P22  0.178549  0.110350  0.389612  0.043350  1.345251
# MOAR012_GI1_24H:P23  0.067650  0.465775  0.345462  1.912200  1.386475
# MOAR012_GI1_24H:P24 -0.361300  0.363325 -0.004938  0.026675  1.221100
#
# [2151 rows x 978 columns]
# Landmark genes in LINCS data: 978 ['AARS', 'ABCB6', 'ABCC5', 'ABCF1', 'ABCF3', 'ABHD4', 'ABHD6', 'ABL1', 'ACAA1', 'ACAT2', 'ACBD3', 'ACD', 'ACLY', 'ACOT9', 'ADAM10', 'ADAT1', 'ADGRE5', 'ADGRG1', 'ADH5', 'ADI1', 'ADO', 'ADRB2', 'AGL', 'AKAP8', 'AKAP8L', 'AKR7A2', 'AKT1', 'ALAS1', 'ALDH7A1', 'ALDOA', 'ALDOC', 'AMDHD2', 'ANKRD10', 'ANO10', 'ANXA7', 'APBB2', 'APOE', 'APP', 'APPBP2', 'ARFIP2', 'ARHGAP1', 'ARHGEF12', 'ARHGEF2', 'ARID4B', 'ARID5B', 'ARL4C', 'ARNT2', 'ARPP19', 'ASAH1', 'ASCC3', 'ATF1', 'ATF5', 'ATF6', 'ATG3', 'ATMIN', 'ATP11B', 'ATP1B1', 'ATP2C1', 'ATP6V0B', 'ATP6V1D', 'AURKA', 'AURKB', 'AXIN1', 'B4GAT1', 'BACE2', 'BAD', 'BAG3', 'BAMBI', 'BAX', 'BCL2', 'BCL7B', 'BDH1', 'BECN1', 'BHLHE40', 'BID', 'BIRC2', 'BIRC5', 'BLCAP', 'BLMH', 'BLVRA', 'BMP4', 'BNIP3', 'BNIP3L', 'BPHL', 'BRCA1', 'BTK', 'BUB1B', 'BZW2', 'C2CD2', 'C2CD2L', 'C2CD5', 'C5', 'CAB39', 'CALM3', 'CALU', 'CAMSAP2', 'CANT1', 'CAPN1', 'CARMIL1', 'CASC3', 'CASK', 'CASP10', 'CASP2', 'CASP3', 'CASP7', 'CAST', 'CAT', 'CBLB', 'CBR1', 'CBR3', 'CCDC85B', 'CCDC86', 'CCDC92', 'CCL2', 'CCNA1', 'CCNA2', 'CCNB1', 'CCNB2', 'CCND1', 'CCND3', 'CCNE2', 'CCNF', 'CCNH', 'CCP110', 'CD320', 'CD40', 'CD44', 'CD58', 'CDC20', 'CDC25A', 'CDC25B', 'CDC42', 'CDC45', 'CDCA4', 'CDH3', 'CDK1', 'CDK19', 'CDK2', 'CDK4', 'CDK5R1', 'CDK6', 'CDK7', 'CDKN1A', 'CDKN1B', 'CDKN2A', 'CEBPA', 'CEBPD', 'CEBPZ', 'CEMIP2', 'CENPE', 'CEP57', 'CERK', 'CETN3', 'CFLAR', 'CGRRF1', 'CHAC1', 'CHEK1', 'CHEK2', 'CHERP', 'CHIC2', 'CHMP4A', 'CHMP6', 'CHN1', 'CHP1', 'CIAO3', 'CIAPIN1', 'CIRBP', 'CISD1', 'CLIC4', 'CLPX', 'CLSTN1', 'CLTB', 'CLTC', 'CNDP2', 'CNOT4', 'CNPY3', 'COASY', 'COG2', 'COG4', 'COG7', 'COL1A1', 'COL4A1', 'COPB2', 'COPS7A', 'COQ8A', 'CORO1A', 'CPNE3', 'CPSF4', 'CREB1', 'CREG1', 'CRELD2', 'CRK', 'CRKL', 'CRTAP', 'CRYZ', 'CSK', 'CSNK1A1', 'CSNK1E', 'CSNK2A2', 'CSRP1', 'CTNNAL1', 'CTNND1', 'CTSD', 'CTSL', 'CTTN', 'CXCL2', 'CXCR4', 'CYB561', 'CYCS', 'CYTH1', 'DAG1', 'DAXX', 'DCK', 'DCTD', 'DCUN1D4', 'DDB2', 'DDIT4', 'DDR1', 'DDX10', 'DDX42', 'DECR1', 'DENND2D', 'DERA', 'DFFA', 'DFFB', 'DHDDS', 'DHRS7', 'DHX29', 'DIPK1A', 'DLD', 'DMAC2L', 'DMTF1', 'DNAJA3', 'DNAJB1', 'DNAJB2', 'DNAJB6', 'DNAJC15', 'DNM1', 'DNM1L', 'DNMT1', 'DNMT3A', 'DNTTIP2', 'DPH2', 'DRAP1', 'DSG2', 'DUSP11', 'DUSP14', 'DUSP22', 'DUSP3', 'DUSP4', 'DUSP6', 'DYNLT3', 'DYRK3', 'E2F2', 'EAPP', 'EBNA1BP2', 'EBP', 'ECD', 'ECH1', 'EDEM1', 'EDN1', 'EED', 'EFCAB14', 'EGF', 'EGFR', 'EGR1', 'EIF4EBP1', 'EIF4G1', 'EIF5', 'ELAC2', 'ELAVL1', 'ELOVL6', 'ELP1', 'EML3', 'ENOPH1', 'ENOSF1', 'EPB41L2', 'EPHA3', 'EPHB2', 'EPN2', 'EPRS', 'ERBB2', 'ERBB3', 'ERO1A', 'ETFB', 'ETS1', 'ETV1', 'EVL', 'EXOSC4', 'EXT1', 'EZH2', 'FAH', 'FAIM', 'FAM20B', 'FAM57A', 'FAS', 'FASTKD5', 'FAT1', 'FBXL12', 'FBXO11', 'FBXO21', 'FBXO7', 'FCHO1', 'FDFT1', 'FEZ2', 'FGFR2', 'FGFR4', 'FHL2', 'FIS1', 'FKBP14', 'FKBP4', 'FOS', 'FOSL1', 'FOXJ3', 'FOXO3', 'FOXO4', 'FPGS', 'FRS2', 'FSD1', 'FUT1', 'FYN', 'FZD1', 'FZD7', 'G3BP1', 'GAA', 'GABPB1', 'GADD45A', 'GADD45B', 'GALE', 'GAPDH', 'GATA2', 'GATA3', 'GDPD5', 'GFOD1', 'GFPT1', 'GHR', 'GLI2', 'GLOD4', 'GLRX', 'GMNN', 'GNA11', 'GNA15', 'GNAI1', 'GNAI2', 'GNAS', 'GNB5', 'GNPDA1', 'GOLT1B', 'GPATCH8', 'GPC1', 'GPER1', 'GRB10', 'GRB7', 'GRN', 'GRWD1', 'GSTM2', 'GSTZ1', 'GTF2A2', 'GTF2E2', 'GTPBP8', 'H2AFV', 'HACD3', 'HADH', 'HAT1', 'HDAC2', 'HDAC6', 'HDGFL3', 'HEATR1', 'HEBP1', 'HERC6', 'HERPUD1', 'HES1', 'HIF1A', 'HIST1H2BK', 'HIST2H2BE', 'HK1', 'HLA-DMA', 'HLA-DRA', 'HMG20B', 'HMGA2', 'HMGCR', 'HMGCS1', 'HMOX1', 'HOMER2', 'HOOK2', 'HOXA10', 'HOXA5', 'HPRT1', 'HS2ST1', 'HSD17B10', 'HSD17B11', 'HSPA1A', 'HSPA4', 'HSPA8', 'HSPB1', 'HSPD1', 'HTATSF1', 'HTRA1', 'HYOU1', 'IARS2', 'ICAM1', 'ICAM3', 'ICMT', 'ID2', 'IDE', 'IER3', 'IFNAR1', 'IFRD2', 'IGF1R', 'IGF2BP2', 'IGF2R', 'IGFBP3', 'IGHMBP2', 'IKBKB', 'IKBKE', 'IKZF1', 'IL13RA1', 'IL1B', 'IL4R', 'ILK', 'INPP1', 'INPP4B', 'INSIG1', 'INTS3', 'IPO13', 'IQGAP1', 'ISOC1', 'ITFG1', 'ITGAE', 'ITGB1BP1', 'ITGB5', 'JADE2', 'JMJD6', 'JPT2', 'JUN', 'KAT6A', 'KAT6B', 'KCNK1', 'KCTD5', 'KDELR2', 'KD ...
# Experiments in LINCS data for GI1 cells: 2151 ['ASG002_GI1_24H:A03', 'ASG002_GI1_24H:A04', 'ASG002_GI1_24H:A05', 'ASG002_GI1_24H:A06', 'ASG002_GI1_24H:J13', 'ASG002_GI1_24H:J14', 'ASG002_GI1_24H:J15', 'ASG002_GI1_24H:J16', 'ASG002_GI1_24H:J17', 'ASG002_GI1_24H:J18', 'ASG002_GI1_24H:O04', 'ASG002_GI1_24H:O05', 'ASG002_GI1_24H:O06', 'MOAR008_GI1_24H:A03', 'MOAR008_GI1_24H:B03', 'MOAR009_GI1_24H:B03', 'MOAR010_GI1_24H:A03', 'MOAR010_GI1_24H:B03', 'MOAR010_GI1_24H:C22', 'MOAR010_GI1_24H:C23', 'MOAR010_GI1_24H:C24', 'MOAR010_GI1_24H:G16', 'MOAR010_GI1_24H:G17', 'MOAR010_GI1_24H:G18', 'MOAR010_GI1_24H:K10', 'MOAR010_GI1_24H:K11', 'MOAR010_GI1_24H:K12', 'MOAR010_GI1_24H:O04', 'MOAR010_GI1_24H:O05', 'MOAR010_GI1_24H:O06', 'MOAR011_GI1_24H:A03', 'MOAR011_GI1_24H:B03', 'MOAR012_GI1_24H:A03', 'MOAR012_GI1_24H:B03', 'ASG002_GI1_24H:A07', 'ASG002_GI1_24H:A08', 'ASG002_GI1_24H:A09', 'ASG002_GI1_24H:A10', 'ASG002_GI1_24H:A11', 'ASG002_GI1_24H:A12', 'ASG002_GI1_24H:A15', 'ASG002_GI1_24H:A16', 'ASG002_GI1_24H:A17', 'ASG002_GI1_24H:A18', 'ASG002_GI1_24H:A19', 'ASG002_GI1_24H:A20', 'ASG002_GI1_24H:A21', 'ASG002_GI1_24H:A22', 'ASG002_GI1_24H:A23', 'ASG002_GI1_24H:A24', 'ASG002_GI1_24H:B03', 'ASG002_GI1_24H:B04', 'ASG002_GI1_24H:B05', 'ASG002_GI1_24H:B06', 'ASG002_GI1_24H:B07', 'ASG002_GI1_24H:B08', 'ASG002_GI1_24H:B09', 'ASG002_GI1_24H:B10', 'ASG002_GI1_24H:B11', 'ASG002_GI1_24H:B12', 'ASG002_GI1_24H:B13', 'ASG002_GI1_24H:B15', 'ASG002_GI1_24H:B16', 'ASG002_GI1_24H:B17', 'ASG002_GI1_24H:B19', 'ASG002_GI1_24H:B20', 'ASG002_GI1_24H:B21', 'ASG002_GI1_24H:B22', 'ASG002_GI1_24H:B23', 'ASG002_GI1_24H:B24', 'ASG002_GI1_24H:C01', 'ASG002_GI1_24H:C02', 'ASG002_GI1_24H:C03', 'ASG002_GI1_24H:C04', 'ASG002_GI1_24H:C05', 'ASG002_GI1_24H:C06', 'ASG002_GI1_24H:C07', 'ASG002_GI1_24H:C08', 'ASG002_GI1_24H:C09', 'ASG002_GI1_24H:C10', 'ASG002_GI1_24H:C11', 'ASG002_GI1_24H:C12', 'ASG002_GI1_24H:C13', 'ASG002_GI1_24H:C14', 'ASG002_GI1_24H:C15', 'ASG002_GI1_24H:C16', 'ASG002_GI1_24H:C17', 'ASG002_GI1_24H:D01', 'ASG002_GI1_24H:D02', 'ASG002_GI1_24H:D03', 'ASG002_GI1_24H:D04', 'ASG002_GI1_24H:D05', 'ASG002_GI1_24H:D06', 'ASG002_GI1_24H:D07', 'ASG002_GI1_24H:D08', 'ASG002_GI1_24H:D09', 'ASG002_GI1_24H:D10', 'ASG002_GI1_24H:D11', 'ASG002_GI1_24H:D12', 'ASG002_GI1_24H:D15', 'ASG002_GI1_24H:D16', 'ASG002_GI1_24H:D17', 'ASG002_GI1_24H:D18', 'ASG002_GI1_24H:D19', 'ASG002_GI1_24H:D20', 'ASG002_GI1_24H:D21', 'ASG002_GI1_24H:D22', 'ASG002_GI1_24H:D23', 'ASG002_GI1_24H:D24', 'ASG002_GI1_24H:E01', 'ASG002_GI1_24H:E02', 'ASG002_GI1_24H:E03', 'ASG002_GI1_24H:E04', 'ASG002_GI1_24H:E05', 'ASG002_GI1_24H:E06', 'ASG002_GI1_24H:E08', 'ASG002_GI1_24H:E09', 'ASG002_GI1_24H:E10', 'ASG002_GI1_24H:E11', 'ASG002_GI1_24H:E13', 'ASG002_GI1_24H:E14', 'ASG002_GI1_24H:E15', 'ASG002_GI1_24H:E16', 'ASG002_GI1_24H:E17', 'ASG002_GI1_24H:E18', 'ASG002_GI1_24H:E19', 'ASG002_GI1_24H:E20', 'ASG002_GI1_24H:E21', 'ASG002_GI1_24H:E22', 'ASG002_GI1_24H:E23', 'ASG002_GI1_24H:E24', 'ASG002_GI1_24H:F01', 'ASG002_GI1_24H:F02', 'ASG002_GI1_24H:F03', 'ASG002_GI1_24H:F04', 'ASG002_GI1_24H:F05', 'ASG002_GI1_24H:F06', 'ASG002_GI1_24H:F07', 'ASG002_GI1_24H:F08', 'ASG002_GI1_24H:F09', 'ASG002_GI1_24H:F10', 'ASG002_GI1_24H:F14', 'ASG002_GI1_24H:F15', 'ASG002_GI1_24H:F16', 'ASG002_GI1_24H:F17', 'ASG002_GI1_24H:F19', 'ASG002_GI1_24H:F20', 'ASG002_GI1_24H:F21', 'ASG002_GI1_24H:F22', 'ASG002_GI1_24H:F23', 'ASG002_GI1_24H:F24', 'ASG002_GI1_24H:G02', 'ASG002_GI1_24H:G03', 'ASG002_GI1_24H:G04', 'ASG002_GI1_24H:G05', 'ASG002_GI1_24H:G06', 'ASG002_GI1_24H:G07', 'ASG002_GI1_24H:G09', 'ASG002_GI1_24H:G10', 'ASG002_GI1_24H:G11', 'ASG002_GI1_24H:G12', 'ASG002_GI1_24H:G13', 'ASG002_GI1_24H:G14', 'ASG002_GI1_24H:G15', 'ASG002_GI1_24H:G16', 'ASG002_GI1_24H:G17', 'ASG002_GI1_24H:G18', 'ASG002_GI1_24H:G19', 'ASG002_GI1_24H:G20', 'ASG002_GI1_24H:G21', 'ASG002_GI1_24H:G22', 'ASG002_GI1_24H:G23', 'ASG002_GI1_24H:G24', 'ASG002_GI1_24H:H01', 'ASG002_GI1_24H:H02', 'ASG002_GI1_24H:H03', 'ASG002_GI1_24H:H04', 'ASG002_GI1_24H:H05', 'ASG002_GI1_24H: ...

# %% [markdown]
# ## Sig_info

# %%
data_file = os.path.join(data_dir, "sig_info_" + data_year + "_" + cell_name+ ".xlsx")
sig_info_cell_df = pd.read_excel(data_file, index_col = 0).fillna("")
display(sig_info_cell_df)
# Out:
#                     cell    plate  time             level_3_samples  \
# level_5_sig_id
# ASG002_GI1_24H:A03   GI1   ASG002  24 h   ASG002_GI1_24H_X1_B35:A03
# ASG002_GI1_24H:A04   GI1   ASG002  24 h   ASG002_GI1_24H_X1_B35:A04
# ASG002_GI1_24H:A05   GI1   ASG002  24 h   ASG002_GI1_24H_X1_B35:A05
# ASG002_GI1_24H:A06   GI1   ASG002  24 h   ASG002_GI1_24H_X1_B35:A06
# ASG002_GI1_24H:J13   GI1   ASG002  24 h   ASG002_GI1_24H_X1_B35:J13
# ...                  ...      ...   ...                         ...
# MOAR012_GI1_24H:P20  GI1  MOAR012  24 h  MOAR012_GI1_24H_X1_B36:P20
# MOAR012_GI1_24H:P21  GI1  MOAR012  24 h  MOAR012_GI1_24H_X1_B36:P21
# MOAR012_GI1_24H:P22  GI1  MOAR012  24 h  MOAR012_GI1_24H_X1_B36:P22
# MOAR012_GI1_24H:P23  GI1  MOAR012  24 h  MOAR012_GI1_24H_X1_B36:P23
# MOAR012_GI1_24H:P24  GI1  MOAR012  24 h  MOAR012_GI1_24H_X1_B36:P24
#
#                      samples_number    pert_type    pert_drug         targets  \
# level_5_sig_id
# ASG002_GI1_24H:A03                1  ctl_vehicle         DMSO  DMSO_No_target
# ASG002_GI1_24H:A04                1  ctl_vehicle         DMSO  DMSO_No_target
# ASG002_GI1_24H:A05                1  ctl_vehicle         DMSO  DMSO_No_target
# ASG002_GI1_24H:A06                1  ctl_vehicle         DMSO  DMSO_No_target
# ASG002_GI1_24H:J13                1  ctl_vehicle         DMSO  DMSO_No_target
# ...                             ...          ...          ...             ...
# MOAR012_GI1_24H:P20               1       trt_cp  BAY-61-3606
# MOAR012_GI1_24H:P21               1       trt_cp  BAY-61-3606
# MOAR012_GI1_24H:P22               1       trt_cp   ethaverine
# MOAR012_GI1_24H:P23               1       trt_cp   ethaverine
# MOAR012_GI1_24H:P24               1       trt_cp   ethaverine
#
#                      targets_number     dose  dose_float
# level_5_sig_id
# ASG002_GI1_24H:A03                0     0 uM        0.00
# ASG002_GI1_24H:A04                0     0 uM        0.00
# ASG002_GI1_24H:A05                0     0 uM        0.00
# ASG002_GI1_24H:A06                0     0 uM        0.00
# ASG002_GI1_24H:J13                0     0 uM        0.00
# ...                             ...      ...         ...
# MOAR012_GI1_24H:P20               0  3.33 uM        3.33
# MOAR012_GI1_24H:P21               0  1.11 uM        1.11
# MOAR012_GI1_24H:P22               0    10 uM       10.00
# MOAR012_GI1_24H:P23               0  3.33 uM        3.33
# MOAR012_GI1_24H:P24               0  1.11 uM        1.11
#
# [2151 rows x 11 columns]

# %% [markdown]
# ## Input_info - ALL_DATA (modules, STV)

# %%
data_file = os.path.join(data_dir, "gbm_STVs.xlsx")

modules = pd.read_excel(data_file, sheet_name = "modules", index_col = 0)
display(modules)
# Out:
# Empty DataFrame
# Columns: []
# Index: [CDK1, CDK2, CDK4_6, p53, EGFR, Aurora, Estrogen, PDGFR, Hypoxia, ERK, PI3K]

# %% [markdown]
# ## STV (State Transition Vectors)

# %%
STVs_df = pd.read_excel(data_file,sheet_name='STVs',index_col = 0)
STVs= pd.read_excel(data_file,sheet_name='STVs',index_col = 0)
display(STVs_df)

states = STVs.columns.to_list()
print("States:", states)
# Out:
#           GBM_onc  GBM_survival
# Gene
# AARS    -0.018282     -1.228394
# ABCF1   -0.011879     -2.215623
# ABL1     0.001878      0.436299
# ACAA1    0.005391      1.394511
# ACAT2   -0.022549      0.000000
# ...           ...           ...
# TXLNA   -0.006227      0.000000
# SPRED2  -0.030307      0.000000
# EML3     0.060709      0.000000
# STIMATE  0.000000      0.000000
# DIPK1A   0.000000      0.000000
#
# [978 rows x 2 columns]
# States: ['GBM_onc', 'GBM_survival']

# %% [markdown]
# ## DPD calculating

# %%
DPD_df = pd.DataFrame(
    np.zeros((len(exp_id_list), len(states))),
    index = exp_id_list,
    columns = states,
)

for exp_id in DPD_df.index:
    for state in states:
        DPD_df.loc[exp_id, state] = np.dot(Data_norm.loc[exp_id], STVs_df.loc[:, state])

display(DPD_df)
# Out:
#                       GBM_onc  GBM_survival
# ASG002_GI1_24H:A03   0.453232     -7.491423
# ASG002_GI1_24H:A04   0.444041      1.367001
# ASG002_GI1_24H:A05   0.109216     -2.434353
# ASG002_GI1_24H:A06   0.259278      1.887550
# ASG002_GI1_24H:J13  -0.599437      0.268642
# ...                       ...           ...
# MOAR012_GI1_24H:P20  0.831339     -0.755155
# MOAR012_GI1_24H:P21  0.242246    -20.610432
# MOAR012_GI1_24H:P22  0.436844     -3.635238
# MOAR012_GI1_24H:P23 -0.685342    -13.267912
# MOAR012_GI1_24H:P24 -0.204687    -14.236868
#
# [2151 rows x 2 columns]

# %%
#DPD_df.loc[exp_id, state]=-(-1.7370242659102717-(np.dot(Data_norm.loc[exp_id], STV_df.loc[:, state])

# %%
DPD_inf_df = pd.concat([
                            DPD_df,
                            sig_info_cell_df.loc[DPD_df.index, ["pert_drug", "targets", "dose"]]
                            ], axis = 1)

display(DPD_inf_df)
# Out:
#                       GBM_onc  GBM_survival    pert_drug         targets  \
# ASG002_GI1_24H:A03   0.453232     -7.491423         DMSO  DMSO_No_target
# ASG002_GI1_24H:A04   0.444041      1.367001         DMSO  DMSO_No_target
# ASG002_GI1_24H:A05   0.109216     -2.434353         DMSO  DMSO_No_target
# ASG002_GI1_24H:A06   0.259278      1.887550         DMSO  DMSO_No_target
# ASG002_GI1_24H:J13  -0.599437      0.268642         DMSO  DMSO_No_target
# ...                       ...           ...          ...             ...
# MOAR012_GI1_24H:P20  0.831339     -0.755155  BAY-61-3606
# MOAR012_GI1_24H:P21  0.242246    -20.610432  BAY-61-3606
# MOAR012_GI1_24H:P22  0.436844     -3.635238   ethaverine
# MOAR012_GI1_24H:P23 -0.685342    -13.267912   ethaverine
# MOAR012_GI1_24H:P24 -0.204687    -14.236868   ethaverine
#
#                         dose
# ASG002_GI1_24H:A03      0 uM
# ASG002_GI1_24H:A04      0 uM
# ASG002_GI1_24H:A05      0 uM
# ASG002_GI1_24H:A06      0 uM
# ASG002_GI1_24H:J13      0 uM
# ...                      ...
# MOAR012_GI1_24H:P20  3.33 uM
# MOAR012_GI1_24H:P21  1.11 uM
# MOAR012_GI1_24H:P22    10 uM
# MOAR012_GI1_24H:P23  3.33 uM
# MOAR012_GI1_24H:P24  1.11 uM
#
# [2151 rows x 5 columns]

# %%
#DPD_inf_df.to_excel(os.path.join(out_dir, "DPD_full" + data_year + "_" + cell_name + "_" + task + ".xlsx"))
#DPD_inf_df.to_csv(os.path.join(out_dir, "DPD_full" + data_year + "_" + cell_name + "_" + task + ".csv"))

# %% [markdown]
# # Read DPDs

# %%
import seaborn as sns

# %%
sns.histplot(DPD_inf_df['GBM_onc'])
# Out:
# <Axes: xlabel='GBM_onc', ylabel='Count'>

# %%
sns.histplot(DPD_inf_df['blca_onc'])
# Out:
# <Axes: xlabel='blca_onc', ylabel='Count'>

# %% [markdown]
# ## Analisys of DPD values to find targets

# %%
i = 0
top = 10

DPD_analysis = pd.concat([
                            DPD_inf_df.sort_values(by = states[i])[:top],
                            DPD_inf_df.sort_values(by = states[i])[len(DPD_df.index) - top:]
                            ], axis = 0)

display(DPD_analysis)

print("Targets:", len(set(DPD_analysis.targets)), sorted(set(DPD_analysis.targets)))
# Out:
#                       GBM_onc  GBM_survival       pert_drug  \
# MOAR008_GI1_24H:J09 -2.252035      1.181126   glibenclamide
# MOAR008_GI1_24H:F15 -2.112683    -11.709348   tetrabenazine
# MOAR008_GI1_24H:D16 -2.070615     -5.163761  salicylic-acid
# MOAR008_GI1_24H:M22 -2.055287     -5.413332       tiagabine
# MOAR008_GI1_24H:F22 -1.953915      0.800130        L-670596
# MOAR008_GI1_24H:J19 -1.911868      1.701446       GW-842166
# MOAR008_GI1_24H:G19 -1.858665     -2.371132   BRD-K58930050
# MOAR008_GI1_24H:H20 -1.797554      0.303761   stemregenin-1
# MOAR011_GI1_24H:C15 -1.784690      0.034914     laropiprant
# MOAR008_GI1_24H:E11 -1.772179     -7.091522   BRD-K84214706
# ASG002_GI1_24H:D12   1.857027      1.186593    panobinostat
# ASG002_GI1_24H:H22   1.936100     53.128464          YM-155
# MOAR009_GI1_24H:I05  1.995423     -9.386508     EMD-1214063
# ASG002_GI1_24H:F04   1.998594     51.413396       alvocidib
# MOAR009_GI1_24H:J01  2.094963     -8.254931           R-428
# ASG002_GI1_24H:H07   2.168057     22.965658    camptothecin
# MOAR009_GI1_24H:I06  2.190614      1.588669     EMD-1214063
# ASG002_GI1_24H:M13   2.256431     11.293864     mitomycin-c
# ASG002_GI1_24H:D11   2.444880      3.145854    panobinostat
# ASG002_GI1_24H:D10   2.946493     -1.420398    panobinostat
#
#                                                                targets  \
# MOAR008_GI1_24H:J09                  ABCC8, CFTR, KCNJ11, KCNJ5, KCNJ8
# MOAR008_GI1_24H:F15                                            SLC18A2
# MOAR008_GI1_24H:D16                                              PTGS1
# MOAR008_GI1_24H:M22                                             SLC6A1
# MOAR008_GI1_24H:F22
# MOAR008_GI1_24H:J19
# MOAR008_GI1_24H:G19
# MOAR008_GI1_24H:H20                                                AHR
# MOAR011_GI1_24H:C15                                              PTGDR
# MOAR008_GI1_24H:E11
# ASG002_GI1_24H:D12                                        HDAC1, HDAC2
# ASG002_GI1_24H:H22                                               BIRC5
# MOAR009_GI1_24H:I05                                                MET
# ASG002_GI1_24H:F04   CDK1, CDK2, CDK4, CDK5, CDK6, CDK7, CDK8, CDK9...
# MOAR009_GI1_24H:J01                                                AXL
# ASG002_GI1_24H:H07                                                TOP1
# MOAR009_GI1_24H:I06                                                MET
# ASG002_GI1_24H:M13
# ASG002_GI1_24H:D11                                        HDAC1, HDAC2
# ASG002_GI1_24H:D10                                        HDAC1, HDAC2
#
#                         dose
# MOAR008_GI1_24H:J09  1.11 uM
# MOAR008_GI1_24H:F15  1.11 uM
# MOAR008_GI1_24H:D16    10 uM
# MOAR008_GI1_24H:M22    10 uM
# MOAR008_GI1_24H:F22    10 uM
# MOAR008_GI1_24H:J19    10 uM
# MOAR008_GI1_24H:G19    10 uM
# MOAR008_GI1_24H:H20  3.33 uM
# MOAR011_GI1_24H:C15  1.11 uM
# MOAR008_GI1_24H:E11  3.33 uM
# ASG002_GI1_24H:D12   0.12 uM
# ASG002_GI1_24H:H22     10 uM
# MOAR009_GI1_24H:I05  3.33 uM
# ASG002_GI1_24H:F04     10 uM
# MOAR009_GI1_24H:J01    10 uM
# ASG002_GI1_24H:H07     10 uM
# MOAR009_GI1_24H:I06  1.11 uM
# ASG002_GI1_24H:M13     10 uM
# ASG002_GI1_24H:D11   1.11 uM
# ASG002_GI1_24H:D10     10 uM
# Targets: 13 ['', 'ABCC8, CFTR, KCNJ11, KCNJ5, KCNJ8', 'AHR', 'AXL', 'BIRC5', 'CDK1, CDK2, CDK4, CDK5, CDK6, CDK7, CDK8, CDK9, EGFR, PYGM', 'HDAC1, HDAC2', 'MET', 'PTGDR', 'PTGS1', 'SLC18A2', 'SLC6A1', 'TOP1']

# %%
i = 1
top = 10

DPD_analysis = pd.concat([
                            DPD_inf_df.sort_values(by = states[i])[:top],
                            DPD_inf_df.sort_values(by = states[i])[len(DPD_df.index) - top:]
                            ], axis = 0)

display(DPD_analysis)

print("Targets:", len(set(DPD_analysis.targets)), sorted(set(DPD_analysis.targets)))
# Out:
#                       GBM_onc  GBM_survival      pert_drug  \
# MOAR009_GI1_24H:I04  0.445144    -34.945876    EMD-1214063
# MOAR012_GI1_24H:K13  0.932596    -29.159762      PF-477736
# MOAR012_GI1_24H:K03 -0.057269    -27.319502     lornoxicam
# MOAR009_GI1_24H:F10  0.869237    -26.835358      AMD-11070
# MOAR009_GI1_24H:C10  0.614822    -25.844429       nutlin-3
# MOAR009_GI1_24H:K13  1.165426    -25.572027  medronic-acid
# MOAR009_GI1_24H:B14  0.543779    -25.049982     LY-3000328
# MOAR012_GI1_24H:C14 -0.485469    -24.964051     ranirestat
# MOAR010_GI1_24H:F10  0.075581    -24.745825       doxapram
# MOAR011_GI1_24H:F04 -0.158285    -23.879215    perhexiline
# ASG002_GI1_24H:K19  -0.982562     40.176783      anguidine
# ASG002_GI1_24H:B04   0.612263     40.718574         XL-888
# ASG002_GI1_24H:B05   1.365531     42.194079         XL-888
# ASG002_GI1_24H:B17  -0.023949     43.434566      indinavir
# ASG002_GI1_24H:L01   1.158953     43.538742     PHA-793887
# ASG002_GI1_24H:D02   0.488313     44.077571     NVP-AUY922
# ASG002_GI1_24H:L04   0.678832     45.034664        KW-2478
# ASG002_GI1_24H:F04   1.998594     51.413396      alvocidib
# ASG002_GI1_24H:H22   1.936100     53.128464         YM-155
# ASG002_GI1_24H:I04   1.404115     60.550410   daunorubicin
#
#                                                                targets  \
# MOAR009_GI1_24H:I04                                                MET
# MOAR012_GI1_24H:K13                                              CHEK1
# MOAR012_GI1_24H:K03                                       PTGS1, PTGS2
# MOAR009_GI1_24H:F10
# MOAR009_GI1_24H:C10                                               MDM2
# MOAR009_GI1_24H:K13
# MOAR009_GI1_24H:B14
# MOAR012_GI1_24H:C14
# MOAR010_GI1_24H:F10                                       KCNK3, KCNK9
# MOAR011_GI1_24H:F04                                        CPT1A, CPT2
# ASG002_GI1_24H:K19                                              SLC5A1
# ASG002_GI1_24H:B04
# ASG002_GI1_24H:B05
# ASG002_GI1_24H:B17                              CYP3A4, CYP3A5, CYP3A7
# ASG002_GI1_24H:L01                  CDK1, CDK2, CDK4, CDK5, CDK7, CDK9
# ASG002_GI1_24H:D02                                  HSP90AA1, HSP90AB1
# ASG002_GI1_24H:L04
# ASG002_GI1_24H:F04   CDK1, CDK2, CDK4, CDK5, CDK6, CDK7, CDK8, CDK9...
# ASG002_GI1_24H:H22                                               BIRC5
# ASG002_GI1_24H:I04                                               TOP2A
#
#                         dose
# MOAR009_GI1_24H:I04    10 uM
# MOAR012_GI1_24H:K13    10 uM
# MOAR012_GI1_24H:K03  1.11 uM
# MOAR009_GI1_24H:F10    10 uM
# MOAR009_GI1_24H:C10    10 uM
# MOAR009_GI1_24H:K13    10 uM
# MOAR009_GI1_24H:B14  3.33 uM
# MOAR012_GI1_24H:C14  3.33 uM
# MOAR010_GI1_24H:F10    10 uM
# MOAR011_GI1_24H:F04    10 uM
# ASG002_GI1_24H:K19     10 uM
# ASG002_GI1_24H:B04     10 uM
# ASG002_GI1_24H:B05   1.11 uM
# ASG002_GI1_24H:B17   1.11 uM
# ASG002_GI1_24H:L01     10 uM
# ASG002_GI1_24H:D02   1.11 uM
# ASG002_GI1_24H:L04     10 uM
# ASG002_GI1_24H:F04     10 uM
# ASG002_GI1_24H:H22     10 uM
# ASG002_GI1_24H:I04     10 uM
# Targets: 14 ['', 'BIRC5', 'CDK1, CDK2, CDK4, CDK5, CDK6, CDK7, CDK8, CDK9, EGFR, PYGM', 'CDK1, CDK2, CDK4, CDK5, CDK7, CDK9', 'CHEK1', 'CPT1A, CPT2', 'CYP3A4, CYP3A5, CYP3A7', 'HSP90AA1, HSP90AB1', 'KCNK3, KCNK9', 'MDM2', 'MET', 'PTGS1, PTGS2', 'SLC5A1', 'TOP2A']

# %%
### copy manually
targets_list = ["ATP4A", "AVPR1A", "CYSLTR1", "CYSLTR2", "ESR1", "ESR2", "FKBP1A", "MTOR", "IDH1", "MAOA", "NFE2L2", "OPRD1", "OPRK1", "OPRM1", "PSMB1", "PSMB1", "PSMB2", "PSMB5", "PTGS1", "PTGS2", "ADRB2", "DRD1", "DRD2", "HRH1", "HTR1A", "HTR1B", "HTR2A", "AURKA", "AURKB", "FGFR1", "FGFR2", "KDR", "PDGFRA", "PDGFRB", "CYP2C19", "CYP2C9", "CYP3A4", "CYP3A5", "PTGS1", "DHODH", "ESR1", "GNRHR", "FKBP1A", "MTOR", "HDAC1", "HDAC2", "HDAC3", "HDAC6", "HDAC8", "MET", "MMUT", "PDE4D", "PSMB1", "PSMB2", "PSMB5", "PTGS1", "PTGS2", "SLC6A2", "AOC1", "ATP4A", "CDK2", "CDK7", "CDK9", "CHRM1", "DRD2", "HTR2A", "FFAR1", "PDE11A", "PDE5A", "PPARG", "PSMB1", "PSMB1", "PSMB2", "PSMB5"]
targets_list = sorted(list(set(targets_list )))
print("Targets:", len(targets_list ), targets_list)
# Out:
# Targets: 57 ['ADRB2', 'AOC1', 'ATP4A', 'AURKA', 'AURKB', 'AVPR1A', 'CDK2', 'CDK7', 'CDK9', 'CHRM1', 'CYP2C19', 'CYP2C9', 'CYP3A4', 'CYP3A5', 'CYSLTR1', 'CYSLTR2', 'DHODH', 'DRD1', 'DRD2', 'ESR1', 'ESR2', 'FFAR1', 'FGFR1', 'FGFR2', 'FKBP1A', 'GNRHR', 'HDAC1', 'HDAC2', 'HDAC3', 'HDAC6', 'HDAC8', 'HRH1', 'HTR1A', 'HTR1B', 'HTR2A', 'IDH1', 'KDR', 'MAOA', 'MET', 'MMUT', 'MTOR', 'NFE2L2', 'OPRD1', 'OPRK1', 'OPRM1', 'PDE11A', 'PDE4D', 'PDE5A', 'PDGFRA', 'PDGFRB', 'PPARG', 'PSMB1', 'PSMB2', 'PSMB5', 'PTGS1', 'PTGS2', 'SLC6A2']

# %% [markdown]
# ## Plots for targets

# %%
print_drugs = []

# %% [markdown]
# ### PIK

# %%
target = "PIK"
drugs = sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.targets.str.contains(target)].pert_drug)))

print("drugs for target " + target + ":" , len(drugs), drugs)
# Out:
# drugs for target PIK: 6 ['AS-605240', 'GDC-0349', 'LY-294002', 'NVP-BEZ235', 'PI-103', 'taselisib']

# %%
drugs_list = drugs

targets = []
doses = []

for drug in drugs_list:
    targets.append(", ".join(sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].targets)))))
    doses.append(", ".join(sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].dose)))))
    
target_drugs_df = pd.DataFrame(list(zip(targets, doses)), index = drugs_list, columns = ["targets","doses"])

display(target_drugs_df)
# Out:
#                                                       targets  \
# AS-605240                                              PIK3CG
# GDC-0349                                               PIK3CA
# LY-294002   MTOR, PIK3CA, PIK3CB, PIK3CD, PIK3CG, PLK1, PRKDC
# NVP-BEZ235                       MTOR, PIK3CA, PIK3CD, PIK3CG
# PI-103                   MTOR, PIK3CA, PIK3CB, PIK3CD, PIK3CG
# taselisib                                              PIK3CA
#
#                               doses
# AS-605240   0.12 uM, 1.11 uM, 10 uM
# GDC-0349    1.11 uM, 10 uM, 3.33 uM
# LY-294002   0.12 uM, 1.11 uM, 10 uM
# NVP-BEZ235           1.11 uM, 10 uM
# PI-103      0.12 uM, 1.11 uM, 10 uM
# taselisib   0.12 uM, 1.11 uM, 10 uM

# %%
target_name = "PI3K"
target_drugs=drugs_list
#target_drugs = ["PF-04691502", "XL-147", "GSK-2334470", "A-66", "BGT-226", "BX-795"]
# deleted idelalisib, quercetin because other targets = PIK3CD, PIK3CG (delta, gamma, we use only alpha)


for DPD_val in states:
    plt.figure(figsize = (6,9))
    for drug in target_drugs:
        doses = sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].dose_float)))
        DPDs = []
        DPD_errs = []
        for dose in doses:
            labels = sig_info_cell_df.loc[(sig_info_cell_df.pert_drug == drug) & (sig_info_cell_df.dose_float == dose)].index
            DPDs.append(statistics.mean(DPD_df.loc[labels, DPD_val]))
            if (len(labels) > 1):
                DPD_errs.append(scipy.stats.sem(DPD_df.loc[labels, DPD_val]))
            else:
                DPD_errs.append(0)
        plt.errorbar(doses, DPDs, yerr = DPD_errs, fmt = "o-", label = drug, capsize = 5)
    plt.legend()
    plt.plot([0,10], [0,0], "--", color = "red")
    plt.xlabel("Dose, uM",fontsize=20)
    plt.ylabel("DPD_" + DPD_val,fontsize=20)
    plt.title("Target: " + target_name,fontsize=20)
    #plt.savefig(os.path.join(out_dir, target_name + "_DPD_" + DPD_val + ".png"), dpi = 300)
    plt.show()

# %% [markdown]
# ### Hypoxia

# %%
target = "MGMT"
drugs = sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.targets.str.contains(target)].pert_drug)))

print("drugs for target " + target + ":" , len(drugs), drugs)
# Out:
# drugs for target MGMT: 2 ['lomeguatrib', 'temozolomide']

# %%
drugs_list = drugs

targets = []
doses = []

for drug in drugs_list:
    targets.append(", ".join(sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].targets)))))
    doses.append(", ".join(sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].dose)))))
    
target_drugs_df = pd.DataFrame(list(zip(targets, doses)), index = drugs_list, columns = ["targets","doses"])

display(target_drugs_df)
# Out:
#              targets                    doses
# lomeguatrib     MGMT  1.11 uM, 10 uM, 3.33 uM
# temozolomide    MGMT           1.11 uM, 10 uM

# %%
target_name = "Hypoxia"
target_drugs=drugs_list
# deleted idelalisib, quercetin because other targets = PIK3CD, PIK3CG (delta, gamma, we use only alpha)


for DPD_val in states:
    plt.figure(figsize = (6,9))
    for drug in target_drugs:
        doses = sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].dose_float)))
        DPDs = []
        DPD_errs = []
        for dose in doses:
            labels = sig_info_cell_df.loc[(sig_info_cell_df.pert_drug == drug) & (sig_info_cell_df.dose_float == dose)].index
            DPDs.append(statistics.mean(DPD_df.loc[labels, DPD_val]))
            if (len(labels) > 1):
                DPD_errs.append(scipy.stats.sem(DPD_df.loc[labels, DPD_val]))
            else:
                DPD_errs.append(0)
        plt.errorbar(doses, DPDs, yerr = DPD_errs, fmt = "o-", label = drug, capsize = 5)
    print(labels)
    plt.legend()
    plt.plot([0,10], [0,0], "--", color = "red")
    plt.xlabel("Dose, uM",fontsize=20)
    plt.ylabel("DPD_" + DPD_val,fontsize=20)
    plt.title("Target: " + target_name,fontsize=20)
    #plt.savefig(os.path.join(out_dir, target_name + "_DPD_" + DPD_val + ".png"), dpi = 300)
    plt.show()
# Out:
# Index(['ASG002_GI1_24H:P04'], dtype='object', name='level_5_sig_id')
# Index(['ASG002_GI1_24H:P04'], dtype='object', name='level_5_sig_id')

# %% [markdown]
# ### ERK

# %%
target_name = "ERK"

target = "MAP2K"
drugs = list(set(sig_info_cell_df.loc[sig_info_cell_df.targets.str.contains(target)].pert_drug))

target = "MAPK"
drugs += list(set(sig_info_cell_df.loc[sig_info_cell_df.targets.str.contains(target)].pert_drug))

target = "RAF"
drugs += list(set(sig_info_cell_df.loc[sig_info_cell_df.targets.str.contains(target)].pert_drug))

drugs = sorted(list(set(drugs)))

print("drugs for target " + target_name + ":" , len(drugs), drugs)
# Out:
# drugs for target ERK: 7 ['AZ-628', 'PD-0325901', 'dabrafenib', 'selumetinib', 'sorafenib', 'trametinib', 'vemurafenib']

# %%
drugs_list = drugs 

targets = []
doses = []

for drug in drugs_list:
    targets.append(", ".join(sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].targets)))))
    doses.append(", ".join(sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].dose)))))
    
target_drugs_df = pd.DataFrame(list(zip(targets, doses)), index = drugs_list, columns = ["targets","doses"])

display(target_drugs_df)
# Out:
#                                                        targets  \
# AZ-628                                              BRAF, RAF1
# PD-0325901                                              MAP2K1
# dabrafenib                                                BRAF
# selumetinib                                             MAP2K1
# sorafenib    BRAF, DDR2, FGFR1, FLT1, FLT3, FLT4, KDR, KIT,...
# trametinib                                      MAP2K1, MAP2K2
# vemurafenib                                               BRAF
#
#                                doses
# AZ-628       0.12 uM, 1.11 uM, 10 uM
# PD-0325901   0.12 uM, 1.11 uM, 10 uM
# dabrafenib   0.12 uM, 1.11 uM, 10 uM
# selumetinib  0.12 uM, 1.11 uM, 10 uM
# sorafenib           0.12 uM, 1.11 uM
# trametinib            0.12 uM, 10 uM
# vemurafenib  0.12 uM, 1.11 uM, 10 uM

# %%
target_name = "ERK"
target_drugs = drugs_list
# deleted SB-203580 (MAPK1)
# select only gene name RAF1, BRAF, MAP2K1, MAP2K2, MAPK1, MAPK3   (Kinase pathway RAF->MEK->ERK) = module "ERK2

for DPD_val in states:
    plt.figure(figsize = (9,8))
    for drug in target_drugs:
        doses = sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].dose_float)))
        DPDs = []
        DPD_errs = []
        for dose in doses:
            labels = sig_info_cell_df.loc[(sig_info_cell_df.pert_drug == drug) & (sig_info_cell_df.dose_float == dose)].index
            DPDs.append(statistics.mean(DPD_df.loc[labels, DPD_val]))
            if (len(labels) > 1):
                DPD_errs.append(scipy.stats.sem(DPD_df.loc[labels, DPD_val]))
            else:
                DPD_errs.append(0)
        plt.errorbar(doses, DPDs, yerr = DPD_errs, fmt = "o-", label = drug, capsize = 5)
    plt.legend()
    plt.plot([0,10], [0,0], "--", color = "black")
    plt.xlabel("Dose, uM")
    plt.ylabel("DPD_" + DPD_val)
    plt.title("Target: " + target_name)
    #plt.savefig(os.path.join(out_dir, target_name + "_DPD_" + DPD_val + ".png"), dpi = 300)
    plt.show()

# %% [markdown]
# ### EGFR

# %%
target = "EGFR"
drugs = sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.targets.str.contains(target)].pert_drug)))

print("drugs for target " + target + ":" , len(drugs), drugs)
# Out:
# drugs for target EGFR: 6 ['afatinib', 'alvocidib', 'erlotinib', 'gefitinib', 'lapatinib', 'vandetanib']

# %%
drugs_list = drugs

targets = []
doses = []

for drug in drugs_list:
    targets.append(", ".join(sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].targets)))))
    doses.append(", ".join(sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].dose)))))
    
target_drugs_df = pd.DataFrame(list(zip(targets, doses)), index = drugs_list, columns = ["targets","doses"])

display(target_drugs_df)
# Out:
#                                                       targets  \
# afatinib                                   EGFR, ERBB2, ERBB4
# alvocidib   CDK1, CDK2, CDK4, CDK5, CDK6, CDK7, CDK8, CDK9...
# erlotinib                                                EGFR
# gefitinib                                                EGFR
# lapatinib                                         EGFR, ERBB2
# vandetanib              EGFR, FLT1, FLT4, KDR, PTK6, RET, TEK
#
#                               doses
# afatinib           0.12 uM, 1.11 uM
# alvocidib   0.12 uM, 1.11 uM, 10 uM
# erlotinib   0.12 uM, 1.11 uM, 10 uM
# gefitinib            1.11 uM, 10 uM
# lapatinib   0.12 uM, 1.11 uM, 10 uM
# vandetanib  0.12 uM, 1.11 uM, 10 uM

# %%
target_name = "EGFR"
target_drugs = drugs_list

for DPD_val in states:
    plt.figure(figsize = (9,8))
    for drug in target_drugs:
        doses = sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].dose_float)))
        DPDs = []
        DPD_errs = []
        for dose in doses:
            labels = sig_info_cell_df.loc[(sig_info_cell_df.pert_drug == drug) & (sig_info_cell_df.dose_float == dose)].index
            DPDs.append(statistics.mean(DPD_df.loc[labels, DPD_val]))
            if (len(labels) > 1):
                DPD_errs.append(scipy.stats.sem(DPD_df.loc[labels, DPD_val]))
            else:
                DPD_errs.append(0)
        plt.errorbar(doses, DPDs, yerr = DPD_errs, fmt = "o-", label = drug, capsize = 5)
    plt.legend()
    plt.plot([0,10], [0,0], "--", color = "black")
    plt.xlabel("Dose, uM")
    plt.ylabel("DPD_" + DPD_val)
    plt.title("Target: " + target_name)
    #plt.savefig(os.path.join(out_dir, target_name + "_DPD_" + DPD_val + ".png"), dpi = 300)
    plt.show()

# %% [markdown]
# ### JAK-STAT

# %%
target = "JAK"
drugs = sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.targets.str.contains(target)].pert_drug)))

print("drugs for target " + target + ":" , len(drugs), drugs)
# Out:
# drugs for target JAK: 1 ['tozasertib']

# %%
drugs_list = drugs 

targets = []
doses = []

for drug in drugs_list:
    targets.append(", ".join(sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].targets)))))
    doses.append(", ".join(sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].dose)))))
    
target_drugs_df = pd.DataFrame(list(zip(targets, doses)), index = drugs_list, columns = ["targets","doses"])

display(target_drugs_df)
# Out:
#                                                targets  \
# tozasertib  ABL1, AURKA, AURKB, AURKC, BCR, FLT3, JAK2
#
#                               doses
# tozasertib  0.12 uM, 1.11 uM, 10 uM

# %%
target_name = "JAK-STAT"
target_drugs = drugs_list

for DPD_val in states:
    plt.figure(figsize = (9,8))
    for drug in target_drugs:
        doses = sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].dose_float)))
        DPDs = []
        DPD_errs = []
        for dose in doses:
            labels = sig_info_cell_df.loc[(sig_info_cell_df.pert_drug == drug) & (sig_info_cell_df.dose_float == dose)].index
            DPDs.append(statistics.mean(DPD_df.loc[labels, DPD_val]))
            if (len(labels) > 1):
                DPD_errs.append(scipy.stats.sem(DPD_df.loc[labels, DPD_val]))
            else:
                DPD_errs.append(0)
        plt.errorbar(doses, DPDs, yerr = DPD_errs, fmt = "o-", label = drug, capsize = 5)
    plt.legend()
    plt.plot([0,10], [0,0], "--", color = "black")
    plt.xlabel("Dose, uM")
    plt.ylabel("DPD_" + DPD_val)
    plt.title("Target: " + target_name)
    #plt.savefig(os.path.join(out_dir, target_name + "_DPD_" + DPD_val + ".png"), dpi = 300)
    plt.show()

# %% [markdown]
# ### Estrogen

# %%
target = "ESR"
drugs = sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.targets.str.contains(target)].pert_drug)))

print("drugs for target " + target + ":" , len(drugs), drugs)
# Out:
# drugs for target ESR: 3 ['dienestrol', 'estradiol-cypionate', 'raloxifene']

# %%
drugs_list = drugs

targets = []
doses = []

for drug in drugs_list:
    targets.append(", ".join(sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].targets)))))
    doses.append(", ".join(sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].dose)))))
    
target_drugs_df = pd.DataFrame(list(zip(targets, doses)), index = drugs_list, columns = ["targets","doses"])

display(target_drugs_df)
# Out:
#                         targets                    doses
# dienestrol                 ESR1  0.12 uM, 1.11 uM, 10 uM
# estradiol-cypionate        ESR1  0.12 uM, 1.11 uM, 10 uM
# raloxifene           ESR1, ESR2  0.12 uM, 1.11 uM, 10 uM

# %%
target_name = "Estrogen"
target_drugs = drugs_list

for DPD_val in states:
    plt.figure(figsize = (9,8))
    for drug in target_drugs:
        doses = sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].dose_float)))
        DPDs = []
        DPD_errs = []
        for dose in doses:
            labels = sig_info_cell_df.loc[(sig_info_cell_df.pert_drug == drug) & (sig_info_cell_df.dose_float == dose)].index
            DPDs.append(statistics.mean(DPD_df.loc[labels, DPD_val]))
            if (len(labels) > 1):
                DPD_errs.append(scipy.stats.sem(DPD_df.loc[labels, DPD_val]))
            else:
                DPD_errs.append(0)
        plt.errorbar(doses, DPDs, yerr = DPD_errs, fmt = "o-", label = drug, capsize = 5)
    plt.legend()
    plt.plot([0,10], [0,0], "--", color = "black")
    plt.xlabel("Dose, uM")
    plt.ylabel("DPD_" + DPD_val)
    plt.title("Target: " + target_name)
    #plt.savefig(os.path.join(out_dir, target_name + "_DPD_" + DPD_val + ".png"), dpi = 300)

# %% [markdown]
# ### p53

# %%
target = "MDM2"
drugs = sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.targets.str.contains(target)].pert_drug)))

print("drugs for target " + target + ":" , len(drugs), drugs)
# Out:
# drugs for target MDM2: 6 ['AMG-232', 'HLI-373', 'RITA', 'SAR405838', 'nutlin-3', 'serdemetan']

# %%
drugs_list = drugs

targets = []
doses = []

for drug in drugs_list:
    targets.append(", ".join(sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].targets)))))
    doses.append(", ".join(sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].dose)))))
    
target_drugs_df = pd.DataFrame(list(zip(targets, doses)), index = drugs_list, columns = ["targets","doses"])

display(target_drugs_df)
# Out:
#            targets                             doses
# AMG-232       MDM2           0.12 uM, 1.11 uM, 10 uM
# HLI-373       MDM2           1.11 uM, 10 uM, 3.33 uM
# RITA          MDM2  0.08 uM, 1.11 uM, 10 uM, 3.33 uM
# SAR405838     MDM2                  1.11 uM, 3.33 uM
# nutlin-3      MDM2  0.12 uM, 1.11 uM, 10 uM, 3.33 uM
# serdemetan    MDM2           1.11 uM, 10 uM, 3.33 uM

# %%
target_name = "p53"
target_drugs = drugs_list

for DPD_val in states:
    plt.figure(figsize = (9,8))
    for drug in target_drugs:
        doses = sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].dose_float)))
        DPDs = []
        DPD_errs = []
        for dose in doses:
            labels = sig_info_cell_df.loc[(sig_info_cell_df.pert_drug == drug) & (sig_info_cell_df.dose_float == dose)].index
            DPDs.append(statistics.mean(DPD_df.loc[labels, DPD_val]))
            if (len(labels) > 1):
                DPD_errs.append(scipy.stats.sem(DPD_df.loc[labels, DPD_val]))
            else:
                DPD_errs.append(0)
        plt.errorbar(doses, DPDs, yerr = DPD_errs, fmt = "o-", label = drug, capsize = 5)
    plt.legend()
    plt.plot([0,10], [0,0], "--", color = "black")
    plt.xlabel("Dose, uM")
    plt.ylabel("DPD_" + DPD_val)
    plt.title("Target: " + target_name)
    #plt.savefig(os.path.join(out_dir, target_name + "_DPD_" + DPD_val + ".png"), dpi = 300)

# %% [markdown]
# ### Aurora

# %%
target = "AURK"
drugs = sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.targets.str.contains(target)].pert_drug)))

print("drugs for target " + target + ":" , len(drugs), drugs)
# Out:
# drugs for target AURK: 3 ['JNJ-7706621', 'barasertib-HQPA', 'tozasertib']

# %%
drugs_list = drugs #+ ["aurora-a-inhibitor-i"]

targets = []
doses = []

for drug in drugs_list:
    targets.append(", ".join(sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].targets)))))
    doses.append(", ".join(sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].dose)))))
    
target_drugs_df = pd.DataFrame(list(zip(targets, doses)), index = drugs_list, columns = ["targets","doses"])

display(target_drugs_df)
# Out:
#                                                     targets  \
# JNJ-7706621                        AURKA, AURKB, CDK1, CDK2
# barasertib-HQPA                                       AURKB
# tozasertib       ABL1, AURKA, AURKB, AURKC, BCR, FLT3, JAK2
#
#                                    doses
# JNJ-7706621      0.12 uM, 1.11 uM, 10 uM
# barasertib-HQPA  0.12 uM, 1.11 uM, 10 uM
# tozasertib       0.12 uM, 1.11 uM, 10 uM

# %%
target_name = "Aurora"
target_drugs = drugs_list
# deleted ENMD-2076, KW-2449, orantinib because other targets 
# deleted aurora-a-inhibitor-i (2017) - not in data 2020

for DPD_val in states:
    plt.figure(figsize = (9,8))
    for drug in target_drugs:
        doses = sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].dose_float)))
        DPDs = []
        DPD_errs = []
        for dose in doses:
            labels = sig_info_cell_df.loc[(sig_info_cell_df.pert_drug == drug) & (sig_info_cell_df.dose_float == dose)].index
            DPDs.append(statistics.mean(DPD_df.loc[labels, DPD_val]))
            if (len(labels) > 1):
                DPD_errs.append(scipy.stats.sem(DPD_df.loc[labels, DPD_val]))
            else:
                DPD_errs.append(0)
        plt.errorbar(doses, DPDs, yerr = DPD_errs, fmt = "o-", label = drug, capsize = 5)
    plt.legend()
    plt.plot([0,10], [0,0], "--", color = "black")
    plt.xlabel("Dose, uM")
    plt.ylabel("DPD_" + DPD_val)
    plt.title("Target: " + target_name)
    #plt.savefig(os.path.join(out_dir, target_name + "_DPD_" + DPD_val + ".png"), dpi = 300)
    plt.show()

# %% [markdown]
# ### TGFbR

# %%
target = "ALK"
drugs = sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.targets.str.contains(target)].pert_drug)))

print("drugs for target " + target + ":" , len(drugs), drugs)
# Out:
# drugs for target ALK: 3 ['alectinib', 'ceritinib', 'crizotinib']

# %%
drugs_list = drugs

targets = []
doses = []

for drug in drugs_list:
    targets.append(", ".join(sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].targets)))))
    doses.append(", ".join(sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].dose)))))
    
target_drugs_df = pd.DataFrame(list(zip(targets, doses)), index = drugs_list, columns = ["targets","doses"])

display(target_drugs_df)
# Out:
#              targets                    doses
# alectinib        ALK  0.12 uM, 1.11 uM, 10 uM
# ceritinib        ALK         0.12 uM, 1.11 uM
# crizotinib  ALK, MET  0.08 uM, 1.11 uM, 10 uM

# %%
target_name = "TGFbR"
target_drugs = drugs_list

for DPD_val in states:
    plt.figure(figsize = (9,8))
    for drug in target_drugs:
        doses = sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].dose_float)))
        DPDs = []
        DPD_errs = []
        for dose in doses:
            labels = sig_info_cell_df.loc[(sig_info_cell_df.pert_drug == drug) & (sig_info_cell_df.dose_float == dose)].index
            DPDs.append(statistics.mean(DPD_df.loc[labels, DPD_val]))
            if (len(labels) > 1):
                DPD_errs.append(scipy.stats.sem(DPD_df.loc[labels, DPD_val]))
            else:
                DPD_errs.append(0)
        plt.errorbar(doses, DPDs, yerr = DPD_errs, fmt = "o-", label = drug, capsize = 5)
    plt.legend()
    plt.plot([0,10], [0,0], "--", color = "black")
    plt.xlabel("Dose, uM")
    plt.ylabel("DPD_" + DPD_val)
    plt.title("Target: " + target_name)
    #plt.savefig(os.path.join(out_dir, target_name + "_DPD_" + DPD_val + ".png"), dpi = 300)
    plt.show()

# %%
target = "CDK2"
drugs = list(set(sig_info_cell_df.loc[sig_info_cell_df.targets.str.contains(target)].pert_drug))

drugs = sorted(list(set(drugs)))

print("drugs for target " + target + ":" , len(drugs), drugs)
# Out:
# drugs for target CDK2: 4 ['JNJ-7706621', 'PHA-793887', 'alvocidib', 'roscovitine']

# %%
drugs_list = drugs 

targets = []
doses = []

for drug in drugs_list:
    targets.append(", ".join(sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].targets)))))
    doses.append(", ".join(sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].dose)))))
    
target_drugs_df = pd.DataFrame(list(zip(targets, doses)), index = drugs_list, columns = ["targets","doses"])

display(target_drugs_df)
# Out:
#                                                        targets  \
# JNJ-7706621                           AURKA, AURKB, CDK1, CDK2
# PHA-793887                  CDK1, CDK2, CDK4, CDK5, CDK7, CDK9
# alvocidib    CDK1, CDK2, CDK4, CDK5, CDK6, CDK7, CDK8, CDK9...
# roscovitine                                   CDK2, CDK7, CDK9
#
#                                doses
# JNJ-7706621  0.12 uM, 1.11 uM, 10 uM
# PHA-793887   0.12 uM, 1.11 uM, 10 uM
# alvocidib    0.12 uM, 1.11 uM, 10 uM
# roscovitine  0.12 uM, 1.11 uM, 10 uM

# %%
target_name = "CDK1_2"
target_drugs=drugs
# deleted PHA-848125, alvocidib because other targets = CDK4, CDK6 (other phase of cell cycle)

for DPD_val in states:
    plt.figure(figsize = (8,9))
    for drug in target_drugs:
        doses = sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].dose_float)))
        DPDs = []
        DPD_errs = []
        for dose in doses:
            labels = sig_info_cell_df.loc[(sig_info_cell_df.pert_drug == drug) & (sig_info_cell_df.dose_float == dose)].index
            DPDs.append(statistics.mean(DPD_df.loc[labels, DPD_val]))
            if (len(labels) > 1):
                DPD_errs.append(scipy.stats.sem(DPD_df.loc[labels, DPD_val]))
            else:
                DPD_errs.append(0)
        plt.errorbar(doses, DPDs, yerr = DPD_errs, fmt = "o-", label = drug, capsize = 5)
    plt.legend()
    plt.plot([0,10], [0,0], "--", color = "red")
    plt.xlabel("Dose, uM",fontsize=20)
    plt.ylabel("DPD_" + DPD_val,fontsize=20)
    plt.title("Target: " + target_name,fontsize=20)
    #plt.savefig(os.path.join(out_dir, target_name + "_DPD_" + DPD_val + ".png"), dpi = 300)
    plt.show()

# %% [markdown]
# ### CDK4_6

# %%
target = "CDK4"
drugs = list(set(sig_info_cell_df.loc[sig_info_cell_df.targets.str.contains(target)].pert_drug))

target = "CDK6"
drugs += list(set(sig_info_cell_df.loc[sig_info_cell_df.targets.str.contains(target)].pert_drug))

drugs = sorted(list(set(drugs)))

print("drugs for target " + target + ":" , len(drugs), drugs)
# Out:
# drugs for target CDK6: 3 ['PHA-793887', 'alvocidib', 'palbociclib']

# %%
drugs_list = drugs 

targets = []
doses = []

for drug in drugs_list:
    targets.append(", ".join(sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].targets)))))
    doses.append(", ".join(sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].dose)))))
    
target_drugs_df = pd.DataFrame(list(zip(targets, doses)), index = drugs_list, columns = ["targets","doses"])

display(target_drugs_df)
# Out:
#                                                        targets  \
# PHA-793887                  CDK1, CDK2, CDK4, CDK5, CDK7, CDK9
# alvocidib    CDK1, CDK2, CDK4, CDK5, CDK6, CDK7, CDK8, CDK9...
# palbociclib                                         CDK4, CDK6
#
#                                doses
# PHA-793887   0.12 uM, 1.11 uM, 10 uM
# alvocidib    0.12 uM, 1.11 uM, 10 uM
# palbociclib  0.12 uM, 1.11 uM, 10 uM

# %%
target_name = "CDK4_6"
target_drugs=drugs
# deleted PHA-848125, alvocidib because other targets = CDK4, CDK6 (other phase of cell cycle)

for DPD_val in states:
    plt.figure(figsize = (8,9))
    for drug in target_drugs:
        doses = sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].dose_float)))
        DPDs = []
        DPD_errs = []
        for dose in doses:
            labels = sig_info_cell_df.loc[(sig_info_cell_df.pert_drug == drug) & (sig_info_cell_df.dose_float == dose)].index
            DPDs.append(statistics.mean(DPD_df.loc[labels, DPD_val]))
            if (len(labels) > 1):
                DPD_errs.append(scipy.stats.sem(DPD_df.loc[labels, DPD_val]))
            else:
                DPD_errs.append(0)
        plt.errorbar(doses, DPDs, yerr = DPD_errs, fmt = "o-", label = drug, capsize = 5)
    plt.legend()
    plt.plot([0,10], [0,0], "--", color = "red")
    plt.xlabel("Dose, uM",fontsize=20)
    plt.ylabel("DPD_" + DPD_val,fontsize=20)
    plt.title("Target: " + target_name,fontsize=20)
    #plt.savefig(os.path.join(out_dir, target_name + "_DPD_" + DPD_val + ".png"), dpi = 300)
    plt.show()

# %% [markdown]
# ### PAK

# %%
target = "PAK"
drugs = sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.targets.str.contains(target)].pert_drug)))

print("drugs for target " + target + ":" , len(drugs), drugs)
# Out:
# drugs for target PAK: 0 []

# %%
drugs_list = drugs

targets = []
doses = []

for drug in drugs_list:
    targets.append(", ".join(sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].targets)))))
    doses.append(", ".join(sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].dose)))))
    
target_drugs_df = pd.DataFrame(list(zip(targets, doses)), index = drugs_list, columns = ["targets","doses"])

display(target_drugs_df)
# Out:
#             targets                                              doses
# PF-03758309    PAK4  0.04 uM, 0.12 uM, 0.125 uM, 0.37 uM, 1.11 uM, ...

# %%
target_name = "PAK"
target_drugs = drugs_list

for DPD_val in states:
    plt.figure(figsize = (9,8))
    for drug in target_drugs:
        doses = sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].dose_float)))
        DPDs = []
        DPD_errs = []
        for dose in doses:
            labels = sig_info_cell_df.loc[(sig_info_cell_df.pert_drug == drug) & (sig_info_cell_df.dose_float == dose)].index
            DPDs.append(statistics.mean(DPD_df.loc[labels, DPD_val]))
            if (len(labels) > 1):
                DPD_errs.append(scipy.stats.sem(DPD_df.loc[labels, DPD_val]))
            else:
                DPD_errs.append(0)
        plt.errorbar(doses, DPDs, yerr = DPD_errs, fmt = "o-", label = drug, capsize = 5)
    plt.legend()
    plt.plot([0,10], [0,0], "--", color = "black")
    plt.xlabel("Dose, uM")
    plt.ylabel("DPD_" + DPD_val)
    plt.title("Target: " + target_name)
    plt.savefig(os.path.join(out_dir, target_name + "_DPD_" + DPD_val + ".png"), dpi = 300)
    plt.show()

# %%
print_drugs += target_drugs

# %%
# delete for PF-03758309 dose 10 uM

labels = sig_info_cell_df.loc[(sig_info_cell_df.pert_drug == "PF-03758309") & (sig_info_cell_df.dose_float == 10)].index.to_list()
print(labels)
# Out:
# ['LJP009_HUVEC.A_24H:D01', 'LJP009_HUVEC_24H:D01']

# %% [markdown]
# ### PI3K

# %%
target = "TOP2A"
drugs = sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.targets.str.contains(target)].pert_drug)))

print("drugs for target " + target + ":" , len(drugs), drugs)
# Out:
# drugs for target TOP2A: 4 ['daunorubicin', 'epirubicin', 'idarubicin', 'mitoxantrone']

# %%
drugs_list = drugs
targets = []
doses = []

for drug in drugs_list:
    targets.append(", ".join(sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].targets)))))
    doses.append(", ".join(sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].dose)))))
    
target_drugs_df = pd.DataFrame(list(zip(targets, doses)), index = drugs_list, columns = ["targets","doses"])

display(target_drugs_df)
# Out:
#              targets                    doses
# daunorubicin   TOP2A  0.12 uM, 1.11 uM, 10 uM
# epirubicin     TOP2A         0.12 uM, 1.11 uM
# idarubicin     TOP2A         0.12 uM, 1.11 uM
# mitoxantrone   TOP2A         0.12 uM, 1.11 uM

# %%
target_name = "TOP2A"
target_drugs=drugs_list

for DPD_val in states:
    plt.figure(figsize = (6,9))
    for drug in target_drugs:
        doses = sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].dose_float)))
        DPDs = []
        DPD_errs = []
        for dose in doses:
            labels = sig_info_cell_df.loc[(sig_info_cell_df.pert_drug == drug) & (sig_info_cell_df.dose_float == dose)].index
            DPDs.append(statistics.mean(DPD_df.loc[labels, DPD_val]))
            if (len(labels) > 1):
                DPD_errs.append(scipy.stats.sem(DPD_df.loc[labels, DPD_val]))
            else:
                DPD_errs.append(0)
        plt.errorbar(doses, DPDs, yerr = DPD_errs, fmt = "o-", label = drug, capsize = 5)
    plt.legend()
    plt.plot([0,10], [0,0], "--", color = "red")
    plt.xlabel("Dose, uM",fontsize=20)
    plt.ylabel("DPD_" + DPD_val,fontsize=20)
    plt.title("Target: " + target_name,fontsize=20)
    #plt.savefig(os.path.join(out_dir, target_name + "_DPD_" + DPD_val + ".png"), dpi = 300)
    plt.show()

# %%
print_drugs += target_drugs

# %% [markdown]
# ### ERK

# %%
target_name = "ERK"

target = "MAP2K"
drugs = list(set(sig_info_cell_df.loc[sig_info_cell_df.targets.str.contains(target)].pert_drug))

target = "MAPK"
drugs += list(set(sig_info_cell_df.loc[sig_info_cell_df.targets.str.contains(target)].pert_drug))

target = "RAF"
drugs += list(set(sig_info_cell_df.loc[sig_info_cell_df.targets.str.contains(target)].pert_drug))

drugs = sorted(list(set(drugs)))

print("drugs for target " + target_name + ":" , len(drugs), drugs)
# Out:
# drugs for target ERK: 7 ['AZ-628', 'PD-0325901', 'dabrafenib', 'selumetinib', 'sorafenib', 'trametinib', 'vemurafenib']

# %%
drugs_list = drugs 

targets = []
doses = []

for drug in drugs_list:
    targets.append(", ".join(sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].targets)))))
    doses.append(", ".join(sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].dose)))))
    
target_drugs_df = pd.DataFrame(list(zip(targets, doses)), index = drugs_list, columns = ["targets","doses"])

display(target_drugs_df)
# Out:
#                                                        targets  \
# AZ-628                                              BRAF, RAF1
# PD-0325901                                              MAP2K1
# dabrafenib                                                BRAF
# selumetinib                                             MAP2K1
# sorafenib    BRAF, DDR2, FGFR1, FLT1, FLT3, FLT4, KDR, KIT,...
# trametinib                                      MAP2K1, MAP2K2
# vemurafenib                                               BRAF
#
#                                doses
# AZ-628       0.12 uM, 1.11 uM, 10 uM
# PD-0325901   0.12 uM, 1.11 uM, 10 uM
# dabrafenib   0.12 uM, 1.11 uM, 10 uM
# selumetinib  0.12 uM, 1.11 uM, 10 uM
# sorafenib           0.12 uM, 1.11 uM
# trametinib            0.12 uM, 10 uM
# vemurafenib  0.12 uM, 1.11 uM, 10 uM

# %%
target_name = "ERK"
target_drugs = drugs_list
# deleted SB-203580 (MAPK1)
# select only gene name RAF1, BRAF, MAP2K1, MAP2K2, MAPK1, MAPK3   (Kinase pathway RAF->MEK->ERK) = module "ERK2

for DPD_val in states:
    plt.figure(figsize = (9,8))
    for drug in target_drugs:
        doses = sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].dose_float)))
        DPDs = []
        DPD_errs = []
        for dose in doses:
            labels = sig_info_cell_df.loc[(sig_info_cell_df.pert_drug == drug) & (sig_info_cell_df.dose_float == dose)].index
            DPDs.append(statistics.mean(DPD_df.loc[labels, DPD_val]))
            if (len(labels) > 1):
                DPD_errs.append(scipy.stats.sem(DPD_df.loc[labels, DPD_val]))
            else:
                DPD_errs.append(0)
        plt.errorbar(doses, DPDs, yerr = DPD_errs, fmt = "o-", label = drug, capsize = 5)
    plt.legend()
    plt.plot([0,10], [0,0], "--", color = "black")
    plt.xlabel("Dose, uM")
    plt.ylabel("DPD_" + DPD_val)
    plt.title("Target: " + target_name)
    #plt.savefig(os.path.join(out_dir, target_name + "_DPD_" + DPD_val + ".png"), dpi = 300)
    plt.show()

# %%
print_drugs += target_drugs

# %% [markdown]
# ### Aurora

# %%
target = "AURK"
drugs = sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.targets.str.contains(target)].pert_drug)))

print("drugs for target " + target + ":" , len(drugs), drugs)
# Out:
# drugs for target AURK: 3 ['JNJ-7706621', 'barasertib-HQPA', 'tozasertib']

# %%
drugs_list = drugs

targets = []
doses = []

for drug in drugs_list:
    targets.append(", ".join(sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].targets)))))
    doses.append(", ".join(sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].dose)))))
    
target_drugs_df = pd.DataFrame(list(zip(targets, doses)), index = drugs_list, columns = ["targets","doses"])

display(target_drugs_df)
# Out:
#                                                     targets  \
# JNJ-7706621                        AURKA, AURKB, CDK1, CDK2
# barasertib-HQPA                                       AURKB
# tozasertib       ABL1, AURKA, AURKB, AURKC, BCR, FLT3, JAK2
#
#                                    doses
# JNJ-7706621      0.12 uM, 1.11 uM, 10 uM
# barasertib-HQPA  0.12 uM, 1.11 uM, 10 uM
# tozasertib       0.12 uM, 1.11 uM, 10 uM

# %%
target_name = "Aurora"
target_drugs = drugs_list
# deleted ENMD-2076, KW-2449, orantinib because other targets 
# deleted aurora-a-inhibitor-i (2017) - not in data 2020

for DPD_val in states:
    plt.figure(figsize = (9,8))
    for drug in target_drugs:
        doses = sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].dose_float)))
        DPDs = []
        DPD_errs = []
        for dose in doses:
            labels = sig_info_cell_df.loc[(sig_info_cell_df.pert_drug == drug) & (sig_info_cell_df.dose_float == dose)].index
            DPDs.append(statistics.mean(DPD_df.loc[labels, DPD_val]))
            if (len(labels) > 1):
                DPD_errs.append(scipy.stats.sem(DPD_df.loc[labels, DPD_val]))
            else:
                DPD_errs.append(0)
        plt.errorbar(doses, DPDs, yerr = DPD_errs, fmt = "o-", label = drug, capsize = 5)
    plt.legend()
    plt.plot([0,10], [0,0], "--", color = "black")
    plt.xlabel("Dose, uM")
    plt.ylabel("DPD_" + DPD_val)
    plt.title("Target: " + target_name)
    #plt.savefig(os.path.join(out_dir, target_name + "_DPD_" + DPD_val + ".png"), dpi = 300)
    plt.show()

# %% [markdown]
# ### TGFbR

# %%
target = "TGF"
drugs = sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.targets.str.contains(target)].pert_drug)))

print("drugs for target " + target + ":" , len(drugs), drugs)
# Out:
# drugs for target TGF: 0 []

# %%
drugs_list = drugs

targets = []
doses = []

for drug in drugs_list:
    targets.append(", ".join(sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].targets)))))
    doses.append(", ".join(sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].dose)))))
    
target_drugs_df = pd.DataFrame(list(zip(targets, doses)), index = drugs_list, columns = ["targets","doses"])

display(target_drugs_df)
# Out:
#           targets                                              doses
# SB-525334  TGFBR1  0.04 uM, 0.12 uM, 0.37 uM, 1.11 uM, 10 uM, 3.3...

# %%
target_name = "TGFbR"
target_drugs = drugs_list

for DPD_val in states:
    plt.figure(figsize = (9,8))
    for drug in target_drugs:
        doses = sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].dose_float)))
        DPDs = []
        DPD_errs = []
        for dose in doses:
            labels = sig_info_cell_df.loc[(sig_info_cell_df.pert_drug == drug) & (sig_info_cell_df.dose_float == dose)].index
            DPDs.append(statistics.mean(DPD_df.loc[labels, DPD_val]))
            if (len(labels) > 1):
                DPD_errs.append(scipy.stats.sem(DPD_df.loc[labels, DPD_val]))
            else:
                DPD_errs.append(0)
        plt.errorbar(doses, DPDs, yerr = DPD_errs, fmt = "o-", label = drug, capsize = 5)
    plt.legend()
    plt.plot([0,10], [0,0], "--", color = "black")
    plt.xlabel("Dose, uM")
    plt.ylabel("DPD_" + DPD_val)
    plt.title("Target: " + target_name)
    plt.savefig(os.path.join(out_dir, target_name + "_DPD_" + DPD_val + ".png"), dpi = 300)
    plt.show()

# %%
print_drugs += target_drugs

# %% [markdown]
# ### VEGFR

# %%
drugs_list = ["rebastinib", "lenvatinib", "orantinib", "foretinib", "cediranib", "sunitinib", "tivozanib"]

targets = []
doses = []

for drug in drugs_list:
    targets.append(", ".join(sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].targets)))))
    doses.append(", ".join(sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].dose)))))
    
target_drugs_df = pd.DataFrame(list(zip(targets, doses)), index = drugs_list, columns = ["targets","doses"])

display(target_drugs_df)
# Out:
#            targets doses
# rebastinib
# lenvatinib
# orantinib
# foretinib
# cediranib
# sunitinib
# tivozanib

# %%
target_name = "VEGFR"
target_drugs = drugs_list

for DPD_val in states:
    plt.figure(figsize = (9,8))
    for drug in target_drugs:
        doses = sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].dose_float)))
        DPDs = []
        DPD_errs = []
        for dose in doses:
            labels = sig_info_cell_df.loc[(sig_info_cell_df.pert_drug == drug) & (sig_info_cell_df.dose_float == dose)].index
            DPDs.append(statistics.mean(DPD_df.loc[labels, DPD_val]))
            if (len(labels) > 1):
                DPD_errs.append(scipy.stats.sem(DPD_df.loc[labels, DPD_val]))
            else:
                DPD_errs.append(0)
        plt.errorbar(doses, DPDs, yerr = DPD_errs, fmt = "o-", label = drug, capsize = 5)
    plt.legend()
    plt.plot([0,10], [0,0], "--", color = "black")
    plt.xlabel("Dose, uM")
    plt.ylabel("DPD_" + DPD_val)
    plt.title("Target: " + target_name)
    plt.savefig(os.path.join(out_dir, target_name + "_DPD_" + DPD_val + ".png"), dpi = 300)
    plt.show()

# %%
print_drugs += target_drugs

# %% [markdown]
# ### PKC

# %%
target = "PRKC"
drugs = sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.targets.str.contains(target)].pert_drug)))

print("drugs for target " + target + ":" , len(drugs), drugs)
# Out:
# drugs for target PRKC: 0 []

# %%
drugs_list = drugs

targets = []
doses = []

for drug in drugs_list:
    targets.append(", ".join(sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].targets)))))
    doses.append(", ".join(sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].dose)))))
    
target_drugs_df = pd.DataFrame(list(zip(targets, doses)), index = drugs_list, columns = ["targets","doses"])

display(target_drugs_df)
# Out:
#             targets                                        doses
# enzastaurin   PRKCB  0.01 uM, 0.03 uM, 0.08 uM, 0.74 uM, 2.22 uM

# %%
target_name = "PKC"
target_drugs = drugs_list

for DPD_val in states:
    plt.figure(figsize = (9,8))
    for drug in target_drugs:
        doses = sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].dose_float)))
        DPDs = []
        DPD_errs = []
        for dose in doses:
            labels = sig_info_cell_df.loc[(sig_info_cell_df.pert_drug == drug) & (sig_info_cell_df.dose_float == dose)].index
            DPDs.append(statistics.mean(DPD_df.loc[labels, DPD_val]))
            if (len(labels) > 1):
                DPD_errs.append(scipy.stats.sem(DPD_df.loc[labels, DPD_val]))
            else:
                DPD_errs.append(0)
        plt.errorbar(doses, DPDs, yerr = DPD_errs, fmt = "o-", label = drug, capsize = 5)
    plt.legend()
    plt.plot([0,10], [0,0], "--", color = "black")
    plt.xlabel("Dose, uM")
    plt.ylabel("DPD_" + DPD_val)
    plt.title("Target: " + target_name)
    plt.savefig(os.path.join(out_dir, target_name + "_DPD_" + DPD_val + ".png"), dpi = 300)

# %%
print_drugs += target_drugs

# %% [markdown]
# ### PTGS

# %%
target = "PTGS"
drugs = sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.targets.str.contains(target)].pert_drug)))

print("drugs for target " + target + ":" , len(drugs), drugs)
# Out:
# drugs for target PTGS: 27 ['DUP-697', 'SC-560', 'aceclofenac', 'acemetacin', 'amtolmetin-guacil', 'asaraldehyde', 'diflunisal', 'epirizole', 'etoricoxib', 'flufenamic-acid', 'ibuprofen-piconol', 'icosapent', 'indoprofen', 'lornoxicam', 'lumiracoxib', 'metoxibutropate', 'nabumetone', 'nepafenac', 'niflumic-acid', 'paracetamol', 'phenacetin', 'rutaecarpine', 'salicylic-acid', 'sulfasalazine', 'suprofen', 'tiaprofenic-acid', 'tolmetin']

# %%
drugs_list = drugs

targets = []
doses = []

for drug in drugs_list:
    targets.append(", ".join(sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].targets)))))
    doses.append(", ".join(sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].dose)))))
    
target_drugs_df = pd.DataFrame(list(zip(targets, doses)), index = drugs_list, columns = ["targets","doses"])

display(target_drugs_df)
# Out:
#                                     targets                    doses
# DUP-697                               PTGS2  1.11 uM, 10 uM, 3.33 uM
# SC-560                                PTGS1  1.11 uM, 10 uM, 3.33 uM
# aceclofenac                           PTGS2  1.11 uM, 10 uM, 3.33 uM
# acemetacin                     PTGS1, PTGS2  1.11 uM, 10 uM, 3.33 uM
# amtolmetin-guacil              PTGS1, PTGS2  1.11 uM, 10 uM, 3.33 uM
# asaraldehyde                          PTGS2  1.11 uM, 10 uM, 3.33 uM
# diflunisal                     PTGS1, PTGS2  1.11 uM, 10 uM, 3.33 uM
# epirizole                      PTGS1, PTGS2  1.11 uM, 10 uM, 3.33 uM
# etoricoxib                            PTGS2  1.11 uM, 10 uM, 3.33 uM
# flufenamic-acid    AKR1C3, AR, PTGS1, PTGS2  1.11 uM, 10 uM, 3.33 uM
# ibuprofen-piconol              PTGS1, PTGS2  1.11 uM, 10 uM, 3.33 uM
# icosapent                      PTGS1, PTGS2  1.11 uM, 10 uM, 3.33 uM
# indoprofen                     PTGS1, PTGS2  1.11 uM, 10 uM, 3.33 uM
# lornoxicam                     PTGS1, PTGS2  1.11 uM, 10 uM, 3.33 uM
# lumiracoxib                           PTGS2  1.11 uM, 10 uM, 3.33 uM
# metoxibutropate                PTGS1, PTGS2  1.11 uM, 10 uM, 3.33 uM
# nabumetone                            PTGS2  1.11 uM, 10 uM, 3.33 uM
# nepafenac                      PTGS1, PTGS2  1.11 uM, 10 uM, 3.33 uM
# niflumic-acid                 CLCNKA, PTGS2  1.11 uM, 10 uM, 3.33 uM
# paracetamol                    PTGS1, PTGS2  1.11 uM, 10 uM, 3.33 uM
# phenacetin                            PTGS1  1.11 uM, 10 uM, 3.33 uM
# rutaecarpine                          PTGS2  1.11 uM, 10 uM, 3.33 uM
# salicylic-acid                        PTGS1  1.11 uM, 10 uM, 3.33 uM
# sulfasalazine           ALOX5, PTGS1, PTGS2  1.11 uM, 10 uM, 3.33 uM
# suprofen                       PTGS1, PTGS2  1.11 uM, 10 uM, 3.33 uM
# tiaprofenic-acid               PTGS1, PTGS2  1.11 uM, 10 uM, 3.33 uM
# tolmetin                       PTGS1, PTGS2  1.11 uM, 10 uM, 3.33 uM

# %%
target_name = "PTGS"
target_drugs = [  'nepafenac', 'niflumic-acid', 'paracetamol', 'phenacetin']#, 'rutaecarpine', 'salicylic-acid', 'sulfasalazine', 'suprofen', 'tiaprofenic-acid', 'tolmetin']

for DPD_val in states:
    plt.figure(figsize = (9,8))
    for drug in target_drugs:
        doses = sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].dose_float)))
        DPDs = []
        DPD_errs = []
        for dose in doses:
            labels = sig_info_cell_df.loc[(sig_info_cell_df.pert_drug == drug) & (sig_info_cell_df.dose_float == dose)].index
            DPDs.append(statistics.mean(DPD_df.loc[labels, DPD_val]))
            if (len(labels) > 1):
                DPD_errs.append(scipy.stats.sem(DPD_df.loc[labels, DPD_val]))
            else:
                DPD_errs.append(0)
        plt.errorbar(doses, DPDs, yerr = DPD_errs, fmt = "o-", label = drug, capsize = 5)
    plt.legend()
    plt.plot([0,10], [0,0], "--", color = "black")
    plt.xlabel("Dose, uM")
    plt.ylabel("DPD_" + DPD_val)
    plt.title("Target: " + target_name)
    #plt.savefig(os.path.join(out_dir, target_name + "_DPD_" + DPD_val + ".png"), dpi = 300)

# %%
# delete module "PTGS"

# %% [markdown]
# ### PSMB

# %%
target = "PSMB"
drugs = sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.targets.str.contains(target)].pert_drug)))

print("drugs for target " + target + ":" , len(drugs), drugs)
# Out:
# drugs for target PSMB: 2 ['MG-132', 'ixazomib']

# %%
drugs_list = drugs

targets = []
doses = []

for drug in drugs_list:
    targets.append(", ".join(sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].targets)))))
    doses.append(", ".join(sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].dose)))))
    
target_drugs_df = pd.DataFrame(list(zip(targets, doses)), index = drugs_list, columns = ["targets","doses"])

display(target_drugs_df)
# Out:
#          targets                    doses
# MG-132     PSMB1         0.12 uM, 1.11 uM
# ixazomib   PSMB1  0.12 uM, 1.11 uM, 10 uM

# %%
target_name = "PSMB"
target_drugs = drugs_list

for DPD_val in states:
    plt.figure(figsize = (9,8))
    for drug in target_drugs:
        doses = sorted(list(set(sig_info_cell_df.loc[sig_info_cell_df.pert_drug == drug].dose_float)))
        DPDs = []
        DPD_errs = []
        for dose in doses:
            labels = sig_info_cell_df.loc[(sig_info_cell_df.pert_drug == drug) & (sig_info_cell_df.dose_float == dose)].index
            DPDs.append(statistics.mean(DPD_df.loc[labels, DPD_val]))
            if (len(labels) > 1):
                DPD_errs.append(scipy.stats.sem(DPD_df.loc[labels, DPD_val]))
            else:
                DPD_errs.append(0)
        plt.errorbar(doses, DPDs, yerr = DPD_errs, fmt = "o-", label = drug, capsize = 5)
    plt.legend()
    plt.plot([0,20], [0,0], "--", color = "black")
    plt.xlabel("Dose, uM")
    plt.ylabel("DPD_" + DPD_val)
    plt.title("Target: " + target_name)
    #plt.savefig(os.path.join(out_dir, target_name + "_DPD_" + DPD_val + ".png"), dpi = 300)

# %%
print_drugs += target_drugs

# %%
# delete module "PPARG"
