# %% [markdown]
# # 01 Data preparation
#
# Processing xlsx files from data folder into suitable inputs and generate other input files

# %%
import pandas as pd
import numpy as np
import os
import pickle

# %%
data_dir = "~/Phd_project/project_GBM/gbm_DATA/gbm_DATA_LINCS_GI1"
info_dir = data_dir

out_dir = "01_outputs_2020"

os.makedirs(out_dir, exist_ok = True)

# %% [markdown]
# ## Modules
#
# Load data about modules and drugs.

# %%
### DATA
### remove whitespaces in names (modules), remove duplicates

modules_df = pd.read_excel(
    os.path.join(info_dir, "ALL_DATA_2020_Jing_gbm.xlsx"), sheet_name = "modules", index_col = 0)
# display(modules_df)

selected_modules = modules_df.index.tolist()
print(len(selected_modules), ' - Size after reading')

# remove duplicates
selected_modules = modules_df.index.unique().tolist()
print(len(selected_modules), ' - Size after remove duplicates')

# remove whitespaces in modules' names 
selected_modules = [d.strip() for d in selected_modules]

print('Selected modules list: ', len(selected_modules), selected_modules)
# Out:
# 11  - Size after reading
# 11  - Size after remove duplicates
# Selected modules list:  11 ['CDK1', 'CDK2', 'CDK4_6', 'p53', 'EGFR', 'Aurora', 'Estrogen', 'PDGFR', 'Hypoxia', 'ERK', 'PI3K']

# %%
### DATA
### remove whitespaces in names (modules, drugs), remove duplicates
### check the dimensions of the indicator IC50 1 uM = 1000 nM
### copy-paste as values, numbers, no formulas

IC50_df = pd.read_excel(os.path.join(info_dir, "ALL_DATA_2020_Jing_gbm.xlsx"), sheet_name = "IC50s")
IC50_df.drop(columns=['Notes','Removed'],inplace=True)

print(len(IC50_df.index), ' - Size after reading')
# display(IC50_df)

# rename
IC50_df = IC50_df.rename(columns = {"IC50, uM": "IC50"})

# manually correcting value IC50, Example  for IOX2 -> 30 nM  
#IC50_df.loc[IC50_df.index == 'IOX2', IC50_df.columns == 'IC50'] = 30/1000

# remove non-selected modules, modules' names with whitespaces or empty
IC50_df = IC50_df[IC50_df.Module.isin(selected_modules)]

print(len(IC50_df.index), ' - Size after remove modules')
# display(IC50_df)

# remove duplicates 
# Considering certain columns is optional. 
# Indexes, including time indexes are ignored.
IC50_df = IC50_df.drop_duplicates()

print(len(IC50_df.index), ' - Size after remove duplicates')
display(IC50_df)
# Out:
# 39  - Size after reading
# 39  - Size after remove modules
# 39  - Size after remove duplicates
#                    Drug    Module       IC50
# 0           JNJ-7706621      CDK1    0.02700
# 1            PHA-793887      CDK1    0.18000
# 2           roscovitine      CDK2    2.00000
# 3             alvocidib    CDK4_6    0.12000
# 4           palbociclib    CDK4_6    0.04500
# 5             AS-605240      PI3K    0.15950
# 6              GDC-0349      PI3K    3.00000
# 7             LY-294002      PI3K    1.36000
# 8            NVP-BEZ235      PI3K    1.71000
# 9             taselisib      PI3K    0.00262
# 10               PI-103      PI3K    0.09000
# 11               AZ-628       ERK    3.00000
# 12           PD-0325901       ERK    0.01500
# 13           dabrafenib       ERK    0.10000
# 14          selumetinib       ERK    0.64300
# 15           trametinib       ERK    0.00408
# 16          vemurafenib       ERK    0.11850
# 17          BAY-87-2243   Hypoxia    0.00210
# 18            CAY-10585   Hypoxia   13.20000
# 19             imatinib     PDGFR    0.30000
# 20           tandutinib     PDGFR    0.60000
# 21            masitinib     PDGFR    2.13000
# 22            ponatinib     PDGFR    0.00330
# 23      barasertib-HQPA    Aurora    0.00111
# 24           tozasertib    Aurora    0.02320
# 25           dienestrol  Estrogen  200.00000
# 26  estradiol-cypionate  Estrogen  200.00000
# 27           raloxifene  Estrogen    0.01710
# 28             afatinib      EGFR    0.03000
# 29            erlotinib      EGFR    0.00600
# 30            gefitinib      EGFR    0.17100
# 31            lapatinib      EGFR    0.03240
# 32           vandetanib      EGFR    1.50000
# 33              AMG-232       p53    0.00180
# 34              HLI-373       p53    3.00000
# 35             nutlin-3       p53    0.54000
# 36                 RITA       p53    9.75000
# 37            SAR405838       p53    0.02640
# 38           serdemetan       p53   62.15000

# %%
modules = IC50_df.Module.unique().tolist()

print('IC50_df  modules list: ', len(modules), modules)
print()
print('Selected modules list: ', len(selected_modules), selected_modules)

### CHECK
print()
print('CHECK: ', len(selected_modules),'=?', len(modules))

n_modules = len(modules)
# Out:
# IC50_df  modules list:  11 ['CDK1', 'CDK2', 'CDK4_6', 'PI3K', 'ERK', 'Hypoxia', 'PDGFR', 'Aurora', 'Estrogen', 'EGFR', 'p53']
#
# Selected modules list:  11 ['CDK1', 'CDK2', 'CDK4_6', 'p53', 'EGFR', 'Aurora', 'Estrogen', 'PDGFR', 'Hypoxia', 'ERK', 'PI3K']
#
# CHECK:  11 =? 11

# %%
drugs = IC50_df.Drug.tolist()
print(len(drugs), ' - Size after reading')

# remove duplicates
drugs = IC50_df.Drug.unique().tolist()
print(len(drugs), ' - Size after remove duplicates')

# remove whitespaces in drugs' names (necessary for some)
drugs = [d.strip() for d in drugs]

# remove duplicates after remove whitespaces
drugs = list(set(drugs))
print(len(drugs), ' - Size after remove duplicates without whitespaces')

print('Drugs list: ', len(drugs), drugs)

n_drugs = len(drugs)
# Out:
# 39  - Size after reading
# 39  - Size after remove duplicates
# 39  - Size after remove duplicates without whitespaces
# Drugs list:  39 ['selumetinib', 'lapatinib', 'trametinib', 'NVP-BEZ235', 'SAR405838', 'gefitinib', 'BAY-87-2243', 'vemurafenib', 'CAY-10585', 'palbociclib', 'AS-605240', 'GDC-0349', 'tozasertib', 'nutlin-3', 'PI-103', 'HLI-373', 'taselisib', 'estradiol-cypionate', 'erlotinib', 'LY-294002', 'dabrafenib', 'JNJ-7706621', 'masitinib', 'PD-0325901', 'barasertib-HQPA', 'ponatinib', 'tandutinib', 'vandetanib', 'RITA', 'afatinib', 'roscovitine', 'PHA-793887', 'raloxifene', 'AMG-232', 'dienestrol', 'alvocidib', 'serdemetan', 'AZ-628', 'imatinib']

# %% [markdown]
# ## L1000 meta data
#
# Get sig_id for selected drugs.

# %%
sig_info_df = pd.read_excel(os.path.join(data_dir, "sig_info_2020_GI1.xlsx"), index_col = 0)

display(sig_info_df)
# Out:
#                     cell    plate  time             level_3_samples  \
# level_5_sig_id
# ASG002_GI1_24H:A03   GI1   ASG002  24 h   ASG002_GI1_24H_X1_B35:A03
# ASG002_GI1_24H:A04   GI1   ASG002  24 h   ASG002_GI1_24H_X1_B35:A04
# ASG002_GI1_24H:A05   GI1   ASG002  24 h   ASG002_GI1_24H_X1_B35:A05
# ASG002_GI1_24H:A06   GI1   ASG002  24 h   ASG002_GI1_24H_X1_B35:A06
# ASG002_GI1_24H:J13   GI1   ASG002  24 h   ASG002_GI1_24H_X1_B35:J13
# ...                  ...      ...   ...                         ...
# MOAR012_GI1_24H:P20  GI1  MOAR012  24 h  MOAR012_GI1_24H_X1_B36:P20
# MOAR012_GI1_24H:P21  GI1  MOAR012  24 h  MOAR012_GI1_24H_X1_B36:P21
# MOAR012_GI1_24H:P22  GI1  MOAR012  24 h  MOAR012_GI1_24H_X1_B36:P22
# MOAR012_GI1_24H:P23  GI1  MOAR012  24 h  MOAR012_GI1_24H_X1_B36:P23
# MOAR012_GI1_24H:P24  GI1  MOAR012  24 h  MOAR012_GI1_24H_X1_B36:P24
#
#                      samples_number    pert_type    pert_drug         targets  \
# level_5_sig_id
# ASG002_GI1_24H:A03                1  ctl_vehicle         DMSO  DMSO_No_target
# ASG002_GI1_24H:A04                1  ctl_vehicle         DMSO  DMSO_No_target
# ASG002_GI1_24H:A05                1  ctl_vehicle         DMSO  DMSO_No_target
# ASG002_GI1_24H:A06                1  ctl_vehicle         DMSO  DMSO_No_target
# ASG002_GI1_24H:J13                1  ctl_vehicle         DMSO  DMSO_No_target
# ...                             ...          ...          ...             ...
# MOAR012_GI1_24H:P20               1       trt_cp  BAY-61-3606             NaN
# MOAR012_GI1_24H:P21               1       trt_cp  BAY-61-3606             NaN
# MOAR012_GI1_24H:P22               1       trt_cp   ethaverine             NaN
# MOAR012_GI1_24H:P23               1       trt_cp   ethaverine             NaN
# MOAR012_GI1_24H:P24               1       trt_cp   ethaverine             NaN
#
#                      targets_number     dose  dose_float
# level_5_sig_id
# ASG002_GI1_24H:A03                0     0 uM        0.00
# ASG002_GI1_24H:A04                0     0 uM        0.00
# ASG002_GI1_24H:A05                0     0 uM        0.00
# ASG002_GI1_24H:A06                0     0 uM        0.00
# ASG002_GI1_24H:J13                0     0 uM        0.00
# ...                             ...      ...         ...
# MOAR012_GI1_24H:P20               0  3.33 uM        3.33
# MOAR012_GI1_24H:P21               0  1.11 uM        1.11
# MOAR012_GI1_24H:P22               0    10 uM       10.00
# MOAR012_GI1_24H:P23               0  3.33 uM        3.33
# MOAR012_GI1_24H:P24               0  1.11 uM        1.11
#
# [2151 rows x 11 columns]

# %%
# now filtering so only the required drugs are present
sig_info_df = sig_info_df.loc[sig_info_df.pert_drug.isin(drugs)]

# here's what we have now
display(sig_info_df)
# Out:
#                     cell    plate  time             level_3_samples  \
# level_5_sig_id
# ASG002_GI1_24H:A10   GI1   ASG002  24 h   ASG002_GI1_24H_X1_B35:A10
# ASG002_GI1_24H:A11   GI1   ASG002  24 h   ASG002_GI1_24H_X1_B35:A11
# ASG002_GI1_24H:A12   GI1   ASG002  24 h   ASG002_GI1_24H_X1_B35:A12
# ASG002_GI1_24H:A19   GI1   ASG002  24 h   ASG002_GI1_24H_X1_B35:A19
# ASG002_GI1_24H:A20   GI1   ASG002  24 h   ASG002_GI1_24H_X1_B35:A20
# ...                  ...      ...   ...                         ...
# MOAR010_GI1_24H:K08  GI1  MOAR010  24 h  MOAR010_GI1_24H_X1_B36:K08
# MOAR010_GI1_24H:K09  GI1  MOAR010  24 h  MOAR010_GI1_24H_X1_B36:K09
# MOAR011_GI1_24H:F07  GI1  MOAR011  24 h  MOAR011_GI1_24H_X1_B36:F07
# MOAR011_GI1_24H:F08  GI1  MOAR011  24 h  MOAR011_GI1_24H_X1_B36:F08
# MOAR011_GI1_24H:F09  GI1  MOAR011  24 h  MOAR011_GI1_24H_X1_B36:F09
#
#                      samples_number pert_type   pert_drug targets  \
# level_5_sig_id
# ASG002_GI1_24H:A10                1    trt_cp   taselisib  PIK3CA
# ASG002_GI1_24H:A11                1    trt_cp   taselisib  PIK3CA
# ASG002_GI1_24H:A12                1    trt_cp   taselisib  PIK3CA
# ASG002_GI1_24H:A19                1    trt_cp   AS-605240  PIK3CG
# ASG002_GI1_24H:A20                1    trt_cp   AS-605240  PIK3CG
# ...                             ...       ...         ...     ...
# MOAR010_GI1_24H:K08               1    trt_cp   SAR405838    MDM2
# MOAR010_GI1_24H:K09               1    trt_cp   SAR405838    MDM2
# MOAR011_GI1_24H:F07               1    trt_cp  serdemetan    MDM2
# MOAR011_GI1_24H:F08               1    trt_cp  serdemetan    MDM2
# MOAR011_GI1_24H:F09               1    trt_cp  serdemetan    MDM2
#
#                      targets_number     dose  dose_float
# level_5_sig_id
# ASG002_GI1_24H:A10                1    10 uM       10.00
# ASG002_GI1_24H:A11                1  1.11 uM        1.11
# ASG002_GI1_24H:A12                1  0.12 uM        0.12
# ASG002_GI1_24H:A19                1    10 uM       10.00
# ASG002_GI1_24H:A20                1  1.11 uM        1.11
# ...                             ...      ...         ...
# MOAR010_GI1_24H:K08               1  3.33 uM        3.33
# MOAR010_GI1_24H:K09               1  1.11 uM        1.11
# MOAR011_GI1_24H:F07               1    10 uM       10.00
# MOAR011_GI1_24H:F08               1  3.33 uM        3.33
# MOAR011_GI1_24H:F09               1  1.11 uM        1.11
#
# [119 rows x 11 columns]

# %% [markdown]
# Manually remove  few inhibition from data set, since it does differ from the other data points.

# %% [markdown]
# inhib_to_filter = "PF-03758309"
# dose_to_filter = 10
#
# id_to_filter = sig_info_df[
#     np.logical_and(
#         sig_info_df.pert_drug == inhib_to_filter,
#         sig_info_df.dose_float == dose_to_filter,
#     )
# ].index.values
#
# print(id_to_filter)
#
# sig_info_df = sig_info_df[~sig_info_df.index.isin(id_to_filter)]
# display(sig_info_df)

# %% [markdown]
# inhib_to_filter = "roscovitine"
# dose_to_filter = 3.33
#
# id_to_filter = sig_info_df[
#     np.logical_and(
#         sig_info_df.pert_drug == inhib_to_filter,
#         sig_info_df.dose_float == dose_to_filter,
#     )
# ].index.values
#
# print(id_to_filter)
#
# sig_info_df = sig_info_df[~sig_info_df.index.isin(id_to_filter)]
# display(sig_info_df)

# %%
exp_ids = sig_info_df.index.unique().tolist()
print('Experiments ids list: ', len(exp_ids))

n_experiments = len(exp_ids)
# Out:
# Experiments ids list:  119

# %% [markdown]
# Confirm data by checking the drugs of interest against the filtered L1000 meta data.

# %%
print(f"Number of drugs of interest:\t{len(drugs)}")
#print(f'Number of drugs in L1000 data:\t{len(sig_info_df.value_counts("drugs"))}')

#sig_info_df.value_counts("drugs")
# Out:
# Number of drugs of interest:	39

# %% [markdown]
# ## L1000 data

# %%
Data_norm_df = pd.read_excel(os.path.join(data_dir, "Data_norm_2020_GI1.xlsx"), index_col = 0)
display(Data_norm_df)
# Out:
#                          AARS     ABCB6     ABCC5     ABCF1     ABCF3  \
# ASG002_GI1_24H:A03   0.014285  0.302692  0.124004  0.005246  0.340042
# ASG002_GI1_24H:A04   0.084985  0.276642  0.324054 -0.016954  0.079942
# ASG002_GI1_24H:A05  -0.019615  0.183842  0.282254 -0.577354  0.316943
# ASG002_GI1_24H:A06   0.324884  0.146642  0.192004  0.043446  0.141842
# ASG002_GI1_24H:J13   0.182484  0.060892 -0.044696 -0.346554 -0.158858
# ...                       ...       ...       ...       ...       ...
# MOAR012_GI1_24H:P20  0.844125  0.359950  0.014575  0.002151  0.108225
# MOAR012_GI1_24H:P21  0.346174  0.102800 -0.449275 -0.206150  0.500625
# MOAR012_GI1_24H:P22  0.195774  0.285975 -0.675725 -0.243999  0.197526
# MOAR012_GI1_24H:P23  0.093424  0.179075 -0.400900 -0.337299  0.084625
# MOAR012_GI1_24H:P24 -0.471975 -0.503550 -0.028525 -0.379799  0.419825
#
#                         ABHD4     ABHD6      ABL1     ACAA1     ACAT2  ...  \
# ASG002_GI1_24H:A03   0.276465  0.127250  0.328650  0.627212 -0.220684  ...
# ASG002_GI1_24H:A04   0.155465 -0.100200  0.345250  0.183511 -0.080484  ...
# ASG002_GI1_24H:A05   0.109765  0.117800  0.301150 -0.187188  0.275415  ...
# ASG002_GI1_24H:A06  -0.053335 -0.028000 -0.580550  0.622812 -0.080985  ...
# ASG002_GI1_24H:J13  -0.031434  0.068500  0.372950 -0.366439 -0.176334  ...
# ...                       ...       ...       ...       ...       ...  ...
# MOAR012_GI1_24H:P20 -0.232287  0.331775  0.190337 -0.644337 -0.320262  ...
# MOAR012_GI1_24H:P21 -0.383837  0.456875  0.125388 -0.490437 -0.240913  ...
# MOAR012_GI1_24H:P22  0.238638 -0.013250 -0.236763 -0.761688 -0.048863  ...
# MOAR012_GI1_24H:P23 -0.015337 -0.073375 -0.276812  0.107612  0.054488  ...
# MOAR012_GI1_24H:P24 -0.197888  0.481525 -0.420913 -0.394637  0.108887  ...
#
#                         ZMIZ1     ZMYM2    ZNF131    ZNF274    ZNF318  \
# ASG002_GI1_24H:A03  -0.102669  0.893785  0.505962 -0.357469  0.517504
# ASG002_GI1_24H:A04  -0.057569 -0.443416  0.094212 -0.303270  0.271754
# ASG002_GI1_24H:A05   0.082731 -0.124365  0.141711 -0.221269  0.206753
# ASG002_GI1_24H:A06   0.246530  0.644485  0.082212 -0.069869  0.142254
# ASG002_GI1_24H:J13  -0.204769 -0.254016  0.310211 -0.177470 -0.026896
# ...                       ...       ...       ...       ...       ...
# MOAR012_GI1_24H:P20 -0.223550  0.344850 -0.421962 -0.379925  0.154400
# MOAR012_GI1_24H:P21 -0.271100 -0.497100 -0.194638 -0.082924 -0.450300
# MOAR012_GI1_24H:P22 -0.190250 -0.331850 -0.556237 -0.161175 -0.274225
# MOAR012_GI1_24H:P23  0.203775 -0.216850 -1.163637 -0.258825 -0.483600
# MOAR012_GI1_24H:P24  0.054900 -0.138650 -0.099087 -0.057925  0.068699
#
#                        ZNF395    ZNF451    ZNF586    ZNF589      ZW10
# ASG002_GI1_24H:A03   0.255096  0.008023 -0.144581 -0.187158 -0.225612
# ASG002_GI1_24H:A04  -0.176304 -0.028377  0.017819 -0.187858 -0.157212
# ASG002_GI1_24H:A05   0.215946  0.000723  0.130619 -0.080258  0.012289
# ASG002_GI1_24H:A06   0.576146  0.092923 -0.041681 -0.253158 -0.221112
# ASG002_GI1_24H:J13   0.068946  0.070023 -0.011181 -0.366158  0.121888
# ...                       ...       ...       ...       ...       ...
# MOAR012_GI1_24H:P20  0.031300 -0.095100 -0.317588  0.103650  1.095600
# MOAR012_GI1_24H:P21 -0.088776  0.427825 -0.431062 -0.064025  1.196051
# MOAR012_GI1_24H:P22  0.178549  0.110350  0.389612  0.043350  1.345251
# MOAR012_GI1_24H:P23  0.067650  0.465775  0.345462  1.912200  1.386475
# MOAR012_GI1_24H:P24 -0.361300  0.363325 -0.004938  0.026675  1.221100
#
# [2151 rows x 978 columns]

# %%
Data_norm_df = Data_norm_df[Data_norm_df.index.isin(exp_ids)]

# arrange experiments in same order as in list
Data_norm_df["sort_col"] = Data_norm_df.index.map({val: i for i, val in enumerate(exp_ids)})
Data_norm_df = Data_norm_df.sort_values("sort_col")
Data_norm_df = Data_norm_df.drop("sort_col", axis = 1)

# transpose
Data_norm_df = Data_norm_df.T

display(Data_norm_df)
# Out:
#         ASG002_GI1_24H:A10  ASG002_GI1_24H:A11  ASG002_GI1_24H:A12  \
# AARS              0.523185            0.938285            0.505484
# ABCB6             0.118442            0.227142            0.304742
# ABCC5             0.564554            0.440104            0.225354
# ABCF1             0.523446           -0.058954           -0.155854
# ABCF3            -0.166158            0.369043           -0.040257
# ...                    ...                 ...                 ...
# ZNF395            2.884646            1.014946            2.148046
# ZNF451            0.404223            0.016124           -0.002077
# ZNF586           -0.524031            0.024019           -0.102681
# ZNF589            0.094642           -0.020358            0.035642
# ZW10             -0.448712           -0.313312           -0.139711
#
#         ASG002_GI1_24H:A19  ASG002_GI1_24H:A20  ASG002_GI1_24H:A21  \
# AARS              0.081884            0.098285           -0.151566
# ABCB6            -0.382158            0.238542            0.155942
# ABCC5             0.310204            0.294754            0.167454
# ABCF1            -0.258454           -0.506854           -0.501254
# ZNF451            -0.283650             0.061800
# ZNF586            -0.108375             0.071375
# ZNF589            -0.146675             0.158125
# ZW10              -0.112700            -0.183300
#
# [978 rows x 119 columns]

# %%
genes = Data_norm_df.index.tolist()
print('Landmark genes list: ', len(genes), genes)

n_genes = len(genes)
# Out:
# Landmark genes list:  978 ['AARS', 'ABCB6', 'ABCC5', 'ABCF1', 'ABCF3', 'ABHD4', 'ABHD6', 'ABL1', 'ACAA1', 'ACAT2', 'ACBD3', 'ACD', 'ACLY', 'ACOT9', 'ADAM10', 'ADAT1', 'ADGRE5', 'ADGRG1', 'ADH5', 'ADI1', 'ADO', 'ADRB2', 'AGL', 'AKAP8', 'AKAP8L', 'AKR7A2', 'AKT1', 'ALAS1', 'ALDH7A1', 'ALDOA', 'ALDOC', 'AMDHD2', 'ANKRD10', 'ANO10', 'ANXA7', 'APBB2', 'APOE', 'APP', 'APPBP2', 'ARFIP2', 'ARHGAP1', 'ARHGEF12', 'ARHGEF2', 'ARID4B', 'ARID5B', 'ARL4C', 'ARNT2', 'ARPP19', 'ASAH1', 'ASCC3', 'ATF1', 'ATF5', 'ATF6', 'ATG3', 'ATMIN', 'ATP11B', 'ATP1B1', 'ATP2C1', 'ATP6V0B', 'ATP6V1D', 'AURKA', 'AURKB', 'AXIN1', 'B4GAT1', 'BACE2', 'BAD', 'BAG3', 'BAMBI', 'BAX', 'BCL2', 'BCL7B', 'BDH1', 'BECN1', 'BHLHE40', 'BID', 'BIRC2', 'BIRC5', 'BLCAP', 'BLMH', 'BLVRA', 'BMP4', 'BNIP3', 'BNIP3L', 'BPHL', 'BRCA1', 'BTK', 'BUB1B', 'BZW2', 'C2CD2', 'C2CD2L', 'C2CD5', 'C5', 'CAB39', 'CALM3', 'CALU', 'CAMSAP2', 'CANT1', 'CAPN1', 'CARMIL1', 'CASC3', 'CASK', 'CASP10', 'CASP2', 'CASP3', 'CASP7', 'CAST', 'CAT', 'CBLB', 'CBR1', 'CBR3', 'CCDC85B', 'CCDC86', 'CCDC92', 'CCL2', 'CCNA1', 'CCNA2', 'CCNB1', 'CCNB2', 'CCND1', 'CCND3', 'CCNE2', 'CCNF', 'CCNH', 'CCP110', 'CD320', 'CD40', 'CD44', 'CD58', 'CDC20', 'CDC25A', 'CDC25B', 'CDC42', 'CDC45', 'CDCA4', 'CDH3', 'CDK1', 'CDK19', 'CDK2', 'CDK4', 'CDK5R1', 'CDK6', 'CDK7', 'CDKN1A', 'CDKN1B', 'CDKN2A', 'CEBPA', 'CEBPD', 'CEBPZ', 'CEMIP2', 'CENPE', 'CEP57', 'CERK', 'CETN3', 'CFLAR', 'CGRRF1', 'CHAC1', 'CHEK1', 'CHEK2', 'CHERP', 'CHIC2', 'CHMP4A', 'CHMP6', 'CHN1', 'CHP1', 'CIAO3', 'CIAPIN1', 'CIRBP', 'CISD1', 'CLIC4', 'CLPX', 'CLSTN1', 'CLTB', 'CLTC', 'CNDP2', 'CNOT4', 'CNPY3', 'COASY', 'COG2', 'COG4', 'CO
DRA', 'HMG20B', 'HMGA2', 'HMGCR', 'HMGCS1', 'HMOX1', 'HOMER2', 'HOOK2', 'HOXA10', 'HOXA5', 'HPRT1', 'HS2ST1', 'HSD17B10', 'HSD17B11', 'HSPA1A', 'HSPA4', 'HSPA8', 'HSPB1', 'HSPD1', 'HTATSF1', 'HTRA1', 'HYOU1', 'IARS2', 'ICAM1', 'ICAM3', 'ICMT', 'ID2', 'IDE', 'IER3', 'IFNAR1', 'IFRD2', 'IGF1R', 'IGF2BP2', 'IGF2R', 'IGFBP3', 'IGHMBP2', 'IKBKB', 'IKBKE', 'IKZF1', 'IL13RA1', 'IL1B', 'IL4R', 'ILK', 'INPP1', 'INPP4B', 'INSIG1', 'INTS3', 'IPO13', 'IQGAP1', 'ISOC1', 'ITFG1', 'ITGAE', 'ITGB1BP1', 'ITGB5', 'JADE2', 'JMJD6', 'JPT2', 'JUN', 'KAT6A', 'KAT6B', 'KCNK1', 'KCTD5', 'KDELR2', 'KDM3A', 'K ...

# %% [markdown]
# ## Inhibitor concentrations, IC50, and perturbation matrices

# %%
inhib_conc_matrix = np.zeros((n_modules, n_experiments))
ic50_matrix = np.ones((n_modules, n_experiments))
gamma_matrix = np.zeros((n_modules, n_experiments))

# %%
for i, module in enumerate(modules):
    drugs_for_module = IC50_df.Drug[IC50_df.Module == module].tolist()
    for drug in drugs_for_module:
        # get IC50 for this drug
        ic50 = IC50_df.IC50[IC50_df.Drug == drug].values
#       gamma = IC50_df.Gamma[IC50_df.Drug == drug].values
        print(drug, ic50)
        assert ic50.size == 1
#       assert gamma.size == 1
        # get experiments with this drug
        exp_with_drug = sig_info_df.index[sig_info_df.pert_drug == drug].tolist()
        print(exp_with_drug) 
        for exp_id in exp_with_drug:
            j = exp_ids.index(exp_id)
            print(j)
            # extract inhibitor concentration
            inhib_conc = sig_info_df.dose_float[sig_info_df.index == exp_id].values
            assert inhib_conc.size == 1
            # insert values in matrices
            inhib_conc_matrix[i, j] = inhib_conc.item()
            ic50_matrix[i, j] = ic50.item()
#           gamma_matrix[i, j] = gamma.item()
# Out:
# JNJ-7706621 [0.027]
# ['ASG002_GI1_24H:N13', 'ASG002_GI1_24H:N14', 'ASG002_GI1_24H:N15']
# 73
# 74
# 75
# PHA-793887 [0.18]
# ['ASG002_GI1_24H:L01', 'ASG002_GI1_24H:L02', 'ASG002_GI1_24H:L03']
# 58
# 59
# 60
# roscovitine [2.]
# ['ASG002_GI1_24H:E22', 'ASG002_GI1_24H:E23', 'ASG002_GI1_24H:E24']
# 22
# 23
# 24
# alvocidib [0.12]
# ['ASG002_GI1_24H:F04', 'ASG002_GI1_24H:F05', 'ASG002_GI1_24H:F06']
# 28
# 29
# 30
# palbociclib [0.045]
# ['ASG002_GI1_24H:P16', 'ASG002_GI1_24H:P17', 'ASG002_GI1_24H:P18']
# 90
# 91
# 92
# AS-605240 [0.1595]
# ['ASG002_GI1_24H:A19', 'ASG002_GI1_24H:A20', 'ASG002_GI1_24H:A21']
# 3
# 4
# 5
# GDC-0349 [3.]
# ['MOAR010_GI1_24H:D01', 'MOAR010_GI1_24H:D02', 'MOAR010_GI1_24H:D03']
# 105
# 106
# 107
# LY-294002 [1.36]
# ['ASG002_GI1_24H:F01', 'ASG002_GI1_24H:F02', 'ASG002_GI1_24H:F03']
# 25
# 26
# 27
# NVP-BEZ235 [1.71]
# ['ASG002_GI1_24H:C16', 'ASG002_GI1_24H:C17']
# 14
# 15
# taselisib [0.00262]
# ['ASG002_GI1_24H:A10', 'ASG002_GI1_24H:A11', 'ASG002_GI1_24H:A12']
# 0
# 1
# 2
# PI-103 [0.09]
# ['ASG002_GI1_24H:O22', 'ASG002_GI1_24H:O23', 'ASG002_GI1_24H:O24']
# 87
# 88
# 89
# AZ-628 [3.]
# ['ASG002_GI1_24H:J19', 'ASG002_GI1_24H:J20', 'ASG002_GI1_24H:J21']
# 52
# 53
# 54
# PD-0325901 [0.015]
# ['ASG002_GI1_24H:O13', 'ASG002_GI1_24H:O14', 'ASG002_GI1_24H:O15']
# 84
# 85
# 86
# dabrafenib [0.1]
# ['ASG002_GI1_24H:K22', 'ASG002_GI1_24H:K23', 'ASG002_GI1_24H:K24']
# 55
# 56
# 57
# selumetinib [0.643]
# ['ASG002_GI1_24H:J04', 'ASG002_GI1_24H:J05', 'ASG002_GI1_24H:J06']
# 46
# 47
# 48
# trametinib [0.00408]
# ['ASG002_GI1_24H:G07', 'ASG002_GI1_24H:G09']
# 33
# 34
# vemurafenib [0.1185]
# ['ASG002_GI1_24H:M07', 'ASG002_GI1_24H:M08', 'ASG002_GI1_24H:M09']
# 67
# 68
# 69
# BAY-87-2243 [0.0021]
# ['MOAR008_GI1_24H:N22', 'MOAR008_GI1_24H:N23', 'MOAR008_GI1_24H:N24']
# 96
# 97
# 98
# CAY-10585 [13.2]
# ['MOAR010_GI1_24H:J04', 'MOAR010_GI1_24H:J05', 'MOAR010_GI1_24H:J06']
# 108
# 109
# 110
# imatinib [0.3]
# ['ASG002_GI1_24H:D22', 'ASG002_GI1_24H:D23', 'ASG002_GI1_24H:D24']
# 16
# 17
# 18
# tandutinib [0.6]
# ['ASG002_GI1_24H:G16', 'ASG002_GI1_24H:G17', 'ASG002_GI1_24H:G18']
# 35
# 36
# 37
# masitinib [2.13]
# ['ASG002_GI1_24H:E19', 'ASG002_GI1_24H:E20', 'ASG002_GI1_24H:E21']
# 19
# 20
# 21
# ponatinib [0.0033]
# ['ASG002_GI1_24H:I20', 'ASG002_GI1_24H:I21']
# 44
# 45
# barasertib-HQPA [0.00111]
# ['ASG002_GI1_24H:L10', 'ASG002_GI1_24H:L11', 'ASG002_GI1_24H:L12']
# 61
# 62
# 63
# tozasertib [0.0232]
# ['ASG002_GI1_24H:J10', 'ASG002_GI1_24H:J11', 'ASG002_GI1_24H:J12']
# 49
# 50
# 51
# dienestrol [200.]
# ['ASG002_GI1_24H:M22', 'ASG002_GI1_24H:M23', 'ASG002_GI1_24H:M24']
# 70
# 71
# 72
# estradiol-cypionate [200.]
# ['ASG002_GI1_24H:L16', 'ASG002_GI1_24H:L17', 'ASG002_GI1_24H:L18']
# 64
# 65
# 66
# raloxifene [0.0171]
# ['ASG002_GI1_24H:O10', 'ASG002_GI1_24H:O11', 'ASG002_GI1_24H:O12']
# 81
# 82
# 83
# afatinib [0.03]
# ['ASG002_GI1_24H:N23', 'ASG002_GI1_24H:N24']
# 79
# 80
# erlotinib [0.006]
# ['ASG002_GI1_24H:H16', 'ASG002_GI1_24H:H17', 'ASG002_GI1_24H:H18']
# 38
# 39
# 40
# gefitinib [0.171]
# ['ASG002_GI1_24H:F16', 'ASG002_GI1_24H:F17']
# 31
# 32
# lapatinib [0.0324]
# ['ASG002_GI1_24H:I13', 'ASG002_GI1_24H:I14', 'ASG002_GI1_24H:I15']
# 41
# 42
# 43
# vandetanib [1.5]
# ['ASG002_GI1_24H:N19', 'ASG002_GI1_24H:N20', 'ASG002_GI1_24H:N21']
# 76
# 77
# 78
# AMG-232 [0.0018]
# ['ASG002_GI1_24H:B10', 'ASG002_GI1_24H:B11', 'ASG002_GI1_24H:B12']
# 6
# 7
# 8
# HLI-373 [3.]
# ['MOAR008_GI1_24H:L07', 'MOAR008_GI1_24H:L08', 'MOAR008_GI1_24H:L09']
# 93
# 94
# 95
# nutlin-3 [0.54]
# ['ASG002_GI1_24H:C13', 'ASG002_GI1_24H:C14', 'ASG002_GI1_24H:C15', 'MOAR009_GI1_24H:C10', 'MOAR009_GI1_24H:C11', 'MOAR009_GI1_24H:C12']
# 11
# 12
# 13
# 99
# 100
# 101
# RITA [9.75]
# ['ASG002_GI1_24H:B13', 'ASG002_GI1_24H:B15', 'MOAR010_GI1_24H:A13', 'MOAR010_GI1_24H:A14', 'MOAR010_GI1_24H:A15']
# 9
# 10
# 102
# 103
# 104
# SAR405838 [0.0264]
# ['MOAR010_GI1_24H:K08', 'MOAR010_GI1_24H:K09']
# 114
# 115
# serdemetan [62.15]
# ['MOAR010_GI1_24H:J22', 'MOAR010_GI1_24H:J23', 'MOAR010_GI1_24H:J24', 'MOAR011_GI1_24H:F07', 'MOAR011_GI1_24H:F08', 'MOAR011_GI1_24H:F09']
# 111
# 112
# 113
# 116
# 117
# 118

# %%
# transform matrices into pandas dfs for export with row and column names
inhib_conc_df = pd.DataFrame(inhib_conc_matrix, index = modules, columns = exp_ids)
ic50_df = pd.DataFrame(ic50_matrix, index = modules, columns = exp_ids)
# gamma_df = pd.DataFrame(gamma_matrix, index = modules, columns = exp_ids)

# create binary perturbation matrix
pert_df = pd.DataFrame(
    np.where(inhib_conc_matrix != 0, 1, 0),
    index = inhib_conc_df.index,
    columns = inhib_conc_df.columns,
)

# %%
display(ic50_df)
# display(gamma_df)
display(inhib_conc_df)
display(pert_df)
# Out:
#           ASG002_GI1_24H:A10  ASG002_GI1_24H:A11  ASG002_GI1_24H:A12  \
# CDK1                 1.00000             1.00000             1.00000
# CDK2                 1.00000             1.00000             1.00000
# CDK4_6               1.00000             1.00000             1.00000
# PI3K                 0.00262             0.00262             0.00262
# PDGFR                  1.0000               1.0000                 1.00
# Aurora                 1.0000               1.0000                 1.00
# Estrogen               1.0000               1.0000                 1.00
# EGFR                   1.0000               1.0000                 1.00
# p53                    0.0264               0.0264                62.15
#
#           MOAR011_GI1_24H:F08  MOAR011_GI1_24H:F09
# CDK1                     1.00                 1.00
# CDK2                     1.00                 1.00
# CDK4_6                   1.00                 1.00
# PI3K                     1.00                 1.00
# ERK                      1.00                 1.00
# Hypoxia                  1.00                 1.00
# PDGFR                    1.00                 1.00
# Aurora                   1.00                 1.00
# Estrogen                 1.00                 1.00
# EGFR                     1.00                 1.00
# p53                     62.15                62.15
#
# [11 rows x 119 columns]
#           ASG002_GI1_24H:A10  ASG002_GI1_24H:A11  ASG002_GI1_24H:A12  \
# CDK1                     0.0                0.00                0.00
# CDK2                     0.0                0.00                0.00
# CDK4_6                   0.0                0.00                0.00
# PI3K                    10.0                1.11                0.12
# ERK                      0.0                0.00                0.00
# Hypoxia                  0.0                0.00                0.00
# PDGFR                    0.0                0.00                0.00
# Aurora                   0.0                0.00                0.00
# Estrogen                 0.0                0.00                0.00
# EGFR                     0.0                0.00                0.00
# p53                      0.0                0.00                0.00
#
#           ASG002_GI1_24H:A19  ASG002_GI1_24H:A20  ASG002_GI1_24H:A21  \
# CDK1                     0.0                0.00                0.00
# CDK2                     0.0                0.00                0.00
# CDK4_6                   0.0                0.00                0.00
# PI3K                    10.0                1.11                0.12
# ERK                      0.0                0.00                0.00
# Hypoxia                  0.0                0.00                0.00
# PDGFR                    0.0                0.00                0.00
# Aurora                   0.0                0.00                0.00
# Estrogen                 0.0                0.00                0.00
# EGFR                     0.0                0.00                0.00
# p53                      0.0                0.00                0.00
#
#           ASG002_GI1_24H:B10  ASG002_GI1_24H:B11  ASG002_GI1_24H:B12  \
# CDK1                     0.0                0.00                0.00
# CDK2                     0.0                0.00                0.00
# CDK4_6                   0.0                0.00                0.00
# PI3K                     0.0                0.00                0.00
# ERK                      0.0                0.00                0.00
# Hypoxia                  0.0                0.00                0.00
# PDGFR                    0.0                0.00                0.00
# Aurora                   0.0                0.00                0.00
# Estrogen                 0.0                0.00                0.00
# EGFR                     0.0                0.00                0.00
# p53                     10.0                1.11                0.12
#
#           ASG002_GI1_24H:B13  ...  MOAR010_GI1_24H:J05  MOAR010_GI1_24H:J06  \
# CDK1                     0.0  ...                 0.00                 0.00
# CDK2                     0.0  ...                 0.00                 0.00
# CDK4_6                   0.0  ...                 0.00                 0.00
# PI3K                     0.0  ...                 0.00                 0.00
# ERK                      0.0  ...                 0.00                 0.00
# Hypoxia                  0.0  ...                 3.33                 1.11
# PDGFR                    0.0  ...                 0.00                 0.00
# Aurora                   0.0  ...                 0.00                 0.00
# Estrogen                 0.0  ...                 0.00                 0.00
# EGFR                     0.0  ...                 0.00                 0.00
# p53                     10.0  ...                 0.00                 0.00
#
#           MOAR010_GI1_24H:J22  MOAR010_GI1_24H:J23  MOAR010_GI1_24H:J24  \
# CDK1                      0.0                 0.00                 0.00
# CDK2                      0.0                 0.00                 0.00
# CDK4_6                    0.0                 0.00                 0.00
# PI3K                      0.0                 0.00                 0.00
# ERK                       0.0                 0.00                 0.00
# Hypoxia                   0.0                 0.00                 0.00
# PDGFR                     0.0                 0.00                 0.00
# Aurora                    0.0                 0.00                 0.00
# Estrogen                  0.0                 0.00                 0.00
# EGFR                      0.0                 0.00                 0.00
# p53                      10.0                 3.33                 1.11
#
#           MOAR010_GI1_24H:K08  MOAR010_GI1_24H:K09  MOAR011_GI1_24H:F07  \
# CDK1                     0.00                 0.00                  0.0
# CDK2                     0.00                 0.00                  0.0
# CDK4_6                   0.00                 0.00                  0.0
# PI3K                     0.00                 0.00                  0.0
# ERK                      0.00                 0.00                  0.0
# Hypoxia                  0.00                 0.00                  0.0
# PDGFR                    0.00                 0.00                  0.0
# Aurora                   0.00                 0.00                  0.0
# Estrogen                 0.00                 0.00                  0.0
# EGFR                     0.00                 0.00                  0.0
# p53                      3.33                 1.11                 10.0
#
#           MOAR011_GI1_24H:F08  MOAR011_GI1_24H:F09
# CDK1                     0.00                 0.00
# CDK2                     0.00                 0.00
# CDK4_6                   0.00                 0.00
# PI3K                     0.00                 0.00
# ERK                      0.00                 0.00
# Hypoxia                  0.00                 0.00
# PDGFR                    0.00                 0.00
# Aurora                   0.00                 0.00
# Estrogen                 0.00                 0.00
# EGFR                     0.00                 0.00
# p53                      3.33                 1.11
#
# [11 rows x 119 columns]
#           ASG002_GI1_24H:A10  ASG002_GI1_24H:A11  ASG002_GI1_24H:A12  \
# CDK1                       0                   0                   0
# CDK2                       0                   0                   0
# CDK4_6                     0                   0                   0
# PI3K                       1                   1                   1
# ERK                        0                   0                   0
# Hypoxia                    0                   0                   0
# PDGFR                      0                   0                   0
# Aurora                     0                   0                   0
# Estrogen                   0                   0                   0
# EGFR                       0                   0                   0
# p53                        0                   0                   0
#
#           ASG002_GI1_24H:A19  ASG002_GI1_24H:A20  ASG002_GI1_24H:A21  \
# CDK1                       0                   0                   0
# CDK2                       0                   0                   0
# CDK4_6                     0                   0                   0
# PI3K                       1                   1                   1
# ERK                        0                   0                   0
# Hypoxia                    0                   0                   0
# PDGFR                      0                   0                   0
# Aurora                     0                   0                   0
# Estrogen                   0                   0                   0
# EGFR                       0                   0                   0
# p53                        0                   0                   0
#
#           ASG002_GI1_24H:B10  ASG002_GI1_24H:B11  ASG002_GI1_24H:B12  \
# CDK1                       0                   0                   0
# CDK2                       0                   0                   0
# CDK4_6                     0                   0                   0
# PI3K                       0                   0                   0
# ERK                        0                   0                   0
# Hypoxia                    0                   0                   0
# PDGFR                      0                   0                   0
# Aurora                     0                   0                   0
# Estrogen                   0                   0                   0
# EGFR                       0                   0                   0
# p53                        1                   1                   1
#
#           ASG002_GI1_24H:B13  ...  MOAR010_GI1_24H:J05  MOAR010_GI1_24H:J06  \
# CDK1                       0  ...                    0                    0
# CDK2                       0  ...                    0                    0
# CDK4_6                     0  ...                    0                    0
# PI3K                       0  ...                    0                    0
# ERK                        0  ...                    0                    0
# Hypoxia                    0  ...                    1                    1
# PDGFR                      0  ...                    0                    0
# Aurora                     0  ...                    0                    0
# Estrogen                   0  ...                    0                    0
# EGFR                       0  ...                    0                    0
# p53                        1  ...                    0                    0
#
#           MOAR010_GI1_24H:J22  MOAR010_GI1_24H:J23  MOAR010_GI1_24H:J24  \
# CDK1                        0                    0                    0
# CDK2                        0                    0                    0
# CDK4_6                      0                    0                    0
# PI3K                        0                    0                    0
# ERK                         0                    0                    0
# Hypoxia                     0                    0                    0
# PDGFR                       0                    0                    0
# Aurora                      0                    0                    0
# Estrogen                    0                    0                    0
# EGFR                        0                    0                    0
# p53                         1                    1                    1
#
#           MOAR010_GI1_24H:K08  MOAR010_GI1_24H:K09  MOAR011_GI1_24H:F07  \
# CDK1                        0                    0                    0
# CDK2                        0                    0                    0
# CDK4_6                      0                    0                    0
# PI3K                        0                    0                    0
# ERK                         0                    0                    0
# Hypoxia                     0                    0                    0
# PDGFR                       0                    0                    0
# Aurora                      0                    0                    0
# Estrogen                    0                    0                    0
# EGFR                        0                    0                    0
# p53                         1                    1                    1
#
#           MOAR011_GI1_24H:F08  MOAR011_GI1_24H:F09
# CDK1                        0                    0
# CDK2                        0                    0
# CDK4_6                      0                    0
# PI3K                        0                    0
# ERK                         0                    0
# Hypoxia                     0                    0
# PDGFR                       0                    0
# Aurora                      0                    0
# Estrogen                    0                    0
# EGFR                        0                    0
# p53                         1                    1
#
# [11 rows x 119 columns]

# %% [markdown]
# ## Global responses for DPD modules
#
# According to our discussion, $R$ for DPD vectors can not be calculated with the same formula as for pathway activities. Instead we are assuming:
#
# \begin{equation}
# R_{DPD},j = DPD = STV_{DPD} \cdot Data_j
# \end{equation}

# %%
# load STV data frame
STVs = pd.read_excel(os.path.join(info_dir, "ALL_DATA_2020_Jing_gbm.xlsx"), sheet_name = "STVs", index_col = 0)
STV_df = pd.DataFrame(np.zeros((len(Data_norm_df.index), 2)), index = Data_norm_df.index, columns = STVs.columns)
STV_df.loc[STVs.index] = STVs

display(STV_df)
# Out:
#          GBM_onc  GBM_survival
# AARS   -0.018282      0.000000
# ABCB6   0.000000      0.000000
# ABCC5  -0.007873      0.000000
# ABCF1  -0.011879     -2.215623
# ABCF3   0.000000      0.000000
# ...          ...           ...
# ZNF395 -0.033083      0.000000
# ZNF451  0.002199      0.000000
# ZNF586 -0.011584      0.000000
# ZNF589 -0.012400      0.000000
# ZW10   -0.014991      0.000000
#
# [978 rows x 2 columns]

# %%
# create empty DPD data frame
DPD_df = pd.DataFrame(
    np.zeros((len(Data_norm_df.columns), len(STV_df.columns))),
    index = Data_norm_df.columns,
    columns = STV_df.columns,
)

# populate
for exp_id in DPD_df.index:
    for state in STV_df.columns:
        DPD_df.loc[exp_id, state] = np.dot(Data_norm_df.T.loc[exp_id], STV_df.loc[:, state])

display(DPD_df)
# Out:
#                       GBM_onc  GBM_survival
# ASG002_GI1_24H:A10   1.363210     -4.750028
# ASG002_GI1_24H:A11  -0.326099     -2.525002
# ASG002_GI1_24H:A12  -0.908391     -1.395286
# ASG002_GI1_24H:A19   0.750205      0.551730
# ASG002_GI1_24H:A20   0.936970      1.213057
# ...                       ...           ...
# MOAR010_GI1_24H:K08  1.082215      0.640095
# MOAR010_GI1_24H:K09 -0.076825     -4.025604
# MOAR011_GI1_24H:F07 -1.366585     -2.966102
# MOAR011_GI1_24H:F08 -0.001349     -5.883910
# MOAR011_GI1_24H:F09 -0.199769     -1.900150
#
# [119 rows x 2 columns]

# %%
# transform to R global
R_global_DPD_df = DPD_df.T
display(R_global_DPD_df)
# Out:
#               ASG002_GI1_24H:A10  ASG002_GI1_24H:A11  ASG002_GI1_24H:A12  \
# GBM_onc                 1.363210           -0.326099           -0.908391
# GBM_survival           -4.750028           -2.525002           -1.395286
#
#               ASG002_GI1_24H:A19  ASG002_GI1_24H:A20  ASG002_GI1_24H:A21  \
# GBM_onc                 0.750205            0.936970            0.590187
# GBM_survival            0.551730            1.213057            0.315073
#
#               ASG002_GI1_24H:B10  ASG002_GI1_24H:B11  ASG002_GI1_24H:B12  \
# GBM_onc                -0.063955            0.814936           -0.164436
# GBM_survival           -2.571901           -5.538101           -0.004049
#
#               ASG002_GI1_24H:B13  ...  MOAR010_GI1_24H:J05  \
# GBM_onc                -0.079985  ...            -0.231234
# GBM_survival           -5.594971  ...            -3.623248
#
#               MOAR010_GI1_24H:J06  MOAR010_GI1_24H:J22  MOAR010_GI1_24H:J23  \
# GBM_onc                 -0.713071            -0.340106            -0.358414
# GBM_survival             0.118619            -2.316815            -5.998430
#
#               MOAR010_GI1_24H:J24  MOAR010_GI1_24H:K08  MOAR010_GI1_24H:K09  \
# GBM_onc                  0.337871             1.082215            -0.076825
# GBM_survival            -5.552708             0.640095            -4.025604
#
#               MOAR011_GI1_24H:F07  MOAR011_GI1_24H:F08  MOAR011_GI1_24H:F09
# GBM_onc                 -1.366585            -0.001349            -0.199769
# GBM_survival            -2.966102            -5.883910            -1.900150
#
# [2 rows x 119 columns]

# %% [markdown]
# ## Save outputs

# %%
# save metadata as pickle
all_metadata = {
    "modules": modules,
    "n_modules": n_modules,
    "drugs": drugs,
    "n_drugs": n_drugs,
    "exp_ids": exp_ids,
    "n_experiments": n_experiments,
    "genes": genes,
    "n_genes": n_genes,
}

print(all_metadata)

with open(os.path.join(out_dir, "metadata.pickle"), "wb") as f:
    pickle.dump(all_metadata, f, protocol = pickle.HIGHEST_PROTOCOL)
# Out:
# {'modules': ['CDK1', 'CDK2', 'CDK4_6', 'PI3K', 'ERK', 'Hypoxia', 'PDGFR', 'Aurora', 'Estrogen', 'EGFR', 'p53'], 'n_modules': 11, 'drugs': ['selumetinib', 'lapatinib', 'trametinib', 'NVP-BEZ235', 'SAR405838', 'gefitinib', 'BAY-87-2243', 'vemurafenib', 'CAY-10585', 'palbociclib', 'AS-605240', 'GDC-0349', 'tozasertib', 'nutlin-3', 'PI-103', 'HLI-373', 'taselisib', 'estradiol-cypionate', 'erlotinib', 'LY-294002', 'dabrafenib', 'JNJ-7706
_24H:N24', 'ASG002_GI1_24H:O10', 'ASG002_GI1_24H:O11', 'ASG002_GI1_24H:O12', 'ASG002_GI1_24H:O13', 'ASG002_GI1_24H:O14', 'ASG002_GI1_24H:O15', 'ASG002_GI1_24H:O22', 'ASG002_GI1_24H:O23', 'ASG002_GI1_24H:O24', 'ASG002_GI1_24H:P16', 'ASG002_GI1_24H:P17', 'ASG002_GI1_24H:P18', 'MOAR008_GI1_24H:L07', 'MOAR008_GI1_24H:L08', 'MOAR008_GI1_24H:L09', 'MOAR008_GI1_24H:N22', 'MOAR008_GI1_24H:N23', 'MOAR008_GI1_24H:N24', 'MOAR009_GI1_24H:C10', 'MOAR009_GI1_24H:C11', 'MOAR009_GI1_24H:C12', 'MOAR010_GI1_24H:A13', 'MOAR010_GI1_24H:A14', 'MOAR010_GI1_24H:A15', 'MOAR010_GI1_24H:D01', 'MOAR010_GI1_24H:D02', 'MOAR010_GI1_24H:D03', 'MOAR010_GI1_24H:J04', 'MOAR010_GI1_24H:J05', 'MOAR010_GI1_24H:J06', 'MOAR010_GI1_24H:J22', 'MOAR010_GI1_24H:J23', 'MOAR010_GI1_24H:J24', 'MOAR010_GI1_24H:K08', 'MOAR010_GI1_24H:K09', 'MOAR011_GI1_24H:F07', 'MOAR011_GI1_24H:F08', 'MOAR011_GI1_24H:F09'], 'n_experiments': 119, 'genes': ['AARS', 'ABCB6', 'ABCC5', 'ABCF1', 'ABCF3', 'ABHD4', 'ABHD6', 'ABL1', 'ACAA1', 'ACAT2', 'ACBD3', 'ACD', 'ACLY', 'ACOT9', 'ADAM10', 'ADAT1', 'ADGRE5', 'ADGRG1', 'ADH5', 'ADI1', 'ADO', 'ADRB2', 'AGL', 'AKAP8', 'AKAP8L', 'AKR7A2', 'AKT1', 'ALAS1', 'ALDH7A1', 'ALDOA', 'ALDOC', 'AMDHD2', 'ANKRD10', 'ANO10', 'ANXA7', 'APBB2', 'APOE', 'APP', 'APPBP2', 'ARFIP2', 'ARHGAP1', 'ARHGEF12', 'ARHGEF2', 'ARID4B', 'ARID5B', 'ARL4C', 'ARNT2', 'ARPP19', 'ASAH1', 'ASCC3', 'ATF1', 'ATF5', 'ATF6', 'ATG3', 'ATMIN', 'ATP11B', 'ATP1B1', 'ATP2C1', 'ATP6V0B', 'ATP6V1D', 'AURKA', 'AURKB', 'AXIN1', 'B4GAT1', 'BACE2', 'BAD', 'BAG3', 'BAMBI', 'BAX', 'B ...

# %%
# save doses and perturbation matrix
inhib_conc_df.to_csv(os.path.join(out_dir, "inhib_conc_annotated.csv"))
ic50_df.to_csv(os.path.join(out_dir, "ic50_annotated.csv"))
# gamma_df.to_csv(os.path.join(out_dir, "gamma_annotated.csv"))
pert_df.to_csv(os.path.join(out_dir, "pert_annotated.csv"))

# %%
# save log fold change L1000 data
Data_norm_df.to_csv(os.path.join(out_dir, "L1000_Data_norm_data.csv"))

# %%
# save R_global for DPDs
R_global_DPD_df.to_csv(os.path.join(out_dir, "R_global_DPDonly_annotated.csv"))
