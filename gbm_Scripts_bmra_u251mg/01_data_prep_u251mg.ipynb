# %% [markdown]
# # 01 Data preparation
#
# Processing xlsx files from data folder into suitable inputs and generate other input files

# %%
import pandas as pd
import numpy as np
import os
import pickle

# %%
data_dir = '/home/jing/Phd_project/project_GBM/gbm_Scripts/gbm_Scripts_bmra_u251mg/00_outputs_2020_U251MG/'
info_dir = data_dir


out_dir = "01_outputs_2020"

os.makedirs(out_dir, exist_ok = True)

# %% [markdown]
# ## Modules
#
# Load data about modules and drugs.

# %%
### DATA
### remove whitespaces in names (modules), remove duplicates

modules_df = pd.read_excel(os.path.join(data_dir,'ALL_DATA_2020_Jing_u251mg.xlsx'), sheet_name = "modules", index_col = 0)
# display(modules_df)

selected_modules = modules_df.index.tolist()
print(len(selected_modules), ' - Size after reading')

# remove duplicates
selected_modules = modules_df.index.unique().tolist()
print(len(selected_modules), ' - Size after remove duplicates')

# remove whitespaces in modules' names 
selected_modules = [d.strip() for d in selected_modules]

print('Selected modules list: ', len(selected_modules), selected_modules)
# Out:
# 10  - Size after reading
# 10  - Size after remove duplicates
# Selected modules list:  10 ['CDK1', 'CDK2', 'CDK4_6', 'p53', 'EGFR', 'Aurora', 'Estrogen', 'PDGFR', 'ERK', 'PI3K']

# %%
### DATA
### remove whitespaces in names (modules, drugs), remove duplicates
### check the dimensions of the indicator IC50 1 uM = 1000 nM
### copy-paste as values, numbers, no formulas

IC50_df = pd.read_excel(os.path.join(data_dir, "ALL_DATA_2020_Jing_u251mg.xlsx"), sheet_name = "IC50s")
IC50_df.drop(columns=['Notes','Removed'],inplace=True)

print(len(IC50_df.index), ' - Size after reading')
# display(IC50_df)

# rename
IC50_df = IC50_df.rename(columns = {"IC50, uM": "IC50"})

# manually correcting value IC50, Example  for IOX2 -> 30 nM  
#IC50_df.loc[IC50_df.index == 'IOX2', IC50_df.columns == 'IC50'] = 30/1000

# remove non-selected modules, modules' names with whitespaces or empty
IC50_df = IC50_df[IC50_df.Module.isin(selected_modules)]

print(len(IC50_df.index), ' - Size after remove modules')
# display(IC50_df)

# remove duplicates 
# Considering certain columns is optional. 
# Indexes, including time indexes are ignored.
IC50_df = IC50_df.drop_duplicates()

print(len(IC50_df.index), ' - Size after remove duplicates')
display(IC50_df)
# Out:
# 39  - Size after reading
# 37  - Size after remove modules
# 37  - Size after remove duplicates
#                    Drug    Module       IC50
# 0           JNJ-7706621      CDK1    0.02700
# 1            PHA-793887      CDK1    0.18000
# 2           roscovitine      CDK2    2.00000
# 3             alvocidib    CDK4_6    0.12000
# 4           palbociclib    CDK4_6    0.04500
# 5             AS-605240      PI3K    0.15950
# 6              GDC-0349      PI3K    3.00000
# 7             LY-294002      PI3K    1.36000
# 8            NVP-BEZ235      PI3K    1.71000
# 9             taselisib      PI3K    0.00262
# 10               PI-103      PI3K    0.09000
# 11               AZ-628       ERK    3.00000
# 12           PD-0325901       ERK    0.01500
# 13           dabrafenib       ERK    0.10000
# 14          selumetinib       ERK    0.64300
# 15           trametinib       ERK    0.00408
# 16          vemurafenib       ERK    0.11850
# 19             imatinib     PDGFR    0.30000
# 20           tandutinib     PDGFR    0.60000
# 21            masitinib     PDGFR    2.13000
# 22            ponatinib     PDGFR    0.00330
# 23      barasertib-HQPA    Aurora    0.00111
# 24           tozasertib    Aurora    0.02320
# 25           dienestrol  Estrogen  200.00000
# 26  estradiol-cypionate  Estrogen  200.00000
# 27           raloxifene  Estrogen    0.01710
# 28             afatinib      EGFR    0.03000
# 29            erlotinib      EGFR    0.00600
# 30            gefitinib      EGFR    0.17100
# 31            lapatinib      EGFR    0.03240
# 32           vandetanib      EGFR    1.50000
# 33              AMG-232       p53    0.00180
# 34              HLI-373       p53    3.00000
# 35             nutlin-3       p53    0.54000
# 36                 RITA       p53    9.75000
# 37            SAR405838       p53    0.02640
# 38           serdemetan       p53   62.15000

# %%
modules = IC50_df.Module.unique().tolist()

print('IC50_df  modules list: ', len(modules), modules)
print()
print('Selected modules list: ', len(selected_modules), selected_modules)

### CHECK
print()
print('CHECK: ', len(selected_modules),'=?', len(modules))

n_modules = len(modules)
# Out:
# IC50_df  modules list:  10 ['CDK1', 'CDK2', 'CDK4_6', 'PI3K', 'ERK', 'PDGFR', 'Aurora', 'Estrogen', 'EGFR', 'p53']
#
# Selected modules list:  10 ['CDK1', 'CDK2', 'CDK4_6', 'p53', 'EGFR', 'Aurora', 'Estrogen', 'PDGFR', 'ERK', 'PI3K']
#
# CHECK:  10 =? 10

# %%
drugs = IC50_df.Drug.tolist()
print(len(drugs), ' - Size after reading')

# remove duplicates
drugs = IC50_df.Drug.unique().tolist()
print(len(drugs), ' - Size after remove duplicates')

# remove whitespaces in drugs' names (necessary for some)
drugs = [d.strip() for d in drugs]

# remove duplicates after remove whitespaces
drugs = list(set(drugs))
print(len(drugs), ' - Size after remove duplicates without whitespaces')

print('Drugs list: ', len(drugs), drugs)

n_drugs = len(drugs)
# Out:
# 37  - Size after reading
# 37  - Size after remove duplicates
# 37  - Size after remove duplicates without whitespaces
# Drugs list:  37 ['RITA', 'nutlin-3', 'lapatinib', 'vemurafenib', 'tozasertib', 'erlotinib', 'vandetanib', 'AMG-232', 'GDC-0349', 'alvocidib', 'SAR405838', 'NVP-BEZ235', 'PHA-793887', 'PD-0325901', 'imatinib', 'HLI-373', 'masitinib', 'PI-103', 'dienestrol', 'palbociclib', 'AZ-628', 'LY-294002', 'estradiol-cypionate', 'ponatinib', 'barasertib-HQPA', 'raloxifene', 'serdemetan', 'gefitinib', 'trametinib', 'taselisib', 'roscovitine', 'JNJ-7706621', 'AS-605240', 'selumetinib', 'afatinib', 'dabrafenib', 'tandutinib']

# %% [markdown]
# ## L1000 meta data
#
# Get sig_id for selected drugs.

# %%
sig_info_df = pd.read_excel(os.path.join(data_dir, "sig_info_2020_U251MG.xlsx"), index_col = 0)

display(sig_info_df)
# Out:
#                          cell   plate  time               level_3_samples  \
# level_5_sig_id
# ASG002_U251MG_24H:A03  U251MG  ASG002  24 h  ASG002_U251MG_24H_X1_B35:A03
# ASG002_U251MG_24H:A04  U251MG  ASG002  24 h  ASG002_U251MG_24H_X1_B35:A04
# ASG002_U251MG_24H:A05  U251MG  ASG002  24 h  ASG002_U251MG_24H_X1_B35:A05
# ASG002_U251MG_24H:J13  U251MG  ASG002  24 h  ASG002_U251MG_24H_X1_B35:J13
# ASG002_U251MG_24H:J14  U251MG  ASG002  24 h  ASG002_U251MG_24H_X1_B35:J14
# ...                       ...     ...   ...                           ...
# ASG002_U251MG_24H:P20  U251MG  ASG002  24 h  ASG002_U251MG_24H_X1_B35:P20
# ASG002_U251MG_24H:P21  U251MG  ASG002  24 h  ASG002_U251MG_24H_X1_B35:P21
# ASG002_U251MG_24H:P22  U251MG  ASG002  24 h  ASG002_U251MG_24H_X1_B35:P22
# ASG002_U251MG_24H:P23  U251MG  ASG002  24 h  ASG002_U251MG_24H_X1_B35:P23
# ASG002_U251MG_24H:P24  U251MG  ASG002  24 h  ASG002_U251MG_24H_X1_B35:P24
#
#                        samples_number    pert_type   pert_drug  \
# level_5_sig_id
# ASG002_U251MG_24H:A03               1  ctl_vehicle        DMSO
# ASG002_U251MG_24H:A04               1  ctl_vehicle        DMSO
# ASG002_U251MG_24H:A05               1  ctl_vehicle        DMSO
# ASG002_U251MG_24H:J13               1  ctl_vehicle        DMSO
# ASG002_U251MG_24H:J14               1  ctl_vehicle        DMSO
# ...                               ...          ...         ...
# ASG002_U251MG_24H:P20               1       trt_cp  idarubicin
# ASG002_U251MG_24H:P21               1       trt_cp  idarubicin
# ASG002_U251MG_24H:P22               1       trt_cp   digitoxin
# ASG002_U251MG_24H:P23               1       trt_cp   digitoxin
# ASG002_U251MG_24H:P24               1       trt_cp   digitoxin
#
#                               targets  targets_number     dose  dose_float
# level_5_sig_id
# ASG002_U251MG_24H:A03  DMSO_No_target               0     0 uM        0.00
# ASG002_U251MG_24H:A04  DMSO_No_target               0     0 uM        0.00
# ASG002_U251MG_24H:A05  DMSO_No_target               0     0 uM        0.00
# ASG002_U251MG_24H:J13  DMSO_No_target               0     0 uM        0.00
# ASG002_U251MG_24H:J14  DMSO_No_target               0     0 uM        0.00
# ...                               ...             ...      ...         ...
# ASG002_U251MG_24H:P20           TOP2A               1  1.11 uM        1.11
# ASG002_U251MG_24H:P21           TOP2A               1  0.12 uM        0.12
# ASG002_U251MG_24H:P22          ATP1A1               1    10 uM       10.00
# ASG002_U251MG_24H:P23          ATP1A1               1  1.11 uM        1.11
# ASG002_U251MG_24H:P24          ATP1A1               1  0.12 uM        0.12
#
# [372 rows x 11 columns]

# %%
# now filtering so only the required drugs are present
sig_info_df = sig_info_df.loc[sig_info_df.pert_drug.isin(drugs)]

# here's what we have now
display(sig_info_df)
# Out:
#                          cell   plate  time               level_3_samples  \
# level_5_sig_id
# ASG002_U251MG_24H:A10  U251MG  ASG002  24 h  ASG002_U251MG_24H_X1_B35:A10
# ASG002_U251MG_24H:A11  U251MG  ASG002  24 h  ASG002_U251MG_24H_X1_B35:A11
# ASG002_U251MG_24H:A12  U251MG  ASG002  24 h  ASG002_U251MG_24H_X1_B35:A12
# ASG002_U251MG_24H:A19  U251MG  ASG002  24 h  ASG002_U251MG_24H_X1_B35:A19
# ASG002_U251MG_24H:A20  U251MG  ASG002  24 h  ASG002_U251MG_24H_X1_B35:A20
# ...                       ...     ...   ...                           ...
# ASG002_U251MG_24H:O23  U251MG  ASG002  24 h  ASG002_U251MG_24H_X1_B35:O23
# ASG002_U251MG_24H:O24  U251MG  ASG002  24 h  ASG002_U251MG_24H_X1_B35:O24
# ASG002_U251MG_24H:P16  U251MG  ASG002  24 h  ASG002_U251MG_24H_X1_B35:P16
# ASG002_U251MG_24H:P17  U251MG  ASG002  24 h  ASG002_U251MG_24H_X1_B35:P17
# ASG002_U251MG_24H:P18  U251MG  ASG002  24 h  ASG002_U251MG_24H_X1_B35:P18
#
#                        samples_number pert_type    pert_drug  \
# level_5_sig_id
# ASG002_U251MG_24H:A10               1    trt_cp    taselisib
# ASG002_U251MG_24H:A11               1    trt_cp    taselisib
# ASG002_U251MG_24H:A12               1    trt_cp    taselisib
# ASG002_U251MG_24H:A19               1    trt_cp    AS-605240
# ASG002_U251MG_24H:A20               1    trt_cp    AS-605240
# ...                               ...       ...          ...
# ASG002_U251MG_24H:O23               1    trt_cp       PI-103
# ASG002_U251MG_24H:O24               1    trt_cp       PI-103
# ASG002_U251MG_24H:P16               1    trt_cp  palbociclib
# ASG002_U251MG_24H:P17               1    trt_cp  palbociclib
# ASG002_U251MG_24H:P18               1    trt_cp  palbociclib
#
#                                                     targets  targets_number  \
# level_5_sig_id
# ASG002_U251MG_24H:A10                                PIK3CA               1
# ASG002_U251MG_24H:A11                                PIK3CA               1
# ASG002_U251MG_24H:A12                                PIK3CA               1
# ASG002_U251MG_24H:A19                                PIK3CG               1
# ASG002_U251MG_24H:A20                                PIK3CG               1
# ...                                                     ...             ...
# ASG002_U251MG_24H:O23  MTOR, PIK3CA, PIK3CB, PIK3CD, PIK3CG               5
# ASG002_U251MG_24H:O24  MTOR, PIK3CA, PIK3CB, PIK3CD, PIK3CG               5
# ASG002_U251MG_24H:P16                            CDK4, CDK6               2
# ASG002_U251MG_24H:P17                            CDK4, CDK6               2
# ASG002_U251MG_24H:P18                            CDK4, CDK6               2
#
#                           dose  dose_float
# level_5_sig_id
# ASG002_U251MG_24H:A10    10 uM       10.00
# ASG002_U251MG_24H:A11  1.11 uM        1.11
# ASG002_U251MG_24H:A12  0.12 uM        0.12
# ASG002_U251MG_24H:A19    10 uM       10.00
# ASG002_U251MG_24H:A20  1.11 uM        1.11
# ...                        ...         ...
# ASG002_U251MG_24H:O23  1.11 uM        1.11
# ASG002_U251MG_24H:O24  0.12 uM        0.12
# ASG002_U251MG_24H:P16    10 uM       10.00
# ASG002_U251MG_24H:P17  1.11 uM        1.11
# ASG002_U251MG_24H:P18  0.12 uM        0.12
#
# [98 rows x 11 columns]

# %% [markdown]
# Manually remove  few inhibition from data set, since it does differ from the other data points.

# %% [markdown]
# inhib_to_filter = "PF-03758309"
# dose_to_filter = 10
#
# id_to_filter = sig_info_df[
#     np.logical_and(
#         sig_info_df.pert_drug == inhib_to_filter,
#         sig_info_df.dose_float == dose_to_filter,
#     )
# ].index.values
#
# print(id_to_filter)
#
# sig_info_df = sig_info_df[~sig_info_df.index.isin(id_to_filter)]
# display(sig_info_df)

# %% [markdown]
# inhib_to_filter = "roscovitine"
# dose_to_filter = 3.33
#
# id_to_filter = sig_info_df[
#     np.logical_and(
#         sig_info_df.pert_drug == inhib_to_filter,
#         sig_info_df.dose_float == dose_to_filter,
#     )
# ].index.values
#
# print(id_to_filter)
#
# sig_info_df = sig_info_df[~sig_info_df.index.isin(id_to_filter)]
# display(sig_info_df)

# %%
exp_ids = sig_info_df.index.unique().tolist()
print('Experiments ids list: ', len(exp_ids))

n_experiments = len(exp_ids)
# Out:
# Experiments ids list:  98

# %% [markdown]
# Confirm data by checking the drugs of interest against the filtered L1000 meta data.

# %%
print(f"Number of drugs of interest:\t{len(drugs)}")
#print(f'Number of drugs in L1000 data:\t{len(sig_info_df.value_counts("drugs"))}')

#sig_info_df.value_counts("drugs")
# Out:
# Number of drugs of interest:	37

# %% [markdown]
# ## L1000 data

# %%
Data_norm_df = pd.read_excel(os.path.join(data_dir, "Data_norm_2020_U251MG.xlsx"), index_col = 0)
display(Data_norm_df)
# Out:
#                            AARS     ABCB6     ABCC5     ABCF1     ABCF3  \
# ASG002_U251MG_24H:A03 -0.178654 -0.106862 -0.053731 -0.205517  0.046979
# ASG002_U251MG_24H:A04 -0.248680 -0.225963 -0.163556  0.102533 -0.094521
# ASG002_U251MG_24H:A05 -0.318979 -0.134862  0.162119  0.012683  0.236779
# ASG002_U251MG_24H:J13 -0.017829 -0.109138 -0.439906 -0.024517 -0.276021
# ASG002_U251MG_24H:J14  0.080071  0.071262  0.019169 -0.044467 -0.038345
# ...                         ...       ...       ...       ...       ...
# ASG002_U251MG_24H:P20 -1.165779 -1.174662 -0.033031  0.864033 -2.100671
# ASG002_U251MG_24H:P21  2.698371 -0.052563  0.054318  0.396834  0.475929
# ASG002_U251MG_24H:P22 -2.207129 -1.624262 -0.820181  0.541859 -0.045420
# ASG002_U251MG_24H:P23 -1.404754 -2.019962 -0.160156 -0.557817 -0.016970
# ASG002_U251MG_24H:P24 -0.240879  0.212288  0.961219 -0.233017  0.077930
#
#                           ABHD4     ABHD6      ABL1     ACAA1     ACAT2  ...  \
# ASG002_U251MG_24H:A03 -0.194327 -0.089152 -0.179361  0.580473 -0.167862  ...
# ASG002_U251MG_24H:A04 -0.197752 -0.163377 -0.010686  0.259747 -0.332512  ...
# ASG002_U251MG_24H:A05  0.052273 -0.033902  0.260514  0.662598  0.126488  ...
# ASG002_U251MG_24H:J13 -0.153127  0.154698 -0.142136 -0.579652 -0.060863  ...
# ASG002_U251MG_24H:J14  0.172273  0.086048 -0.017986  0.383748  0.217487  ...
# ...                         ...       ...       ...       ...       ...  ...
# ASG002_U251MG_24H:P20 -0.869127  0.980848 -0.957510 -2.027652 -0.916212  ...
# ASG002_U251MG_24H:P21  0.169673 -0.033352  0.673964  0.264697 -0.116463  ...
# ASG002_U251MG_24H:P22 -0.630427 -0.345902  1.146464 -1.532527 -1.898763  ...
# ASG002_U251MG_24H:P23 -0.422152  0.227673  0.505590 -1.000402 -0.751763  ...
# ASG002_U251MG_24H:P24 -0.302327 -0.051452  0.428414 -0.377452  0.248012  ...
#
#                           ZMIZ1     ZMYM2    ZNF131    ZNF274    ZNF318  \
# ASG002_U251MG_24H:A03  1.102416  0.583696 -0.301771 -0.348191 -0.085294
# ASG002_U251MG_24H:A04  0.538267 -0.496454 -0.205721 -0.418292 -0.023744
# ASG002_U251MG_24H:A05 -0.358134 -0.290955  0.919129 -0.370292  0.109456
# ASG002_U251MG_24H:J13  0.318117  0.102971 -0.366371  0.459958 -0.106243
# ASG002_U251MG_24H:J14 -0.775883 -0.376554 -0.269170  0.549808 -0.072744
# ...                         ...       ...       ...       ...       ...
# ASG002_U251MG_24H:P20 -1.323284 -1.647129 -0.519096  0.569209  0.038007
# ASG002_U251MG_24H:P21 -1.609534 -0.306254  1.567429 -0.415591  0.827707
# ASG002_U251MG_24H:P22 -1.565234  2.628596  1.788479 -0.665641 -0.261144
# ASG002_U251MG_24H:P23 -0.537583 -0.185179  1.177080 -0.563542 -0.071394
# ASG002_U251MG_24H:P24  0.381668 -0.192304  0.208454 -0.556892  0.407856
#
#                          ZNF395    ZNF451    ZNF586    ZNF589      ZW10
# ASG002_U251MG_24H:A03  0.432292  0.038529  0.056377  0.169081  0.546863
# ASG002_U251MG_24H:A04 -0.851458  0.069729  0.042527  0.191131  0.021112
# ASG002_U251MG_24H:A05 -0.814808 -0.214571  0.144152 -0.026894  0.258962
# ASG002_U251MG_24H:J13  3.750292 -0.208071  0.016977 -0.028694 -1.352387
# ASG002_U251MG_24H:J14 -0.168908  0.191229 -0.164898  0.107981  0.059913
# ...                         ...       ...       ...       ...       ...
# ASG002_U251MG_24H:P20  3.672717 -0.317571 -0.919523  0.538206 -0.492037
# ASG002_U251MG_24H:P21 -1.394509  0.763679  0.609552  0.484657 -0.194987
# ASG002_U251MG_24H:P22 -2.291608  1.374029  1.721677 -1.342619 -0.320988
# ASG002_U251MG_24H:P23 -2.813858 -0.135696  0.358527 -0.698244 -1.047038
# ASG002_U251MG_24H:P24 -3.272858  0.108405 -0.214498 -0.263344  0.400262
#
# [372 rows x 978 columns]

# %%
Data_norm_df = Data_norm_df[Data_norm_df.index.isin(exp_ids)]

# arrange experiments in same order as in list
Data_norm_df["sort_col"] = Data_norm_df.index.map({val: i for i, val in enumerate(exp_ids)})
Data_norm_df = Data_norm_df.sort_values("sort_col")
Data_norm_df = Data_norm_df.drop("sort_col", axis = 1)

# transpose
Data_norm_df = Data_norm_df.T

display(Data_norm_df)
# Out:
#         ASG002_U251MG_24H:A10  ASG002_U251MG_24H:A11  ASG002_U251MG_24H:A12  \
# AARS                -0.494279               0.151221               0.044521
# ABCB6               -1.826287              -0.041488               0.178438
# ABCC5                0.031419               0.078144               0.103768
# ABCF1                0.590333               0.201883              -0.273517
# ABCF3               -1.080121              -0.267320              -0.074120
# ...                       ...                    ...                    ...
# ZNF395               3.018842              -0.629308              -0.971758
# ZNF451              -0.510021              -0.131121               0.029579
# ZNF586              -0.367248               0.254077               0.146027
# ZNF589              -0.299019              -0.264469              -0.133344
# ZW10                -1.652187               0.092813               0.568613
#
#         ASG002_U251MG_24H:A19  ASG002_U251MG_24H:A20  ASG002_U251MG_24H:A21  \
# AARS                 0.044971              -0.587829              -0.615779
# ABCB6                0.127937              -0.083612              -0.028063
# ABCC5               -0.067731               0.206394               0.088544
# ABCF1                0.020884               0.195283              -0.273667
# ABCF3                0.306130               0.283429               0.252605
# ...                       ...                    ...                    ...
# ZNF395               0.969142               0.113142              -0.847609
# ZNF451               0.199280              -0.178070              -0.352221
# ZNF586               0.250677               0.162302               0.361602
# ZNF589              -0.084844              -0.161744              -0.361344
# ZW10                 0.308412               0.316263               0.366362
#
#         ASG002_U251MG_24H:B10  ASG002_U251MG_24H:B11  ASG002_U251MG_24H:B12  \
# AARS                 0.206571               0.166671              -0.091379
# ABCB6                0.110487              -0.029463              -0.285112
# ABCC5               -0.010331              -0.374056              -0.301856
# ABCF1                0.330033               0.056033               0.299683
# ABCF3                0.028229              -0.318671              -0.041821
# ...                       ...                    ...                    ...
# ZNF395              -0.667733               0.666241               0.975591
# ZNF451              -0.281321              -0.420571               0.046280
# ZNF586              -0.032673              -0.160773               0.038127
# ZNF589              -0.057144              -0.259994               0.077506
# ZW10                -1.126937               0.204387               0.173812
#
#         ASG002_U251MG_24H:B13  ...  ASG002_U251MG_24H:O12  \
# AARS                -0.026729  ...               0.096071
# ABCB6                0.090837  ...               0.230188
# ABCC5               -0.305206  ...               0.052144
# ABCF1                1.457133  ...              -0.395367
# ABCF3               -0.247721  ...               0.002480
# ...                       ...  ...                    ...
# ZNF395               1.503742  ...              -1.658758
# ZNF451              -0.039596  ...              -0.003870
# ZNF586              -0.191123  ...               0.419677
# ZNF589               0.615782  ...               0.122156
# ZW10                 0.410363  ...               0.228962
#
#         ASG002_U251MG_24H:O13  ASG002_U251MG_24H:O14  ASG002_U251MG_24H:O15  \
# AARS                 0.200097               0.207596               0.189071
# ABCB6                0.065338              -0.058263               0.242738
# ABCC5                0.377919               0.356669               0.005468
# ABCF1               -0.096117              -0.183117               0.107884
# ABCF3                0.119555               0.264779               0.223629
# ...                       ...                    ...                    ...
# ZNF395              -1.970259              -1.787859              -1.405909
# ZNF451              -0.217346               0.041029              -0.074770
# ZNF586              -0.122048               0.263327               0.196877
# ZNF589              -0.173169               0.452531              -0.129044
# ZW10                -0.303688              -0.707787               0.878612
#
#         ASG002_U251MG_24H:O22  ASG002_U251MG_24H:O23  ASG002_U251MG_24H:O24  \
# AARS                 0.690121               0.246471              -0.505054
# ABCB6               -0.674963              -0.015238              -0.033812
# ABCC5                0.526119               0.361218              -0.161831
# ABCF1               -0.145467              -0.838792              -0.629392
# ABCF3                0.415630               0.028229               0.118304
# ...                       ...                    ...                    ...
# ZNF395              -1.481358              -2.612784              -2.005709
# ZNF451              -0.160370              -0.052921              -0.210571
# ZNF586               0.232027               0.169127              -0.094573
# ZNF589               0.069756              -0.119744              -0.390693
# ZW10                -0.323337               0.024913              -0.022237
#
#         ASG002_U251MG_24H:P16  ASG002_U251MG_24H:P17  ASG002_U251MG_24H:P18
# AARS                 0.832671               0.220846               0.072772
# ABCB6                0.000463               0.205563               0.187887
# ABCC5                0.758819               0.120744               0.103768
# ABCF1               -0.099417              -0.272317              -0.077166
# ABCF3                0.220430               0.331180              -0.179221
# ...                       ...                    ...                    ...
# ZNF395               0.383192              -0.587058              -0.025608
# ZNF451              -0.479195              -0.062521              -0.240771
# ZNF586              -0.547323              -0.485098              -0.404173
# ZNF589               0.033006              -0.325444              -0.072919
# ZW10                -0.763962              -0.645137              -1.376187
#
# [978 rows x 98 columns]

# %%
genes = Data_norm_df.index.tolist()
print('Landmark genes list: ', len(genes), genes)

n_genes = len(genes)
# Out:
# Landmark genes list:  978 ['AARS', 'ABCB6', 'ABCC5', 'ABCF1', 'ABCF3', 'ABHD4', 'ABHD6', 'ABL1', 'ACAA1', 'ACAT2', 'ACBD3', 'ACD', 'ACLY', 'ACOT9', 'ADAM10', 'ADAT1', 'ADGRE5', 'ADGRG1', 'ADH5', 'ADI1', 'ADO', 'ADRB2', 'AGL', 'AKAP8', 'AKAP8L', 'AKR7A2', 'AKT1', 'ALAS1', 'ALDH7A1', 'ALDOA', 'ALDOC', 'AMDHD2', 'ANKRD10', 'ANO10', 'ANXA7', 'APBB2', 'APOE', 'APP', 'APPBP2', 'ARFIP2', 'ARHGAP1', 'ARHGEF12', 'ARHGEF2', 'ARID4B', 'ARID5B', 'ARL4C', 'ARNT2', 'ARPP19', 'ASAH1', 'ASCC3', 'ATF1', 'ATF5', 'ATF6', 'ATG3', 'ATMIN', 'ATP11B', 'ATP1B1', 'ATP2C1', 'ATP6V0B', 'ATP6V1D', 'AURKA', 'AURKB', 'AXIN1', 'B4GAT1', 'BACE2', 'BAD', 'BAG3', 'BAMBI', 'BAX', 'BCL2', 'BCL7B', 'BDH1', 'BECN1', 'BHLHE40', 'BID', 'BIRC2', 'BIRC5', 'BLCAP', 'BLMH', 'BLVRA', 'BMP4', 'BNIP3', 'BNIP3L', 'BPHL', 'BRCA1', 'BTK', 'BUB1B', 'BZW2', 'C2CD2', 'C2CD2L', 'C2CD5', 'C5', 'CAB39', 'CALM3', 'CALU', 'CAMSAP2', 'CANT1', 'CAPN1', 'CARMIL1', 'CASC3', 'CASK', 'CASP10', 'CASP2', 'CASP3', 'CASP7', 'CAST', 'CAT', 'CBLB', 'CBR1', 'CBR3', 'CCDC85B', 'CCDC86', 'CCDC92', 'CCL2', 'CCNA1', 'CCNA2', 'CCNB1', 'CCNB2', 'CCND1', 'CCND3', 'CCNE2', 'CCNF', 'CCNH', 'CCP110', 'CD320', 'CD40', 'CD44', 'CD58', 'CDC20', 'CDC25A', 'CDC25B', 'CDC42', 'CDC45', 'CDCA4', 'CDH3', 'CDK1', 'CDK19', 'CDK2', 'CDK4', 'CDK5R1', 'CDK6', 'CDK7', 'CDKN1A', 'CDKN1B', 'CDKN2A', 'CEBPA', 'CEBPD', 'CEBPZ', 'CEMIP2', 'CENPE', 'CEP57', 'CERK', 'CETN3', 'CFLAR', 'CGRRF1', 'CHAC1', 'CHEK1', 'CHEK2', 'CHERP', 'CHIC2', 'CHMP4A', 'CHMP6', 'CHN1', 'CHP1', 'CIAO3', 'CIAPIN1', 'CIRBP', 'CISD1', 'CLIC4', 'CLPX', 'CLSTN1', 'CLTB', 'CLTC', 'CNDP2', 'CNOT4', 'CNPY3', 'COASY', 'COG2', 'COG4', 'COG7', 'COL1A1', 'COL4A1', 'COPB2', 'COPS7A', 'COQ8A', 'CORO1A', 'CPNE3', 'CPSF4', 'CREB1', 'CREG1', 'CRELD2', 'CRK', 'CRKL', 'CRTAP', 'CRYZ', 'CSK', 'CSNK1A1', 'CSNK1E', 'CSNK2A2', 'CSRP1', 'CTNNAL1', 'CTNND1', 'CTSD', 'CTSL', 'CTTN', 'CXCL2', 'CXCR4', 'CYB561', 'CYCS', 'CYTH1', 'DAG1', 'DAXX', 'DCK', 'DCTD', 'DCUN1D4', 'DDB2', 'DDIT4', 'DDR1', 'DDX10', 'DDX42', 'DECR1', 'DENND2D', 'DERA', 'DFFA', 'DFFB', 'DHDDS', 'DHRS7', 'DHX29', 'DIPK1A', 'DLD', 'DMAC2L', 'DMTF1', 'DNAJA3', 'DNAJB1', 'DNAJB2', 'DNAJB6', 'DNAJC15', 'DNM1', 'DNM1L', 'DNMT1', 'DNMT3A', 'DNTTIP2', 'DPH2', 'DRAP1', 'DSG2', 'DUSP11', 'DUSP14', 'DUSP22', 'DUSP3', 'DUSP4', 'DUSP6', 'DYNLT3', 'DYRK3', 'E2F2', 'EAPP', 'EBNA1BP2', 'EBP', 'ECD', 'ECH1', 'EDEM1', 'EDN1', 'EED', 'EFCAB14', 'EGF', 'EGFR', 'EGR1', 'EIF4EBP1', 'EIF4G1', 'EIF5', 'ELAC2', 'ELAVL1', 'ELOVL6', 'ELP1', 'EML3', 'ENOPH1', 'ENOSF1', 'EPB41L2', 'EPHA3', 'EPHB2', 'EPN2', 'EPRS', 'ERBB2', 'ERBB3', 'ERO1A', 'ETFB', 'ETS1', 'ETV1', 'EVL', 'EXOSC4', 'EXT1', 'EZH2', 'FAH', 'FAIM', 'FAM20B', 'FAM57A', 'FAS', 'FASTKD5', 'FAT1', 'FBXL12', 'FBXO11', 'FBXO21', 'FBXO7', 'FCHO1', 'FDFT1', 'FEZ2', 'FGFR2', 'FGFR4', 'FHL2', 'FIS1', 'FKBP14', 'FKBP4', 'FOS', 'FOSL1', 'FOXJ3', 'FOXO3', 'FOXO4', 'FPGS', 'FRS2', 'FSD1', 'FUT1', 'FYN', 'FZD1', 'FZD7', 'G3BP1', 'GAA', 'GABPB1', 'GADD45A', 'GADD45B', 'GALE', 'GAPDH', 'GATA2', 'GATA3', 'GDPD5', 'GFOD1', 'GFPT1', 'GHR', 'GLI2', 'GLOD4', 'GLRX', 'GMNN', 'GNA11', 'GNA15', 'GNAI1', 'GNAI2', 'GNAS', 'GNB5', 'GNPDA1', 'GOLT1B', 'GPATCH8', 'GPC1', 'GPER1', 'GRB10', 'GRB7', 'GRN', 'GRWD1', 'GSTM2', 'GSTZ1', 'GTF2A2', 'GTF2E2', 'GTPBP8', 'H2AFV', 'HACD3', 'HADH', 'HAT1', 'HDAC2', 'HDAC6', 'HDGFL3', 'HEATR1', 'HEBP1', 'HERC6', 'HERPUD1', 'HES1', 'HIF1A', 'HIST1H2BK', 'HIST2H2BE', 'HK1', 'HLA-DMA', 'HLA-DRA', 'HMG20B', 'HMGA2', 'HMGCR', 'HMGCS1', 'HMOX1', 'HOMER2', 'HOOK2', 'HOXA10', 'HOXA5', 'HPRT1', 'HS2ST1', 'HSD17B10', 'HSD17B11', 'HSPA1A', 'HSPA4', 'HSPA8', 'HSPB1', 'HSPD1', 'HTATSF1', 'HTRA1', 'HYOU1', 'IARS2', 'ICAM1', 'ICAM3', 'ICMT', 'ID2', 'IDE', 'IER3', 'IFNAR1', 'IFRD2', 'IGF1R', 'IGF2BP2', 'IGF2R', 'IGFBP3', 'IGHMBP2', 'IKBKB', 'IKBKE', 'IKZF1', 'IL13RA1', 'IL1B', 'IL4R', 'ILK', 'INPP1', 'INPP4B', 'INSIG1', 'INTS3', 'IPO13', 'IQGAP1', 'ISOC1', 'ITFG1', 'ITGAE', 'ITGB1BP1', 'ITGB5', 'JADE2', 'JMJD6', 'JPT2', 'JUN', 'KAT6A', 'KAT6B', 'KCNK1', 'KCTD5', 'KDELR2', 'KDM3A', 'K ...

# %% [markdown]
# ## Inhibitor concentrations, IC50, and perturbation matrices

# %%
inhib_conc_matrix = np.zeros((n_modules, n_experiments))
ic50_matrix = np.ones((n_modules, n_experiments))
gamma_matrix = np.zeros((n_modules, n_experiments))

# %%
for i, module in enumerate(modules):
    drugs_for_module = IC50_df.Drug[IC50_df.Module == module].tolist()
    for drug in drugs_for_module:
        # get IC50 for this drug
        ic50 = IC50_df.IC50[IC50_df.Drug == drug].values
#       gamma = IC50_df.Gamma[IC50_df.Drug == drug].values
        print(drug, ic50)
        assert ic50.size == 1
#       assert gamma.size == 1
        # get experiments with this drug
        exp_with_drug = sig_info_df.index[sig_info_df.pert_drug == drug].tolist()
        print(exp_with_drug) 
        for exp_id in exp_with_drug:
            j = exp_ids.index(exp_id)
            print(j)
            # extract inhibitor concentration
            inhib_conc = sig_info_df.dose_float[sig_info_df.index == exp_id].values
            assert inhib_conc.size == 1
            # insert values in matrices
            inhib_conc_matrix[i, j] = inhib_conc.item()
            ic50_matrix[i, j] = ic50.item()
#           gamma_matrix[i, j] = gamma.item()
# Out:
# JNJ-7706621 [0.027]
# ['ASG002_U251MG_24H:N13', 'ASG002_U251MG_24H:N14', 'ASG002_U251MG_24H:N15']
# 77
# 78
# 79
# PHA-793887 [0.18]
# ['ASG002_U251MG_24H:L01', 'ASG002_U251MG_24H:L02', 'ASG002_U251MG_24H:L03']
# 62
# 63
# 64
# roscovitine [2.]
# ['ASG002_U251MG_24H:E22', 'ASG002_U251MG_24H:E23', 'ASG002_U251MG_24H:E24']
# 24
# 25
# 26
# alvocidib [0.12]
# ['ASG002_U251MG_24H:F04', 'ASG002_U251MG_24H:F05', 'ASG002_U251MG_24H:F06']
# 30
# 31
# 32
# palbociclib [0.045]
# ['ASG002_U251MG_24H:P16', 'ASG002_U251MG_24H:P17', 'ASG002_U251MG_24H:P18']
# 95
# 96
# 97
# AS-605240 [0.1595]
# ['ASG002_U251MG_24H:A19', 'ASG002_U251MG_24H:A20', 'ASG002_U251MG_24H:A21']
# 3
# 4
# 5
# GDC-0349 [3.]
# []
# LY-294002 [1.36]
# ['ASG002_U251MG_24H:F01', 'ASG002_U251MG_24H:F02', 'ASG002_U251MG_24H:F03']
# 27
# 28
# 29
# NVP-BEZ235 [1.71]
# ['ASG002_U251MG_24H:C16', 'ASG002_U251MG_24H:C17', 'ASG002_U251MG_24H:C18']
# 15
# 16
# 17
# taselisib [0.00262]
# ['ASG002_U251MG_24H:A10', 'ASG002_U251MG_24H:A11', 'ASG002_U251MG_24H:A12']
# 0
# 1
# 2
# PI-103 [0.09]
# ['ASG002_U251MG_24H:O22', 'ASG002_U251MG_24H:O23', 'ASG002_U251MG_24H:O24']
# 92
# 93
# 94
# AZ-628 [3.]
# ['ASG002_U251MG_24H:J19', 'ASG002_U251MG_24H:J20', 'ASG002_U251MG_24H:J21']
# 56
# 57
# 58
# PD-0325901 [0.015]
# ['ASG002_U251MG_24H:O13', 'ASG002_U251MG_24H:O14', 'ASG002_U251MG_24H:O15']
# 89
# 90
# 91
# dabrafenib [0.1]
# ['ASG002_U251MG_24H:K22', 'ASG002_U251MG_24H:K23', 'ASG002_U251MG_24H:K24']
# 59
# 60
# 61
# selumetinib [0.643]
# ['ASG002_U251MG_24H:J04', 'ASG002_U251MG_24H:J05', 'ASG002_U251MG_24H:J06']
# 50
# 51
# 52
# trametinib [0.00408]
# ['ASG002_U251MG_24H:G07', 'ASG002_U251MG_24H:G08', 'ASG002_U251MG_24H:G09']
# 36
# 37
# 38
# vemurafenib [0.1185]
# ['ASG002_U251MG_24H:M07', 'ASG002_U251MG_24H:M08', 'ASG002_U251MG_24H:M09']
# 71
# 72
# 73
# imatinib [0.3]
# ['ASG002_U251MG_24H:D22', 'ASG002_U251MG_24H:D23', 'ASG002_U251MG_24H:D24']
# 18
# 19
# 20
# tandutinib [0.6]
# ['ASG002_U251MG_24H:G16', 'ASG002_U251MG_24H:G17', 'ASG002_U251MG_24H:G18']
# 39
# 40
# 41
# masitinib [2.13]
# ['ASG002_U251MG_24H:E19', 'ASG002_U251MG_24H:E20', 'ASG002_U251MG_24H:E21']
# 21
# 22
# 23
# ponatinib [0.0033]
# ['ASG002_U251MG_24H:I19', 'ASG002_U251MG_24H:I20', 'ASG002_U251MG_24H:I21']
# 47
# 48
# 49
# barasertib-HQPA [0.00111]
# ['ASG002_U251MG_24H:L10', 'ASG002_U251MG_24H:L11', 'ASG002_U251MG_24H:L12']
# 65
# 66
# 67
# tozasertib [0.0232]
# ['ASG002_U251MG_24H:J10', 'ASG002_U251MG_24H:J11', 'ASG002_U251MG_24H:J12']
# 53
# 54
# 55
# dienestrol [200.]
# ['ASG002_U251MG_24H:M22', 'ASG002_U251MG_24H:M23', 'ASG002_U251MG_24H:M24']
# 74
# 75
# 76
# estradiol-cypionate [200.]
# ['ASG002_U251MG_24H:L16', 'ASG002_U251MG_24H:L17', 'ASG002_U251MG_24H:L18']
# 68
# 69
# 70
# raloxifene [0.0171]
# ['ASG002_U251MG_24H:O10', 'ASG002_U251MG_24H:O11', 'ASG002_U251MG_24H:O12']
# 86
# 87
# 88
# afatinib [0.03]
# ['ASG002_U251MG_24H:N22', 'ASG002_U251MG_24H:N23', 'ASG002_U251MG_24H:N24']
# 83
# 84
# 85
# erlotinib [0.006]
# ['ASG002_U251MG_24H:H17', 'ASG002_U251MG_24H:H18']
# 42
# 43
# gefitinib [0.171]
# ['ASG002_U251MG_24H:F16', 'ASG002_U251MG_24H:F17', 'ASG002_U251MG_24H:F18']
# 33
# 34
# 35
# lapatinib [0.0324]
# ['ASG002_U251MG_24H:I13', 'ASG002_U251MG_24H:I14', 'ASG002_U251MG_24H:I15']
# 44
# 45
# 46
# vandetanib [1.5]
# ['ASG002_U251MG_24H:N19', 'ASG002_U251MG_24H:N20', 'ASG002_U251MG_24H:N21']
# 80
# 81
# 82
# AMG-232 [0.0018]
# ['ASG002_U251MG_24H:B10', 'ASG002_U251MG_24H:B11', 'ASG002_U251MG_24H:B12']
# 6
# 7
# 8
# HLI-373 [3.]
# []
# nutlin-3 [0.54]
# ['ASG002_U251MG_24H:C13', 'ASG002_U251MG_24H:C14', 'ASG002_U251MG_24H:C15']
# 12
# 13
# 14
# RITA [9.75]
# ['ASG002_U251MG_24H:B13', 'ASG002_U251MG_24H:B14', 'ASG002_U251MG_24H:B15']
# 9
# 10
# 11
# SAR405838 [0.0264]
# []
# serdemetan [62.15]
# []

# %%
# transform matrices into pandas dfs for export with row and column names
inhib_conc_df = pd.DataFrame(inhib_conc_matrix, index = modules, columns = exp_ids)
ic50_df = pd.DataFrame(ic50_matrix, index = modules, columns = exp_ids)
# gamma_df = pd.DataFrame(gamma_matrix, index = modules, columns = exp_ids)

# create binary perturbation matrix
pert_df = pd.DataFrame(
    np.where(inhib_conc_matrix != 0, 1, 0),
    index = inhib_conc_df.index,
    columns = inhib_conc_df.columns,
# ERK                           0  ...                      0
# PDGFR                         0  ...                      0
# Aurora                        0  ...                      0
# Estrogen                      0  ...                      1
# EGFR                          0  ...                      0
# p53                           1  ...                      0
#
#           ASG002_U251MG_24H:O13  ASG002_U251MG_24H:O14  ASG002_U251MG_24H:O15  \
# CDK1                          0                      0                      0
# CDK2                          0                      0                      0
# CDK4_6                        0                      0                      0
# PI3K                          0                      0                      0
# ERK                           1                      1                      1
# PDGFR                         0                      0                      0
# Aurora                        0                      0                      0
# Estrogen                      0                      0                      0
# EGFR                          0                      0                      0
# p53                           0                      0                      0
#
#           ASG002_U251MG_24H:O22  ASG002_U251MG_24H:O23  ASG002_U251MG_24H:O24  \
# CDK1                          0                      0                      0
# CDK2                          0                      0                      0
# CDK4_6                        0                      0                      0
# PI3K                          1                      1                      1
# ERK                           0                      0                      0
# PDGFR                         0                      0                      0
# Aurora                        0                      0                      0
# Estrogen                      0                      0                      0
# EGFR                          0                      0                      0
# p53                           0                      0                      0
#
#           ASG002_U251MG_24H:P16  ASG002_U251MG_24H:P17  ASG002_U251MG_24H:P18
# CDK1                          0                      0                      0
# CDK2                          0                      0                      0
# CDK4_6                        1                      1                      1
# PI3K                          0                      0                      0
# ERK                           0                      0                      0
# PDGFR                         0                      0                      0
# Aurora                        0                      0                      0
# Estrogen                      0                      0                      0
# EGFR                          0                      0                      0
# p53                           0                      0                      0
#
# [10 rows x 98 columns]

# %% [markdown]
# ## Global responses for DPD modules
#
# According to our discussion, $R$ for DPD vectors can not be calculated with the same formula as for pathway activities. Instead we are assuming:
#
# \begin{equation}
# R_{DPD},j = DPD = STV_{DPD} \cdot Data_j
# \end{equation}

# %%
# load STV data frame
STVs = pd.read_excel(os.path.join(data_dir,'ALL_DATA_2020_Jing_u251mg.xlsx'), sheet_name = "STVs", index_col = 0)

STV_df = pd.DataFrame(np.zeros((len(Data_norm_df.index), 2)), index = Data_norm_df.index, columns = STVs.columns)
STV_df.loc[STVs.index] = STVs

display(STV_df)
# Out:
#          GBM_onc  GBM_survival
# AARS   -0.018282     -1.228394
# ABCB6   0.000000      0.000000
# ABCC5  -0.007873      0.000000
# ABCF1  -0.011879     -2.215623
# ABCF3   0.000000      0.000000
# ...          ...           ...
# ZNF395 -0.033083      0.000000
# ZNF451  0.002199      0.000000
# ZNF586 -0.011584     -0.017534
# ZNF589 -0.012400     -1.006080
# ZW10   -0.014991      0.000000
#
# [978 rows x 2 columns]

# %%
# create empty DPD data frame
DPD_df = pd.DataFrame(
    np.zeros((len(Data_norm_df.columns), len(STV_df.columns))),
    index = Data_norm_df.columns,
    columns = STV_df.columns,
)

# populate
for exp_id in DPD_df.index:
    for state in STV_df.columns:
        DPD_df.loc[exp_id, state] = np.dot(Data_norm_df.T.loc[exp_id], STV_df.loc[:, state])

display(DPD_df)
# Out:
#                         GBM_onc  GBM_survival
# ASG002_U251MG_24H:A10  1.979015     -7.817739
# ASG002_U251MG_24H:A11  0.221957     14.055979
# ASG002_U251MG_24H:A12  0.379708      1.230610
# ASG002_U251MG_24H:A19  0.905402     -1.291184
# ASG002_U251MG_24H:A20  1.947269     12.000663
# ...                         ...           ...
# ASG002_U251MG_24H:O23 -0.030627      5.999362
# ASG002_U251MG_24H:O24  0.182223      7.363056
# ASG002_U251MG_24H:P16  1.414242      2.783695
# ASG002_U251MG_24H:P17  1.510780      9.892769
# ASG002_U251MG_24H:P18  0.047220      3.311671
#
# [98 rows x 2 columns]

# %%
# transform to R global
R_global_DPD_df = DPD_df.T
display(R_global_DPD_df)
# Out:
#               ASG002_U251MG_24H:A10  ASG002_U251MG_24H:A11  \
# GBM_onc                    1.979015               0.221957
# GBM_survival              -7.817739              14.055979
#
#               ASG002_U251MG_24H:A12  ASG002_U251MG_24H:A19  \
# GBM_onc                    0.379708               0.905402
# GBM_survival               1.230610              -1.291184
#
#               ASG002_U251MG_24H:A20  ASG002_U251MG_24H:A21  \
# GBM_onc                    1.947269               0.185462
# GBM_survival              12.000663              -1.796645
#
#               ASG002_U251MG_24H:B10  ASG002_U251MG_24H:B11  \
# GBM_onc                    0.234524                1.08982
# GBM_survival              -3.664586                4.43985
#
#               ASG002_U251MG_24H:B12  ASG002_U251MG_24H:B13  ...  \
# GBM_onc                    0.639857               0.915347  ...
# GBM_survival              10.295292              -8.553705  ...
#
#               ASG002_U251MG_24H:O12  ASG002_U251MG_24H:O13  \
# GBM_onc                   -0.291152               0.352087
# GBM_survival               5.423407              -7.942981
#
#               ASG002_U251MG_24H:O14  ASG002_U251MG_24H:O15  \
# GBM_onc                    0.503912              -0.446126
# GBM_survival               2.683590              -5.235766
#
#               ASG002_U251MG_24H:O22  ASG002_U251MG_24H:O23  \
# GBM_onc                    0.881017              -0.030627
# GBM_survival               8.799630               5.999362
#
#               ASG002_U251MG_24H:O24  ASG002_U251MG_24H:P16  \
# GBM_onc                    0.182223               1.414242
# GBM_survival               7.363056               2.783695
#
#               ASG002_U251MG_24H:P17  ASG002_U251MG_24H:P18
# GBM_onc                    1.510780               0.047220
# GBM_survival               9.892769               3.311671
#
# [2 rows x 98 columns]

# %% [markdown]
# ## Save outputs

# %%
# save metadata as pickle
all_metadata = {
    "modules": modules,
    "n_modules": n_modules,
    "drugs": drugs,
    "n_drugs": n_drugs,
    "exp_ids": exp_ids,
    "n_experiments": n_experiments,
    "genes": genes,
    "n_genes": n_genes,
}

print(all_metadata)

with open(os.path.join(out_dir, "metadata.pickle"), "wb") as f:
    pickle.dump(all_metadata, f, protocol = pickle.HIGHEST_PROTOCOL)
# Out:
# {'modules': ['CDK1', 'CDK2', 'CDK4_6', 'PI3K', 'ERK', 'PDGFR', 'Aurora', 'Estrogen', 'EGFR', 'p53'], 'n_modules': 10, 'drugs': ['RITA', 'nutlin-3', 'lapatinib', 'vemurafenib', 'tozasertib', 'erlotinib', 'vandetanib', 'AMG-232', 'GDC-0349', 'alvocidib', 'SAR405838', 'NVP-BEZ235', 'PHA-793887', 'PD-0325901', 'imatinib', 'H
_24H:M08', 'ASG002_U251MG_24H:M09', 'ASG002_U251MG_24H:M22', 'ASG002_U251MG_24H:M23', 'ASG002_U251MG_24H:M24', 'ASG002_U251MG_24H:N13', 'ASG002_U251MG_24H:N14', 'ASG002_U251MG_24H:N15', 'ASG002_U251MG_24H:N19', 'ASG002_U251MG_24H:N20', 'ASG002_U251MG_24H:N21', 'ASG002_U251MG_24H:N22', 'ASG002_U251MG_24H:N23', 'ASG002_U251MG_24H:N24', 'ASG002_U251MG_24H:O10', 'ASG002_U251MG_24H:O11', 'ASG002_U251MG_24H:O12', 'ASG002_U251MG_24H:O13', 'ASG002_U251MG_24H:O14', 'ASG002_U251MG_24H:O15', 'ASG002_U251MG_24H:O22', 'ASG002_U251MG_24H:O23', 'ASG002_U251MG_24H:O24', 'ASG002_U251MG_24H:P16', 'ASG002_U251MG_24H:P17', 'ASG002_U251MG_24H:P18'], 'n_experiments': 98, 'genes': ['AARS', 'ABCB6', 'ABCC5', 'ABCF1', 'ABCF3', 'ABHD4', 'ABHD6', 'ABL1', 'ACAA1', 'ACAT2', 'ACBD3', 'ACD', 'ACLY', 'ACOT9', 'ADAM10', 'ADAT1', 'ADGRE5', 'ADGRG1', 'ADH5', 'ADI1', 'ADO', 'ADRB2', 'AGL', 'AKAP8', 'AKAP8L', 'AKR7A2', 'AKT1', 'ALAS1', 'ALDH7A1', 'ALDOA', 'ALDOC', 'AMDHD2', 'ANKRD10', 'ANO10', 'ANXA7', 'APBB2', 'APOE', 'APP', 'APPBP2', 'ARFIP2', 'ARHGAP1', 'ARHGEF12', 'ARHGEF2', 'ARID4B', 'ARID5B', 'ARL4C', 'ARNT2', 'ARPP19', 'ASAH1', 'ASCC3', 'ATF1', 'ATF5', 'ATF6', 'ATG3', 'ATMIN', 'ATP11B', 'ATP1B1', 'ATP2C1', 'ATP6V0B', 'ATP6V1D', 'AURKA', 'AURKB', 'AXIN1', 'B4GAT1', 'BACE2', 'BAD', 'BAG3', 'BAMBI', 'BAX', 'BCL2', 'BCL7B', 'BDH1', 'BECN1', 'BHLHE40', 'BID', 'BIRC2', 'BIRC5', 'BLCAP', 'BLMH', 'BLVRA', 'BMP4', 'BNIP3', 'BNIP3L', 'BPHL', 'BRCA1', 'BTK', 'BUB1B', 'BZW2', 'C2CD2', 'C2CD2L', 'C2CD5', 'C5', 'CAB39', 'CALM3', 'CALU', 'CAMSAP2', ' ...

# %%
# save doses and perturbation matrix
inhib_conc_df.to_csv(os.path.join(out_dir, "inhib_conc_annotated.csv"))
ic50_df.to_csv(os.path.join(out_dir, "ic50_annotated.csv"))
# gamma_df.to_csv(os.path.join(out_dir, "gamma_annotated.csv"))
pert_df.to_csv(os.path.join(out_dir, "pert_annotated.csv"))

# %%
# save log fold change L1000 data
Data_norm_df.to_csv(os.path.join(out_dir, "L1000_Data_norm_data.csv"))

# %%
# save R_global for DPDs
R_global_DPD_df.to_csv(os.path.join(out_dir, "R_global_DPDonly_annotated.csv"))
