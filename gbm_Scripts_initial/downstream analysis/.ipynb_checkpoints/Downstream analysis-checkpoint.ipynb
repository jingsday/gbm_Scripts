# %%
import os
import numpy as np
import pandas as pd
import scanpy as sc
import loompy as lp
from MulticoreTSNE import MulticoreTSNE as TSNE
import seaborn as sns
import matplotlib.pyplot as plt
import scipy
import csv
import gzip
import anndata as ad
from pathlib import Path
import glob

sc.settings.verbosity = 3 # verbosity: errors (0), warnings (1), info (2), hints (3)
sc.logging.print_versions()
# Out:
# -----
# anndata     0.8.0
# scanpy      1.9.1
# -----
# MulticoreTSNE               NA
# PIL                         9.1.0
# appnope                     0.1.2
# asttokens                   NA
# backcall                    0.2.0
# beta_ufunc                  NA
# binom_ufunc                 NA
# cffi                        1.15.0
# cloudpickle                 2.1.0
# cycler                      0.10.0
# cython_runtime              NA
# cytoolz                     0.11.0
# dask                        2022.9.0
# dateutil                    2.8.2
# debugpy                     1.5.1
# decorator                   5.1.1
# defusedxml                  0.7.1
# entrypoints                 0.4
# executing                   0.8.3
# fsspec                      2022.8.2
# h5py                        3.7.0
# hypergeom_ufunc             NA
# igraph                      0.10.1
# ipykernel                   6.9.1
# ipython_genutils            0.2.0
# ipywidgets                  7.6.5
# jedi                        0.18.1
# jinja2                      3.0.3
# joblib                      1.1.0
# kiwisolver                  1.4.2
# leidenalg                   0.9.0
# llvmlite                    0.38.0
# loompy                      3.0.7
# louvain                     0.8.0
# markupsafe                  2.0.1
# matplotlib                  3.5.2
# mpl_toolkits                NA
# natsort                     8.1.0
# nbinom_ufunc                NA
# numba                       0.55.1
# numexpr                     2.8.3
# numpy                       1.21.5
# numpy_groupies              0.9.19
# packaging                   21.3
# pandas                      1.4.2
# parso                       0.8.3
# pexpect                     4.8.0
# pickleshare                 0.7.5
# pkg_resources               NA
# prompt_toolkit              3.0.20
# psutil                      5.9.1
# ptyprocess                  0.7.0
# pure_eval                   0.2.2
# pyarrow                     9.0.0
# pycparser                   2.21
# pydev_ipython               NA
# pydevconsole                NA
# pydevd                      2.6.0
# pydevd_concurrency_analyser NA
# pydevd_file_utils           NA
# pydevd_plugins              NA
# pydevd_tracing              NA
# pyexpat                     NA
# pygments                    2.11.2
# pyparsing                   3.0.4
# pytz                        2022.1
# scipy                       1.8.0
# seaborn                     0.11.2
# session_info                1.0.0
# six                         1.16.0
# sklearn                     1.0.2
# stack_data                  0.2.0
# statsmodels                 0.13.2
# tblib                       1.7.0
# texttable                   1.6.4
# threadpoolctl               3.1.0
# tlz                         0.11.0
# toolz                       0.12.0
# tornado                     6.1
# traitlets                   5.1.1
# typing_extensions           NA
# wcwidth                     0.2.5
# yaml                        6.0
# zmq                         22.3.0
# -----
# IPython             8.2.0
# jupyter_client      7.2.2
# jupyter_core        4.9.2
# notebook            6.4.8
# -----
# Python 3.9.7 (default, Sep 16 2021, 08:50:36) [Clang 10.0.0 ]
# macOS-10.16-x86_64-i386-64bit
# -----
# Session information updated at 2023-04-13 12:45

# %%
integrated_to_plot=pd.read_pickle('/Users/lidiayung/github/notebooks/GBM/calculation/integrated_to_plot.pkl')
integrated_to_plot
# Out:
#        Sample Post-filtering Percentage   Sum  percentage      Stage Pair#  \
# 0     SF10857       2094/142      93.65   886   25.000000    Primary    33
# 1     SF11916         916/71      92.81   916   91.666667    Primary    31
# 2     SF11815       3060/272      91.83  3060   96.875000    Primary    32
# 3     SF11873       166/2964        5.3   166   70.625000    Primary    36
# 4      SF2777       3323/385      89.62  3323   90.630000    Primary    11
# ..        ...            ...        ...   ...         ...        ...   ...
# 74    SF10441        466/640      42.13   466   40.000000  Recurrent     2
# 75   SF9715v2      2536/1195      67.97  2536         NaN        NaN   NaN
# 76    SF12704       1189/639      65.04  1189         NaN  Recurrent   NaN
# 77  SF12704v2      1253/2919      30.03  1253         NaN        NaN   NaN
# 78   SF6118v2        133/357      27.14   133         NaN        NaN   NaN
#
#      Age  Sex
# 0   52.0    M
# 1   71.0    M
# 2   49.0    F
# 3   64.0    F
# 4   29.0    F
# ..   ...  ...
# 74  56.0    M
# 75   NaN  NaN
# 76  51.0    F
# 77   NaN  NaN
# 78   NaN  NaN
#
# [79 rows x 9 columns]

# %%
items = ['SF7307','SF11916','SF11815','SF10857']
new_rows = []
for item in items:
    row =integrated_to_plot[integrated_to_plot['Sample']== item]
    new_rows.append(row)
    
print(new_rows)
# Out:
# [    Sample Post-filtering Percentage  Sum  percentage    Stage Pair#   Age Sex
# 20  SF7307         153/46      76.88  153      54.375  Primary    23  60.0   M
# 67  SF7307         153/46      76.88  153      54.375  Primary    23  60.0   M,     Sample Post-filtering Percentage  Sum  percentage    Stage Pair#   Age Sex
# 1  SF11916         916/71      92.81  916   91.666667  Primary    31  71.0   M,     Sample Post-filtering Percentage   Sum  percentage    Stage Pair#   Age  \
# 2  SF11815       3060/272      91.83  3060      96.875  Primary    32  49.0
#
#   Sex
# 2   F  ,     Sample Post-filtering Percentage  Sum  percentage    Stage Pair#   Age Sex
# 0  SF10857       2094/142      93.65  886        25.0  Primary    33  52.0   M]

# %%
integrated_to_plot[integrated_to_plot['Pair#']==33]
# Out:
#      Sample Post-filtering Percentage   Sum  percentage      Stage Pair#  \
# 0   SF10857       2094/142      93.65   886        25.0    Primary    33
# 26  SF12008      1488/1242      54.51  1488        52.0  Recurrent    33
#
#      Age Sex
# 0   52.0   M
# 26  54.0   M

# %%
integrated_to_plot['Sum']=pd.to_numeric(integrated_to_plot['Sum'], errors='coerce')

# %%
integrated_to_plot.to_pickle('/Users/lidiayung/github/notebooks/GBM/calculation/integrated_to_plot.pkl')

# %%
pairs['Pair#']=pd.to_numeric(pairs['Pair#'], errors='coerce')

# %%
pairs['Sum'] = pairs['Post-filtering'].str.split('/').str[0]
pairs['Sum']=pd.to_numeric(pairs['Sum'], errors='coerce')

# %%
pairs['Sum']=pd.to_numeric(pairs['Sum'], errors='coerce')

# %%
pairs
# Out:
#      Sample Post-filtering Percentage   Sum percentage      Stage  Pair#  \
# 0    SF3996        294/111      72.59   294       50.0  Recurrent      1
# 1   SF10099        437/116      79.02   437      56.25    Primary      2
# 2   SF10441        466/640      42.13   466       40.0  Recurrent      2
# 3   SF10565       245/2627       8.53   245       8.75  Recurrent      3
# 4   SF10432         434/19      95.81   434       87.5    Primary      4
# ..      ...            ...        ...   ...        ...        ...    ...
# 66  SF11587        1252/47      96.38  1252     96.875    Primary     35
# 68  SF11873       166/2964        5.3   166     70.625    Primary     36
# 69  SF12754       510/1537      24.91   510       25.0  Recurrent     36
# 67  SF12407        29/1557       1.83    29        1.0  Recurrent     36
# 70  SF11720        630/906      41.02   630       20.0  Recurrent     37
#
#      Age Sex
# 0   67.0   M
# 1   55.0   M
# 2   56.0   M
# 3   45.0   F
# 4   50.0   F
# ..   ...  ..
# 66  58.0   F
# 68  64.0   F
# 69  65.0   F
# 67  65.0   F
# 70  56.0   M
#
# [72 rows x 9 columns]

# %%
pairs = pairs[pairs['Pair#'].notnull()].sort_values('Pair#',ascending = True)
pairs.head(40)
# Out:
#      Sample Post-filtering Percentage   Sum percentage      Stage  Pair#  \
# 0    SF3996        294/111      72.59   294       50.0  Recurrent      1
# 1   SF10099        437/116      79.02   437      56.25    Primary      2
# 2   SF10441        466/640      42.13   466       40.0  Recurrent      2
# 3   SF10565       245/2627       8.53   245       8.75  Recurrent      3
# 4   SF10432         434/19      95.81   434       87.5    Primary      4
# 5   SF11248        906/982      47.99   906       48.0  Recurrent      4
# 6   SF11857       157/3236       4.63   157        6.0  Recurrent      5
# 7   SF10592       296/1037      22.21   296       23.0    Primary      5
# 9   SF11082       4021/111      97.31  4021  97.916667    Primary      6
# 8   SF11488       4257/155      96.49  4257      96.75  Recurrent      6
# 10  SF11344       589/5194      10.19   589  11.111111    Primary      7
# 11  SF12460      1602/2654      37.64  1602       32.5  Recurrent      7
# 13   SF1199         111/11      90.98   111       50.0    Primary      8
# 12   SF1343       2021/688       74.6  2021       75.0  Recurrent      8
# 14  SF12243      1021/1565      39.48  1021       47.5  Recurrent      9
# 15  SF11780       6462/216      96.77  6462     96.875    Primary      9
# 17   SF2628       1958/578      77.21  1958       75.7  Recurrent     10
# 16   SF2501         231/92      71.52   231        NaN    Primary     10
# 18   SF2777       3323/385      89.62  3323      90.63    Primary     11
# 19   SF2979      3028/1247      70.83  3028       66.5  Recurrent     11
# 20   SF3073       608/2550      19.25   608      21.25  Recurrent     12
# 21   SF2990       1471/427       77.5  1471       78.0    Primary     12
# 22   SF3076       2332/882      72.56  2332       70.0    Primary     13
# 23   SF3243       2133/411      83.84  2133       84.0  Recurrent     13
# 24   SF3391       6160/667      90.23  6160      90.63    Primary     14
# 25   SF3448       495/4337      10.24   495       14.0  Recurrent     14
# 71   SF3996        294/111      72.59   294        NaN        NaN     15
# 26   SF4449        21/4313       0.48    21        0.0  Recurrent     15
# 27   SF6621       977/1299      42.93   977       41.0  Recurrent     16
# 28   SF6186       2322/587      79.82  2322      81.25  Recurrent     17
# 29   SF4810         499/27      94.87   499      81.25    Primary     18
# 30   SF6098        55/1694       3.14    55        4.0  Recurrent     18
# 31   SF4849         471/63       88.2   471       80.0    Primary     19
# 32   SF6118        133/357      27.14   133  91.666667  Recurrent     19
# 34   SF5581       3900/306      92.72  3900      91.67    Primary     20
# 33   SF9715          4/214       1.83     4       55.0  Recurrent     20
# 35   SF6809         127/55      67.00   127        NaN    Primary     21
# 36   SF7025          77/72      51.68    77     96.875  Recurrent     21
# 37   SF7062       713/2413      22.81   713       23.0  Recurrent     22
# 38   SF7307         153/46      76.88   153     54.375    Primary     23
#
#      Age  Sex
# 0   67.0    M
# 1   55.0    M
# 2   56.0    M
# 3   45.0    F
# 4   50.0    F
# 5   52.0    F
# 6   69.0    M
# 7   66.0    M
# 9   59.0    F
# 8   60.0    F
# 10  37.0    F
# 11  40.0    F
# 13  57.0    M
# 12  57.0    M
# 14  47.0    F
# 15  46.0    F
# 17  45.0    F
# 16  55.0    F
# 18  29.0    F
# 19  30.0    F
# 20  64.0    F
# 21  71.0    F
# 22  25.0    M
# 23  24.0    M
# 24  56.0    F
# 25  56.0    F
# 71   NaN  NaN
# 26  45.0    F
# 27  43.0    M
# 28  53.0    F
# 29  59.0    F
# 30  60.0    F
# 31  62.0    M
# 32  62.0    M
# 34  35.0    M
# 33  36.0    M
# 35  57.0    M
# 36  58.0    M
# 37  40.0    F
# 38  60.0    M

# %%
#to drop 19 66 18 67

pairs.drop([26],inplace=True)

# %%
pairs.update(pd.DataFrame.from_dict(new_row))

# %%
pairs = pd.read_pickle('/Users/lidiayung/github/notebooks/GBM/calculation/pairs.pkl')

# %%
pairs.to_pickle('/Users/lidiayung/github/notebooks/GBM/calculation/pairs.pkl')

# %%
pairs.head(40)
# Out:
#      Sample Post-filtering Percentage   Sum percentage      Stage  Pair#  \
# 0    SF3996        294/111      72.59   294       50.0  Recurrent      1
# 1   SF10099        437/116      79.02   437      56.25    Primary      2
# 2   SF10441        466/640      42.13   466       40.0  Recurrent      2
# 3   SF10565       245/2627       8.53   245       8.75  Recurrent      3
# 4   SF10432         434/19      95.81   434       87.5    Primary      4
# 5   SF11248        906/982      47.99   906       48.0  Recurrent      4
# 6   SF11857       157/3236       4.63   157        6.0  Recurrent      5
# 7   SF10592       296/1037      22.21   296       23.0    Primary      5
# 9   SF11082       4021/111      97.31  4021  97.916667    Primary      6
# 8   SF11488       4257/155      96.49  4257      96.75  Recurrent      6
# 10  SF11344       589/5194      10.19   589  11.111111    Primary      7
# 11  SF12460      1602/2654      37.64  1602       32.5  Recurrent      7
# 13   SF1199         111/11      90.98   111       50.0    Primary      8
# 12   SF1343       2021/688       74.6  2021       75.0  Recurrent      8
# 14  SF12243      1021/1565      39.48  1021       47.5  Recurrent      9
# 15  SF11780       6462/216      96.77  6462     96.875    Primary      9
# 17   SF2628       1958/578      77.21  1958       75.7  Recurrent     10
# 16   SF2501         231/92      71.52   231        NaN    Primary     10
# 18   SF2777       3323/385      89.62  3323      90.63    Primary     11
# 19   SF2979      3028/1247      70.83  3028       66.5  Recurrent     11
# 20   SF3073       608/2550      19.25   608      21.25  Recurrent     12
# 21   SF2990       1471/427       77.5  1471       78.0    Primary     12
# 22   SF3076       2332/882      72.56  2332       70.0    Primary     13
# 23   SF3243       2133/411      83.84  2133       84.0  Recurrent     13
# 24   SF3391       6160/667      90.23  6160      90.63    Primary     14
# 25   SF3448       495/4337      10.24   495       14.0  Recurrent     14
# 71   SF3996        294/111      72.59   294        NaN        NaN     15
# 26   SF4449        21/4313       0.48    21        0.0  Recurrent     15
# 27   SF6621       977/1299      42.93   977       41.0  Recurrent     16
# 28   SF6186       2322/587      79.82  2322      81.25  Recurrent     17
# 29   SF4810         499/27      94.87   499      81.25    Primary     18
# 30   SF6098        55/1694       3.14    55        4.0  Recurrent     18
# 31   SF4849         471/63       88.2   471       80.0    Primary     19
# 32   SF6118        133/357      27.14   133  91.666667  Recurrent     19
# 34   SF5581       3900/306      92.72  3900      91.67    Primary     20
# 33   SF9715          4/214       1.83     4       55.0  Recurrent     20
# 35   SF6809         127/55      67.00   127        NaN    Primary     21
# 36   SF7025          77/72      51.68    77     96.875  Recurrent     21
# 37   SF7062       713/2413      22.81   713       23.0  Recurrent     22
# 38   SF7307         153/46      76.88   153     54.375    Primary     23
#
#      Age  Sex
# 0   67.0    M
# 1   55.0    M
# 2   56.0    M
# 3   45.0    F
# 4   50.0    F
# 5   52.0    F
# 6   69.0    M
# 7   66.0    M
# 9   59.0    F
# 8   60.0    F
# 10  37.0    F
# 11  40.0    F
# 13  57.0    M
# 12  57.0    M
# 14  47.0    F
# 15  46.0    F
# 17  45.0    F
# 16  55.0    F
# 18  29.0    F
# 19  30.0    F
# 20  64.0    F
# 21  71.0    F
# 22  25.0    M
# 23  24.0    M
# 24  56.0    F
# 25  56.0    F
# 71   NaN  NaN
# 26  45.0    F
# 27  43.0    M
# 28  53.0    F
# 29  59.0    F
# 30  60.0    F
# 31  62.0    M
# 32  62.0    M
# 34  35.0    M
# 33  36.0    M
# 35  57.0    M
# 36  58.0    M
# 37  40.0    F
# 38  60.0    M

# %%
#new_row = [{'Sample': 'SF10857', 'Post-filtering': '2094/142','Percentage':'93.65'}]
new_row = [{'Sample': 'SF2501', 'Post-filtering': '231/92','Percentage':'71.52','Pair#':'10'}]

# %%
new_row = [{'Sample': 'SF6809', 'Post-filtering': '127/55','Percentage':'67.00','Pair#':21}]

# %%
pairs.tail(30)
# Out:
#      Sample Post-filtering Percentage   Sum percentage      Stage  Pair#  \
# 41   SF7307         153/46      76.88   153     54.375    Primary     23
# 42  SF12165       756/2381       24.1   756       24.0  Recurrent     24
# 43   SF9510       756/4148      15.42   756       19.0  Recurrent     25
# 44   SF9962       2660/808       76.7  2660       75.5  Recurrent     26
# 45   SF9358       494/2616      15.88   494       16.0    Primary     26
# 46   SF9798       3849/200      95.06  3849      93.75    Primary     27
# 47   SF9494       748/2706      21.66   748      23.25  Recurrent     27
# 49  SF10108      2821/1584      64.04  2821       59.0  Recurrent     28
# 48   SF9871         6/3592       0.17     6        0.0    Primary     28
# 51  SF10433        502/670      42.83   502       17.5  Recurrent     29
# 50   SF9372       3345/736      81.97  3345      81.25    Primary     29
# 53   SF4324       886/2779      24.17   886        NaN  Recurrent     30
# 52   SF4209        633/102      86.12   633       74.0    Primary     30
# 56  SF12382       1678/380      81.54  1678       82.0  Recurrent     31
# 54  SF11916         916/71      92.81   916  91.666667    Primary     31
# 55  SF11916         916/71      92.81   916  91.666667    Primary     31
# 57  SF11815       3060/272      91.83  3060     96.875    Primary     32
# 58  SF11815       3060/272      91.83  3060     96.875    Primary     32
# 59  SF12408        2877/46      98.43  2877       98.0  Recurrent     32
# 61  SF12008      1488/1242      54.51  1488       52.0  Recurrent     33
# 62  SF10857       2094/142      93.65  2094       25.0    Primary     33
# 60  SF10857       2094/142      93.65  2094       25.0    Primary     33
# 63  SF12751       541/3506      13.37   541       17.5  Recurrent     34
# 64  SF12115         59/194      23.32    59       26.0    Primary     34
# 65  SF11981         0/1107        0.0     0      81.25  Recurrent     35
# 66  SF11587        1252/47      96.38  1252     96.875    Primary     35
# 68  SF11873       166/2964        5.3   166     70.625    Primary     36
# 69  SF12754       510/1537      24.91   510       25.0  Recurrent     36
# 67  SF12407        29/1557       1.83    29        1.0  Recurrent     36
# 70  SF11720        630/906      41.02   630       20.0  Recurrent     37
#
#      Age Sex
# 41  60.0   M
# 42  40.0   F
# 43  73.0   M
# 44  61.0   M
# 45  60.0   M
# 46  64.0   M
# 47  64.0   M
# 49  47.0   M
# 48  46.0   M
# 51  53.0   F
# 50  50.0   F
# 53  57.0   F
# 52  57.0   F
# 56  72.0   M
# 54  71.0   M
# 55  71.0   M
# 57  49.0   F
# 58  49.0   F
# 59  50.0   F
# 61  54.0   M
# 62  52.0   M
# 60  52.0   M
# 63  43.0   M
# 64  43.0   M
# 65  59.0   F
# 66  58.0   F
# 68  64.0   F
# 69  65.0   F
# 67  65.0   F
# 70  56.0   M

# %%
new_row = [{'Sample': 'SF1199', 'Post-filtering': '111/11','Percentage':'90.98','Pair#':8}]

# %%
new_row = [{'Sample': 'SF3996', 'Post-filtering': '294/111','Percentage':'72.59','Pair#':15}]

# %%
pairs.update(pd.DataFrame.from_dict(new_row))

# %%
pairs = pairs.append(new_row, ignore_index=True)
# Out:
# /var/folders/qq/n8l4bgxs53j_s3twq5jzc7g00000gn/T/ipykernel_36945/2834396713.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pairs = pairs.append(new_row, ignore_index=True)

# %%
new_row= [{'Sample': 'SF11873', 'Post-filtering': '166/2964','Percentage':'5.3','percentage':'70.625',
           'Stage':'Primary','Pair#':'36','Age':'55.0','Sex':'F'}]

# %%
#to update
new_row = [{'Sample': 'SF3996', 'Post-filtering': '294/111','Percentage':'72.59'},
           {'Sample': 'SF6118', 'Post-filtering': '133/357','Percentage':'27.14'},
           {'Sample': 'SF7025', 'Post-filtering': '77/72','Percentage':'51.68'},
           {'Sample': 'SF9358', 'Post-filtering': '494/2616','Percentage':'15.88'},
           {'Sample': 'SF4324', 'Post-filtering': '886/2779','Percentage':'24.17'}]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [120], in <cell line: 7>()
#       1 #to update
#       2 new_row = [{'Sample': 'SF3996', 'Post-filtering': '294/111','Percentage':'72.59'},
#       3            {'Sample': 'SF6118', 'Post-filtering': '133/357','Percentage':'27.14'},
#       4            {'Sample': 'SF7025', 'Post-filtering': '77/72','Percentage':'51.68'},
#       5            {'Sample': 'SF9358', 'Post-filtering': '494/2616','Percentage':'15.88'},
#       6            {'Sample': 'SF4324', 'Post-filtering': '886/2779','Percentage':'24.17'}]
# ----> 7 integrated_to_plot.update(new_row)
#
# AttributeError: 'NoneType' object has no attribute 'update'

# %%
integrated_to_plot.update(pd.DataFrame.from_dict(new_row))

# %%
print(111/(111+11))
# Out:
# 0.9098360655737705

# %%
integrated_to_plot.update(new_row)

# %%
integrated_to_plot
# Out:
#        Sample Post-filtering Percentage   Sum  percentage      Stage Pair#  \
# 0      SF3996        294/111      72.59   886   25.000000    Primary    33
# 1      SF6118        133/357      27.14   916   91.666667    Primary    31
# 2      SF7025          77/72      51.68  3060   96.875000    Primary    32
# 3      SF9358       494/2616      15.88   166   70.625000    Primary    36
# 4      SF4324       886/2779      24.17  3323   90.630000    Primary    11
# ..        ...            ...        ...   ...         ...        ...   ...
# 74    SF10441        466/640      42.13   466   40.000000  Recurrent     2
# 75   SF9715v2      2536/1195      67.97  2536         NaN        NaN   NaN
# 76    SF12704       1189/639      65.04  1189         NaN  Recurrent   NaN
# 77  SF12704v2      1253/2919      30.03  1253         NaN        NaN   NaN
# 78   SF6118v2        133/357      27.14   133         NaN        NaN   NaN
#
#      Age  Sex
# 0   52.0    M
# 1   71.0    M
# 2   49.0    F
# 3   64.0    F
# 4   29.0    F
# ..   ...  ...
# 74  56.0    M
# 75   NaN  NaN
# 76  51.0    F
# 77   NaN  NaN
# 78   NaN  NaN
#
# [79 rows x 9 columns]

# %%
integrated_to_plot[integrated_to_plot['Sample']=='SF10857']
# Out:
#     Sample Post-filtering Percentage  Sum  percentage    Stage  Pair#   Age  \
# 0  SF10857       2094/142      93.65  886        25.0  Primary    NaN  61.0
#
#   Sex
# 0   F

# %%
pairs=pairs.drop(columns=['Stage_x','Pair#_x','Age_x','Sex_x','Stage_y','Pair#_y','Age_y','Sex_y'])

# %%
pairs
# Out:
#      Sample Post-filtering Percentage     Sum percentage
# 0    SF1199         111/11      90.98  1449.0       50.0
# 1   SF10099        437/116      79.02   437.0      56.25
# 2   SF10441        466/640      42.13   466.0       40.0
# 3   SF10565       245/2627       8.53   245.0       8.75
# 4   SF10432         434/19      95.81   434.0       87.5
# ..      ...            ...        ...     ...        ...
# 60  SF11720        630/906      41.02   630.0       20.0
# 61   SF1199         111/11      90.98     NaN        NaN
# 62   SF2501         231/92      71.52     NaN        NaN
# 63   SF6809         127/55      67.00     NaN        NaN
# 64   SF4324       886/2779      24.17     NaN        NaN
#
# [65 rows x 5 columns]

# %%
to_join = pd.read_excel('/Users/lidiayung/project/resource/descriptive.xlsx')
df_select = to_join.iloc[:, [0, 1, 2, 4, 5]]
df_select.rename(columns={'ID':'Sample'},inplace= True)
# Out:
# /var/folders/qq/n8l4bgxs53j_s3twq5jzc7g00000gn/T/ipykernel_36945/3156440438.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_select.rename(columns={'ID':'Sample'},inplace= True)

# %%
pairs = pairs.merge(df_select, on='Sample',how='left')
pairs
# Out:
#      Sample Post-filtering Percentage     Sum percentage      Stage Pair#  \
# 0    SF1199         111/11      90.98  1449.0       50.0    Primary     8
# 1   SF10099        437/116      79.02   437.0      56.25    Primary     2
# 2   SF10441        466/640      42.13   466.0       40.0  Recurrent     2
# 3   SF10565       245/2627       8.53   245.0       8.75  Recurrent     3
# 4   SF10432         434/19      95.81   434.0       87.5    Primary     4
# ..      ...            ...        ...     ...        ...        ...   ...
# 60  SF11720        630/906      41.02   630.0       20.0  Recurrent    37
# 61   SF1199         111/11      90.98     NaN        NaN    Primary     8
# 62   SF2501         231/92      71.52     NaN        NaN    Primary    10
# 63   SF6809         127/55      67.00     NaN        NaN    Primary    21
# 64   SF4324       886/2779      24.17     NaN        NaN  Recurrent    30
#
#      Age Sex
# 0   57.0   M
# 1   55.0   M
# 2   56.0   M
# 3   45.0   F
# 4   50.0   F
# ..   ...  ..
# 60  56.0   M
# 61  57.0   M
# 62  55.0   F
# 63  57.0   M
# 64  57.0   F
#
# [65 rows x 9 columns]

# %%
sns.displot(pairs, x='Sum',kde=True, bins=10)

# %%
plt.rcParams.update({'font.size':20, 'font.family':'sans-serif', 
                            'xtick.labelsize':15, 'ytick.labelsize':25, 'figure.figsize':(12, 6.75), 
                            'axes.labelsize':30})
sns.set_style("whitegrid")

sns.barplot(data=pairs, y='Sum', x='Pair#', hue='Stage',hue_order = ['Primary','Recurrent'])
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))

plt.xticks(rotation=75)

plt.show()

# %%
#Pair 7,12,31
#Pair 13 'SF3076''SF3243'
# 11 'SF2777','SF2979'
# 6 SF11082
#33

# %%
sns.displot(pairs, x='Sum', hue='Stage',hue_order = ['Primary','Recurrent'], kde=True, bins=10)

plt.grid(True)

# %%
sns.displot(pairs, x='Sum', hue='Stage', kde=True, bins=10)

plt.grid(True)

# %%
#Pair 7,12,31
#Pair 13 'SF3076''SF3243'
# 11 'SF2777','SF2979'
# 6 'SF11082','SF1488'

# %%
def readann(sample):
    input_folder = "/Users/lidiayung/project/specimens"
    input_path = os.path.join(input_folder, sample) 
    
    results_file = f"{input_path}/gbm.h5ad"
    
    print(input_path)
    f_anndata_path = f"{input_path}/anndata.h5ad"
    adata = sc.read_h5ad( f_anndata_path )
    
    sc.pp.normalize_total(adata, target_sum=1e4, exclude_highly_expressed=True)

    sc.pp.log1p(adata)
    
    sc.pp.filter_genes_dispersion(adata, n_top_genes=2000)
    sc.pl.filter_genes_dispersion(adata)
    
    pca = PCA(n_components=15)
    adata.obsm["X_pca"] = pca.fit_transform(adata.X)
    
    # Perform t-SNE with default parameters
    tsne = TSNE(random_state=42)
    adata.obsm["X_tsne"] = tsne.fit_transform(adata.obsm["X_pca"])

    # Save the anndata object
    adata.write_h5ad(results_file)

    return adata

# %% [markdown]
# The snRNA-seq data were processed with Seurat v.3 (ref. 47). Data were normalized via the LogNormalize method with scale.factor of 10,000 using the NormalizeData function.
#
# Highly variable genes were identified via Seurat using the mean.var.plot method with default parameters. Based on these genes,
#
#
# a PCA was performed and the first 15 PCs were retained for clustering and visualization via t-SNE.

# %%
readann('SF11082')
# Out:
# /Users/lidiayung/project/specimens/SF11082
#   (0, 14)	0.6931472
#   (0, 27)	0.6931472
#   (0, 28)	0.6931472
#   (0, 49)	0.6931472
#   (0, 52)	0.6931472
#   (0, 78)	0.6931472
#   (0, 86)	1.7917595
#   (0, 99)	0.6931472
#   (0, 115)	0.6931472
#   (0, 126)	0.6931472
#   (0, 175)	0.6931472
#   (0, 176)	0.6931472
#   (0, 180)	0.6931472
#   (0, 184)	0.6931472
#   (0, 190)	0.6931472
#   (0, 194)	2.0794415
#   (0, 222)	1.0986123
#   (0, 228)	0.6931472
#   (0, 262)	0.6931472
#   (0, 333)	0.6931472
#   (0, 359)	1.0986123
#   (0, 375)	0.6931472
#   (0, 405)	0.6931472
#   (0, 430)	0.6931472
#   (0, 441)	0.6931472
#   :	:
#   (4020, 32956)	0.6931472
#   (4020, 32961)	0.6931472
#   (4020, 32992)	0.6931472
#   (4020, 33012)	0.6931472
#   (4020, 33030)	1.0986123
#   (4020, 33043)	0.6931472
#   (4020, 33051)	1.0986123
#   (4020, 33093)	0.6931472
#   (4020, 33118)	0.6931472
#   (4020, 33190)	0.6931472
#   (4020, 33221)	0.6931472
#   (4020, 33250)	1.3862944
#   (4020, 33285)	1.3862944
#   (4020, 33313)	0.6931472
#   (4020, 33379)	0.6931472
#   (4020, 33398)	0.6931472
#   (4020, 33406)	0.6931472
#   (4020, 33410)	1.0986123
#   (4020, 33437)	0.6931472
#   (4020, 33443)	0.6931472
#   (4020, 33458)	1.0986123
#   (4020, 33476)	1.0986123
#   (4020, 33489)	1.0986123
#   (4020, 33601)	0.6931472
#   (4020, 33642)	1.0986123

# %%
sample='SF2979'
readann(sample)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [15], in <cell line: 2>()
#       1 sample='SF2979'
# ----> 2 readann(sample)
#
# NameError: name 'readann' is not defined
