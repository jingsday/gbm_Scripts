# %%
import pandas as pd

# %%
depmap=pd.read_csv('/Users/lidiayung/PhD_project/project_UCD_blca/blca_DATA/blca_DATA_depmap/OmicsExpressionProteinCodingGenesTPMLogp1.csv',index_col=0)

# %%
display(depmap)
# Out:
#             TSPAN6 (7105)  TNMD (64102)  DPM1 (8813)  SCYL3 (57147)  \
# ACH-001113       4.331992      0.000000     7.364660       2.792855
# ACH-001289       4.567424      0.584963     7.106641       2.543496
# ACH-001339       3.150560      0.000000     7.379118       2.333424
# ACH-001538       5.085340      0.000000     7.154211       2.545968
# ACH-000242       6.729417      0.000000     6.537917       2.456806
# ...                   ...           ...          ...            ...
# ACH-000285       0.056584      0.000000     6.604368       3.266037
# ACH-002669       3.111031      0.000000     7.031329       1.541019
# ACH-001858       4.390943      0.000000     7.013239       1.887525
# ACH-001997       5.057450      0.000000     7.815191       2.538538
# ACH-000052       4.249445      0.000000     6.175724       2.319040
#
#             C1orf112 (55732)  FGR (2268)  CFH (3075)  FUCA2 (2519)  \
# ACH-001113          4.471187    0.028569    1.226509      3.044394
# ...

# %%
viena=pd.read_excel('/Users/lidiayung/PhD_project/project_UCD_blca/blca_DATA/blca_DATA_viena/1-s2.0-S0302283822016785-mmc2.xlsx',sheet_name='Suppl. table 2',index_col='GENE')

# %%
display(viena)
# Out:
#                                                  Description    HT1376  \
# GENE
# ACTB                                    actin, cytoplasmic 1  10764.00
# B2M                           beta-2-microglobulin precursor  13398.80
# HLA-A      HLA class I histocompatibility antigen, A-1 al...   6532.75
# GNB2L1     guanine nucleotide-binding protein subunit bet...   2438.67
# TMSB10                                      thymosin beta-10   2391.47
# ...                                                      ...       ...
# ZSCAN1      zinc finger and SCAN domain-containing protein 1      0.00
# ZSCAN10    zinc finger and SCAN domain-containing protein 10      0.00
# ZSWIM2                    E3 ubiquitin-protein ligase ZSWIM2      0.00
# psiTPTE22                                                NaN      0.00
# tAKR                                                     NaN      0.00
#
#              SCaBER       T24    SV-HUC    94-10     97-1       J82      RT4  \
# GENE
# ...
