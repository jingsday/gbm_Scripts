# %%
import os
import anndata
import numpy as np
import pandas as pd
import scanpy as sc
import loompy as lp
import seaborn as sns 
import matplotlib.pyplot as plt
import scipy
import csv
import gzip
import anndata as ad
from pathlib import Path
import glob
import scvi
from sklearn.preprocessing import StandardScaler
from matplotlib.colors import ListedColormap
sc.settings.verbosity = 3 # verbosity: errors (0), warnings (1), info (2), hints (3)
sc.logging.print_versions()
# Out:
# -----
# anndata     0.10.8
# scanpy      1.10.3
# -----
# PIL                 11.0.0
# absl                NA
# asttokens           NA
# attr                24.2.0
# bottleneck          1.4.1
# cffi                1.17.1
# chex                0.1.87
# cloudpickle         3.1.1
# comm                0.2.1
# contextlib2         NA
# cycler              0.12.1
# cython_runtime      NA
# cytoolz             1.0.1
# dask                2024.2.1
# dateutil            2.9.0.post0
# debugpy             1.6.7
# decorator           5.1.1
# dill                0.4.0
# distutils           3.12.7
# docrep              0.3.2
# etils               1.9.4
# executing           0.8.3
# filelock            3.16.1
# flax                0.9.0
# fsspec              2024.10.0
# gmpy2               2.1.5
# h5py                3.11.0
# igraph              0.11.6
# ipykernel           6.28.0
# ipywidgets          8.1.3
# jaraco              NA
# jax                 0.4.34
# jaxlib              0.4.34
# jedi                0.18.1
# jinja2              3.1.4
# joblib              1.4.2
# kiwisolver          1.4.8
# legacy_api_wrap     NA
# leidenalg           0.10.2
# lightning           2.4.0
# lightning_utilities 0.11.7
# llvmlite            0.43.0
# loompy              3.0.6
# lz4                 4.4.4
# markupsafe          3.0.1
# matplotlib          3.10.1
# ml_collections      NA
# ml_dtypes           0.5.0
# more_itertools      10.5.0
# mpl_toolkits        NA
# mpmath              1.3.0
# msgpack             1.1.0
# mudata              0.3.1
# multipledispatch    0.6.0
# natsort             8.4.0
# numba               0.60.0
# numexpr             2.10.1
# numpy               1.26.4
# numpy_groupies      0.11.1
# numpyro             0.15.3
# opt_einsum          3.4.0
# optax               0.2.3
# packaging           24.1
# pandas              2.2.3
# parso               0.8.3
# patsy               0.5.6
# pkg_resources       NA
# platformdirs        4.2.2
# plotly              5.24.1
# prompt_toolkit      3.0.43
# psutil              6.0.0
# pure_eval           0.2.2
# pyarrow             20.0.0
# pycparser           2.22
# pydev_ipython       NA
# pydevconsole        NA
# pydevd              2.9.5
# pydevd_file_utils   NA
# pydevd_plugins      NA
# pydevd_tracing      NA
# pygments            2.18.0
# pyparsing           3.2.1
# pyro                1.9.1
# pytz                2024.1
# rich                NA
# scipy               1.14.1
# scvi                1.2.0
# seaborn             0.13.2
# session_info        1.0.0
# setuptools          75.6.0
# six                 1.16.0
# sklearn             1.5.2
# sparse              0.15.4
# stack_data          0.2.0
# statsmodels         0.14.4
# sympy               1.11.1
# tblib               3.1.0
# texttable           1.7.0
# threadpoolctl       3.5.0
# tlz                 1.0.1
# toolz               1.0.0
# torch               2.4.1+cu121
# torchgen            NA
# torchmetrics        1.4.3
# tornado             6.4.1
# tqdm                4.66.5
# traitlets           5.14.3
# triton              3.0.0
# typing_extensions   NA
# vscode              NA
# wcwidth             0.2.13
# xarray              2024.9.0
# yaml                6.0.2
# zipp                NA
# zmq                 25.1.2
# zstandard           0.23.0
# -----
# IPython             8.25.0
# jupyter_client      8.6.0
# jupyter_core        5.7.2
# -----
# Python 3.12.7 | packaged by conda-forge | (main, Oct  4 2024, 16:05:46) [GCC 13.3.0]
# Linux-6.5.0-1025-oem-x86_64-with-glibc2.35
# -----
# Session information updated at 2025-05-20 18:46
# /home/jing/miniforge3/envs/cstar/lib/python3.12/site-packages/session_info/main.py:213: UserWarning: The '__version__' attribute is deprecated and will be removed in MarkupSafe 3.1. Use feature detection, or `importlib.metadata.version("markupsafe")`, instead.
#   mod_version = _find_version(mod.__version__)

# %%
outdir='/home/jing/Phd_project/project_GBM/gbm_OUTPUT/gbm_OUTPUT_publication'

# %%
adata= ad.read_h5ad(os.path.join(outdir,'gbm_OUTPUT_scvi.h5ad'))

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 56716 × 2000
#     obs: 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'source', '_scvi_batch', '_scvi_labels', 'leiden', 'Cellid'
#     var: 'Gene', 'mt', 'n_cells_by_counts-SF11082', 'mean_counts-SF11082', 'pct_dropout_by_counts-SF11082', 'total_counts-SF11082', 'n_cells_by_counts-SF11488', 'mean_counts-SF11488', 'pct_dropout_by_counts-SF11488', 'total_counts-SF11488', 'n_cells_by_counts-SF11916', 'mean_counts-SF11916', 'pct_dropout_by_counts-SF11916', 'total_counts-SF11916', 'n_cells_by_counts-SF12382', 'mean_counts-SF12382', 'pct_dropout_by_counts-SF12382', 'total_counts-SF12382', 'n_cells_by_counts-SF2777', 'mean_counts-SF2777', 'pct_dropout_by_counts-SF2777', 'total_counts-SF2777', 'n_cells_by_counts-SF2979', 'mean_counts-SF2979', 'pct_dropout_by_counts-SF2979', 'total_counts-SF2979', 'n_cells_by_counts-SF2990', 'mean_counts-SF2990', 'pct_dropout_by_counts-SF2990', 'total_counts-SF2990', 'n_cells_by_counts-SF3073', 'mean_counts-SF3073', 'pct_dropout_by_counts-SF3073', 'total_counts-SF3073', 'n_cells_by_counts-SF3076', 'mean_counts-SF3076', 'pct_dropout_by_counts-SF3076', 'total_counts-SF3076', 'n_cells_by_counts-SF3243', 'mean_counts-SF3243', 'pct_dropout_by_counts-SF3243', 'total_counts-SF3243', 'n_cells_by_counts-SF3391', 'mean_counts-SF3391', 'pct_dropout_by_counts-SF3391', 'total_counts-SF3391', 'n_cells_by_counts-SF3448', 'mean_counts-SF3448', 'pct_dropout_by_counts-SF3448', 'total_counts-SF3448', 'n_cells_by_counts-SF9358', 'mean_counts-SF9358', 'pct_dropout_by_counts-SF9358', 'total_counts-SF9358', 'n_cells_by_counts-SF9494', 'mean_counts-SF9494', 'pct_dropout_by_counts-SF9494', 'total_counts-SF9494', 'n_cells_by_counts-SF9798', 'mean_counts-SF9798', 'pct_dropout_by_counts-SF9798', 'total_counts-SF9798', 'n_cells_by_counts-SF9962', 'mean_counts-SF9962', 'pct_dropout_by_counts-SF9962', 'total_counts-SF9962', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm', 'highly_variable_nbatches'
#     uns: '_scvi_manager_uuid', '_scvi_uuid', 'hvg', 'leiden', 'neighbors'
#     obsm: 'X_scVI'
#     layers: 'counts'
#     obsp: 'connectivities', 'distances'

# %%
adata.obs
# Out:
#                            n_genes  n_genes_by_counts  total_counts  \
# CellID
# AAACCCAAGGGATCAC-1-SF2777      468                468         579.0
# AAACCCAGTCGATTTG-1-SF2777      311                311         402.0
# AAACCCAGTCGTCAGC-1-SF2777      864                864        1518.0
# AAACCCAGTTGTAAAG-1-SF2777      632                632         891.0
# AAACCCATCTATCGGA-1-SF2777      849                849        1338.0
# ...                            ...                ...           ...
# TTTGGTTTCATTATCC-1-SF9494     2027               2027        4502.0
# TTTGGTTTCCCTCGTA-1-SF9494     1972               1972        4071.0
# TTTGTTGTCAGACAAA-1-SF9494     2340               2340        5272.0
# TTTGTTGTCCATTGGA-1-SF9494     2137               2137        4709.0
# TTTGTTGTCCGACATA-1-SF9494     2032               2032        4223.0
#
#                            total_counts_mt  pct_counts_mt  source  \
# CellID
# AAACCCAAGGGATCAC-1-SF2777              9.0       1.554404  SF2777
# AAACCCAGTCGATTTG-1-SF2777              4.0       0.995025  SF2777
# AAACCCAGTCGTCAGC-1-SF2777              3.0       0.197628  SF2777
# AAACCCAGTTGTAAAG-1-SF2777             12.0       1.346801  SF2777
# AAACCCATCTATCGGA-1-SF2777             43.0       3.213752  SF2777
# ...                                    ...            ...     ...
# TTTGGTTTCATTATCC-1-SF9494              0.0       0.000000  SF9494
# TTTGGTTTCCCTCGTA-1-SF9494              0.0       0.000000  SF9494
# TTTGTTGTCAGACAAA-1-SF9494              0.0       0.000000  SF9494
# TTTGTTGTCCATTGGA-1-SF9494              6.0       0.127416  SF9494
# TTTGTTGTCCGACATA-1-SF9494              0.0       0.000000  SF9494
#
#                            _scvi_batch  _scvi_labels leiden  \
# CellID
# AAACCCAAGGGATCAC-1-SF2777            0             0      0
# AAACCCAGTCGATTTG-1-SF2777            0             0      6
# AAACCCAGTCGTCAGC-1-SF2777            0             0      6
# AAACCCAGTTGTAAAG-1-SF2777            0             0      0
# AAACCCATCTATCGGA-1-SF2777            0             0      0
# ...                                ...           ...    ...
# TTTGGTTTCATTATCC-1-SF9494           15             0      2
# TTTGGTTTCCCTCGTA-1-SF9494           15             0      2
# TTTGTTGTCAGACAAA-1-SF9494           15             0     13
# TTTGTTGTCCATTGGA-1-SF9494           15             0      4
# TTTGTTGTCCGACATA-1-SF9494           15             0      1
#
#                                        Cellid
# CellID
# AAACCCAAGGGATCAC-1-SF2777  AAACCCAAGGGATCAC-1
# AAACCCAGTCGATTTG-1-SF2777  AAACCCAGTCGATTTG-1
# AAACCCAGTCGTCAGC-1-SF2777  AAACCCAGTCGTCAGC-1
# AAACCCAGTTGTAAAG-1-SF2777  AAACCCAGTTGTAAAG-1
# AAACCCATCTATCGGA-1-SF2777  AAACCCATCTATCGGA-1
# ...                                       ...
# TTTGGTTTCATTATCC-1-SF9494  TTTGGTTTCATTATCC-1
# TTTGGTTTCCCTCGTA-1-SF9494  TTTGGTTTCCCTCGTA-1
# TTTGTTGTCAGACAAA-1-SF9494  TTTGTTGTCAGACAAA-1
# TTTGTTGTCCATTGGA-1-SF9494  TTTGTTGTCCATTGGA-1
# TTTGTTGTCCGACATA-1-SF9494  TTTGTTGTCCGACATA-1
#
# [56716 rows x 10 columns]

# %% [markdown]
# ### Anno

# %%
adata.obs['Status'] = 'Recurrent'
for i in ['SF2770', 'SF2990', 'SF3076', 'SF3391', 'SF11916', 'SF11082', 'SF9358', 'SF9798']:
    adata.obs.loc[adata.obs['source'].str.contains(i, na=False), 'Status'] = 'Primary'

# %%
metadata= pd.read_csv('/home/jing/Phd_project/project_GBM/gbm_DATA/gbm_DATA_metadata/GSE174554_Tumor_normal_metadata_11916v2.txt',
                      sep=' ')
metadata['Barcode'] = metadata['Barcode']+ '-1'
metadata
# Out:
#           Sample             Barcode Tumor_Normal_annotation
# 0        SF10022  CTATCTAAGCAAGCCA-1                   Tumor
# 1        SF10022  AAACCCAGTCTACGAT-1                  Normal
# 2        SF10022  AAAGGGCTCACCCTGT-1                  Normal
# 3        SF10022  AACAACCAGACCCGCT-1                  Normal
# 4        SF10022  AACAAGAGTGTAAACA-1                  Normal
# ...          ...                 ...                     ...
# 254283  SF9791v2  TTTCAGTCATCTTCGC-1                   Tumor
# 254284  SF9791v2  TTTCGATAGTCATAGA-1                   Tumor
# 254285  SF9791v2  TTTGGAGCACTGTCGG-1                   Tumor
# 254286  SF9791v2  TTTGGAGTCACGTCCT-1                   Tumor
# 254287  SF9791v2  CTATCCGTCAACTGGT-1                  Normal
#
# [254288 rows x 3 columns]

# %%
metadata['Barcode'] = metadata['Barcode']+ '-' +metadata['Sample']

# %%
adata.obs = adata.obs.merge(
    metadata[["Sample", "Barcode", "Tumor_Normal_annotation"]],
    how="left",
    left_on=["source", adata.obs.index],
    right_on=["Sample", "Barcode"]
)

# %%
adata.obs.index = adata.obs['Barcode']

# %%
adata.obs
# Out:
#                            n_genes  n_genes_by_counts  total_counts  \
# Barcode
# AAACCCAAGGGATCAC-1-SF2777      468                468         579.0
# AAACCCAGTCGATTTG-1-SF2777      311                311         402.0
# AAACCCAGTCGTCAGC-1-SF2777      864                864        1518.0
# AAACCCAGTTGTAAAG-1-SF2777      632                632         891.0
# AAACCCATCTATCGGA-1-SF2777      849                849        1338.0
# ...                            ...                ...           ...
# TTTGGTTTCATTATCC-1-SF9494     2027               2027        4502.0
# TTTGGTTTCCCTCGTA-1-SF9494     1972               1972        4071.0
# TTTGTTGTCAGACAAA-1-SF9494     2340               2340        5272.0
# TTTGTTGTCCATTGGA-1-SF9494     2137               2137        4709.0
# TTTGTTGTCCGACATA-1-SF9494     2032               2032        4223.0
#
#                            total_counts_mt  pct_counts_mt  source  \
# Barcode
# AAACCCAAGGGATCAC-1-SF2777              9.0       1.554404  SF2777
# AAACCCAGTCGATTTG-1-SF2777              4.0       0.995025  SF2777
# AAACCCAGTCGTCAGC-1-SF2777              3.0       0.197628  SF2777
# AAACCCAGTTGTAAAG-1-SF2777             12.0       1.346801  SF2777
# AAACCCATCTATCGGA-1-SF2777             43.0       3.213752  SF2777
# ...                                    ...            ...     ...
# TTTGGTTTCATTATCC-1-SF9494              0.0       0.000000  SF9494
# TTTGGTTTCCCTCGTA-1-SF9494              0.0       0.000000  SF9494
# TTTGTTGTCAGACAAA-1-SF9494              0.0       0.000000  SF9494
# TTTGTTGTCCATTGGA-1-SF9494              6.0       0.127416  SF9494
# TTTGTTGTCCGACATA-1-SF9494              0.0       0.000000  SF9494
#
#                            _scvi_batch  _scvi_labels leiden  \
# Barcode
# AAACCCAAGGGATCAC-1-SF2777            0             0      0
# AAACCCAGTCGATTTG-1-SF2777            0             0      6
# AAACCCAGTCGTCAGC-1-SF2777            0             0      6
# AAACCCAGTTGTAAAG-1-SF2777            0             0      0
# AAACCCATCTATCGGA-1-SF2777            0             0      0
# ...                                ...           ...    ...
# TTTGGTTTCATTATCC-1-SF9494           15             0      2
# TTTGGTTTCCCTCGTA-1-SF9494           15             0      2
# TTTGTTGTCAGACAAA-1-SF9494           15             0     13
# TTTGTTGTCCATTGGA-1-SF9494           15             0      4
# TTTGTTGTCCGACATA-1-SF9494           15             0      1
#
#                                        Cellid     Status  Sample  \
# Barcode
# AAACCCAAGGGATCAC-1-SF2777  AAACCCAAGGGATCAC-1  Recurrent  SF2777
# AAACCCAGTCGATTTG-1-SF2777  AAACCCAGTCGATTTG-1  Recurrent  SF2777
# AAACCCAGTCGTCAGC-1-SF2777  AAACCCAGTCGTCAGC-1  Recurrent  SF2777
# AAACCCAGTTGTAAAG-1-SF2777  AAACCCAGTTGTAAAG-1  Recurrent  SF2777
# AAACCCATCTATCGGA-1-SF2777  AAACCCATCTATCGGA-1  Recurrent  SF2777
# ...                                       ...        ...     ...
# TTTGGTTTCATTATCC-1-SF9494  TTTGGTTTCATTATCC-1  Recurrent  SF9494
# TTTGGTTTCCCTCGTA-1-SF9494  TTTGGTTTCCCTCGTA-1  Recurrent  SF9494
# TTTGTTGTCAGACAAA-1-SF9494  TTTGTTGTCAGACAAA-1  Recurrent  SF9494
# TTTGTTGTCCATTGGA-1-SF9494  TTTGTTGTCCATTGGA-1  Recurrent  SF9494
# TTTGTTGTCCGACATA-1-SF9494  TTTGTTGTCCGACATA-1  Recurrent  SF9494
#
#                                              Barcode Tumor_Normal_annotation
# Barcode
# AAACCCAAGGGATCAC-1-SF2777  AAACCCAAGGGATCAC-1-SF2777                   Tumor
# AAACCCAGTCGATTTG-1-SF2777  AAACCCAGTCGATTTG-1-SF2777                   Tumor
# AAACCCAGTCGTCAGC-1-SF2777  AAACCCAGTCGTCAGC-1-SF2777                   Tumor
# AAACCCAGTTGTAAAG-1-SF2777  AAACCCAGTTGTAAAG-1-SF2777                   Tumor
# AAACCCATCTATCGGA-1-SF2777  AAACCCATCTATCGGA-1-SF2777                   Tumor
# ...                                              ...                     ...
# TTTGGTTTCATTATCC-1-SF9494  TTTGGTTTCATTATCC-1-SF9494                  Normal
# TTTGGTTTCCCTCGTA-1-SF9494  TTTGGTTTCCCTCGTA-1-SF9494                  Normal
# TTTGTTGTCAGACAAA-1-SF9494  TTTGTTGTCAGACAAA-1-SF9494                   Tumor
# TTTGTTGTCCATTGGA-1-SF9494  TTTGTTGTCCATTGGA-1-SF9494                  Normal
# TTTGTTGTCCGACATA-1-SF9494  TTTGTTGTCCGACATA-1-SF9494                   Tumor
#
# [56716 rows x 14 columns]

# %%
doublet_df = pd.read_csv(os.path.join(outdir,'doublet_predictions.csv'), index_col=0)
doublet_df
# Out:
#                           Solo_Prediction
# Index
# AAACCCAAGCGAACTG-1-SF9494         doublet
# AAACCCAAGGCATTTC-1-SF9494         singlet
# AAACCCAAGTACCGGA-1-SF9494         doublet
# AAACCCATCATTCGGA-1-SF9494         singlet
# AAACCCATCCTCTCGA-1-SF9494         singlet
# ...                                   ...
# TTTGTTGAGTACCATC-1-SF2777         singlet
# TTTGTTGCACTGGCCA-1-SF2777         doublet
# TTTGTTGGTACTCAAC-1-SF2777         doublet
# TTTGTTGTCCCAAGTA-1-SF2777         doublet
# TTTGTTGTCGGATTAC-1-SF2777         singlet
#
# [56716 rows x 1 columns]

# %%
adata.obs['Solo_Prediction'] ='singlet'
for i in adata.obs.index:
    adata.obs.loc[i,'Solo_Prediction'] = doublet_df.loc[i,'Solo_Prediction']

# %%
adata_sing = adata[adata.obs['Solo_Prediction'] == 'singlet']

# %%
adata_sing
# Out:
# View of AnnData object with n_obs × n_vars = 50738 × 2000
#     obs: 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'source', '_scvi_batch', '_scvi_labels', 'leiden', 'Cellid', 'Status', 'Sample', 'Barcode', 'Tumor_Normal_annotation', 'Solo_Prediction'
#     var: 'Gene', 'mt', 'n_cells_by_counts-SF11082', 'mean_counts-SF11082', 'pct_dropout_by_counts-SF11082', 'total_counts-SF11082', 'n_cells_by_counts-SF11488', 'mean_counts-SF11488', 'pct_dropout_by_counts-SF11488', 'total_counts-SF11488', 'n_cells_by_counts-SF11916', 'mean_counts-SF11916', 'pct_dropout_by_counts-SF11916', 'total_counts-SF11916', 'n_cells_by_counts-SF12382', 'mean_counts-SF12382', 'pct_dropout_by_counts-SF12382', 'total_counts-SF12382', 'n_cells_by_counts-SF2777', 'mean_counts-SF2777', 'pct_dropout_by_counts-SF2777', 'total_counts-SF2777', 'n_cells_by_counts-SF2979', 'mean_counts-SF2979', 'pct_dropout_by_counts-SF2979', 'total_counts-SF2979', 'n_cells_by_counts-SF2990', 'mean_counts-SF2990', 'pct_dropout_by_counts-SF2990', 'total_counts-SF2990', 'n_cells_by_counts-SF3073', 'mean_counts-SF3073', 'pct_dropout_by_counts-SF3073', 'total_counts-SF3073', 'n_cells_by_counts-SF3076', 'mean_counts-SF3076', 'pct_dropout_by_counts-SF3076', 'total_counts-SF3076', 'n_cells_by_counts-SF3243', 'mean_counts-SF3243', 'pct_dropout_by_counts-SF3243', 'total_counts-SF3243', 'n_cells_by_counts-SF3391', 'mean_counts-SF3391', 'pct_dropout_by_counts-SF3391', 'total_counts-SF3391', 'n_cells_by_counts-SF3448', 'mean_counts-SF3448', 'pct_dropout_by_counts-SF3448', 'total_counts-SF3448', 'n_cells_by_counts-SF9358', 'mean_counts-SF9358', 'pct_dropout_by_counts-SF9358', 'total_counts-SF9358', 'n_cells_by_counts-SF9494', 'mean_counts-SF9494', 'pct_dropout_by_counts-SF9494', 'total_counts-SF9494', 'n_cells_by_counts-SF9798', 'mean_counts-SF9798', 'pct_dropout_by_counts-SF9798', 'total_counts-SF9798', 'n_cells_by_counts-SF9962', 'mean_counts-SF9962', 'pct_dropout_by_counts-SF9962', 'total_counts-SF9962', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm', 'highly_variable_nbatches'
#     uns: '_scvi_manager_uuid', '_scvi_uuid', 'hvg', 'leiden', 'neighbors'
#     obsm: 'X_scVI'
#     layers: 'counts'
#     obsp: 'connectivities', 'distances'

# %%
adata_sing.raw = adata_sing

# %%
scvi.model.SCVI.setup_anndata(adata_sing, layer="counts", batch_key="source")

# %%
model = scvi.model.SCVI(adata_sing, n_layers=2, n_latent=30, gene_likelihood="nb")

# %%
model.train()
# Out:
# /home/jing/miniforge3/envs/cstar/lib/python3.12/site-packages/lightning/fabric/plugins/environments/slurm.py:204: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python /home/jing/miniforge3/envs/cstar/lib/python3.12/site ...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# /home/jing/miniforge3/envs/cstar/lib/python3.12/site-packages/lightning/fabric/plugins/environments/slurm.py:204: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python /home/jing/miniforge3/envs/cstar/lib/python3.12/site ...
# /home/jing/miniforge3/envs/cstar/lib/python3.12/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:424: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=31` in the `DataLoader` to improve performance.
# Training:   0%|          | 0/158 [00:00<?, ?it/s]
