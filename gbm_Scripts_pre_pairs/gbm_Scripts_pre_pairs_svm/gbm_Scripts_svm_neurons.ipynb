# %%
import pandas as pd
import scanpy as sc
import anndata as ad
import cstarpy
import os
import numpy as np
from cstarpy.separation import CellStateTransition

# %%
outdir='/home/jing/Phd_project/project_GBM/gbm_OUTPUT/gbm_OUTPUT_publication'

# %%
directory = '/home/jing/Phd_project/project_GBM/gbm_DATA/gbm_DATA_GSE174554/gbm_DATA_scRNA_atlas'
os.chdir(directory)

# %%
names_list=['GSM5319518_SF2777','GSM5319548_SF2979','GSM5319519_SF2990',
                'GSM5319549_SF3073','GSM5319520_SF3076','GSM5319550_SF3243',
                'GSM5319521_SF3391','GSM5319551_SF3448','GSM5319511_SF11916',
                'GSM5319543_SF12382','GSM5319506_SF11082','GSM5319562_SF11488',
                'GSM5319530_SF9358','GSM5319568_SF9962','GSM5319559_SF9798','GSM5319532_SF9494']

# %%
adata_list = []

# Loop over each sample and read in the AnnData object
for name in names_list:

    mtx =f"{name}_matrix.mtx.gz"
    adata = sc.read_mtx(mtx)
    cells=pd.read_csv(f'{name}_barcodes.tsv.gz',header=None)
    features=pd.read_csv(f'{name}_features.tsv.gz',header=None,sep='\t')
    adata= adata.T
    #check the columns first to make sure they are the ones you need 
    adata.obs['CellID']= cells[0].tolist()
    adata.obs.index = adata.obs['CellID']
    adata.var['Gene']= features[0].tolist()
    adata.var.index= adata.var['Gene']
    adata.var_names_make_unique() 
    adata.var['mt'] =adata.var_names.str.startswith('MT-')


    sc.pp.filter_cells(adata, min_genes=200)
    sc.pp.calculate_qc_metrics(adata,qc_vars=['mt'], percent_top=None, log1p=False, inplace=True)
    adata= adata[adata.obs.n_genes_by_counts <6000, :]
    adata= adata[adata.obs.pct_counts_mt< 5, :].copy()


    adata.obs['source'] = name[11:]
    adata.layers["counts"] = adata.X.copy()    
    adata.raw = adata  # keep full dimension safe
    adata_list.append(adata)

# %%
batch_names = [adata.obs['source'].iloc[0] for adata in adata_list]
adata = adata_list[0].concatenate(adata_list[1:], batch_key='source', batch_categories=batch_names)
# Out:
# /tmp/ipykernel_348471/1379501109.py:2: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adata = adata_list[0].concatenate(adata_list[1:], batch_key='source', batch_categories=batch_names)

# %%
adata.obs
# Out:
#                                        CellID  n_genes  n_genes_by_counts  \
# CellID
# AAACCCAAGGGATCAC-1-SF2777  AAACCCAAGGGATCAC-1      468                468
# AAACCCAGTCGATTTG-1-SF2777  AAACCCAGTCGATTTG-1      311                311
# AAACCCAGTCGTCAGC-1-SF2777  AAACCCAGTCGTCAGC-1      864                864
# AAACCCAGTTGTAAAG-1-SF2777  AAACCCAGTTGTAAAG-1      632                632
# AAACCCATCTATCGGA-1-SF2777  AAACCCATCTATCGGA-1      849                849
# ...                                       ...      ...                ...
# TTTGGTTTCATTATCC-1-SF9494  TTTGGTTTCATTATCC-1     2027               2027
# TTTGGTTTCCCTCGTA-1-SF9494  TTTGGTTTCCCTCGTA-1     1972               1972
# TTTGTTGTCAGACAAA-1-SF9494  TTTGTTGTCAGACAAA-1     2340               2340
# AACCAACCATCGATCA-1-SF2990         0.0         0.0         0.0         0.0
# AAGAACAAGCCTGACC-1-SF2990         0.0         0.0         0.0         0.0
# AAGATAGGTTGTTTGG-1-SF2990         0.0         0.0         0.0         0.0
# AAGTCGTCACAACCGC-1-SF2990         0.0         0.0         0.0         0.0
# ...                               ...         ...         ...         ...
# GGAGAACCATAGGCGA-1-SF9798         0.0         0.0         0.0         0.0
# GGGAGATCAGTGTGCC-1-SF9798         0.0         0.0         1.0         0.0
# TACCCGTAGCATCCTA-1-SF9798         0.0         0.0         0.0         0.0
# TCTGCCATCAAACCTG-1-SF9798         0.0         0.0         0.0         0.0
# TGCATCCCATCCTATT-1-SF9798         0.0         0.0         0.0         0.0
#
# Gene                       AC004556.1  AC233755.2  AC233755.1  AC240274.1  \
# CellID
# AAAGTCCAGACGAGCT-1-SF2990         0.0         0.0         0.0         0.0
# AACCAACCATCGATCA-1-SF2990         0.0         0.0         0.0         0.0
# AAGAACAAGCCTGACC-1-SF2990         0.0         0.0         0.0         0.0
# AAGATAGGTTGTTTGG-1-SF2990         0.0         0.0         0.0         0.0
# AAGTCGTCACAACCGC-1-SF2990         0.0         0.0         0.0         1.0
# ...                               ...         ...         ...         ...
# GGAGAACCATAGGCGA-1-SF9798         0.0         0.0         0.0         0.0
# GGGAGATCAGTGTGCC-1-SF9798         0.0         0.0         0.0         0.0
# TACCCGTAGCATCCTA-1-SF9798         0.0         0.0         0.0         0.0
# TCTGCCATCAAACCTG-1-SF9798         0.0         0.0         0.0         0.0
# TGCATCCCATCCTATT-1-SF9798         0.0         0.0         0.0         0.0
#
# Gene                       AC213203.1  FAM231B
# CellID
# AAAGTCCAGACGAGCT-1-SF2990         0.0      0.0
# AACCAACCATCGATCA-1-SF2990         0.0      0.0
# AAGAACAAGCCTGACC-1-SF2990         0.0      0.0
# AAGATAGGTTGTTTGG-1-SF2990         0.0      0.0
# AAGTCGTCACAACCGC-1-SF2990         0.0      0.0
# ...                               ...      ...
# GGAGAACCATAGGCGA-1-SF9798         0.0      0.0
# GGGAGATCAGTGTGCC-1-SF9798         0.0      0.0
# TACCCGTAGCATCCTA-1-SF9798         0.0      0.0
# TCTGCCATCAAACCTG-1-SF9798         0.0      0.0
# TGCATCCCATCCTATT-1-SF9798         0.0      0.0
#
# [292 rows x 33694 columns]

# %%
rct_neu=adata[neurons_adata.obs[
    (neurons_adata.obs['custom_annotation'] == 'Neurons') & 
    (neurons_adata.obs['Status'] == 'Recurrent')
].index].copy()

# %%
rct_neu_df = pd.DataFrame(
    rct_neu.layers['counts'].toarray(),  # Convert sparse matrix to dense array
    index=rct_neu.obs.index, 
    columns=rct_neu.var.index
)

# %%
rct_neu_df
# Out:
# Gene                       RP11-34P13.3  FAM138A  OR4F5  RP11-34P13.7  \
# CellID
# AAACGCTCATCCTCAC-1-SF2777           0.0      0.0    0.0           0.0
# AAAGGTAGTTTGTGGT-1-SF2777           0.0      0.0    0.0           0.0
# AAAGTCCCAACTGCCG-1-SF2777           0.0      0.0    0.0           0.0
# TCTTTGAGTACAGTCT-1-SF9494         0.0         0.0         0.0         0.0
# TGCTTGCAGGTCCTGC-1-SF9494         0.0         0.0         0.0         0.0
#
# Gene                       AC004556.1  AC233755.2  AC233755.1  AC240274.1  \
# CellID
# AAACGCTCATCCTCAC-1-SF2777         0.0         0.0         0.0         0.0
# AAAGGTAGTTTGTGGT-1-SF2777         0.0         0.0         0.0         0.0
# AAAGTCCCAACTGCCG-1-SF2777         0.0         0.0         0.0         0.0
# AAATGGAGTAGGAGGG-1-SF2777         0.0         0.0         0.0         0.0
# AACACACCAAGTTCCA-1-SF2777         0.0         0.0         0.0         0.0
# ...                               ...         ...         ...         ...
# GTCAAACCATGCCGAC-1-SF9494         0.0         0.0         0.0         2.0
# TATATCCAGGCGTTAG-1-SF9494         0.0         0.0         0.0         0.0
# TCAAGACGTGCAGGAT-1-SF9494         0.0         0.0         0.0         0.0
# TCTTTGAGTACAGTCT-1-SF9494         0.0         0.0         0.0         0.0
# TGCTTGCAGGTCCTGC-1-SF9494         0.0         0.0         0.0         0.0
#
# Gene                       AC213203.1  FAM231B
# CellID
# AAACGCTCATCCTCAC-1-SF2777         0.0      0.0
# AAAGGTAGTTTGTGGT-1-SF2777         0.0      0.0
# AAAGTCCCAACTGCCG-1-SF2777         0.0      0.0
# AAATGGAGTAGGAGGG-1-SF2777         0.0      0.0
# AACACACCAAGTTCCA-1-SF2777         0.0      0.0
# ...                               ...      ...
# GTCAAACCATGCCGAC-1-SF9494         0.0      0.0
# TATATCCAGGCGTTAG-1-SF9494         0.0      0.0
# TCAAGACGTGCAGGAT-1-SF9494         0.0      0.0
# TCTTTGAGTACAGTCT-1-SF9494         0.0      0.0
# TGCTTGCAGGTCCTGC-1-SF9494         0.0      0.0
#
# [2254 rows x 33694 columns]

# %% [markdown]
# ### SVM

# %%
cst = CellStateTransition('pneu_rneu', pmr_neu_df, rct_neu_df)

# %%
dpd_scores = cst.get_dpd()

norm_s_df = pd.DataFrame(np.stack([cst.n, cst.s], axis=1), index=cst.svm_input.data.columns, columns=["n", "s"])

print(cst.h)
# Out:
# -0.14865541547242148

# %% [markdown]
# dpd_scores.to_pickle(os.path.join(outdir, 'dpd_p_r_high_neu.pkl'))
#
# norm_s_df.to_pickle(os.path.join(outdir, 'stv_p_r_high_neu.pkl'))

# %% [markdown]
# ### LINCs genes

# %%
lm_df=pd.read_csv('/home/jing/Phd_project/project_UCD_blca/blca_Scripts/perturbations/01_outputs_2020/L1000_Data_norm_data.csv',index_col=0)
display(lm_df)
# Out:
#         ASG002_BC3C_24H:A10  ASG002_BC3C_24H:A11  ASG002_BC3C_24H:A19  \
# AARS              -0.496854             0.288446             0.189747
# ABCB6             -0.658596            -0.142196            -0.075397
# ABCC5             -0.080204             0.231996            -0.329354
# ABCF1              0.202535             0.602335             0.403335
# ABCF3             -0.520919            -0.192819             0.001032
# ...                     ...                  ...                  ...
# ZNF395             1.796254             1.773154             0.668354
# ZNF451            -0.244519             0.116732             0.058081
# ZNF451              0.080550             -0.114950             -0.337650
# ZNF586             -0.259400              0.163600             -0.428700
# ZNF589             -0.013900             -0.035050              1.836400
# ZW10                0.443400             -0.145650              0.433800
#
#         MOAR011_BC3C_24H:C11  MOAR011_BC3C_24H:J10
# AARS                0.007400              0.031399
# ABCB6               0.122550             -0.029350
# ABCC5               0.138650              0.568950
# ABCF1               0.580075              0.322875
# ABCF3              -0.128351             -0.012850
# ...                      ...                   ...
# ZNF395             -1.844650             -0.612350
# ZNF451             -0.024950             -0.151550
# ZNF586             -0.069200              0.073700
# ZNF589             -0.223300             -0.343400
# ZW10                0.048100              0.049950
#
# [978 rows x 98 columns]

# %%
lm_df.index
# Out:
# Index(['AARS', 'ABCB6', 'ABCC5', 'ABCF1', 'ABCF3', 'ABHD4', 'ABHD6', 'ABL1',
#        'ACAA1', 'ACAT2',
#        ...
#        'ZMIZ1', 'ZMYM2', 'ZNF131', 'ZNF274', 'ZNF318', 'ZNF395', 'ZNF451',
#        'ZNF586', 'ZNF589', 'ZW10'],
#       dtype='object', length=978)

# %%
pmr_neu_df.columns
# Out:
# Index(['RP11-34P13.3', 'FAM138A', 'OR4F5', 'RP11-34P13.7', 'RP11-34P13.8',
#        'RP11-34P13.14', 'RP11-34P13.9', 'FO538757.3', 'FO538757.2',
#        'AP006222.2',
#        ...
#        'AC007325.2', 'BX072566.1', 'AL354822.1', 'AC023491.2', 'AC004556.1',
#        'AC233755.2', 'AC233755.1', 'AC240274.1', 'AC213203.1', 'FAM231B'],
#       dtype='object', name='Gene', length=33694)

# %%
common_genes = pmr_neu_df.columns.intersection(lm_df.index)

# %%
rct_neu_lincs = rct_neu_df[common_genes]
rct_neu_lincs.shape
# Out:
# (2254, 958)

# %%
pmr_neu_lincs = pmr_neu_df[common_genes]
pmr_neu_lincs.shape
# Out:
# (292, 958)

# %%
cst_lincs = CellStateTransition('pneu_rneu', pmr_neu_lincs, rct_neu_lincs)

# %%
dpd_scores_lincs = cst_lincs.get_dpd()

norm_s_lincs = pd.DataFrame(np.stack([cst_lincs.n, cst_lincs.s], axis=1), index=cst_lincs.svm_input.data.columns, columns=["n", "s"])

print(cst_lincs.h)
# Out:
# -0.049729984267670196

# %% [markdown]
# dpd_scores_lincs.to_pickle(os.path.join(outdir, 'dpd_p_r_lincs_neu.pkl'))
#
# norm_s_lincs.to_pickle(os.path.join(outdir, 'stv_p_r_lincs_neu.pkl'))

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import KFold, cross_val_score

clf = DecisionTreeClassifier(random_state=42)
k_folds = KFold(n_splits = 5)

# %%
data_all_cells = cst_lincs.svm_input.data

# %%
df = pd.DataFrame(neurons_adata.obs.loc[data_all_cells.index, 'Status'])
df.columns = ['Status']  # Explicitly setting column name

# %%
data_all_cells.drop(columns='Status',inplace=True)

# %%
scores = cross_val_score(clf, data_all_cells, df['Status'], cv = k_folds)
print("Cross Validation Scores: ", np.round(scores,2))
print("Average CV Score: ", np.round(scores.mean(),2))
# Out:
# Cross Validation Scores:  [0.43 0.82 0.89 0.9  0.75]
# Average CV Score:  0.76
