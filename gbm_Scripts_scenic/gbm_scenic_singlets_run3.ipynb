# %%
import loompy as lp
import seaborn as sns 

import os, glob, re, pickle
from functools import partial
from collections import OrderedDict
import operator as op
from cytoolz import compose

import pandas as pd
import seaborn as sns
import numpy as np
import scanpy as sc
import anndata as ad
import matplotlib as mpl
import matplotlib.pyplot as plt

from pyscenic.export import export2loom, add_scenic_metadata
from pyscenic.utils import load_motifs
from pyscenic.transform import df2regulons
from pyscenic.aucell import aucell
from pyscenic.binarization import binarize
from pyscenic.rss import regulon_specificity_scores
from pyscenic.plotting import plot_binarization, plot_rss

from IPython.display import HTML, display

# %%
#Resource
AUXILLIARIES_FOLDERNAME = "/home/jing/pySCENIC/resources/"
HUMAN_TFS_FNAME = os.path.join(AUXILLIARIES_FOLDERNAME, 'allTFs_mm.txt')

RANKING_DBS_FNAMES = list(map(lambda fn: os.path.join(AUXILLIARIES_FOLDERNAME, fn),
                       ['hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings.feather',
                       'hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings.feather']))

MOTIF_ANNOTATIONS_FNAME = os.path.join(AUXILLIARIES_FOLDERNAME, 'motifs-v10nr_clust-nr.hgnc-m0.001-o0.0.tbl')

# %%
#Outputs
DATASET_ID = 'GBM'
RESULTS_FOLDERNAME = "/home/jing/Phd_project/project_GBM/gbm_OUTPUT/gbm_OUTPUT_publication/gbm_OUT_publication_scenic_run3/"
os.chdir(RESULTS_FOLDERNAME)
F_LOOM_SCE =  os.path.join(RESULTS_FOLDERNAME, '{}_filtered_scenic.loom'.format(DATASET_ID))
f_pyscenic_output = os.path.join(RESULTS_FOLDERNAME, '{}_final_scenic.loom'.format(DATASET_ID))


ADJACENCIES_FNAME = os.path.join(RESULTS_FOLDERNAME, '{}.adjacencies.tsv'.format(DATASET_ID))
MOTIFS_FNAME = os.path.join(RESULTS_FOLDERNAME, '{}.motifs.csv'.format(DATASET_ID))

# %%
REGULONS_DAT_FNAME = os.path.join(RESULTS_FOLDERNAME, '{}.regulons.dat'.format(DATASET_ID))
AUCELL_MTX_FNAME = os.path.join(RESULTS_FOLDERNAME, '{}.auc.csv'.format(DATASET_ID))
BIN_MTX_FNAME = os.path.join(RESULTS_FOLDERNAME, '{}.bin.csv'.format(DATASET_ID))
THR_FNAME = os.path.join(RESULTS_FOLDERNAME, '{}.thresholds.csv'.format(DATASET_ID))

# %% [markdown]
# ### Adata

# %%
directory = '/home/jing/Phd_project/project_GBM/gbm_DATA/gbm_DATA_GSE174554/gbm_DATA_scRNA_atlas'
os.chdir(directory)
names_list=['GSM5319518_SF2777','GSM5319548_SF2979','GSM5319519_SF2990',
                'GSM5319549_SF3073','GSM5319520_SF3076','GSM5319550_SF3243',
                'GSM5319521_SF3391','GSM5319551_SF3448','GSM5319511_SF11916',
                'GSM5319543_SF12382','GSM5319506_SF11082','GSM5319562_SF11488',
                'GSM5319530_SF9358','GSM5319568_SF9962','GSM5319559_SF9798','GSM5319532_SF9494']
adata_list = []

# Loop over each sample and read in the AnnData object
for name in names_list:

    mtx =f"{name}_matrix.mtx.gz"
    adata = sc.read_mtx(mtx)
    cells=pd.read_csv(f'{name}_barcodes.tsv.gz',header=None)
    features=pd.read_csv(f'{name}_features.tsv.gz',header=None,sep='\t')
    adata= adata.T
    #check the columns first to make sure they are the ones you need 
    adata.obs['CellID']= cells[0].tolist()
    adata.obs.index = adata.obs['CellID']
    adata.var['Gene']= features[0].tolist()
    adata.var.index= adata.var['Gene']
    adata.var_names_make_unique() 
    adata.var['mt'] =adata.var_names.str.startswith('MT-')


    sc.pp.filter_cells(adata, min_genes=200)
    sc.pp.calculate_qc_metrics(adata,qc_vars=['mt'], percent_top=None, log1p=False, inplace=True)
    adata= adata[adata.obs.n_genes_by_counts <6000, :]
    adata= adata[adata.obs.pct_counts_mt< 5, :].copy()


    adata.obs['source'] = name[11:]
    adata.layers["counts"] = adata.X.copy()    
    #sc.pp.normalize_total(adata, target_sum=1e4)
    #sc.pp.log1p(adata)
    #adata.raw = adata  # keep full dimension safe
    adata_list.append(adata)
batch_names = [adata.obs['source'].iloc[0] for adata in adata_list]
adata = adata_list[0].concatenate(adata_list[1:], batch_key='source', batch_categories=batch_names) 
adata.obs.index.name = "ref"
display(adata.obs)
# Out:
# /tmp/ipykernel_1053072/4194437479.py:40: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adata = adata_list[0].concatenate(adata_list[1:], batch_key='source', batch_categories=batch_names)
#                                        CellID  n_genes  n_genes_by_counts  \
# ref
# AAACCCAAGGGATCAC-1-SF2777  AAACCCAAGGGATCAC-1      468                468
# AAACCCAGTCGATTTG-1-SF2777  AAACCCAGTCGATTTG-1      311                311
# AAACCCAGTCGTCAGC-1-SF2777  AAACCCAGTCGTCAGC-1      864                864
# AAACCCAGTTGTAAAG-1-SF2777  AAACCCAGTTGTAAAG-1      632                632
# AAACCCATCTATCGGA-1-SF2777  AAACCCATCTATCGGA-1      849                849
# ...                                       ...      ...                ...
# TTTGGTTTCATTATCC-1-SF9494  TTTGGTTTCATTATCC-1     2027               2027
# TTTGGTTTCCCTCGTA-1-SF9494  TTTGGTTTCCCTCGTA-1     1972               1972
# TTTGTTGTCAGACAAA-1-SF9494  TTTGTTGTCAGACAAA-1     2340               2340
# TTTGTTGTCCATTGGA-1-SF9494  TTTGTTGTCCATTGGA-1     2137               2137
# TTTGTTGTCCGACATA-1-SF9494  TTTGTTGTCCGACATA-1     2032               2032
#
#                            total_counts  total_counts_mt  pct_counts_mt  \
# ref
# AAACCCAAGGGATCAC-1-SF2777         579.0              9.0       1.554404
# AAACCCAGTCGATTTG-1-SF2777         402.0              4.0       0.995025
# AAACCCAGTCGTCAGC-1-SF2777        1518.0              3.0       0.197628
# AAACCCAGTTGTAAAG-1-SF2777         891.0             12.0       1.346801
# AAACCCATCTATCGGA-1-SF2777        1338.0             43.0       3.213752
# ...                                 ...              ...            ...
# TTTGGTTTCATTATCC-1-SF9494        4502.0              0.0       0.000000
# TTTGGTTTCCCTCGTA-1-SF9494        4071.0              0.0       0.000000
# TTTGTTGTCAGACAAA-1-SF9494        5272.0              0.0       0.000000
# TTTGTTGTCCATTGGA-1-SF9494        4709.0              6.0       0.127416
# TTTGTTGTCCGACATA-1-SF9494        4223.0              0.0       0.000000
#
#                            source
# ref
# AAACCCAAGGGATCAC-1-SF2777  SF2777
# AAACCCAGTCGATTTG-1-SF2777  SF2777
# AAACCCAGTCGTCAGC-1-SF2777  SF2777
# AAACCCAGTTGTAAAG-1-SF2777  SF2777
# AAACCCATCTATCGGA-1-SF2777  SF2777
# ...                           ...
# TTTGGTTTCATTATCC-1-SF9494  SF9494
# TTTGGTTTCCCTCGTA-1-SF9494  SF9494
# TTTGTTGTCAGACAAA-1-SF9494  SF9494
# TTTGTTGTCCATTGGA-1-SF9494  SF9494
# TTTGTTGTCCGACATA-1-SF9494  SF9494
#
# [56716 rows x 7 columns]

# %%
outdir='/home/jing/Phd_project/project_GBM/gbm_OUTPUT/gbm_OUTPUT_publication'
doublet_df = pd.read_csv(os.path.join(outdir,'doublet_predictions.csv'), index_col=0)
doublet_df

for i in adata.obs.index:
    adata.obs.loc[i,'solo'] = doublet_df.loc[i,'Solo_Prediction']
adata_singlet = adata[adata.obs['solo']=='singlet']
adata_singlet
# Out:
# View of AnnData object with n_obs × n_vars = 50738 × 33694
#     obs: 'CellID', 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'source', 'solo'
#     var: 'Gene', 'mt', 'n_cells_by_counts-SF11082', 'mean_counts-SF11082', 'pct_dropout_by_counts-SF11082', 'total_counts-SF11082', 'n_cells_by_counts-SF11488', 'mean_counts-SF11488', 'pct_dropout_by_counts-SF11488', 'total_counts-SF11488', 'n_cells_by_counts-SF11916', 'mean_counts-SF11916', 'pct_dropout_by_counts-SF11916', 'total_counts-SF11916', 'n_cells_by_counts-SF12382', 'mean_counts-SF12382', 'pct_dropout_by_counts-SF12382', 'total_counts-SF12382', 'n_cells_by_counts-SF2777', 'mean_counts-SF2777', 'pct_dropout_by_counts-SF2777', 'total_counts-SF2777', 'n_cells_by_counts-SF2979', 'mean_counts-SF2979', 'pct_dropout_by_counts-SF2979', 'total_counts-SF2979', 'n_cells_by_counts-SF2990', 'mean_counts-SF2990', 'pct_dropout_by_counts-SF2990', 'total_counts-SF2990', 'n_cells_by_counts-SF3073', 'mean_counts-SF3073', 'pct_dropout_by_counts-SF3073', 'total_counts-SF3073', 'n_cells_by_counts-SF3076', 'mean_counts-SF3076', 'pct_dropout_by_counts-SF3076', 'total_counts-SF3076', 'n_cells_by_counts-SF3243', 'mean_counts-SF3243', 'pct_dropout_by_counts-SF3243', 'total_counts-SF3243', 'n_cells_by_counts-SF3391', 'mean_counts-SF3391', 'pct_dropout_by_counts-SF3391', 'total_counts-SF3391', 'n_cells_by_counts-SF3448', 'mean_counts-SF3448', 'pct_dropout_by_counts-SF3448', 'total_counts-SF3448', 'n_cells_by_counts-SF9358', 'mean_counts-SF9358', 'pct_dropout_by_counts-SF9358', 'total_counts-SF9358', 'n_cells_by_counts-SF9494', 'mean_counts-SF9494', 'pct_dropout_by_counts-SF9494', 'total_counts-SF9494', 'n_cells_by_counts-SF9798', 'mean_counts-SF9798', 'pct_dropout_by_counts-SF9798', 'total_counts-SF9798', 'n_cells_by_counts-SF9962', 'mean_counts-SF9962', 'pct_dropout_by_counts-SF9962', 'total_counts-SF9962'
#     layers: 'counts'

# %%
# create basic row and column attributes for the loom file:
row_attrs = {
    "Gene": np.array(adata_singlet.var_names) ,
}
col_attrs = {
    "CellID": np.array(adata_singlet.obs_names) ,
    "nGene": np.array( np.sum(adata_singlet.X.transpose()>0 , axis=0)).flatten() ,
    "nUMI": np.array( np.sum(adata_singlet.X.transpose() , axis=0)).flatten() ,
}
lp.create( F_LOOM_SCE, adata_singlet.X.transpose(), row_attrs, col_attrs)

# %% [markdown]
# ### SECNIC inference

# %%
#I) GRN
# !pyscenic grn {F_LOOM_SCE} {HUMAN_TFS_FNAME} -o {ADJACENCIES_FNAME} --num_workers 20
# Out:
# 2025-05-21 11:52:05,911 - pyscenic.cli.pyscenic - INFO - Loading expression matrix.
#
# 2025-05-21 11:52:16,687 - pyscenic.cli.pyscenic - INFO - Inferring regulatory networks.
# preparing dask client
# parsing input
# creating dask graph
# 20 partitions
# computing dask graph
# /home/jing/miniforge3/envs/pyscenic/lib/python3.10/site-packages/distributed/client.py:3169: UserWarning: Sending large graph of size 5.64 GiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# not shutting down client, client was created externally
# finished
#
# 2025-05-21 14:51:32,923 - pyscenic.cli.pyscenic - INFO - Writing results to file.

# %%
DBS_PARAM = ' '.join(RANKING_DBS_FNAMES)

# %%
#II) CTX
# !pyscenic ctx {ADJACENCIES_FNAME} \
    {DBS_PARAM} \
    --annotations_fname {MOTIF_ANNOTATIONS_FNAME} \
    --expression_mtx_fname {F_LOOM_SCE} \
    --output reg.csv \
    --mask_dropouts \
    --num_workers 20
# Out:
# 2025-05-21 16:42:35,211 - pyscenic.cli.pyscenic - INFO - Creating modules.
#
# 2025-05-21 16:42:35,867 - pyscenic.cli.pyscenic - INFO - Loading expression matrix.
#
# 2025-05-21 16:43:02,871 - pyscenic.utils - INFO - Calculating Pearson correlations.
#
# 2025-05-21 16:43:03,076 - pyscenic.utils - WARNING - Note on correlation calculation: the default behaviour for calculating the correlations has changed after pySCENIC verion 0.9.16. Previously, the default was to calculate the correlation between a TF and target gene using only cells with non-zero expression values (mask_dropouts=True). The current default is now to use all cells to match the behavior of the R verision of SCENIC. The original settings can be retained by setting 'rho_mask_dropouts=True' in the modules_from_adjacencies function, or '--mask_dropouts' from the CLI.
# 	Dropout masking is currently set to [True].
#
# 2025-05-21 16:49:14,651 - pyscenic.utils - INFO - Creating modules.
#
# 2025-05-21 16:49:52,818 - pyscenic.cli.pyscenic - INFO - Loading databases.
#
# 2025-05-21 16:49:52,993 - pyscenic.cli.pyscenic - INFO - Calculating regulons.
#
# 2025-05-21 16:49:52,993 - pyscenic.prune - INFO - Using 20 workers.
#
# 2025-05-21 16:49:52,993 - pyscenic.prune - INFO - Using 20 workers.
#
# 2025-05-21 16:49:54,960 - pyscenic.prune - INFO - Worker hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(7): database loaded in memory.
#
# 2025-05-21 16:49:54,960 - pyscenic.prune - INFO - Worker hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(7): database loaded in memory.
#
# 2025-05-21 16:49:54,990 - pyscenic.prune - INFO - Worker hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(5): database loaded in memory.
#
# 2025-05-21 16:49:54,990 - pyscenic.prune - INFO - Worker hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(5): database loaded in memory.
#
# 2025-05-21 16:49:55,127 - pyscenic.prune - INFO - Worker hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(4): database loaded in memory.
#
# 2025-05-21 16:49:55,127 - pyscenic.prune - INFO - Worker hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(4): database loaded in memory.
#
# 2025-05-21 16:49:55,150 - pyscenic.prune - INFO - Worker hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(8): database loaded in memory.
#
# 2025-05-21 16:49:55,150 - pyscenic.prune - INFO - Worker hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(8): database loaded in memory.
#
# 2025-05-21 16:49:55,160 - pyscenic.prune - INFO - Worker hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(5): database loaded in memory.
#
# 2025-05-21 16:49:55,160 - pyscenic.prune - INFO - Worker hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(5): database loaded in memory.
#
# 2025-05-21 16:49:55,177 - pyscenic.prune - INFO - Worker hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(1): database loaded in memory.
#
# 2025-05-21 16:49:55,177 - pyscenic.prune - INFO - Worker hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(1): database loaded in memory.
#
# 2025-05-21 16:49:55,181 - pyscenic.prune - INFO - Worker hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(3): database loaded in memory.
#
# 2025-05-21 16:49:55,181 - pyscenic.prune - INFO - Worker hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(3): database loaded in memory.
#
# 2025-05-21 16:49:55,206 - pyscenic.prune - INFO - Worker hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(2): database loaded in memory.
#
# 2025-05-21 16:49:55,206 - pyscenic.prune - INFO - Worker hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(2): database loaded in memory.
#
# 2025-05-21 16:49:55,275 - pyscenic.prune - INFO - Worker hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(6): database loaded in memory.
#
# 2025-05-21 16:49:55,275 - pyscenic.prune - INFO - Worker hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(6): database loaded in memory.
#
# 2025-05-21 16:49:55,313 - pyscenic.prune - INFO - Worker hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(9): database loaded in memory.
#
# 2025-05-21 16:49:55,313 - pyscenic.prune - INFO - Worker hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(9): database loaded in memory.
#
# 2025-05-21 16:49:55,327 - pyscenic.prune - INFO - Worker hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(10): database loaded in memory.
#
# 2025-05-21 16:49:55,327 - pyscenic.prune - INFO - Worker hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(10): database loaded in memory.
#
# 2025-05-21 16:49:55,331 - pyscenic.prune - INFO - Worker hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(4): database loaded in memory.
#
# 2025-05-21 16:49:55,331 - pyscenic.prune - INFO - Worker hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(4): database loaded in memory.
#
# 2025-05-21 16:49:55,418 - pyscenic.prune - INFO - Worker hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(3): database loaded in memory.
#
# 2025-05-21 16:49:55,418 - pyscenic.prune - INFO - Worker hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(3): database loaded in memory.
#
# 2025-05-21 16:49:55,418 - pyscenic.prune - INFO - Worker hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(1): database loaded in memory.
#
# 2025-05-21 16:49:55,418 - pyscenic.prune - INFO - Worker hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(1): database loaded in memory.
#
# 2025-05-21 16:49:55,429 - pyscenic.prune - INFO - Worker hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(6): database loaded in memory.
#
# 2025-05-21 16:49:55,429 - pyscenic.prune - INFO - Worker hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(6): database loaded in memory.
#
# 2025-05-21 16:49:55,480 - pyscenic.prune - INFO - Worker hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(7): database loaded in memory.
#
# 2025-05-21 16:49:55,480 - pyscenic.prune - INFO - Worker hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(7): database loaded in memory.
#
# 2025-05-21 16:49:55,494 - pyscenic.prune - INFO - Worker hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(2): database loaded in memory.
#
# 2025-05-21 16:49:55,494 - pyscenic.prune - INFO - Worker hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(2): database loaded in memory.
#
# 2025-05-21 16:49:55,508 - pyscenic.prune - INFO - Worker hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(8): database loaded in memory.
#
# 2025-05-21 16:49:55,508 - pyscenic.prune - INFO - Worker hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(8): database loaded in memory.
#
# 2025-05-21 16:49:55,514 - pyscenic.prune - INFO - Worker hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(9): database loaded in memory.
#
# 2025-05-21 16:49:55,514 - pyscenic.prune - INFO - Worker hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(9): database loaded in memory.
#
# 2025-05-21 16:49:55,589 - pyscenic.prune - INFO - Worker hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(10): database loaded in memory.
#
# 2025-05-21 16:49:55,589 - pyscenic.prune - INFO - Worker hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(10): database loaded in memory.
#
# 2025-05-21 16:49:55,831 - pyscenic.prune - INFO - Worker hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(1): motif annotations loaded in memory.
#
# 2025-05-21 16:49:55,831 - pyscenic.prune - INFO - Worker hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(5): motif annotations loaded in memory.
#
# 2025-05-21 16:49:55,831 - pyscenic.prune - INFO - Worker hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(1): motif annotations loaded in memory.
#
# 2025-05-21 16:49:55,831 - pyscenic.prune - INFO - Worker hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(5): motif annotations loaded in memory.
#
# 2025-05-21 16:49:55,862 - pyscenic.prune - INFO - Worker hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(2): motif annotations loaded in memory.
#
# 2025-05-21 16:49:55,862 - pyscenic.prune - INFO - Worker hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(2): motif annotations loaded in memory.
#
# 2025-05-21 16:49:55,874 - pyscenic.prune - INFO - Worker hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(7): motif annotations loaded in memory.
#
# 2025-05-21 16:49:55,874 - pyscenic.prune - INFO - Worker hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(7): motif annotations loaded in memory.
#
# 2025-05-21 16:49:55,883 - pyscenic.prune - INFO - Worker hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(5): motif annotations loaded in memory.
#
# 2025-05-21 16:49:55,883 - pyscenic.prune - INFO - Worker hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(5): motif annotations loaded in memory.
#
# 2025-05-21 16:49:55,933 - pyscenic.prune - INFO - Worker hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(4): motif annotations loaded in memory.
#
# 2025-05-21 16:49:55,933 - pyscenic.prune - INFO - Worker hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(4): motif annotations loaded in memory.
#
# 2025-05-21 16:49:55,944 - pyscenic.prune - INFO - Worker hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(10): motif annotations loaded in memory.
#
# 2025-05-21 16:49:55,944 - pyscenic.prune - INFO - Worker hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(10): motif annotations loaded in memory.
#
# 2025-05-21 16:49:55,952 - pyscenic.prune - INFO - Worker hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(4): motif annotations loaded in memory.
#
# 2025-05-21 16:49:55,952 - pyscenic.prune - INFO - Worker hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(4): motif annotations loaded in memory.
#
# 2025-05-21 16:49:55,981 - pyscenic.prune - INFO - Worker hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(8): motif annotations loaded in memory.
#
# 2025-05-21 16:49:55,981 - pyscenic.prune - INFO - Worker hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(8): motif annotations loaded in memory.
#
# 2025-05-21 16:49:56,002 - pyscenic.prune - INFO - Worker hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(3): motif annotations loaded in memory.
#
# 2025-05-21 16:49:56,002 - pyscenic.prune - INFO - Worker hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(3): motif annotations loaded in memory.
#
# 2025-05-21 16:49:56,017 - pyscenic.prune - INFO - Worker hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(6): motif annotations loaded in memory.
#
# 2025-05-21 16:49:56,017 - pyscenic.prune - INFO - Worker hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(6): motif annotations loaded in memory.
#
# 2025-05-21 16:49:56,028 - pyscenic.prune - INFO - Worker hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(3): motif annotations loaded in memory.
#
# 2025-05-21 16:49:56,028 - pyscenic.prune - INFO - Worker hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(3): motif annotations loaded in memory.
#
# 2025-05-21 16:49:56,080 - pyscenic.prune - INFO - Worker hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(8): motif annotations loaded in memory.
#
# 2025-05-21 16:49:56,080 - pyscenic.prune - INFO - Worker hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(8): motif annotations loaded in memory.
#
# 2025-05-21 16:49:56,089 - pyscenic.prune - INFO - Worker hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(6): motif annotations loaded in memory.
#
# 2025-05-21 16:49:56,089 - pyscenic.prune - INFO - Worker hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(6): motif annotations loaded in memory.
#
# 2025-05-21 16:49:56,125 - pyscenic.prune - INFO - Worker hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(9): motif annotations loaded in memory.
#
# 2025-05-21 16:49:56,125 - pyscenic.prune - INFO - Worker hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(9): motif annotations loaded in memory.
#
# 2025-05-21 16:49:56,175 - pyscenic.prune - INFO - Worker hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(1): motif annotations loaded in memory.
#
# 2025-05-21 16:49:56,175 - pyscenic.prune - INFO - Worker hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(1): motif annotations loaded in memory.
#
# 2025-05-21 16:49:56,226 - pyscenic.prune - INFO - Worker hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(7): motif annotations loaded in memory.
#
# 2025-05-21 16:49:56,226 - pyscenic.prune - INFO - Worker hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(7): motif annotations loaded in memory.
#
# 2025-05-21 16:49:56,261 - pyscenic.prune - INFO - Worker hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(9): motif annotations loaded in memory.
#
# 2025-05-21 16:49:56,261 - pyscenic.prune - INFO - Worker hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(9): motif annotations loaded in memory.
#
# 2025-05-21 16:49:56,263 - pyscenic.prune - INFO - Worker hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(2): motif annotations loaded in memory.
#
# 2025-05-21 16:49:56,263 - pyscenic.prune - INFO - Worker hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(2): motif annotations loaded in memory.
#
# 2025-05-21 16:49:56,316 - pyscenic.prune - INFO - Worker hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(10): motif annotations loaded in memory.
#
# 2025-05-21 16:49:56,316 - pyscenic.prune - INFO - Worker hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(10): motif annotations loaded in memory.
#
# 2025-05-21 16:49:57,610 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ADNP could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,614 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for SP1 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,619 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ZBTB11 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,623 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ADNP2 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,633 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for SP110 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,644 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for SP140 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,655 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for SP140L could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,665 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for SP2 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,668 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ZZZ3 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,671 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ZBTB17 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,674 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for SP3 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,678 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ADNP could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,683 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ZBTB18 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,683 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for SP4 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,687 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ADNP2 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,692 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ZBTB2 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,706 - pyscenic.transform - WARNING - Less than 80% of the genes in SPDEF could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,716 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for AHCTF1 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,726 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for AHDC1 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,733 - pyscenic.transform - WARNING - Less than 80% of the genes in SPEN could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,735 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for AHR could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,743 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for SPEN could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,744 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for AHRR could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,745 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ZSCAN32 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,754 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for AIRE could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,754 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ZSCAN5A could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,763 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for SRCAP could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,763 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for AKAP8 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,764 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ZSCAN9 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,772 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for SREBF1 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,773 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ZUFSP could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,781 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for SREBF2 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,782 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ZXDA could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,783 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for AKNA could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,790 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for SRF could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,792 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ALX3 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,802 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ALX4 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,802 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ZXDC could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,808 - pyscenic.transform - WARNING - Less than 80% of the genes in PPARD could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,811 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ZZZ3 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,811 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ANKZF1 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,818 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ZBTB24 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,820 - pyscenic.transform - WARNING - Less than 80% of the genes in PPARG could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,821 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for AR could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,822 - pyscenic.transform - WARNING - Less than 80% of the genes in ADNP could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,829 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ZBTB25 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,830 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ARGFX could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,831 - pyscenic.transform - WARNING - Less than 80% of the genes in PRDM1 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,831 - pyscenic.transform - WARNING - Less than 80% of the genes in ADNP2 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,833 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for HOXD3 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,838 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ZBTB26 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,840 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ARHGAP35 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,841 - pyscenic.transform - WARNING - Less than 80% of the genes in PRDM10 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,841 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for STAT4 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,842 - pyscenic.transform - WARNING - Less than 80% of the genes in AEBP1 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,847 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ZBTB32 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,849 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ARID2 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,851 - pyscenic.transform - WARNING - Less than 80% of the genes in PRDM15 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,851 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for STAT5A could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,858 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ARID3A could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,861 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for STAT5B could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,866 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ZBTB34 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,868 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ARID3B could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,870 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for AHCTF1 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,877 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ZBTB37 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,877 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ARID5A could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,878 - pyscenic.transform - WARNING - Less than 80% of the genes in PRDM2 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,881 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for AHDC1 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,888 - pyscenic.transform - WARNING - Less than 80% of the genes in PRDM4 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,891 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ZBTB38 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,892 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for AHR could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,897 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ARNT could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,899 - pyscenic.transform - WARNING - Less than 80% of the genes in PRDM5 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,902 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ZBTB4 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,902 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for AHRR could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,906 - pyscenic.transform - WARNING - Less than 80% of the genes in AHCTF1 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,908 - pyscenic.transform - WARNING - Less than 80% of the genes in PRDM6 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,911 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for AIRE could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,912 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ZBTB40 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,916 - pyscenic.transform - WARNING - Less than 80% of the genes in AHDC1 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,918 - pyscenic.transform - WARNING - Less than 80% of the genes in PRDM8 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,923 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for AKAP8 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,927 - pyscenic.transform - WARNING - Less than 80% of the genes in PREB could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,939 - pyscenic.transform - WARNING - Less than 80% of the genes in PRMT3 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,950 - pyscenic.transform - WARNING - Less than 80% of the genes in PROX1 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,960 - pyscenic.transform - WARNING - Less than 80% of the genes in PRR12 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,967 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for AKNA could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,976 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ALX3 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,979 - pyscenic.transform - WARNING - Less than 80% of the genes in PRRX1 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,988 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ALX4 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:57,990 - pyscenic.transform - WARNING - Less than 80% of the genes in PRRX2 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:58,000 - pyscenic.transform - WARNING - Less than 80% of the genes in PURA could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:58,000 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ANKZF1 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:58,012 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for AR could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:58,013 - pyscenic.transform - WARNING - Less than 80% of the genes in PURB could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:58,027 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ARHGAP35 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:58,028 - pyscenic.transform - WARNING - Less than 80% of the genes in PURG could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:58,040 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ARID2 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:58,042 - pyscenic.transform - WARNING - Less than 80% of the genes in RAG1 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:58,053 - pyscenic.transform - WARNING - Less than 80% of the genes in RARA could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:58,067 - pyscenic.transform - WARNING - Less than 80% of the genes in RARB could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:58,078 - pyscenic.transform - WARNING - Less than 80% of the genes in RARG could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:58,087 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for SP1 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:58,090 - pyscenic.transform - WARNING - Less than 80% of the genes in RBCK1 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:58,105 - pyscenic.transform - WARNING - Less than 80% of the genes in RBPJ could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:58,113 - pyscenic.transform - WARNING - Less than 80% of the genes in ZNF281 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:58,118 - pyscenic.transform - WARNING - Less than 80% of the genes in RBSN could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:58,122 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for SP110 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:58,130 - pyscenic.transform - WARNING - Less than 80% of the genes in ZNF282 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:58,138 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for SP140 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:58,147 - pyscenic.transform - WARNING - Less than 80% of the genes in ZNF283 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:58,157 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for SP140L could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:58,177 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for SP2 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:58,196 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for SP3 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:58,204 - pyscenic.transform - WARNING - Less than 80% of the genes in ZNF3 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:58,214 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for SP4 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:58,222 - pyscenic.transform - WARNING - Less than 80% of the genes in ZNF30 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:58,236 - pyscenic.transform - WARNING - Less than 80% of the genes in ZNF300 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:58,255 - pyscenic.transform - WARNING - Less than 80% of the genes in ZNF302 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:58,264 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ZZZ3 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:58,271 - pyscenic.transform - WARNING - Less than 80% of the genes in ZNF317 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:58,281 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ADNP could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:58,289 - pyscenic.transform - WARNING - Less than 80% of the genes in ZNF318 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:58,299 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ADNP2 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:58,300 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for SPEN could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:58,308 - pyscenic.transform - WARNING - Less than 80% of the genes in ZNF322 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:58,312 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for HOXD3 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:58,326 - pyscenic.transform - WARNING - Less than 80% of the genes in ZNF326 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:58,334 - pyscenic.transform - WARNING - Less than 80% of the genes in PPARD could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:58,341 - pyscenic.transform - WARNING - Less than 80% of the genes in ZNF329 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:58,345 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for STAT6 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:58,346 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for HSF2 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:58,350 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for AHCTF1 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:58,354 - pyscenic.transform - WARNING - Less than 80% of the genes in PPARG could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:58,359 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for T could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:58,364 - pyscenic.transform - WARNING - Less than 80% of the genes in ZNF331 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:58,364 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for HSF4 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:58,367 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for AHDC1 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:58,374 - pyscenic.transform - WARNING - Less than 80% of the genes in PRDM1 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:58,386 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for AHR could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:58,393 - pyscenic.transform - WARNING - Less than 80% of the genes in PRDM10 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:58,404 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for AHRR could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:58,411 - pyscenic.transform - WARNING - Less than 80% of the genes in PRDM15 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:58,423 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for AIRE could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:58,424 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for IKZF2 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:58,426 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ARNTL could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:58,427 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ZBTB41 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:58,433 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ZSCAN32 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:58,438 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ARNTL2 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:58,439 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for AKAP8 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:58,441 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ZBTB43 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:58,445 - pyscenic.transform - WARNING - Less than 80% of the genes in AHR could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:58,449 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ZSCAN5A could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:58,455 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ZBTB44 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:58,456 - pyscenic.transform - WARNING - Less than 80% of the genes in AHRR could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:58,457 - pyscenic.transform - WARNING - Less than 80% of the genes in PRDM2 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:58,460 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ASCL1 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:58,465 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ZBTB45 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:49:58,467 - pyscenic.transform - WARNING - Less than 80% of the genes in AKAP8 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# ...
#
# 2025-05-21 16:51:21,230 - pyscenic.transform - WARNING - Less than 80% of the genes in SHOX could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:51:21,242 - pyscenic.transform - WARNING - Less than 80% of the genes in SHOX2 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:51:21,257 - pyscenic.transform - WARNING - Less than 80% of the genes in SIM1 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:51:21,273 - pyscenic.transform - WARNING - Less than 80% of the genes in SIM2 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:51:21,311 - pyscenic.transform - WARNING - Less than 80% of the genes in SIX4 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:51:21,324 - pyscenic.transform - WARNING - Less than 80% of the genes in SIX5 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:51:21,332 - pyscenic.transform - WARNING - Less than 80% of the genes in SIX6 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:51:21,420 - pyscenic.transform - WARNING - Less than 80% of the genes in SKOR1 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:51:21,432 - pyscenic.transform - WARNING - Less than 80% of the genes in SKOR2 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:51:21,450 - pyscenic.transform - WARNING - Less than 80% of the genes in SLC2A4RG could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:51:21,482 - pyscenic.transform - WARNING - Less than 80% of the genes in SMAD1 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:51:21,517 - pyscenic.transform - WARNING - Less than 80% of the genes in SMAD3 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:51:21,532 - pyscenic.transform - WARNING - Less than 80% of the genes in SCRT1 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:51:21,538 - pyscenic.transform - WARNING - Less than 80% of the genes in SMAD4 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:51:21,546 - pyscenic.transform - WARNING - Less than 80% of the genes in SCX could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:51:21,564 - pyscenic.transform - WARNING - Less than 80% of the genes in SMAD5 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:51:21,587 - pyscenic.transform - WARNING - Less than 80% of the genes in SMAD9 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:51:21,900 - pyscenic.transform - WARNING - Less than 80% of the genes in SETDB1 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:51:21,919 - pyscenic.transform - WARNING - Less than 80% of the genes in SETDB2 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:51:21,946 - pyscenic.transform - WARNING - Less than 80% of the genes in SGSM2 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:51:22,052 - pyscenic.transform - WARNING - Less than 80% of the genes in SNAI2 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:51:22,065 - pyscenic.transform - WARNING - Less than 80% of the genes in SNAI3 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:51:22,092 - pyscenic.transform - WARNING - Less than 80% of the genes in SNAPC4 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:51:22,107 - pyscenic.transform - WARNING - Less than 80% of the genes in SNAPC5 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:51:22,123 - pyscenic.transform - WARNING - Less than 80% of the genes in SOHLH1 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:51:22,155 - pyscenic.transform - WARNING - Less than 80% of the genes in SHOX could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:51:22,169 - pyscenic.transform - WARNING - Less than 80% of the genes in SHOX2 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:51:22,188 - pyscenic.transform - WARNING - Less than 80% of the genes in SIM1 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:51:22,202 - pyscenic.transform - WARNING - Less than 80% of the genes in SIM2 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:51:22,238 - pyscenic.transform - WARNING - Less than 80% of the genes in SIX4 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:51:22,253 - pyscenic.transform - WARNING - Less than 80% of the genes in SIX5 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:51:22,263 - pyscenic.transform - WARNING - Less than 80% of the genes in SIX6 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:51:22,348 - pyscenic.transform - WARNING - Less than 80% of the genes in SKOR1 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:51:22,359 - pyscenic.transform - WARNING - Less than 80% of the genes in SKOR2 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:51:22,371 - pyscenic.transform - WARNING - Less than 80% of the genes in SLC2A4RG could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:51:22,649 - pyscenic.transform - WARNING - Less than 80% of the genes in SMAD1 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:51:22,682 - pyscenic.transform - WARNING - Less than 80% of the genes in SMAD3 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:51:22,695 - pyscenic.transform - WARNING - Less than 80% of the genes in SMAD4 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:51:22,714 - pyscenic.transform - WARNING - Less than 80% of the genes in SMAD5 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:51:22,740 - pyscenic.transform - WARNING - Less than 80% of the genes in SMAD9 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:51:23,205 - pyscenic.transform - WARNING - Less than 80% of the genes in SNAI2 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:51:23,218 - pyscenic.transform - WARNING - Less than 80% of the genes in SNAI3 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:51:23,244 - pyscenic.transform - WARNING - Less than 80% of the genes in SNAPC4 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:51:23,255 - pyscenic.transform - WARNING - Less than 80% of the genes in SNAPC5 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:51:23,268 - pyscenic.transform - WARNING - Less than 80% of the genes in SOHLH1 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:51:23,545 - pyscenic.transform - WARNING - Less than 80% of the genes in SOX11 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:51:23,558 - pyscenic.transform - WARNING - Less than 80% of the genes in SOX12 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:51:23,579 - pyscenic.transform - WARNING - Less than 80% of the genes in SOX13 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:51:23,589 - pyscenic.transform - WARNING - Less than 80% of the genes in SOX15 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:51:23,628 - pyscenic.transform - WARNING - Less than 80% of the genes in SOX2 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:51:23,639 - pyscenic.transform - WARNING - Less than 80% of the genes in SOX21 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:51:23,658 - pyscenic.transform - WARNING - Less than 80% of the genes in SOX30 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:51:23,660 - pyscenic.transform - WARNING - Less than 80% of the genes in SOX11 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:51:23,673 - pyscenic.transform - WARNING - Less than 80% of the genes in SOX12 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:51:23,698 - pyscenic.transform - WARNING - Less than 80% of the genes in SOX13 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:51:23,710 - pyscenic.transform - WARNING - Less than 80% of the genes in SOX15 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:51:23,753 - pyscenic.transform - WARNING - Less than 80% of the genes in SOX2 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:51:23,764 - pyscenic.transform - WARNING - Less than 80% of the genes in SOX21 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:51:23,784 - pyscenic.transform - WARNING - Less than 80% of the genes in SOX30 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:51:23,821 - pyscenic.transform - WARNING - Less than 80% of the genes in SOX4 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:51:24,021 - pyscenic.transform - WARNING - Less than 80% of the genes in SOX7 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:51:24,107 - pyscenic.transform - WARNING - Less than 80% of the genes in SP1 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:51:24,123 - pyscenic.transform - WARNING - Less than 80% of the genes in SOX7 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:51:24,204 - pyscenic.transform - WARNING - Less than 80% of the genes in SP1 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:51:24,205 - pyscenic.transform - WARNING - Less than 80% of the genes in SP110 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:51:24,271 - pyscenic.transform - WARNING - Less than 80% of the genes in SP2 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:51:24,297 - pyscenic.transform - WARNING - Less than 80% of the genes in SP110 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:51:24,299 - pyscenic.transform - WARNING - Less than 80% of the genes in SP3 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:51:24,317 - pyscenic.transform - WARNING - Less than 80% of the genes in SP4 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:51:24,359 - pyscenic.transform - WARNING - Less than 80% of the genes in SP2 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:51:24,380 - pyscenic.prune - INFO - Worker hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(9): All regulons derived.
#
# 2025-05-21 16:51:24,380 - pyscenic.prune - INFO - Worker hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(9): All regulons derived.
#
# 2025-05-21 16:51:24,387 - pyscenic.transform - WARNING - Less than 80% of the genes in SP3 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:51:24,388 - pyscenic.prune - INFO - Worker hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(9): Done.
#
# 2025-05-21 16:51:24,388 - pyscenic.prune - INFO - Worker hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(9): Done.
#
# 2025-05-21 16:51:24,406 - pyscenic.transform - WARNING - Less than 80% of the genes in SP4 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 16:51:24,459 - pyscenic.prune - INFO - Worker hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(9): All regulons derived.
#
# 2025-05-21 16:51:24,459 - pyscenic.prune - INFO - Worker hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(9): All regulons derived.
#
# 2025-05-21 16:51:24,468 - pyscenic.prune - INFO - Worker hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(9): Done.
#
# 2025-05-21 16:51:24,468 - pyscenic.prune - INFO - Worker hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(9): Done.
#
# 2025-05-21 16:51:24,500 - pyscenic.cli.pyscenic - INFO - Writing results to file.

# %%
#III) AUCELL
# !pyscenic aucell \
    {F_LOOM_SCE} \
    reg.csv \
    --output {f_pyscenic_output} \
    --num_workers 20

# %%
import json
import zlib
import base64

# collect SCENIC AUCell output
lf = lp.connect( f_pyscenic_output, mode='r+', validate=False )
auc_mtx = pd.DataFrame( lf.ca.RegulonsAUC, index=lf.ca.CellID)
lf.close()
AUCELL_MTX_FNAME = os.path.join(outdir, 'auc.csv')
auc_mtx.to_csv(AUCELL_MTX_FNAME)

# %%
def derive_regulons(motifs, db_names=('hg38_10kbp_up_10kbp_down', 
                                 'hg38_500bp_up_100bp')):
    motifs.columns = motifs.columns.droplevel(0)

    def contains(*elems):
        def f(context):
            return any(elem in context for elem in elems)
        return f

    # For the creation of regulons we only keep the 10-species databases and the activating modules. We also remove the
    # enriched motifs for the modules that were created using the method 'weight>50.0%' (because these modules are not part
    # of the default settings of modules_from_adjacencies anymore.
    motifs = motifs[
        np.fromiter(map(compose(op.not_, contains('weight>50.0%')), motifs.Context), dtype=np.bool) & \
        np.fromiter(map(contains(*db_names), motifs.Context), dtype=np.bool) & \
        np.fromiter(map(contains('activating'), motifs.Context), dtype=np.bool)]

    # We build regulons only using enriched motifs with a NES of 3.0 or higher; we take only directly annotated TFs or TF annotated
    # for an orthologous gene into account; and we only keep regulons with at least 10 genes.
    regulons = list(filter(lambda r: len(r) >= 10, df2regulons(motifs[(motifs['NES'] >= 3.0) 
                                                                      & ((motifs['Annotation'] == 'gene is directly annotated')
                                                                        | (motifs['Annotation'].str.startswith('gene is orthologous to')
                                                                           & motifs['Annotation'].str.endswith('which is directly annotated for motif')))
                                                                     ])))
    
    # Rename regulons, i.e. remove suffix.
    return list(map(lambda r: r.rename(r.transcription_factor), regulons))

# %%
df_motifs = load_motifs(MOTIFS_FNAME)
regulons = derive_regulons(df_motifs)

# %%
from pyscenic.utils import load_motifs
df_motifs = load_motifs(MOTIFS_FNAME)
df_motifs

# %%
modules = list(modules_from_adjacencies(ADJACENCIES_FNAME, F_LOOM_SCE))

# %%
# Calculate a list of enriched motifs and the corresponding target genes for all modules.
with ProgressBar():
    df = prune2df(dbs, modules, MOTIF_ANNOTATIONS_FNAME)

# Create regulons from this table of enriched motifs.
regulons = df2regulons(df)

# %%
REGULONS_FNAME = os.path.join(RESULTS_FOLDERNAME, "regulons.p")

# %%
import pickle
df = load_motifs(MOTIFS_FNAME)
with open(REGULONS_FNAME, "rb") as f:
    regulons = pickle.load(f)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[45], line 3
#       1 import pickle
#       2 df = load_motifs(MOTIFS_FNAME)
# ----> 3 with open(REGULONS_FNAME, "rb") as f:
#       4     regulons = pickle.load(f)
#
# File ~/miniforge3/envs/pyscenic/lib/python3.10/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/jing/Phd_project/project_GBM/gbm_OUTPUT/gbm_OUTPUT_publication/gbm_OUT_publication_scenic_run3/regulons.p'

# %%
BASE_URL = "http://motifcollections.aertslab.org/v9/logos/"
COLUMN_NAME_LOGO = "MotifLogo"
COLUMN_NAME_MOTIF_ID = "MotifID"
COLUMN_NAME_TARGETS = "TargetGenes"

# %%
def display_logos(df: pd.DataFrame, top_target_genes: int = 3, base_url: str = BASE_URL):
    """
    :param df:
    :param base_url:
    """
    # Make sure the original dataframe is not altered.
    df = df.copy()
    
    # Add column with URLs to sequence logo.
    def create_url(motif_id):
        return '<img src="{}{}.png" style="max-height:124px;"></img>'.format(base_url, motif_id)
    df[("Enrichment", COLUMN_NAME_LOGO)] = list(map(create_url, df.index.get_level_values(COLUMN_NAME_MOTIF_ID)))
    
    # Truncate TargetGenes.
    def truncate(col_val):
        return sorted(col_val, key=op.itemgetter(1))[:top_target_genes]
    df[("Enrichment", COLUMN_NAME_TARGETS)] = list(map(truncate, df[("Enrichment", COLUMN_NAME_TARGETS)]))
    
    MAX_COL_WIDTH = pd.get_option('display.max_colwidth')
    pd.set_option('display.max_colwidth', -1)
    display(HTML(df.head().to_html(escape=False)))
    pd.set_option('display.max_colwidth', MAX_COL_WIDTH)

# %%
# !pyscenic aucell \
    {F_LOOM_SCE} \
    {MOTIFS_FNAME} \
    --output {f_pyscenic_output} \
    --num_workers 20
# Out:
# 2025-05-21 17:13:32,364 - pyscenic.cli.pyscenic - INFO - Loading expression matrix.
#
# 2025-05-21 17:13:43,347 - pyscenic.cli.pyscenic - INFO - Loading gene signatures.
# Create regulons from a dataframe of enriched features.
# Additional columns saved: []
#
# 2025-05-21 17:13:43,494 - pyscenic.cli.pyscenic - INFO - Calculating cellular enrichment.

# %%
auc_mtx = pd.read_csv(AUCELL_MTX_FNAME, index_col=0)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 auc_mtx = pd.read_csv(AUCELL_MTX_FNAME, index_col=0)
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/jing/Phd_project/project_GBM/gbm_OUTPUT/gbm_OUTPUT_publication/gbm_OUT_publication_scenic_run3/GBM.auc.csv'

# %%
from pyscenic.export import export2loom, add_scenic_metadata
from pyscenic.utils import load_motifs
from pyscenic.transform import df2regulons
from pyscenic.aucell import aucell
from pyscenic.binarization import binarize
from pyscenic.rss import regulon_specificity_scores
from pyscenic.plotting import plot_binarization, plot_rss

# %%
bin_mtx, thresholds = binarize(auc_mtx) bin_mtx.to_csv(BIN_MTX_FNAME) thresholds.to_frame().rename(columns={0:'threshold'}).to_csv(THR_FNAME)

# %%
bin_mtx = pd.read_csv(BIN_MTX_FNAME, index_col=0)
thresholds = pd.read_csv(THR_FNAME, index_col=0).threshold

# %%
plot_binarization(auc_mtx, 'NFKB2', thresholds['NFKB2'], ax=ax1)
plot_binarization(auc_mtx, 'MITF', thresholds['MITF'], ax=ax2)
plot_binarization(auc_mtx, 'FOXP3', thresholds['FOXP3'], ax=ax3)
plot_binarization(auc_mtx, 'PAX5', thresholds['PAX5'], ax=ax4)
plot_binarization(auc_mtx, 'IRF8', thresholds['IRF8'], ax=ax5)
plot_binarization(auc_mtx, 'IRF3', thresholds['IRF3'], ax=ax6)
plot_binarization(auc_mtx, 'MLX', thresholds['MLX'], ax=ax7)
plot_binarization(auc_mtx, 'YY1', thresholds['YY1'], ax=ax8)
