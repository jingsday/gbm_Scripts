# %%
import loompy as lp
import seaborn as sns 

import os, glob, re, pickle
from functools import partial
from collections import OrderedDict
import operator as op
from cytoolz import compose

import pandas as pd
import seaborn as sns
import numpy as np
import scanpy as sc
import anndata as ad
import matplotlib as mpl
import matplotlib.pyplot as plt

from pyscenic.export import export2loom, add_scenic_metadata
from pyscenic.utils import load_motifs
from pyscenic.transform import df2regulons
from pyscenic.aucell import aucell
from pyscenic.binarization import binarize
from pyscenic.rss import regulon_specificity_scores
from pyscenic.plotting import plot_binarization, plot_rss

from IPython.display import HTML, display

# %%
#Resource
AUXILLIARIES_FOLDERNAME = "/home/jing/pySCENIC/resources/"
HUMAN_TFS_FNAME = os.path.join(AUXILLIARIES_FOLDERNAME, 'allTFs_mm.txt')

RANKING_DBS_FNAMES = list(map(lambda fn: os.path.join(AUXILLIARIES_FOLDERNAME, fn),
                       ['hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings.feather',
                       'hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings.feather']))

MOTIF_ANNOTATIONS_FNAME = os.path.join(AUXILLIARIES_FOLDERNAME, 'motifs-v10nr_clust-nr.hgnc-m0.001-o0.0.tbl')

# %%
#Outputs
DATASET_ID = 'GBM'
RESULTS_FOLDERNAME = "/home/jing/Phd_project/project_GBM/gbm_OUTPUT/gbm_OUTPUT_publication/gbm_OUT_publication_scenic_run3/"
os.chdir(RESULTS_FOLDERNAME)
F_LOOM_SCE =  os.path.join(RESULTS_FOLDERNAME, '{}_filtered_scenic.loom'.format(DATASET_ID))
f_pyscenic_output = os.path.join(RESULTS_FOLDERNAME, '{}_final_scenic.loom'.format(DATASET_ID))


ADJACENCIES_FNAME = os.path.join(RESULTS_FOLDERNAME, '{}.adjacencies.tsv'.format(DATASET_ID))
MOTIFS_FNAME = os.path.join(RESULTS_FOLDERNAME, '{}.motifs.csv'.format(DATASET_ID))

# %%
REGULONS_DAT_FNAME = os.path.join(RESULTS_FOLDERNAME, '{}.regulons.dat'.format(DATASET_ID))
AUCELL_MTX_FNAME = os.path.join(RESULTS_FOLDERNAME, '{}.auc.csv'.format(DATASET_ID))
BIN_MTX_FNAME = os.path.join(RESULTS_FOLDERNAME, '{}.bin.csv'.format(DATASET_ID))
THR_FNAME = os.path.join(RESULTS_FOLDERNAME, '{}.thresholds.csv'.format(DATASET_ID))

# %% [markdown]
# ### Adata

# %%
directory = '/home/jing/Phd_project/project_GBM/gbm_DATA/gbm_DATA_GSE174554/gbm_DATA_scRNA_atlas'
os.chdir(directory)
names_list=['GSM5319518_SF2777','GSM5319548_SF2979','GSM5319519_SF2990',
                'GSM5319549_SF3073','GSM5319520_SF3076','GSM5319550_SF3243',
                'GSM5319521_SF3391','GSM5319551_SF3448','GSM5319511_SF11916',
                'GSM5319543_SF12382','GSM5319506_SF11082','GSM5319562_SF11488',
                'GSM5319530_SF9358','GSM5319568_SF9962','GSM5319559_SF9798','GSM5319532_SF9494']
adata_list = []

# Loop over each sample and read in the AnnData object
for name in names_list:

    mtx =f"{name}_matrix.mtx.gz"
    adata = sc.read_mtx(mtx)
    cells=pd.read_csv(f'{name}_barcodes.tsv.gz',header=None)
    features=pd.read_csv(f'{name}_features.tsv.gz',header=None,sep='\t')
    adata= adata.T
    #check the columns first to make sure they are the ones you need 
    adata.obs['CellID']= cells[0].tolist()
    adata.obs.index = adata.obs['CellID']
    adata.var['Gene']= features[0].tolist()
    adata.var.index= adata.var['Gene']
    adata.var_names_make_unique() 
    adata.var['mt'] =adata.var_names.str.startswith('MT-')


    sc.pp.filter_cells(adata, min_genes=200)
    sc.pp.calculate_qc_metrics(adata,qc_vars=['mt'], percent_top=None, log1p=False, inplace=True)
    adata= adata[adata.obs.n_genes_by_counts <6000, :]
    adata= adata[adata.obs.pct_counts_mt< 5, :].copy()


    adata.obs['source'] = name[11:]
    adata.layers["counts"] = adata.X.copy()    
    #sc.pp.normalize_total(adata, target_sum=1e4)
    #sc.pp.log1p(adata)
    #adata.raw = adata  # keep full dimension safe
    adata_list.append(adata)
batch_names = [adata.obs['source'].iloc[0] for adata in adata_list]
adata = adata_list[0].concatenate(adata_list[1:], batch_key='source', batch_categories=batch_names) 
adata.obs.index.name = "ref"
display(adata.obs)
# Out:
# /tmp/ipykernel_1053072/4194437479.py:40: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adata = adata_list[0].concatenate(adata_list[1:], batch_key='source', batch_categories=batch_names)
#                                        CellID  n_genes  n_genes_by_counts  \
# ref
# AAACCCAAGGGATCAC-1-SF2777  AAACCCAAGGGATCAC-1      468                468
# AAACCCAGTCGATTTG-1-SF2777  AAACCCAGTCGATTTG-1      311                311
# AAACCCAGTCGTCAGC-1-SF2777  AAACCCAGTCGTCAGC-1      864                864
# AAACCCAGTTGTAAAG-1-SF2777  AAACCCAGTTGTAAAG-1      632                632
# AAACCCATCTATCGGA-1-SF2777  AAACCCATCTATCGGA-1      849                849
# ...                                       ...      ...                ...
# TTTGGTTTCATTATCC-1-SF9494  TTTGGTTTCATTATCC-1     2027               2027
# TTTGGTTTCCCTCGTA-1-SF9494  TTTGGTTTCCCTCGTA-1     1972               1972
# TTTGTTGTCAGACAAA-1-SF9494  TTTGTTGTCAGACAAA-1     2340               2340
# TTTGTTGTCCATTGGA-1-SF9494  TTTGTTGTCCATTGGA-1     2137               2137
# TTTGTTGTCCGACATA-1-SF9494  TTTGTTGTCCGACATA-1     2032               2032
#
#                            total_counts  total_counts_mt  pct_counts_mt  \
# ref
# AAACCCAAGGGATCAC-1-SF2777         579.0              9.0       1.554404
# AAACCCAGTCGATTTG-1-SF2777         402.0              4.0       0.995025
# AAACCCAGTCGTCAGC-1-SF2777        1518.0              3.0       0.197628
# AAACCCAGTTGTAAAG-1-SF2777         891.0             12.0       1.346801
# AAACCCATCTATCGGA-1-SF2777        1338.0             43.0       3.213752
# ...                                 ...              ...            ...
# TTTGGTTTCATTATCC-1-SF9494        4502.0              0.0       0.000000
# TTTGGTTTCCCTCGTA-1-SF9494        4071.0              0.0       0.000000
# TTTGTTGTCAGACAAA-1-SF9494        5272.0              0.0       0.000000
# TTTGTTGTCCATTGGA-1-SF9494        4709.0              6.0       0.127416
# TTTGTTGTCCGACATA-1-SF9494        4223.0              0.0       0.000000
#
#                            source
# ref
# AAACCCAAGGGATCAC-1-SF2777  SF2777
# AAACCCAGTCGATTTG-1-SF2777  SF2777
# AAACCCAGTCGTCAGC-1-SF2777  SF2777
# AAACCCAGTTGTAAAG-1-SF2777  SF2777
# AAACCCATCTATCGGA-1-SF2777  SF2777
# ...                           ...
# TTTGGTTTCATTATCC-1-SF9494  SF9494
# TTTGGTTTCCCTCGTA-1-SF9494  SF9494
# TTTGTTGTCAGACAAA-1-SF9494  SF9494
# TTTGTTGTCCATTGGA-1-SF9494  SF9494
# TTTGTTGTCCGACATA-1-SF9494  SF9494
#
# [56716 rows x 7 columns]

# %%
outdir='/home/jing/Phd_project/project_GBM/gbm_OUTPUT/gbm_OUTPUT_publication'
doublet_df = pd.read_csv(os.path.join(outdir,'doublet_predictions.csv'), index_col=0)
doublet_df

for i in adata.obs.index:
    adata.obs.loc[i,'solo'] = doublet_df.loc[i,'Solo_Prediction']
adata_singlet = adata[adata.obs['solo']=='singlet']
adata_singlet
# Out:
# View of AnnData object with n_obs × n_vars = 50738 × 33694
#     obs: 'CellID', 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'source', 'solo'
#     var: 'Gene', 'mt', 'n_cells_by_counts-SF11082', 'mean_counts-SF11082', 'pct_dropout_by_counts-SF11082', 'total_counts-SF11082', 'n_cells_by_counts-SF11488', 'mean_counts-SF11488', 'pct_dropout_by_counts-SF11488', 'total_counts-SF11488', 'n_cells_by_counts-SF11916', 'mean_counts-SF11916', 'pct_dropout_by_counts-SF11916', 'total_counts-SF11916', 'n_cells_by_counts-SF12382', 'mean_counts-SF12382', 'pct_dropout_by_counts-SF12382', 'total_counts-SF12382', 'n_cells_by_counts-SF2777', 'mean_counts-SF2777', 'pct_dropout_by_counts-SF2777', 'total_counts-SF2777', 'n_cells_by_counts-SF2979', 'mean_counts-SF2979', 'pct_dropout_by_counts-SF2979', 'total_counts-SF2979', 'n_cells_by_counts-SF2990', 'mean_counts-SF2990', 'pct_dropout_by_counts-SF2990', 'total_counts-SF2990', 'n_cells_by_counts-SF3073', 'mean_counts-SF3073', 'pct_dropout_by_counts-SF3073', 'total_counts-SF3073', 'n_cells_by_counts-SF3076', 'mean_counts-SF3076', 'pct_dropout_by_counts-SF3076', 'total_counts-SF3076', 'n_cells_by_counts-SF3243', 'mean_counts-SF3243', 'pct_dropout_by_counts-SF3243', 'total_counts-SF3243', 'n_cells_by_counts-SF3391', 'mean_counts-SF3391', 'pct_dropout_by_counts-SF3391', 'total_counts-SF3391', 'n_cells_by_counts-SF3448', 'mean_counts-SF3448', 'pct_dropout_by_counts-SF3448', 'total_counts-SF3448', 'n_cells_by_counts-SF9358', 'mean_counts-SF9358', 'pct_dropout_by_counts-SF9358', 'total_counts-SF9358', 'n_cells_by_counts-SF9494', 'mean_counts-SF9494', 'pct_dropout_by_counts-SF9494', 'total_counts-SF9494', 'n_cells_by_counts-SF9798', 'mean_counts-SF9798', 'pct_dropout_by_counts-SF9798', 'total_counts-SF9798', 'n_cells_by_counts-SF9962', 'mean_counts-SF9962', 'pct_dropout_by_counts-SF9962', 'total_counts-SF9962'
#     layers: 'counts'

# %%
# create basic row and column attributes for the loom file:
row_attrs = {
    "Gene": np.array(adata_singlet.var_names) ,
}
col_attrs = {
    "CellID": np.array(adata_singlet.obs_names) ,
    "nGene": np.array( np.sum(adata_singlet.X.transpose()>0 , axis=0)).flatten() ,
    "nUMI": np.array( np.sum(adata_singlet.X.transpose() , axis=0)).flatten() ,
}
lp.create( F_LOOM_SCE, adata_singlet.X.transpose(), row_attrs, col_attrs)

# %%
os.chdir(RESULTS_FOLDERNAME)

# %% [markdown]
# ### SECNIC inference

# %%
#I) GRN
# !pyscenic grn {F_LOOM_SCE} {HUMAN_TFS_FNAME} -o {ADJACENCIES_FNAME} --num_workers 20
# Out:
# 2025-05-21 11:52:05,911 - pyscenic.cli.pyscenic - INFO - Loading expression matrix.
#
# 2025-05-21 11:52:16,687 - pyscenic.cli.pyscenic - INFO - Inferring regulatory networks.
# preparing dask client
# parsing input
# creating dask graph
# 20 partitions
# computing dask graph
# /home/jing/miniforge3/envs/pyscenic/lib/python3.10/site-packages/distributed/client.py:3169: UserWarning: Sending large graph of size 5.64 GiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# not shutting down client, client was created externally
# finished
#
# 2025-05-21 14:51:32,923 - pyscenic.cli.pyscenic - INFO - Writing results to file.

# %%
DBS_PARAM = ' '.join(RANKING_DBS_FNAMES)

# %%
#II) CTX
# !pyscenic ctx {ADJACENCIES_FNAME} \
    {DBS_PARAM} \
    --annotations_fname {MOTIF_ANNOTATIONS_FNAME} \
    --expression_mtx_fname {F_LOOM_SCE} \
    --output reg.csv \
    --mask_dropouts \
    --num_workers 20
# Out:
# 2025-05-21 18:27:48,877 - pyscenic.cli.pyscenic - INFO - Creating modules.
#
# 2025-05-21 18:27:49,548 - pyscenic.cli.pyscenic - INFO - Loading expression matrix.
#
# 2025-05-21 18:28:16,932 - pyscenic.utils - INFO - Calculating Pearson correlations.
#
# 2025-05-21 18:28:17,138 - pyscenic.utils - WARNING - Note on correlation calculation: the default behaviour for calculating the correlations has changed after pySCENIC verion 0.9.16. Previously, the default was to calculate the correlation between a TF and target gene using only cells with non-zero expression values (mask_dropouts=True). The current default is now to use all cells to match the behavior of the R verision of SCENIC. The original settings can be retained by setting 'rho_mask_dropouts=True' in the modules_from_adjacencies function, or '--mask_dropouts' from the CLI.
# 	Dropout masking is currently set to [True].
#
# 2025-05-21 18:34:29,577 - pyscenic.utils - INFO - Creating modules.
#
# 2025-05-21 18:35:07,888 - pyscenic.cli.pyscenic - INFO - Loading databases.
#
# 2025-05-21 18:35:08,100 - pyscenic.cli.pyscenic - INFO - Calculating regulons.
#
# 2025-05-21 18:35:08,101 - pyscenic.prune - INFO - Using 20 workers.
#
# 2025-05-21 18:35:08,101 - pyscenic.prune - INFO - Using 20 workers.
#
# 2025-05-21 18:35:09,993 - pyscenic.prune - INFO - Worker hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(9): database loaded in memory.
#
# 2025-05-21 18:35:09,993 - pyscenic.prune - INFO - Worker hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(9): database loaded in memory.
#
# 2025-05-21 18:35:10,020 - pyscenic.prune - INFO - Worker hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(3): database loaded in memory.
#
# 2025-05-21 18:35:10,020 - pyscenic.prune - INFO - Worker hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(3): database loaded in memory.
#
# 2025-05-21 18:35:10,058 - pyscenic.prune - INFO - Worker hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(10): database loaded in memory.
#
# 2025-05-21 18:35:10,058 - pyscenic.prune - INFO - Worker hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(10): database loaded in memory.
#
# 2025-05-21 18:35:10,060 - pyscenic.prune - INFO - Worker hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(1): database loaded in memory.
#
# 2025-05-21 18:35:10,060 - pyscenic.prune - INFO - Worker hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(6): database loaded in memory.
#
# 2025-05-21 18:35:10,060 - pyscenic.prune - INFO - Worker hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(1): database loaded in memory.
#
# 2025-05-21 18:35:10,060 - pyscenic.prune - INFO - Worker hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(6): database loaded in memory.
#
# 2025-05-21 18:35:10,099 - pyscenic.prune - INFO - Worker hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(2): database loaded in memory.
#
# 2025-05-21 18:35:10,099 - pyscenic.prune - INFO - Worker hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(2): database loaded in memory.
#
# 2025-05-21 18:35:10,114 - pyscenic.prune - INFO - Worker hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(7): database loaded in memory.
#
# 2025-05-21 18:35:10,114 - pyscenic.prune - INFO - Worker hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(7): database loaded in memory.
#
# 2025-05-21 18:35:10,127 - pyscenic.prune - INFO - Worker hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(4): database loaded in memory.
#
# 2025-05-21 18:35:10,127 - pyscenic.prune - INFO - Worker hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(4): database loaded in memory.
#
# 2025-05-21 18:35:10,136 - pyscenic.prune - INFO - Worker hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(8): database loaded in memory.
#
# 2025-05-21 18:35:10,136 - pyscenic.prune - INFO - Worker hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(8): database loaded in memory.
#
# 2025-05-21 18:35:10,139 - pyscenic.prune - INFO - Worker hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(5): database loaded in memory.
#
# 2025-05-21 18:35:10,139 - pyscenic.prune - INFO - Worker hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(5): database loaded in memory.
#
# 2025-05-21 18:35:10,261 - pyscenic.prune - INFO - Worker hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(2): database loaded in memory.
#
# 2025-05-21 18:35:10,261 - pyscenic.prune - INFO - Worker hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(2): database loaded in memory.
#
# 2025-05-21 18:35:10,340 - pyscenic.prune - INFO - Worker hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(1): database loaded in memory.
#
# 2025-05-21 18:35:10,340 - pyscenic.prune - INFO - Worker hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(1): database loaded in memory.
#
# 2025-05-21 18:35:10,347 - pyscenic.prune - INFO - Worker hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(3): database loaded in memory.
#
# 2025-05-21 18:35:10,347 - pyscenic.prune - INFO - Worker hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(3): database loaded in memory.
#
# 2025-05-21 18:35:10,384 - pyscenic.prune - INFO - Worker hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(4): database loaded in memory.
#
# 2025-05-21 18:35:10,384 - pyscenic.prune - INFO - Worker hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(4): database loaded in memory.
#
# 2025-05-21 18:35:10,431 - pyscenic.prune - INFO - Worker hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(5): database loaded in memory.
#
# 2025-05-21 18:35:10,431 - pyscenic.prune - INFO - Worker hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(5): database loaded in memory.
#
# 2025-05-21 18:35:10,579 - pyscenic.prune - INFO - Worker hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(6): database loaded in memory.
#
# 2025-05-21 18:35:10,579 - pyscenic.prune - INFO - Worker hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(6): database loaded in memory.
#
# 2025-05-21 18:35:10,586 - pyscenic.prune - INFO - Worker hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(7): database loaded in memory.
#
# 2025-05-21 18:35:10,586 - pyscenic.prune - INFO - Worker hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(7): database loaded in memory.
#
# 2025-05-21 18:35:10,694 - pyscenic.prune - INFO - Worker hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(8): database loaded in memory.
#
# 2025-05-21 18:35:10,694 - pyscenic.prune - INFO - Worker hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(8): database loaded in memory.
#
# 2025-05-21 18:35:10,740 - pyscenic.prune - INFO - Worker hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(9): database loaded in memory.
#
# 2025-05-21 18:35:10,740 - pyscenic.prune - INFO - Worker hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(9): database loaded in memory.
#
# 2025-05-21 18:35:10,837 - pyscenic.prune - INFO - Worker hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(9): motif annotations loaded in memory.
#
# 2025-05-21 18:35:10,837 - pyscenic.prune - INFO - Worker hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(9): motif annotations loaded in memory.
#
# 2025-05-21 18:35:10,851 - pyscenic.prune - INFO - Worker hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(10): motif annotations loaded in memory.
#
# 2025-05-21 18:35:10,851 - pyscenic.prune - INFO - Worker hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(10): motif annotations loaded in memory.
#
# 2025-05-21 18:35:10,884 - pyscenic.prune - INFO - Worker hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(7): motif annotations loaded in memory.
#
# 2025-05-21 18:35:10,884 - pyscenic.prune - INFO - Worker hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(7): motif annotations loaded in memory.
#
# 2025-05-21 18:35:10,892 - pyscenic.prune - INFO - Worker hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(10): database loaded in memory.
#
# 2025-05-21 18:35:10,892 - pyscenic.prune - INFO - Worker hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(10): database loaded in memory.
#
# 2025-05-21 18:35:10,914 - pyscenic.prune - INFO - Worker hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(1): motif annotations loaded in memory.
#
# 2025-05-21 18:35:10,914 - pyscenic.prune - INFO - Worker hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(1): motif annotations loaded in memory.
#
# 2025-05-21 18:35:10,915 - pyscenic.prune - INFO - Worker hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(3): motif annotations loaded in memory.
#
# 2025-05-21 18:35:10,915 - pyscenic.prune - INFO - Worker hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(3): motif annotations loaded in memory.
#
# 2025-05-21 18:35:10,915 - pyscenic.prune - INFO - Worker hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(6): motif annotations loaded in memory.
#
# 2025-05-21 18:35:10,915 - pyscenic.prune - INFO - Worker hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(6): motif annotations loaded in memory.
#
# 2025-05-21 18:35:10,939 - pyscenic.prune - INFO - Worker hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(2): motif annotations loaded in memory.
#
# 2025-05-21 18:35:10,939 - pyscenic.prune - INFO - Worker hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(2): motif annotations loaded in memory.
#
# 2025-05-21 18:35:10,956 - pyscenic.prune - INFO - Worker hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(4): motif annotations loaded in memory.
#
# 2025-05-21 18:35:10,956 - pyscenic.prune - INFO - Worker hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(4): motif annotations loaded in memory.
#
# 2025-05-21 18:35:11,000 - pyscenic.prune - INFO - Worker hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(8): motif annotations loaded in memory.
#
# 2025-05-21 18:35:11,000 - pyscenic.prune - INFO - Worker hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(8): motif annotations loaded in memory.
#
# 2025-05-21 18:35:11,005 - pyscenic.prune - INFO - Worker hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(5): motif annotations loaded in memory.
#
# 2025-05-21 18:35:11,005 - pyscenic.prune - INFO - Worker hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(5): motif annotations loaded in memory.
#
# 2025-05-21 18:35:11,019 - pyscenic.prune - INFO - Worker hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(1): motif annotations loaded in memory.
#
# 2025-05-21 18:35:11,019 - pyscenic.prune - INFO - Worker hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(1): motif annotations loaded in memory.
#
# 2025-05-21 18:35:11,061 - pyscenic.prune - INFO - Worker hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(4): motif annotations loaded in memory.
#
# 2025-05-21 18:35:11,061 - pyscenic.prune - INFO - Worker hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(4): motif annotations loaded in memory.
#
# 2025-05-21 18:35:11,082 - pyscenic.prune - INFO - Worker hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(5): motif annotations loaded in memory.
#
# 2025-05-21 18:35:11,082 - pyscenic.prune - INFO - Worker hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(5): motif annotations loaded in memory.
#
# 2025-05-21 18:35:11,111 - pyscenic.prune - INFO - Worker hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(2): motif annotations loaded in memory.
#
# 2025-05-21 18:35:11,111 - pyscenic.prune - INFO - Worker hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(2): motif annotations loaded in memory.
#
# 2025-05-21 18:35:11,162 - pyscenic.prune - INFO - Worker hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(3): motif annotations loaded in memory.
#
# 2025-05-21 18:35:11,162 - pyscenic.prune - INFO - Worker hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(3): motif annotations loaded in memory.
#
# 2025-05-21 18:35:11,247 - pyscenic.prune - INFO - Worker hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(8): motif annotations loaded in memory.
#
# 2025-05-21 18:35:11,247 - pyscenic.prune - INFO - Worker hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(8): motif annotations loaded in memory.
#
# 2025-05-21 18:35:11,363 - pyscenic.prune - INFO - Worker hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(6): motif annotations loaded in memory.
#
# 2025-05-21 18:35:11,363 - pyscenic.prune - INFO - Worker hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(6): motif annotations loaded in memory.
#
# 2025-05-21 18:35:11,384 - pyscenic.prune - INFO - Worker hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(7): motif annotations loaded in memory.
#
# 2025-05-21 18:35:11,384 - pyscenic.prune - INFO - Worker hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(7): motif annotations loaded in memory.
#
# 2025-05-21 18:35:11,389 - pyscenic.prune - INFO - Worker hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(9): motif annotations loaded in memory.
#
# 2025-05-21 18:35:11,389 - pyscenic.prune - INFO - Worker hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(9): motif annotations loaded in memory.
#
# 2025-05-21 18:35:11,556 - pyscenic.prune - INFO - Worker hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(10): motif annotations loaded in memory.
#
# 2025-05-21 18:35:11,556 - pyscenic.prune - INFO - Worker hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(10): motif annotations loaded in memory.
#
# 2025-05-21 18:35:12,708 - pyscenic.transform - WARNING - Less than 80% of the genes in ZNF281 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:12,723 - pyscenic.transform - WARNING - Less than 80% of the genes in ZNF282 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:12,727 - pyscenic.transform - WARNING - Less than 80% of the genes in SPDEF could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:12,738 - pyscenic.transform - WARNING - Less than 80% of the genes in ZNF283 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:12,756 - pyscenic.transform - WARNING - Less than 80% of the genes in SPEN could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:12,768 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ZZZ3 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:12,778 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ADNP could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:12,783 - pyscenic.transform - WARNING - Less than 80% of the genes in ZNF3 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:12,788 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ADNP2 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:12,798 - pyscenic.transform - WARNING - Less than 80% of the genes in ZNF30 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:12,812 - pyscenic.transform - WARNING - Less than 80% of the genes in ZNF300 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:12,818 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for AHCTF1 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:12,828 - pyscenic.transform - WARNING - Less than 80% of the genes in ZNF302 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:12,828 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for AHDC1 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:12,838 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for AHR could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:12,842 - pyscenic.transform - WARNING - Less than 80% of the genes in ZNF317 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:12,847 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for AHRR could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:12,856 - pyscenic.transform - WARNING - Less than 80% of the genes in ZNF318 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:12,858 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for AIRE could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:12,868 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for AKAP8 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:12,872 - pyscenic.transform - WARNING - Less than 80% of the genes in ZNF322 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:12,888 - pyscenic.transform - WARNING - Less than 80% of the genes in ZNF326 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:12,888 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for AKNA could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:12,898 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ALX3 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:12,903 - pyscenic.transform - WARNING - Less than 80% of the genes in ZNF329 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:12,908 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ALX4 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:12,918 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ANKZF1 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:12,924 - pyscenic.transform - WARNING - Less than 80% of the genes in ZNF331 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:12,927 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ADNP could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:12,928 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for AR could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:12,938 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ARGFX could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:12,939 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ADNP2 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:12,948 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ARHGAP35 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:12,958 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ARID2 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:12,969 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ARID3A could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:12,979 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ARID3B could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:12,989 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ARID5A could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,009 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ARNT could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,014 - pyscenic.transform - WARNING - Less than 80% of the genes in PPARD could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,028 - pyscenic.transform - WARNING - Less than 80% of the genes in PPARG could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,031 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for SP1 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,040 - pyscenic.transform - WARNING - Less than 80% of the genes in PRDM1 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,052 - pyscenic.transform - WARNING - Less than 80% of the genes in PRDM10 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,054 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for SP110 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,063 - pyscenic.transform - WARNING - Less than 80% of the genes in PRDM15 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,064 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for SP140 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,074 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for SP140L could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,084 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for SP2 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,092 - pyscenic.transform - WARNING - Less than 80% of the genes in PRDM2 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,094 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for SP3 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,103 - pyscenic.transform - WARNING - Less than 80% of the genes in PRDM4 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,104 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for SP4 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,109 - pyscenic.transform - WARNING - Less than 80% of the genes in AHDC1 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,115 - pyscenic.transform - WARNING - Less than 80% of the genes in PRDM5 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,127 - pyscenic.transform - WARNING - Less than 80% of the genes in PRDM6 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,130 - pyscenic.transform - WARNING - Less than 80% of the genes in AHR could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,138 - pyscenic.transform - WARNING - Less than 80% of the genes in PRDM8 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,148 - pyscenic.transform - WARNING - Less than 80% of the genes in PREB could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,148 - pyscenic.transform - WARNING - Less than 80% of the genes in AHRR could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,161 - pyscenic.transform - WARNING - Less than 80% of the genes in PRMT3 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,162 - pyscenic.transform - WARNING - Less than 80% of the genes in AIRE could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,173 - pyscenic.transform - WARNING - Less than 80% of the genes in PROX1 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,183 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for SPEN could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,185 - pyscenic.transform - WARNING - Less than 80% of the genes in PRR12 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,192 - pyscenic.transform - WARNING - Less than 80% of the genes in AKAP8 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,194 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for AHCTF1 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,207 - pyscenic.transform - WARNING - Less than 80% of the genes in PRRX1 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,207 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for AHDC1 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,219 - pyscenic.transform - WARNING - Less than 80% of the genes in PRRX2 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,219 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for AHR could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,230 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for AHRR could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,230 - pyscenic.transform - WARNING - Less than 80% of the genes in PURA could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,239 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for AIRE could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,242 - pyscenic.transform - WARNING - Less than 80% of the genes in PURB could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,253 - pyscenic.transform - WARNING - Less than 80% of the genes in PURG could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,253 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for AKAP8 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,257 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ADNP could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,265 - pyscenic.transform - WARNING - Less than 80% of the genes in RAG1 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,276 - pyscenic.transform - WARNING - Less than 80% of the genes in RARA could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,276 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ADNP2 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,279 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ZSCAN32 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,286 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ZZZ3 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,290 - pyscenic.transform - WARNING - Less than 80% of the genes in RARB could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,295 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ZSCAN5A could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,296 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for HOXD3 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,298 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for AKNA could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,300 - pyscenic.transform - WARNING - Less than 80% of the genes in RARG could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,302 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ADNP could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,308 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ALX3 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,311 - pyscenic.transform - WARNING - Less than 80% of the genes in RBCK1 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,319 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ADNP2 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,320 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ALX4 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,326 - pyscenic.transform - WARNING - Less than 80% of the genes in RBPJ could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,327 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ZBTB11 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,329 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for HSF2 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,332 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ANKZF1 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,340 - pyscenic.transform - WARNING - Less than 80% of the genes in RBSN could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,344 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for AR could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,347 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for HSF4 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,347 - pyscenic.transform - WARNING - Less than 80% of the genes in ALX3 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,359 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ARHGAP35 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,365 - pyscenic.transform - WARNING - Less than 80% of the genes in ALX4 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,369 - pyscenic.transform - WARNING - Less than 80% of the genes in PPARD could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,369 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for SP1 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,370 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for AHCTF1 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,373 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ARID2 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,385 - pyscenic.transform - WARNING - Less than 80% of the genes in ANKZF1 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,386 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ARID3A could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,386 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for AHDC1 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,389 - pyscenic.transform - WARNING - Less than 80% of the genes in PPARG could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,394 - pyscenic.transform - WARNING - Less than 80% of the genes in ZNF333 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,398 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ARID3B could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,402 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for AHR could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,403 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for IKZF2 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,403 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ZBTB17 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,404 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for SP110 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,404 - pyscenic.transform - WARNING - Less than 80% of the genes in AR could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,407 - pyscenic.transform - WARNING - Less than 80% of the genes in PRDM1 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,411 - pyscenic.transform - WARNING - Less than 80% of the genes in ZNF334 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,411 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ARID5A could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,419 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for AHRR could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,420 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for SP140 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,423 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ZBTB18 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,425 - pyscenic.transform - WARNING - Less than 80% of the genes in PRDM10 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,427 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ARID5B could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,427 - pyscenic.transform - WARNING - Less than 80% of the genes in ZNF335 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,435 - pyscenic.transform - WARNING - Less than 80% of the genes in ARHGAP35 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,435 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for AIRE could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,436 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for SP140L could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,439 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ZBTB2 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,440 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ARNT could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,441 - pyscenic.transform - WARNING - Less than 80% of the genes in PRDM15 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,442 - pyscenic.transform - WARNING - Less than 80% of the genes in ZNF337 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,443 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ARNTL could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,452 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for AKAP8 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,454 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for SP2 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,456 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ARNTL2 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,458 - pyscenic.transform - WARNING - Less than 80% of the genes in ZNF33A could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,467 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ZBTB11 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,470 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for SP3 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,473 - pyscenic.transform - WARNING - Less than 80% of the genes in ZNF33B could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,473 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for HOXD3 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,478 - pyscenic.transform - WARNING - Less than 80% of the genes in ARID2 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,478 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ASCL1 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,485 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for AKNA could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,486 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for SP4 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,487 - pyscenic.transform - WARNING - Less than 80% of the genes in PRDM2 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,487 - pyscenic.transform - WARNING - Less than 80% of the genes in ZNF34 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,501 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ALX3 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,503 - pyscenic.transform - WARNING - Less than 80% of the genes in PRDM4 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,504 - pyscenic.transform - WARNING - Less than 80% of the genes in ZNF341 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,510 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ATF1 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,518 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ALX4 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,519 - pyscenic.transform - WARNING - Less than 80% of the genes in ZNF345 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,521 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ATF2 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,523 - pyscenic.transform - WARNING - Less than 80% of the genes in PRDM5 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,534 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ANKZF1 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,534 - pyscenic.transform - WARNING - Less than 80% of the genes in ZNF346 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,539 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ZBTB17 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:35:13,539 - pyscenic.transform - WARNING - Less than 80% of the genes in PRDM6 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# ...
#
# 2025-05-21 18:36:40,052 - pyscenic.transform - WARNING - Less than 80% of the genes in RARG could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:36:40,082 - pyscenic.transform - WARNING - Less than 80% of the genes in RBCK1 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:36:40,123 - pyscenic.transform - WARNING - Less than 80% of the genes in RBPJ could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:36:40,140 - pyscenic.transform - WARNING - Less than 80% of the genes in RBSN could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:36:40,199 - pyscenic.transform - WARNING - Less than 80% of the genes in RELA could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:36:40,234 - pyscenic.transform - WARNING - Less than 80% of the genes in REST could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:36:40,249 - pyscenic.transform - WARNING - Less than 80% of the genes in REXO4 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:36:40,265 - pyscenic.transform - WARNING - Less than 80% of the genes in RFX1 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:36:40,731 - pyscenic.transform - WARNING - Less than 80% of the genes in RFX6 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:36:40,830 - pyscenic.transform - WARNING - Less than 80% of the genes in RFX8 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:36:40,840 - pyscenic.transform - WARNING - Less than 80% of the genes in RHOXF1 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:36:41,054 - pyscenic.transform - WARNING - Less than 80% of the genes in SOX11 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:36:41,068 - pyscenic.transform - WARNING - Less than 80% of the genes in SOX12 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:36:41,090 - pyscenic.transform - WARNING - Less than 80% of the genes in SOX13 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:36:41,101 - pyscenic.transform - WARNING - Less than 80% of the genes in SOX15 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:36:41,151 - pyscenic.transform - WARNING - Less than 80% of the genes in SOX2 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:36:41,164 - pyscenic.transform - WARNING - Less than 80% of the genes in SOX21 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:36:41,186 - pyscenic.transform - WARNING - Less than 80% of the genes in SOX30 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:36:41,227 - pyscenic.transform - WARNING - Less than 80% of the genes in SOX4 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:36:41,362 - pyscenic.transform - WARNING - Less than 80% of the genes in RORB could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:36:41,533 - pyscenic.transform - WARNING - Less than 80% of the genes in SOX7 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:36:41,613 - pyscenic.transform - WARNING - Less than 80% of the genes in SP1 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:36:41,624 - pyscenic.transform - WARNING - Less than 80% of the genes in RXRA could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:36:41,635 - pyscenic.transform - WARNING - Less than 80% of the genes in RXRB could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:36:41,720 - pyscenic.transform - WARNING - Less than 80% of the genes in SP110 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:36:41,802 - pyscenic.transform - WARNING - Less than 80% of the genes in SP2 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:36:41,835 - pyscenic.transform - WARNING - Less than 80% of the genes in SP3 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:36:41,855 - pyscenic.transform - WARNING - Less than 80% of the genes in SP4 could be mapped to hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:36:41,858 - pyscenic.transform - WARNING - Less than 80% of the genes in RXRG could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:36:41,888 - pyscenic.transform - WARNING - Less than 80% of the genes in SAFB could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:36:41,915 - pyscenic.transform - WARNING - Less than 80% of the genes in SAFB2 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:36:41,932 - pyscenic.prune - INFO - Worker hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(9): All regulons derived.
#
# 2025-05-21 18:36:41,932 - pyscenic.prune - INFO - Worker hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(9): All regulons derived.
#
# 2025-05-21 18:36:41,940 - pyscenic.prune - INFO - Worker hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(9): Done.
#
# 2025-05-21 18:36:41,940 - pyscenic.prune - INFO - Worker hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(9): Done.
#
# 2025-05-21 18:36:41,943 - pyscenic.transform - WARNING - Less than 80% of the genes in SALL2 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:36:41,965 - pyscenic.transform - WARNING - Less than 80% of the genes in SALL3 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:36:41,978 - pyscenic.transform - WARNING - Less than 80% of the genes in SALL4 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:36:42,533 - pyscenic.transform - WARNING - Less than 80% of the genes in SCRT1 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:36:42,547 - pyscenic.transform - WARNING - Less than 80% of the genes in SCX could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:36:42,912 - pyscenic.transform - WARNING - Less than 80% of the genes in SETDB1 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:36:42,931 - pyscenic.transform - WARNING - Less than 80% of the genes in SETDB2 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:36:42,958 - pyscenic.transform - WARNING - Less than 80% of the genes in SGSM2 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:36:43,174 - pyscenic.transform - WARNING - Less than 80% of the genes in SHOX could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:36:43,189 - pyscenic.transform - WARNING - Less than 80% of the genes in SHOX2 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:36:43,203 - pyscenic.transform - WARNING - Less than 80% of the genes in SIM1 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:36:43,217 - pyscenic.transform - WARNING - Less than 80% of the genes in SIM2 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:36:43,266 - pyscenic.transform - WARNING - Less than 80% of the genes in SIX4 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:36:43,280 - pyscenic.transform - WARNING - Less than 80% of the genes in SIX5 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:36:43,290 - pyscenic.transform - WARNING - Less than 80% of the genes in SIX6 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:36:43,375 - pyscenic.transform - WARNING - Less than 80% of the genes in SKOR1 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:36:43,386 - pyscenic.transform - WARNING - Less than 80% of the genes in SKOR2 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:36:43,399 - pyscenic.transform - WARNING - Less than 80% of the genes in SLC2A4RG could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:36:43,667 - pyscenic.transform - WARNING - Less than 80% of the genes in SMAD1 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:36:43,701 - pyscenic.transform - WARNING - Less than 80% of the genes in SMAD3 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:36:43,714 - pyscenic.transform - WARNING - Less than 80% of the genes in SMAD4 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:36:43,736 - pyscenic.transform - WARNING - Less than 80% of the genes in SMAD5 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:36:43,762 - pyscenic.transform - WARNING - Less than 80% of the genes in SMAD9 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:36:44,241 - pyscenic.transform - WARNING - Less than 80% of the genes in SNAI2 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:36:44,255 - pyscenic.transform - WARNING - Less than 80% of the genes in SNAI3 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:36:44,282 - pyscenic.transform - WARNING - Less than 80% of the genes in SNAPC4 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:36:44,295 - pyscenic.transform - WARNING - Less than 80% of the genes in SNAPC5 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:36:44,308 - pyscenic.transform - WARNING - Less than 80% of the genes in SOHLH1 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:36:44,587 - pyscenic.transform - WARNING - Less than 80% of the genes in SOX11 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:36:44,600 - pyscenic.transform - WARNING - Less than 80% of the genes in SOX12 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:36:44,622 - pyscenic.transform - WARNING - Less than 80% of the genes in SOX13 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:36:44,633 - pyscenic.transform - WARNING - Less than 80% of the genes in SOX15 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:36:44,673 - pyscenic.transform - WARNING - Less than 80% of the genes in SOX2 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:36:44,684 - pyscenic.transform - WARNING - Less than 80% of the genes in SOX21 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:36:44,705 - pyscenic.transform - WARNING - Less than 80% of the genes in SOX30 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:36:45,081 - pyscenic.transform - WARNING - Less than 80% of the genes in SOX7 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:36:45,161 - pyscenic.transform - WARNING - Less than 80% of the genes in SP1 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:36:45,260 - pyscenic.transform - WARNING - Less than 80% of the genes in SP110 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:36:45,327 - pyscenic.transform - WARNING - Less than 80% of the genes in SP2 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:36:45,355 - pyscenic.transform - WARNING - Less than 80% of the genes in SP3 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:36:45,373 - pyscenic.transform - WARNING - Less than 80% of the genes in SP4 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-05-21 18:36:45,437 - pyscenic.prune - INFO - Worker hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(9): All regulons derived.
#
# 2025-05-21 18:36:45,437 - pyscenic.prune - INFO - Worker hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(9): All regulons derived.
#
# 2025-05-21 18:36:45,443 - pyscenic.prune - INFO - Worker hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(9): Done.
#
# 2025-05-21 18:36:45,443 - pyscenic.prune - INFO - Worker hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(9): Done.
#
# 2025-05-21 18:36:45,471 - pyscenic.cli.pyscenic - INFO - Writing results to file.

# %%
F_LOOM_SCE
# Out:
# '/home/jing/Phd_project/project_GBM/gbm_OUTPUT/gbm_OUTPUT_publication/gbm_OUT_publication_scenic_run3/GBM_filtered_scenic.loom'

# %%
outdir= '/home/jing/Phd_project/project_GBM/gbm_OUTPUT/gbm_OUTPUT_publication/gbm_OUT_publication_scenic_run2/'
f_loom_path_scenic = os.path.join(outdir, "full_filtered_scenic.loom")

# %%
#III) AUCELL
# !pyscenic aucell \
    {f_loom_path_scenic} \
    reg.csv \
    --output {f_pyscenic_output} \
    --num_workers 20
# Out:
# 2025-05-21 18:54:38,030 - pyscenic.cli.pyscenic - INFO - Loading expression matrix.
#
# 2025-05-21 18:54:50,297 - pyscenic.cli.pyscenic - INFO - Loading gene signatures.
# Create regulons from a dataframe of enriched features.
# Additional columns saved: []
#
# 2025-05-21 18:54:50,441 - pyscenic.cli.pyscenic - INFO - Calculating cellular enrichment.
#
# 2025-05-21 18:56:10,289 - pyscenic.cli.pyscenic - INFO - Writing results to file.
#
# 2025-05-21 18:57:29,988 - pyscenic.cli.pyscenic - ERROR - Expression matrix should be provided in the loom file format.

# %%
import json
import zlib
import base64

# collect SCENIC AUCell output
lf = lp.connect( f_pyscenic_output, mode='r+', validate=False )
auc_mtx = pd.DataFrame( lf.ca.RegulonsAUC, index=lf.ca.CellID)
lf.close()
AUCELL_MTX_FNAME = os.path.join(outdir, 'auc.csv')
auc_mtx.to_csv(AUCELL_MTX_FNAME)

# %%
def derive_regulons(motifs, db_names=('hg38_10kbp_up_10kbp_down', 
                                 'hg38_500bp_up_100bp')):
    motifs.columns = motifs.columns.droplevel(0)

    def contains(*elems):
        def f(context):
            return any(elem in context for elem in elems)
        return f

    # For the creation of regulons we only keep the 10-species databases and the activating modules. We also remove the
    # enriched motifs for the modules that were created using the method 'weight>50.0%' (because these modules are not part
    # of the default settings of modules_from_adjacencies anymore.
    motifs = motifs[
        np.fromiter(map(compose(op.not_, contains('weight>50.0%')), motifs.Context), dtype=np.bool) & \
        np.fromiter(map(contains(*db_names), motifs.Context), dtype=np.bool) & \
        np.fromiter(map(contains('activating'), motifs.Context), dtype=np.bool)]

    # We build regulons only using enriched motifs with a NES of 3.0 or higher; we take only directly annotated TFs or TF annotated
    # for an orthologous gene into account; and we only keep regulons with at least 10 genes.
    regulons = list(filter(lambda r: len(r) >= 10, df2regulons(motifs[(motifs['NES'] >= 3.0) 
                                                                      & ((motifs['Annotation'] == 'gene is directly annotated')
                                                                        | (motifs['Annotation'].str.startswith('gene is orthologous to')
                                                                           & motifs['Annotation'].str.endswith('which is directly annotated for motif')))
                                                                     ])))
    
    # Rename regulons, i.e. remove suffix.
    return list(map(lambda r: r.rename(r.transcription_factor), regulons))

# %%
df_motifs = load_motifs(MOTIFS_FNAME)
regulons = derive_regulons(df_motifs)

# %%
from pyscenic.utils import load_motifs
df_motifs = load_motifs(MOTIFS_FNAME)
df_motifs

# %%
modules = list(modules_from_adjacencies(ADJACENCIES_FNAME, F_LOOM_SCE))

# %%
# Calculate a list of enriched motifs and the corresponding target genes for all modules.
with ProgressBar():
    df = prune2df(dbs, modules, MOTIF_ANNOTATIONS_FNAME)

# Create regulons from this table of enriched motifs.
regulons = df2regulons(df)

# %%
REGULONS_FNAME = os.path.join(RESULTS_FOLDERNAME, "regulons.p")

# %%
import pickle
df = load_motifs(MOTIFS_FNAME)
with open(REGULONS_FNAME, "rb") as f:
    regulons = pickle.load(f)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[45], line 3
#       1 import pickle
#       2 df = load_motifs(MOTIFS_FNAME)
# ----> 3 with open(REGULONS_FNAME, "rb") as f:
#       4     regulons = pickle.load(f)
#
# File ~/miniforge3/envs/pyscenic/lib/python3.10/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/jing/Phd_project/project_GBM/gbm_OUTPUT/gbm_OUTPUT_publication/gbm_OUT_publication_scenic_run3/regulons.p'

# %%
BASE_URL = "http://motifcollections.aertslab.org/v9/logos/"
COLUMN_NAME_LOGO = "MotifLogo"
COLUMN_NAME_MOTIF_ID = "MotifID"
COLUMN_NAME_TARGETS = "TargetGenes"

# %%
def display_logos(df: pd.DataFrame, top_target_genes: int = 3, base_url: str = BASE_URL):
    """
    :param df:
    :param base_url:
    """
    # Make sure the original dataframe is not altered.
    df = df.copy()
    
    # Add column with URLs to sequence logo.
    def create_url(motif_id):
        return '<img src="{}{}.png" style="max-height:124px;"></img>'.format(base_url, motif_id)
    df[("Enrichment", COLUMN_NAME_LOGO)] = list(map(create_url, df.index.get_level_values(COLUMN_NAME_MOTIF_ID)))
    
    # Truncate TargetGenes.
    def truncate(col_val):
        return sorted(col_val, key=op.itemgetter(1))[:top_target_genes]
    df[("Enrichment", COLUMN_NAME_TARGETS)] = list(map(truncate, df[("Enrichment", COLUMN_NAME_TARGETS)]))
    
    MAX_COL_WIDTH = pd.get_option('display.max_colwidth')
    pd.set_option('display.max_colwidth', -1)
    display(HTML(df.head().to_html(escape=False)))
    pd.set_option('display.max_colwidth', MAX_COL_WIDTH)

# %%
# !pyscenic aucell \
    {F_LOOM_SCE} \
    {MOTIFS_FNAME} \
    --output {f_pyscenic_output} \
    --num_workers 20
# Out:
# 2025-05-21 17:13:32,364 - pyscenic.cli.pyscenic - INFO - Loading expression matrix.
#
# 2025-05-21 17:13:43,347 - pyscenic.cli.pyscenic - INFO - Loading gene signatures.
# Create regulons from a dataframe of enriched features.
# Additional columns saved: []
#
# 2025-05-21 17:13:43,494 - pyscenic.cli.pyscenic - INFO - Calculating cellular enrichment.

# %%
auc_mtx = pd.read_csv(AUCELL_MTX_FNAME, index_col=0)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 auc_mtx = pd.read_csv(AUCELL_MTX_FNAME, index_col=0)
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/jing/Phd_project/project_GBM/gbm_OUTPUT/gbm_OUTPUT_publication/gbm_OUT_publication_scenic_run3/GBM.auc.csv'

# %%
from pyscenic.export import export2loom, add_scenic_metadata
from pyscenic.utils import load_motifs
from pyscenic.transform import df2regulons
from pyscenic.aucell import aucell
from pyscenic.binarization import binarize
from pyscenic.rss import regulon_specificity_scores
from pyscenic.plotting import plot_binarization, plot_rss

# %%
bin_mtx, thresholds = binarize(auc_mtx) bin_mtx.to_csv(BIN_MTX_FNAME) thresholds.to_frame().rename(columns={0:'threshold'}).to_csv(THR_FNAME)

# %%
bin_mtx = pd.read_csv(BIN_MTX_FNAME, index_col=0)
thresholds = pd.read_csv(THR_FNAME, index_col=0).threshold

# %%
plot_binarization(auc_mtx, 'NFKB2', thresholds['NFKB2'], ax=ax1)
plot_binarization(auc_mtx, 'MITF', thresholds['MITF'], ax=ax2)
plot_binarization(auc_mtx, 'FOXP3', thresholds['FOXP3'], ax=ax3)
plot_binarization(auc_mtx, 'PAX5', thresholds['PAX5'], ax=ax4)
plot_binarization(auc_mtx, 'IRF8', thresholds['IRF8'], ax=ax5)
plot_binarization(auc_mtx, 'IRF3', thresholds['IRF3'], ax=ax6)
plot_binarization(auc_mtx, 'MLX', thresholds['MLX'], ax=ax7)
plot_binarization(auc_mtx, 'YY1', thresholds['YY1'], ax=ax8)
